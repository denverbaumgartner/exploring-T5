# %%
print('hello, world')
# Out:
# hello, world

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !nvidia-smi
# Out:
# Sat Jan 27 20:28:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A10                     On  | 00000000:07:00.0 Off |                    0 |
# |  0%   28C    P8              16W / 150W |      4MiB / 23028MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Instal apex if you want to do 16 bit training. You'll probably need to restart the notebook after installing apex

# %%
# !export CUDA_HOME=/usr/local/cuda-10.1
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ubuntu/.local/lib/python3.10/site-packages (23.3.2)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip uninstall transformers -y
# !pip uninstall pytorch_lightning -y
# !pip uninstall datasets -y
# !pip uninstall nltk -y
# !pip uninstall SentencePiece -y
# Out:
# WARNING: Skipping transformers as it is not installed.
# Found existing installation: pytorch-lightning 0.7.5
# Uninstalling pytorch-lightning-0.7.5:
#   Successfully uninstalled pytorch-lightning-0.7.5
# Found existing installation: datasets 2.16.1
# Uninstalling datasets-2.16.1:
#   Successfully uninstalled datasets-2.16.1
# Found existing installation: nltk 3.8.1
# Uninstalling nltk-3.8.1:
#   Successfully uninstalled nltk-3.8.1
# Found existing installation: sentencepiece 0.1.99
# Uninstalling sentencepiece-0.1.99:
#   Successfully uninstalled sentencepiece-0.1.99

# %%
# !pip install transformers==2.11.0

# %%
# !pip install transformers
# !pip install pytorch_lightning==0.7.5
# !pip install datasets
# !pip install nltk
# !pip install SentencePiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Using cached transformers-4.37.1-py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers) (2020.6.20)
# Using cached transformers-4.37.1-py3-none-any.whl (8.4 MB)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: transformers
# Successfully installed transformers-4.37.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch_lightning==0.7.5
#   Using cached pytorch_lightning-0.7.5-py3-none-any.whl (233 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pytorch_lightning==0.7.5) (4.66.1)
# Requirement already satisfied: numpy>=1.16.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from pytorch_lightning==0.7.5) (1.25.2)
# Requirement already satisfied: torch>=1.1 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (2.0.1)
# Requirement already satisfied: tensorboard>=1.14 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (2.13.0)
# Requirement already satisfied: future>=0.17.1 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (0.18.2)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pytorch_lightning
# Successfully installed pytorch_lightning-0.7.5
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datasets
#   Using cached datasets-2.16.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (2020.6.20)
# Using cached datasets-2.16.1-py3-none-any.whl (507 kB)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: datasets
# Successfully installed datasets-2.16.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /usr/lib/python3/dist-packages (from nltk) (0.17.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk) (4.66.1)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting SentencePiece
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)

# %% [markdown]
# ## T5 fine-tuning
#
# This notebook is to showcase how to fine-tune [T5 model](https://arxiv.org/abs/1910.10683) with Huggigface's [Transformers](https://github.com/huggingface/transformers/) to solve different NLP tasks using text-2-text approach proposed in the T5 paper. For demo I chose 3 non text-2-text problems just to reiterate the fact from the paper that how widely applicable this text-2-text framework is and how it can be used for different tasks without changing the model at all.
#
# This is a rough draft so if you find any issues with this notebook or have any  questions reach out to me via [Twitter](https://twitter.com/psuraj28).

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
from itertools import chain
from string import punctuation

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# ## Model
#
# We'll be using the awesome [pytorch-lightning](https://github.com/PytorchLightning/pytorch-lightning) library for training. Most of the below code is adapted from here https://github.com/huggingface/transformers/blob/master/examples/lightning_base.py
#
# The trainer is generic and can be used for any text-2-text task. You'll just need to change the dataset. Rest of the code will stay unchanged for all the tasks.
#
# This is the most intresting and powerfull thing about the text-2-text format. You can fine-tune the model on variety of NLP tasks by just formulating the problem in text-2-text setting. No need to change hyperparameters, learning rate, optimizer or loss function. Just plug in your dataset and you are ready to go!

# %%
class T5FineTuner(pl.LightningModule):
  def __init__(self, hparams):
    super(T5FineTuner, self).__init__()
    self.hparams = hparams
    
    self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
    self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)
  
  def is_logger(self):
    return self.trainer.proc_rank <= 0
  
  def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None, # lm_labels=None
  ):
    return self.model(
        input_ids,
        attention_mask=attention_mask,
        decoder_input_ids=decoder_input_ids,
        decoder_attention_mask=decoder_attention_mask,
        labels=labels,
        #lm_labels=lm_labels,
    )

  def _step(self, batch):
    lm_labels = batch["target_ids"]
    lm_labels[lm_labels[:, :] == self.tokenizer.pad_token_id] = -100

    outputs = self(
        input_ids=batch["source_ids"],
        attention_mask=batch["source_mask"],
        #lm_labels=lm_labels,
        labels=lm_labels,
        decoder_attention_mask=batch['target_mask']
    )

    loss = outputs[0]

    return loss

  def training_step(self, batch, batch_idx):
    loss = self._step(batch)

    tensorboard_logs = {"train_loss": loss}
    return {"loss": loss, "log": tensorboard_logs}
  
  def training_epoch_end(self, outputs):
    avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
    tensorboard_logs = {"avg_train_loss": avg_train_loss}
    return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def validation_step(self, batch, batch_idx):
    loss = self._step(batch)
    return {"val_loss": loss}
  
  def validation_epoch_end(self, outputs):
    avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
    tensorboard_logs = {"val_loss": avg_loss}
    return {"avg_val_loss": avg_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def configure_optimizers(self):
    "Prepare optimizer and schedule (linear warmup and decay)"

    model = self.model
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": self.hparams.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
    self.opt = optimizer
    return [optimizer]
  
  def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure=None):
    if self.trainer.use_tpu:
      xm.optimizer_step(optimizer)
    else:
      optimizer.step()
    optimizer.zero_grad()
    self.lr_scheduler.step()
  
  def get_tqdm_dict(self):
    tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

    return tqdm_dict

  def train_dataloader(self):
    train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
    dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
    t_total = (
        (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
        // self.hparams.gradient_accumulation_steps
        * float(self.hparams.num_train_epochs)
    )
    scheduler = get_linear_schedule_with_warmup(
        self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
    )
    self.lr_scheduler = scheduler
    return dataloader

  def val_dataloader(self):
    val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
    return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %%
logger = logging.getLogger(__name__)

class LoggingCallback(pl.Callback):
  def on_validation_end(self, trainer, pl_module):
    logger.info("***** Validation results *****")
    if pl_module.is_logger():
      metrics = trainer.callback_metrics
      # Log results
      for key in sorted(metrics):
        if key not in ["log", "progress_bar"]:
          logger.info("{} = {}\n".format(key, str(metrics[key])))

  def on_test_end(self, trainer, pl_module):
    logger.info("***** Test results *****")

    if pl_module.is_logger():
      metrics = trainer.callback_metrics

      # Log and save results to file
      output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
      with open(output_test_results_file, "w") as writer:
        for key in sorted(metrics):
          if key not in ["log", "progress_bar"]:
            logger.info("{} = {}\n".format(key, str(metrics[key])))
            writer.write("{} = {}\n".format(key, str(metrics[key])))

# %% [markdown]
# Let's define the hyperparameters and other arguments. You can overide this `dict` for specific task as needed. While in most of cases you'll only need to change the `data_dir`and `output_dir`.
#
# Here the batch size is 8 and gradient_accumulation_steps are 16 so the effective batch size is 128

# %%
args_dict = dict(
    data_dir="", # path for data files
    output_dir="", # path to save the checkpoints
    model_name_or_path='t5-base',
    tokenizer_name_or_path='t5-base',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=8,
    eval_batch_size=8,
    num_train_epochs=2,
    gradient_accumulation_steps=16,
    n_gpu=1,
    early_stop_callback=False,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %% [markdown]
# ## IMDB review classification

# %% [markdown]
# ### Download IMDB Data

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xvf aclImdb_v1.tar.gz
# Out:
# --2024-01-27 19:33:27--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  9.13MB/s    in 9.1s
#
# 2024-01-27 19:33:37 (8.83 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]
#
# aclImdb/
# aclImdb/test/
# aclImdb/train/
# aclImdb/test/neg/
# aclImdb/test/pos/
# aclImdb/train/neg/
# aclImdb/train/pos/
# aclImdb/train/unsup/
# aclImdb/imdbEr.txt
# aclImdb/imdb.vocab
# aclImdb/README
# aclImdb/test/labeledBow.feat
# aclImdb/test/urls_neg.txt
# aclImdb/test/urls_pos.txt
# aclImdb/train/unsupBow.feat
# aclImdb/train/labeledBow.feat
# aclImdb/train/urls_neg.txt
# aclImdb/train/urls_pos.txt
# aclImdb/train/urls_unsup.txt
# aclImdb/test/neg/127_3.txt
# aclImdb/test/neg/126_4.txt
# aclImdb/test/neg/125_3.txt
# aclImdb/test/neg/124_2.txt
# aclImdb/test/neg/123_4.txt
# aclImdb/test/neg/122_4.txt
# aclImdb/test/neg/121_4.txt
# aclImdb/test/neg/120_2.txt
# aclImdb/test/neg/119_3.txt
# aclImdb/test/neg/118_1.txt
# aclImdb/test/neg/117_1.txt
# aclImdb/test/neg/116_4.txt
# aclImdb/test/neg/115_3.txt
# aclImdb/test/neg/114_2.txt
# aclImdb/test/neg/113_3.txt
# aclImdb/test/neg/112_2.txt
# aclImdb/test/neg/111_3.txt
# aclImdb/test/neg/110_1.txt
# aclImdb/test/neg/109_4.txt
# aclImdb/test/neg/108_2.txt
# aclImdb/test/neg/107_4.txt
# aclImdb/test/neg/106_3.txt
# aclImdb/test/neg/105_3.txt
# aclImdb/test/neg/104_1.txt
# aclImdb/test/neg/103_3.txt
# aclImdb/test/neg/102_4.txt
# aclImdb/test/neg/101_3.txt
# aclImdb/test/neg/100_4.txt
# aclImdb/test/neg/99_3.txt
# aclImdb/test/neg/98_1.txt
# aclImdb/test/neg/97_1.txt
# aclImdb/test/neg/96_1.txt
# aclImdb/test/neg/95_3.txt
# aclImdb/test/neg/94_2.txt
# aclImdb/test/neg/93_1.txt
# aclImdb/test/neg/92_1.txt
# aclImdb/test/neg/91_4.txt
# aclImdb/test/neg/90_2.txt
# aclImdb/test/neg/89_3.txt
# aclImdb/test/neg/88_3.txt
# aclImdb/test/neg/87_1.txt
# aclImdb/test/neg/86_3.txt
# aclImdb/test/neg/85_2.txt
# aclImdb/test/neg/84_3.txt
# aclImdb/test/neg/83_1.txt
# aclImdb/test/neg/82_3.txt
# aclImdb/test/neg/81_3.txt
# aclImdb/test/neg/80_4.txt
# aclImdb/test/neg/79_2.txt
# aclImdb/test/neg/78_1.txt
# aclImdb/test/neg/77_2.txt
# aclImdb/test/neg/76_4.txt
# aclImdb/test/neg/75_1.txt
# aclImdb/test/neg/74_4.txt
# aclImdb/test/neg/73_4.txt
# aclImdb/test/neg/72_4.txt
# aclImdb/test/neg/71_4.txt
# aclImdb/test/neg/70_1.txt
# aclImdb/test/neg/69_4.txt
# aclImdb/test/neg/68_1.txt
# aclImdb/test/neg/67_3.txt
# aclImdb/test/neg/66_3.txt
# aclImdb/test/neg/65_2.txt
# aclImdb/test/neg/64_3.txt
# aclImdb/test/neg/63_1.txt
# aclImdb/test/neg/62_2.txt
# aclImdb/test/neg/61_1.txt
# aclImdb/test/neg/60_1.txt
# aclImdb/test/neg/59_3.txt
# aclImdb/test/neg/58_3.txt
# aclImdb/test/neg/57_4.txt
# aclImdb/test/neg/56_3.txt
# aclImdb/test/neg/55_4.txt
# aclImdb/test/neg/54_3.txt
# aclImdb/test/neg/53_4.txt
# aclImdb/test/neg/52_4.txt
# aclImdb/test/neg/51_4.txt
# aclImdb/test/neg/50_3.txt
# aclImdb/test/neg/49_4.txt
# aclImdb/test/neg/48_4.txt
# aclImdb/test/neg/47_2.txt
# aclImdb/test/neg/46_2.txt
# aclImdb/test/neg/45_2.txt
# aclImdb/test/neg/44_4.txt
# aclImdb/test/neg/43_1.txt
# aclImdb/test/neg/42_4.txt
# aclImdb/test/neg/41_4.txt
# aclImdb/test/neg/40_4.txt
# aclImdb/test/neg/39_3.txt
# aclImdb/test/neg/38_1.txt
# aclImdb/test/neg/37_1.txt
# aclImdb/test/neg/36_3.txt
# aclImdb/test/neg/35_1.txt
# aclImdb/test/neg/34_1.txt
# aclImdb/test/neg/33_3.txt
# aclImdb/test/neg/32_3.txt
# aclImdb/test/neg/31_4.txt
# aclImdb/test/neg/30_4.txt
# aclImdb/test/neg/29_3.txt
# aclImdb/test/neg/28_3.txt
# aclImdb/test/neg/27_4.txt
# aclImdb/test/neg/26_3.txt
# aclImdb/test/neg/25_3.txt
# aclImdb/test/neg/24_4.txt
# aclImdb/test/neg/23_4.txt
# aclImdb/test/neg/22_3.txt
# aclImdb/test/neg/21_1.txt
# aclImdb/test/neg/20_1.txt
# aclImdb/test/neg/19_1.txt
# aclImdb/test/neg/18_1.txt
# aclImdb/test/neg/17_3.txt
# aclImdb/test/neg/16_1.txt
# aclImdb/test/neg/15_2.txt
# aclImdb/test/neg/14_1.txt
# aclImdb/test/neg/13_1.txt
# aclImdb/test/neg/12_4.txt
# aclImdb/test/neg/11_3.txt
# aclImdb/test/neg/10_3.txt
# aclImdb/test/neg/9_4.txt
# aclImdb/test/neg/8_2.txt
# aclImdb/test/neg/7_1.txt
# aclImdb/test/neg/6_3.txt
# aclImdb/test/neg/5_4.txt
# aclImdb/test/neg/4_4.txt
# aclImdb/test/neg/3_4.txt
# aclImdb/test/neg/2_3.txt
# aclImdb/test/neg/1_3.txt
# aclImdb/test/neg/0_2.txt
# aclImdb/test/neg/255_4.txt
# aclImdb/test/neg/254_3.txt
# aclImdb/test/neg/253_3.txt
# aclImdb/test/neg/252_3.txt
# aclImdb/test/neg/251_2.txt
# aclImdb/test/neg/250_1.txt
# aclImdb/test/neg/249_2.txt
# aclImdb/test/neg/248_2.txt
# aclImdb/test/neg/247_2.txt
# aclImdb/test/neg/246_2.txt
# aclImdb/test/neg/245_2.txt
# aclImdb/test/neg/244_2.txt
# aclImdb/test/neg/243_4.txt
# aclImdb/test/neg/242_3.txt
# aclImdb/test/neg/241_1.txt
# aclImdb/test/neg/240_4.txt
# aclImdb/test/neg/239_2.txt
# aclImdb/test/neg/238_1.txt
# aclImdb/test/neg/237_1.txt
# aclImdb/test/neg/236_3.txt
# aclImdb/test/neg/235_4.txt
# aclImdb/test/neg/234_3.txt
# aclImdb/test/neg/233_2.txt
# aclImdb/test/neg/232_4.txt
# aclImdb/test/neg/231_1.txt
# aclImdb/test/neg/230_1.txt
# aclImdb/test/neg/229_1.txt
# aclImdb/test/neg/228_1.txt
# aclImdb/test/neg/227_1.txt
# aclImdb/test/neg/226_4.txt
# aclImdb/test/neg/225_3.txt
# aclImdb/test/neg/224_3.txt
# aclImdb/test/neg/223_3.txt
# aclImdb/test/neg/222_3.txt
# aclImdb/test/neg/221_3.txt
# aclImdb/test/neg/220_4.txt
# aclImdb/test/neg/219_1.txt
# aclImdb/test/neg/218_3.txt
# aclImdb/test/neg/217_3.txt
# aclImdb/test/neg/216_2.txt
# aclImdb/test/neg/215_4.txt
# aclImdb/test/neg/214_1.txt
# aclImdb/test/neg/213_3.txt
# aclImdb/test/neg/212_4.txt
# aclImdb/test/neg/211_3.txt
# aclImdb/test/neg/210_4.txt
# aclImdb/test/neg/209_4.txt
# aclImdb/test/neg/208_3.txt
# aclImdb/test/neg/207_3.txt
# aclImdb/test/neg/206_2.txt
# aclImdb/test/neg/205_2.txt
# aclImdb/test/neg/204_1.txt
# aclImdb/test/neg/203_3.txt
# aclImdb/test/neg/202_4.txt
# aclImdb/test/neg/201_2.txt
# aclImdb/test/neg/200_4.txt
# aclImdb/test/neg/199_4.txt
# aclImdb/test/neg/198_3.txt
# aclImdb/test/neg/197_1.txt
# aclImdb/test/neg/196_4.txt
# aclImdb/test/neg/195_4.txt
# aclImdb/test/neg/194_1.txt
# aclImdb/test/neg/193_4.txt
# aclImdb/test/neg/192_2.txt
# aclImdb/test/neg/191_3.txt
# aclImdb/test/neg/190_2.txt
# aclImdb/test/neg/189_4.txt
# aclImdb/test/neg/188_3.txt
# aclImdb/test/neg/187_1.txt
# aclImdb/test/neg/186_1.txt
# aclImdb/test/neg/185_4.txt
# aclImdb/test/neg/184_3.txt
# aclImdb/test/neg/183_4.txt
# aclImdb/test/neg/182_3.txt
# aclImdb/test/neg/181_3.txt
# aclImdb/test/neg/180_3.txt
# aclImdb/test/neg/179_1.txt
# aclImdb/test/neg/178_2.txt
# aclImdb/test/neg/177_1.txt
# aclImdb/test/neg/176_3.txt
# aclImdb/test/neg/175_4.txt
# aclImdb/test/neg/174_2.txt
# aclImdb/test/neg/173_4.txt
# aclImdb/test/neg/172_4.txt
# aclImdb/test/neg/171_2.txt
# aclImdb/test/neg/170_2.txt
# aclImdb/test/neg/169_4.txt
# aclImdb/test/neg/168_1.txt
# aclImdb/test/neg/167_2.txt
# aclImdb/test/neg/166_4.txt
# aclImdb/test/neg/165_4.txt
# aclImdb/test/neg/164_2.txt
# aclImdb/test/neg/163_1.txt
# aclImdb/test/neg/162_3.txt
# aclImdb/test/neg/161_3.txt
# aclImdb/test/neg/160_1.txt
# aclImdb/test/neg/159_1.txt
# aclImdb/test/neg/158_1.txt
# aclImdb/test/neg/157_3.txt
# aclImdb/test/neg/156_3.txt
# aclImdb/test/neg/155_2.txt
# aclImdb/test/neg/154_2.txt
# aclImdb/test/neg/153_4.txt
# aclImdb/test/neg/152_4.txt
# aclImdb/test/neg/151_2.txt
# aclImdb/test/neg/150_4.txt
# aclImdb/test/neg/149_1.txt
# aclImdb/test/neg/148_1.txt
# aclImdb/test/neg/147_4.txt
# aclImdb/test/neg/146_1.txt
# aclImdb/test/neg/145_1.txt
# aclImdb/test/neg/144_2.txt
# aclImdb/test/neg/143_4.txt
# aclImdb/test/neg/142_1.txt
# aclImdb/test/neg/141_1.txt
# aclImdb/test/neg/140_2.txt
# aclImdb/test/neg/139_4.txt
# aclImdb/test/neg/138_1.txt
# aclImdb/test/neg/137_3.txt
# aclImdb/test/neg/136_2.txt
# aclImdb/test/neg/135_3.txt
# aclImdb/test/neg/134_1.txt
# aclImdb/test/neg/133_1.txt
# aclImdb/test/neg/132_1.txt
# aclImdb/test/neg/131_1.txt
# aclImdb/test/neg/130_4.txt
# aclImdb/test/neg/129_1.txt
# aclImdb/test/neg/128_4.txt
# aclImdb/test/neg/383_1.txt
# aclImdb/test/neg/382_4.txt
# aclImdb/test/neg/381_1.txt
# aclImdb/test/neg/380_2.txt
# aclImdb/test/neg/379_1.txt
# aclImdb/test/neg/378_1.txt
# aclImdb/test/neg/377_1.txt
# aclImdb/test/neg/376_2.txt
# aclImdb/test/neg/375_1.txt
# aclImdb/test/neg/374_4.txt
# aclImdb/test/neg/373_2.txt
# aclImdb/test/neg/372_2.txt
# aclImdb/test/neg/371_4.txt
# aclImdb/test/neg/370_2.txt
# aclImdb/test/neg/369_1.txt
# aclImdb/test/neg/368_4.txt
# aclImdb/test/neg/367_3.txt
# aclImdb/test/neg/366_1.txt
# aclImdb/test/neg/365_1.txt
# aclImdb/test/neg/364_1.txt
# aclImdb/test/neg/363_3.txt
# aclImdb/test/neg/362_2.txt
# aclImdb/test/neg/361_1.txt
# aclImdb/test/neg/360_3.txt
# aclImdb/test/neg/359_4.txt
# aclImdb/test/neg/358_4.txt
# aclImdb/test/neg/357_1.txt
# aclImdb/test/neg/356_3.txt
# aclImdb/test/neg/355_4.txt
# aclImdb/test/neg/354_4.txt
# aclImdb/test/neg/353_3.txt
# aclImdb/test/neg/352_4.txt
# aclImdb/test/neg/351_4.txt
# aclImdb/test/neg/350_4.txt
# aclImdb/test/neg/349_2.txt
# aclImdb/test/neg/348_1.txt
# aclImdb/test/neg/347_1.txt
# aclImdb/test/neg/346_2.txt
# aclImdb/test/neg/345_3.txt
# aclImdb/test/neg/344_4.txt
# aclImdb/test/neg/343_1.txt
# aclImdb/test/neg/342_1.txt
# aclImdb/test/neg/341_1.txt
# aclImdb/test/neg/340_2.txt
# aclImdb/test/neg/339_1.txt
# aclImdb/test/neg/338_1.txt
# aclImdb/test/neg/337_1.txt
# aclImdb/test/neg/336_1.txt
# aclImdb/test/neg/335_2.txt
# aclImdb/test/neg/334_2.txt
# aclImdb/test/neg/333_3.txt
# aclImdb/test/neg/332_1.txt
# aclImdb/test/neg/331_4.txt
# aclImdb/test/neg/330_1.txt
# aclImdb/test/neg/329_1.txt
# aclImdb/test/neg/328_4.txt
# aclImdb/test/neg/327_1.txt
# aclImdb/test/neg/326_1.txt
# aclImdb/test/neg/325_1.txt
# aclImdb/test/neg/324_3.txt
# aclImdb/test/neg/323_2.txt
# aclImdb/test/neg/322_1.txt
# aclImdb/test/neg/321_1.txt
# aclImdb/test/neg/320_3.txt
# aclImdb/test/neg/319_1.txt
# aclImdb/test/neg/318_3.txt
# aclImdb/test/neg/317_2.txt
# aclImdb/test/neg/316_1.txt
# aclImdb/test/neg/315_4.txt
# aclImdb/test/neg/314_2.txt
# aclImdb/test/neg/313_1.txt
# aclImdb/test/neg/312_4.txt
# aclImdb/test/neg/311_3.txt
# aclImdb/test/neg/310_1.txt
# aclImdb/test/neg/309_3.txt
# aclImdb/test/neg/308_1.txt
# aclImdb/test/neg/307_1.txt
# aclImdb/test/neg/306_1.txt
# aclImdb/test/neg/305_2.txt
# aclImdb/test/neg/304_2.txt
# aclImdb/test/neg/303_2.txt
# aclImdb/test/neg/302_3.txt
# aclImdb/test/neg/301_4.txt
# aclImdb/test/neg/300_1.txt
# aclImdb/test/neg/299_1.txt
# aclImdb/test/neg/298_1.txt
# aclImdb/test/neg/297_2.txt
# aclImdb/test/neg/296_4.txt
# aclImdb/test/neg/295_1.txt
# aclImdb/test/neg/294_1.txt
# aclImdb/test/neg/293_1.txt
# aclImdb/test/neg/292_3.txt
# aclImdb/test/neg/291_3.txt
# aclImdb/test/neg/290_1.txt
# aclImdb/test/neg/289_1.txt
# aclImdb/test/neg/288_1.txt
# aclImdb/test/neg/287_1.txt
# aclImdb/test/neg/286_1.txt
# aclImdb/test/neg/285_4.txt
# aclImdb/test/neg/284_2.txt
# aclImdb/test/neg/283_1.txt
# aclImdb/test/neg/282_1.txt
# aclImdb/test/neg/281_1.txt
# aclImdb/test/neg/280_1.txt
# aclImdb/test/neg/279_1.txt
# aclImdb/test/neg/278_1.txt
# aclImdb/test/neg/277_1.txt
# aclImdb/test/neg/276_1.txt
# aclImdb/test/neg/275_1.txt
# aclImdb/test/neg/274_1.txt
# aclImdb/test/neg/273_1.txt
# aclImdb/test/neg/272_1.txt
# aclImdb/test/neg/271_4.txt
# aclImdb/test/neg/270_1.txt
# aclImdb/test/neg/269_2.txt
# aclImdb/test/neg/268_3.txt
# aclImdb/test/neg/267_1.txt
# aclImdb/test/neg/266_4.txt
# aclImdb/test/neg/265_1.txt
# aclImdb/test/neg/264_1.txt
# aclImdb/test/neg/263_1.txt
# aclImdb/test/neg/262_1.txt
# aclImdb/test/neg/261_3.txt
# aclImdb/test/neg/260_1.txt
# aclImdb/test/neg/259_2.txt
# aclImdb/test/neg/258_1.txt
# aclImdb/test/neg/257_3.txt
# aclImdb/test/neg/256_4.txt
# aclImdb/test/neg/511_3.txt
# aclImdb/test/neg/510_2.txt
# aclImdb/test/neg/509_3.txt
# aclImdb/test/neg/508_4.txt
# aclImdb/test/neg/507_1.txt
# aclImdb/test/neg/506_2.txt
# aclImdb/test/neg/505_1.txt
# aclImdb/test/neg/504_1.txt
# aclImdb/test/neg/503_2.txt
# aclImdb/test/neg/502_4.txt
# aclImdb/test/neg/501_1.txt
# aclImdb/test/neg/500_1.txt
# aclImdb/test/neg/499_2.txt
# aclImdb/test/neg/498_1.txt
# aclImdb/test/neg/497_2.txt
# aclImdb/test/neg/496_3.txt
# aclImdb/test/neg/495_2.txt
# aclImdb/test/neg/494_2.txt
# aclImdb/test/neg/493_1.txt
# aclImdb/test/neg/492_1.txt
# aclImdb/test/neg/491_2.txt
# aclImdb/test/neg/490_2.txt
# aclImdb/test/neg/489_1.txt
# aclImdb/test/neg/488_4.txt
# aclImdb/test/neg/487_3.txt
# aclImdb/test/neg/486_4.txt
# aclImdb/test/neg/485_4.txt
# aclImdb/test/neg/484_1.txt
# aclImdb/test/neg/483_2.txt
# aclImdb/test/neg/482_1.txt
# aclImdb/test/neg/481_2.txt
# aclImdb/test/neg/480_3.txt
# aclImdb/test/neg/479_3.txt
# aclImdb/test/neg/478_3.txt
# aclImdb/test/neg/477_2.txt
# aclImdb/test/neg/476_1.txt
# aclImdb/test/neg/475_1.txt
# aclImdb/test/neg/474_4.txt
# aclImdb/test/neg/473_1.txt
# aclImdb/test/neg/472_4.txt
# aclImdb/test/neg/471_3.txt
# aclImdb/test/neg/470_4.txt
# aclImdb/test/neg/469_2.txt
# aclImdb/test/neg/468_1.txt
# aclImdb/test/neg/467_3.txt
# aclImdb/test/neg/466_1.txt
# aclImdb/test/neg/465_4.txt
# aclImdb/test/neg/464_4.txt
# aclImdb/test/neg/463_1.txt
# aclImdb/test/neg/462_4.txt
# aclImdb/test/neg/461_1.txt
# aclImdb/test/neg/460_1.txt
# aclImdb/test/neg/459_4.txt
# aclImdb/test/neg/458_4.txt
# aclImdb/test/neg/457_2.txt
# aclImdb/test/neg/456_1.txt
# aclImdb/test/neg/455_1.txt
# aclImdb/test/neg/454_1.txt
# aclImdb/test/neg/453_4.txt
# aclImdb/test/neg/452_2.txt
# aclImdb/test/neg/451_2.txt
# aclImdb/test/neg/450_2.txt
# aclImdb/test/neg/449_3.txt
# aclImdb/test/neg/448_2.txt
# aclImdb/test/neg/447_4.txt
# aclImdb/test/neg/446_1.txt
# aclImdb/test/neg/445_3.txt
# aclImdb/test/neg/444_2.txt
# aclImdb/test/neg/443_2.txt
# aclImdb/test/neg/442_3.txt
# aclImdb/test/neg/441_4.txt
# aclImdb/test/neg/440_1.txt
# aclImdb/test/neg/439_1.txt
# aclImdb/test/neg/438_2.txt
# aclImdb/test/neg/437_2.txt
# aclImdb/test/neg/436_4.txt
# aclImdb/test/neg/435_1.txt
# aclImdb/test/neg/434_1.txt
# aclImdb/test/neg/433_1.txt
# aclImdb/test/neg/432_3.txt
# aclImdb/test/neg/431_2.txt
# aclImdb/test/neg/430_4.txt
# aclImdb/test/neg/429_3.txt
# aclImdb/test/neg/428_3.txt
# aclImdb/test/neg/427_3.txt
# aclImdb/test/neg/426_4.txt
# aclImdb/test/neg/425_2.txt
# aclImdb/test/neg/424_2.txt
# aclImdb/test/neg/423_2.txt
# aclImdb/test/neg/422_3.txt
# aclImdb/test/neg/421_1.txt
# aclImdb/test/neg/420_3.txt
# aclImdb/test/neg/419_4.txt
# aclImdb/test/neg/418_4.txt
# aclImdb/test/neg/417_1.txt
# aclImdb/test/neg/416_2.txt
# aclImdb/test/neg/415_1.txt
# aclImdb/test/neg/414_2.txt
# aclImdb/test/neg/413_4.txt
# aclImdb/test/neg/412_2.txt
# aclImdb/test/neg/411_3.txt
# aclImdb/test/neg/410_2.txt
# aclImdb/test/neg/409_4.txt
# aclImdb/test/neg/408_3.txt
# aclImdb/test/neg/407_4.txt
# aclImdb/test/neg/406_1.txt
# aclImdb/test/neg/405_3.txt
# aclImdb/test/neg/404_1.txt
# aclImdb/test/neg/403_1.txt
# aclImdb/test/neg/402_1.txt
# aclImdb/test/neg/401_1.txt
# aclImdb/test/neg/400_1.txt
# aclImdb/test/neg/399_1.txt
# aclImdb/test/neg/398_4.txt
# aclImdb/test/neg/397_3.txt
# aclImdb/test/neg/396_2.txt
# aclImdb/test/neg/395_2.txt
# aclImdb/test/neg/394_4.txt
# aclImdb/test/neg/393_1.txt
# aclImdb/test/neg/392_2.txt
# aclImdb/test/neg/391_1.txt
# aclImdb/test/neg/390_4.txt
# aclImdb/test/neg/389_1.txt
# aclImdb/test/neg/388_1.txt
# aclImdb/test/neg/387_1.txt
# aclImdb/test/neg/386_1.txt
# aclImdb/test/neg/385_1.txt
# aclImdb/test/neg/384_4.txt
# aclImdb/test/neg/639_1.txt
# aclImdb/test/neg/638_1.txt
# aclImdb/test/neg/637_3.txt
# aclImdb/test/neg/636_1.txt
# aclImdb/test/neg/635_2.txt
# aclImdb/test/neg/634_1.txt
# aclImdb/test/neg/633_1.txt
# aclImdb/test/neg/632_1.txt
# aclImdb/test/neg/631_4.txt
# aclImdb/test/neg/630_3.txt
# aclImdb/test/neg/629_4.txt
# aclImdb/test/neg/628_1.txt
# aclImdb/test/neg/627_1.txt
# aclImdb/test/neg/626_4.txt
# aclImdb/test/neg/625_2.txt
# aclImdb/test/neg/624_3.txt
# aclImdb/test/neg/623_2.txt
# aclImdb/test/neg/622_1.txt
# aclImdb/test/neg/621_2.txt
# aclImdb/test/neg/620_2.txt
# aclImdb/test/neg/619_1.txt
# aclImdb/test/neg/618_1.txt
# aclImdb/test/neg/617_4.txt
# aclImdb/test/neg/616_1.txt
# aclImdb/test/neg/615_3.txt
# aclImdb/test/neg/614_2.txt
# aclImdb/test/neg/613_4.txt
# aclImdb/test/neg/612_3.txt
# aclImdb/test/neg/611_1.txt
# aclImdb/test/neg/610_1.txt
# aclImdb/test/neg/609_1.txt
# aclImdb/test/neg/608_1.txt
# aclImdb/test/neg/607_1.txt
# aclImdb/test/neg/606_1.txt
# aclImdb/test/neg/605_4.txt
# aclImdb/test/neg/604_3.txt
# aclImdb/test/neg/603_4.txt
# aclImdb/test/neg/602_1.txt
# aclImdb/test/neg/601_3.txt
# aclImdb/test/neg/600_1.txt
# aclImdb/test/neg/599_1.txt
# aclImdb/test/neg/598_1.txt
# aclImdb/test/neg/597_4.txt
# aclImdb/test/neg/596_1.txt
# aclImdb/test/neg/595_1.txt
# aclImdb/test/neg/594_1.txt
# aclImdb/test/neg/593_1.txt
# aclImdb/test/neg/592_3.txt
# aclImdb/test/neg/591_1.txt
# aclImdb/test/neg/590_1.txt
# aclImdb/test/neg/589_2.txt
# aclImdb/test/neg/588_2.txt
# aclImdb/test/neg/587_3.txt
# aclImdb/test/neg/586_2.txt
# aclImdb/test/neg/585_1.txt
# aclImdb/test/neg/584_3.txt
# aclImdb/test/neg/583_2.txt
# aclImdb/test/neg/582_4.txt
# aclImdb/test/neg/581_4.txt
# aclImdb/test/neg/580_3.txt
# aclImdb/test/neg/579_1.txt
# aclImdb/test/neg/578_2.txt
# aclImdb/test/neg/577_3.txt
# aclImdb/test/neg/576_4.txt
# aclImdb/test/neg/575_4.txt
# aclImdb/test/neg/574_4.txt
# aclImdb/test/neg/573_3.txt
# aclImdb/test/neg/572_3.txt
# aclImdb/test/neg/571_1.txt
# aclImdb/test/neg/570_1.txt
# aclImdb/test/neg/569_4.txt
# aclImdb/test/neg/568_4.txt
# aclImdb/test/neg/567_3.txt
# aclImdb/test/neg/566_3.txt
# aclImdb/test/neg/565_2.txt
# aclImdb/test/neg/564_4.txt
# aclImdb/test/neg/563_4.txt
# aclImdb/test/neg/562_1.txt
# aclImdb/test/neg/561_1.txt
# aclImdb/test/neg/560_3.txt
# aclImdb/test/neg/559_4.txt
# aclImdb/test/neg/558_2.txt
# aclImdb/test/neg/557_4.txt
# aclImdb/test/neg/556_1.txt
# aclImdb/test/neg/555_4.txt
# aclImdb/test/neg/554_4.txt
# aclImdb/test/neg/553_1.txt
# aclImdb/test/neg/552_2.txt
# aclImdb/test/neg/551_4.txt
# aclImdb/test/neg/550_3.txt
# aclImdb/test/neg/549_3.txt
# aclImdb/test/neg/548_4.txt
# aclImdb/test/neg/547_4.txt
# aclImdb/test/neg/546_3.txt
# aclImdb/test/neg/545_4.txt
# aclImdb/test/neg/544_4.txt
# aclImdb/test/neg/543_4.txt
# aclImdb/test/neg/542_4.txt
# aclImdb/test/neg/541_1.txt
# aclImdb/test/neg/540_1.txt
# aclImdb/test/neg/539_3.txt
# aclImdb/test/neg/538_4.txt
# aclImdb/test/neg/537_2.txt
# aclImdb/test/neg/536_3.txt
# aclImdb/test/neg/535_4.txt
# aclImdb/test/neg/534_4.txt
# aclImdb/test/neg/533_1.txt
# aclImdb/test/neg/532_3.txt
# aclImdb/test/neg/531_2.txt
# aclImdb/test/neg/530_2.txt
# aclImdb/test/neg/529_1.txt
# aclImdb/test/neg/528_1.txt
# aclImdb/test/neg/527_2.txt
# aclImdb/test/neg/526_3.txt
# aclImdb/test/neg/525_3.txt
# aclImdb/test/neg/524_1.txt
# aclImdb/test/neg/523_1.txt
# aclImdb/test/neg/522_2.txt
# aclImdb/test/neg/521_1.txt
# aclImdb/test/neg/520_2.txt
# aclImdb/test/neg/519_1.txt
# aclImdb/test/neg/518_4.txt
# aclImdb/test/neg/517_1.txt
# aclImdb/test/neg/516_1.txt
# aclImdb/test/neg/515_1.txt
# aclImdb/test/neg/514_3.txt
# aclImdb/test/neg/513_1.txt
# aclImdb/test/neg/512_2.txt
# aclImdb/test/neg/767_1.txt
# aclImdb/test/neg/766_2.txt
# aclImdb/test/neg/765_2.txt
# aclImdb/test/neg/764_2.txt
# aclImdb/test/neg/763_2.txt
# aclImdb/test/neg/762_3.txt
# aclImdb/test/neg/761_2.txt
# aclImdb/test/neg/760_1.txt
# aclImdb/test/neg/759_1.txt
# aclImdb/test/neg/758_3.txt
# aclImdb/test/neg/757_1.txt
# aclImdb/test/neg/756_1.txt
# aclImdb/test/neg/755_1.txt
# aclImdb/test/neg/754_2.txt
# aclImdb/test/neg/753_2.txt
# aclImdb/test/neg/752_4.txt
# aclImdb/test/neg/751_1.txt
# aclImdb/test/neg/750_2.txt
# aclImdb/test/neg/749_1.txt
# aclImdb/test/neg/748_1.txt
# aclImdb/test/neg/747_3.txt
# aclImdb/test/neg/746_1.txt
# aclImdb/test/neg/745_1.txt
# aclImdb/test/neg/744_1.txt
# aclImdb/test/neg/743_2.txt
# aclImdb/test/neg/742_2.txt
# aclImdb/test/neg/741_1.txt
# aclImdb/test/neg/740_3.txt
# aclImdb/test/neg/739_1.txt
# aclImdb/test/neg/738_1.txt
# aclImdb/test/neg/737_1.txt
# aclImdb/test/neg/736_2.txt
# aclImdb/test/neg/735_1.txt
# aclImdb/test/neg/734_1.txt
# aclImdb/test/neg/733_1.txt
# aclImdb/test/neg/732_3.txt
# aclImdb/test/neg/731_4.txt
# aclImdb/test/neg/730_1.txt
# aclImdb/test/neg/729_1.txt
# aclImdb/test/neg/728_1.txt
# aclImdb/test/neg/727_3.txt
# aclImdb/test/neg/726_1.txt
# aclImdb/test/neg/725_2.txt
# aclImdb/test/neg/724_3.txt
# aclImdb/test/neg/723_2.txt
# aclImdb/test/neg/722_3.txt
# aclImdb/test/neg/721_4.txt
# aclImdb/test/neg/720_1.txt
# aclImdb/test/neg/719_1.txt
# aclImdb/test/neg/718_3.txt
# aclImdb/test/neg/717_4.txt
# aclImdb/test/neg/716_2.txt
# aclImdb/test/neg/715_4.txt
# aclImdb/test/neg/714_4.txt
# aclImdb/test/neg/713_1.txt
# aclImdb/test/neg/712_3.txt
# aclImdb/test/neg/711_4.txt
# aclImdb/test/neg/710_3.txt
# aclImdb/test/neg/709_4.txt
# aclImdb/test/neg/708_3.txt
# aclImdb/test/neg/707_3.txt
# aclImdb/test/neg/706_1.txt
# aclImdb/test/neg/705_2.txt
# aclImdb/test/neg/704_2.txt
# aclImdb/test/neg/703_2.txt
# aclImdb/test/neg/702_1.txt
# aclImdb/test/neg/701_4.txt
# aclImdb/test/neg/700_4.txt
# aclImdb/test/neg/699_1.txt
# aclImdb/test/neg/698_1.txt
# aclImdb/test/neg/697_4.txt
# aclImdb/test/neg/696_4.txt
# aclImdb/test/neg/695_4.txt
# aclImdb/test/neg/694_4.txt
# aclImdb/test/neg/693_4.txt
# aclImdb/test/neg/692_4.txt
# aclImdb/test/neg/691_2.txt
# aclImdb/test/neg/690_3.txt
# aclImdb/test/neg/689_3.txt
# aclImdb/test/neg/688_4.txt
# aclImdb/test/neg/687_3.txt
# aclImdb/test/neg/686_4.txt
# aclImdb/test/neg/685_1.txt
# aclImdb/test/neg/684_1.txt
# aclImdb/test/neg/683_2.txt
# aclImdb/test/neg/682_4.txt
# aclImdb/test/neg/681_3.txt
# aclImdb/test/neg/680_2.txt
# aclImdb/test/neg/679_4.txt
# aclImdb/test/neg/678_1.txt
# aclImdb/test/neg/677_1.txt
# aclImdb/test/neg/676_1.txt
# aclImdb/test/neg/675_2.txt
# aclImdb/test/neg/674_3.txt
# aclImdb/test/neg/673_2.txt
# aclImdb/test/neg/672_4.txt
# aclImdb/test/neg/671_3.txt
# aclImdb/test/neg/670_3.txt
# aclImdb/test/neg/669_2.txt
# aclImdb/test/neg/668_4.txt
# aclImdb/test/neg/667_4.txt
# aclImdb/test/neg/666_4.txt
# aclImdb/test/neg/665_1.txt
# aclImdb/test/neg/664_3.txt
# aclImdb/test/neg/663_1.txt
# aclImdb/test/neg/662_4.txt
# aclImdb/test/neg/661_1.txt
# aclImdb/test/neg/660_2.txt
# aclImdb/test/neg/659_1.txt
# aclImdb/test/neg/658_3.txt
# aclImdb/test/neg/657_1.txt
# aclImdb/test/neg/656_4.txt
# aclImdb/test/neg/655_3.txt
# aclImdb/test/neg/654_3.txt
# aclImdb/test/neg/653_1.txt
# aclImdb/test/neg/652_1.txt
# aclImdb/test/neg/651_1.txt
# aclImdb/test/neg/650_3.txt
# aclImdb/test/neg/649_2.txt
# aclImdb/test/neg/648_3.txt
# aclImdb/test/neg/647_1.txt
# aclImdb/test/neg/646_1.txt
# aclImdb/test/neg/645_1.txt
# aclImdb/test/neg/644_2.txt
# aclImdb/test/neg/643_4.txt
# aclImdb/test/neg/642_2.txt
# aclImdb/test/neg/641_1.txt
# aclImdb/test/neg/640_1.txt
# aclImdb/test/neg/895_1.txt
# aclImdb/test/neg/894_1.txt
# aclImdb/test/neg/893_1.txt
# aclImdb/test/neg/892_1.txt
# aclImdb/test/neg/891_1.txt
# aclImdb/test/neg/890_1.txt
# aclImdb/test/neg/889_3.txt
# aclImdb/test/neg/888_1.txt
# aclImdb/test/neg/887_2.txt
# aclImdb/test/neg/886_2.txt
# aclImdb/test/neg/885_3.txt
# aclImdb/test/neg/884_1.txt
# aclImdb/test/neg/883_4.txt
# aclImdb/test/neg/882_2.txt
# aclImdb/test/neg/881_4.txt
# aclImdb/test/neg/880_3.txt
# aclImdb/test/neg/879_3.txt
# aclImdb/test/neg/878_2.txt
# aclImdb/test/neg/877_1.txt
# aclImdb/test/neg/876_3.txt
# aclImdb/test/neg/875_4.txt
# aclImdb/test/neg/874_4.txt
# aclImdb/test/neg/873_3.txt
# aclImdb/test/neg/872_1.txt
# aclImdb/test/neg/871_1.txt
# aclImdb/test/neg/870_4.txt
# aclImdb/test/neg/869_1.txt
# aclImdb/test/neg/868_4.txt
# aclImdb/test/neg/867_2.txt
# aclImdb/test/neg/866_2.txt
# aclImdb/test/neg/865_3.txt
# aclImdb/test/neg/864_2.txt
# aclImdb/test/neg/863_4.txt
# aclImdb/test/neg/862_3.txt
# aclImdb/test/neg/861_4.txt
# aclImdb/test/neg/860_4.txt
# aclImdb/test/neg/859_1.txt
# aclImdb/test/neg/858_4.txt
# aclImdb/test/neg/857_1.txt
# aclImdb/test/neg/856_3.txt
# aclImdb/test/neg/855_4.txt
# aclImdb/test/neg/854_1.txt
# aclImdb/test/neg/853_1.txt
# aclImdb/test/neg/852_4.txt
# aclImdb/test/neg/851_1.txt
# aclImdb/test/neg/850_4.txt
# aclImdb/test/neg/849_1.txt
# aclImdb/test/neg/848_2.txt
# aclImdb/test/neg/847_2.txt
# aclImdb/test/neg/846_2.txt
# aclImdb/test/neg/845_2.txt
# aclImdb/test/neg/844_1.txt
# aclImdb/test/neg/843_1.txt
# aclImdb/test/neg/842_1.txt
# aclImdb/test/neg/841_1.txt
# aclImdb/test/neg/840_2.txt
# aclImdb/test/neg/839_4.txt
# aclImdb/test/neg/838_4.txt
# aclImdb/test/neg/837_4.txt
# aclImdb/test/neg/836_4.txt
# aclImdb/test/neg/835_4.txt
# aclImdb/test/neg/834_4.txt
# aclImdb/test/neg/833_3.txt
# aclImdb/test/neg/832_4.txt
# aclImdb/test/neg/831_4.txt
# aclImdb/test/neg/830_4.txt
# aclImdb/test/neg/829_2.txt
# aclImdb/test/neg/828_3.txt
# aclImdb/test/neg/827_1.txt
# aclImdb/test/neg/826_3.txt
# aclImdb/test/neg/825_1.txt
# aclImdb/test/neg/824_4.txt
# aclImdb/test/neg/823_1.txt
# aclImdb/test/neg/822_1.txt
# aclImdb/test/neg/821_1.txt
# aclImdb/test/neg/820_1.txt
# aclImdb/test/neg/819_1.txt
# aclImdb/test/neg/818_1.txt
# aclImdb/test/neg/817_1.txt
# aclImdb/test/neg/816_3.txt
# aclImdb/test/neg/815_3.txt
# aclImdb/test/neg/814_4.txt
# aclImdb/test/neg/813_1.txt
# aclImdb/test/neg/812_3.txt
# aclImdb/test/neg/811_1.txt
# aclImdb/test/neg/810_1.txt
# aclImdb/test/neg/809_1.txt
# aclImdb/test/neg/808_3.txt
# aclImdb/test/neg/807_3.txt
# aclImdb/test/neg/806_1.txt
# aclImdb/test/neg/805_1.txt
# aclImdb/test/neg/804_1.txt
# aclImdb/test/neg/803_3.txt
# aclImdb/test/neg/802_1.txt
# aclImdb/test/neg/801_2.txt
# aclImdb/test/neg/800_3.txt
# aclImdb/test/neg/799_4.txt
# aclImdb/test/neg/798_1.txt
# aclImdb/test/neg/797_1.txt
# aclImdb/test/neg/796_4.txt
# aclImdb/test/neg/795_3.txt
# aclImdb/test/neg/794_1.txt
# aclImdb/test/neg/793_1.txt
# aclImdb/test/neg/792_2.txt
# aclImdb/test/neg/791_4.txt
# aclImdb/test/neg/790_1.txt
# aclImdb/test/neg/789_1.txt
# aclImdb/test/neg/788_1.txt
# aclImdb/test/neg/787_1.txt
# aclImdb/test/neg/786_3.txt
# aclImdb/test/neg/785_2.txt
# aclImdb/test/neg/784_4.txt
# aclImdb/test/neg/783_1.txt
# aclImdb/test/neg/782_3.txt
# aclImdb/test/neg/781_4.txt
# aclImdb/test/neg/780_3.txt
# aclImdb/test/neg/779_1.txt
# aclImdb/test/neg/778_1.txt
# aclImdb/test/neg/777_2.txt
# aclImdb/test/neg/776_1.txt
# aclImdb/test/neg/775_1.txt
# aclImdb/test/neg/774_4.txt
# aclImdb/test/neg/773_1.txt
# aclImdb/test/neg/772_1.txt
# aclImdb/test/neg/771_4.txt
# aclImdb/test/neg/770_3.txt
# aclImdb/test/neg/769_3.txt
# aclImdb/test/neg/768_2.txt
# aclImdb/test/neg/1023_3.txt
# aclImdb/test/neg/1022_3.txt
# aclImdb/test/neg/1021_2.txt
# aclImdb/test/neg/1020_2.txt
# aclImdb/test/neg/1019_3.txt
# aclImdb/test/neg/1018_4.txt
# aclImdb/test/neg/1017_1.txt
# aclImdb/test/neg/1016_3.txt
# aclImdb/test/neg/1015_4.txt
# aclImdb/test/neg/1014_4.txt
# aclImdb/test/neg/1013_1.txt
# aclImdb/test/neg/1012_1.txt
# aclImdb/test/neg/1011_4.txt
# aclImdb/test/neg/1010_1.txt
# aclImdb/test/neg/1009_3.txt
# aclImdb/test/neg/1008_2.txt
# aclImdb/test/neg/1007_4.txt
# aclImdb/test/neg/1006_3.txt
# aclImdb/test/neg/1005_2.txt
# aclImdb/test/neg/1004_4.txt
# aclImdb/test/neg/1003_4.txt
# aclImdb/test/neg/1002_3.txt
# aclImdb/test/neg/1001_4.txt
# aclImdb/test/neg/1000_3.txt
# aclImdb/test/neg/999_3.txt
# aclImdb/test/neg/998_2.txt
# aclImdb/test/neg/997_3.txt
# aclImdb/test/neg/996_3.txt
# aclImdb/test/neg/995_1.txt
# aclImdb/test/neg/994_3.txt
# aclImdb/test/neg/993_3.txt
# aclImdb/test/neg/992_1.txt
# aclImdb/test/neg/991_4.txt
# aclImdb/test/neg/990_1.txt
# aclImdb/test/neg/989_4.txt
# aclImdb/test/neg/988_3.txt
# aclImdb/test/neg/987_4.txt
# aclImdb/test/neg/986_3.txt
# aclImdb/test/neg/985_4.txt
# aclImdb/test/neg/984_3.txt
# aclImdb/test/neg/983_4.txt
# aclImdb/test/neg/982_4.txt
# aclImdb/test/neg/981_1.txt
# aclImdb/test/neg/980_2.txt
# aclImdb/test/neg/979_3.txt
# aclImdb/test/neg/978_1.txt
# aclImdb/test/neg/977_4.txt
# aclImdb/test/neg/976_3.txt
# aclImdb/test/neg/975_4.txt
# aclImdb/test/neg/974_4.txt
# aclImdb/test/neg/973_4.txt
# aclImdb/test/neg/972_1.txt
# aclImdb/test/neg/971_3.txt
# aclImdb/test/neg/970_4.txt
# aclImdb/test/neg/969_4.txt
# aclImdb/test/neg/968_2.txt
# aclImdb/test/neg/967_2.txt
# aclImdb/test/neg/966_4.txt
# aclImdb/test/neg/965_3.txt
# aclImdb/test/neg/964_3.txt
# aclImdb/test/neg/963_2.txt
# aclImdb/test/neg/962_4.txt
# aclImdb/test/neg/961_1.txt
# aclImdb/test/neg/960_3.txt
# aclImdb/test/neg/959_4.txt
# aclImdb/test/neg/958_4.txt
# aclImdb/test/neg/957_2.txt
# aclImdb/test/neg/956_3.txt
# aclImdb/test/neg/955_4.txt
# aclImdb/test/neg/954_4.txt
# aclImdb/test/neg/953_2.txt
# aclImdb/test/neg/952_1.txt
# aclImdb/test/neg/951_1.txt
# aclImdb/test/neg/950_1.txt
# aclImdb/test/neg/949_3.txt
# aclImdb/test/neg/948_1.txt
# aclImdb/test/neg/947_3.txt
# aclImdb/test/neg/946_1.txt
# aclImdb/test/neg/945_2.txt
# aclImdb/test/neg/944_2.txt
# aclImdb/test/neg/943_3.txt
# aclImdb/test/neg/942_1.txt
# aclImdb/test/neg/941_2.txt
# aclImdb/test/neg/940_3.txt
# aclImdb/test/neg/939_4.txt
# aclImdb/test/neg/938_1.txt
# aclImdb/test/neg/937_4.txt
# aclImdb/test/neg/936_2.txt
# aclImdb/test/neg/935_4.txt
# aclImdb/test/neg/934_1.txt
# aclImdb/test/neg/933_3.txt
# aclImdb/test/neg/932_2.txt
# aclImdb/test/neg/931_4.txt
# aclImdb/test/neg/930_3.txt
# aclImdb/test/neg/929_2.txt
# aclImdb/test/neg/928_1.txt
# aclImdb/test/neg/927_3.txt
# aclImdb/test/neg/926_4.txt
# aclImdb/test/neg/925_2.txt
# aclImdb/test/neg/924_4.txt
# aclImdb/test/neg/923_4.txt
# aclImdb/test/neg/922_3.txt
# aclImdb/test/neg/921_1.txt
# aclImdb/test/neg/920_1.txt
# aclImdb/test/neg/919_4.txt
# aclImdb/test/neg/918_4.txt
# aclImdb/test/neg/917_4.txt
# aclImdb/test/neg/916_3.txt
# aclImdb/test/neg/915_4.txt
# aclImdb/test/neg/914_1.txt
# aclImdb/test/neg/913_1.txt
# aclImdb/test/neg/912_1.txt
# aclImdb/test/neg/911_1.txt
# aclImdb/test/neg/910_4.txt
# aclImdb/test/neg/909_4.txt
# aclImdb/test/neg/908_3.txt
# aclImdb/test/neg/907_3.txt
# aclImdb/test/neg/906_4.txt
# aclImdb/test/neg/905_3.txt
# aclImdb/test/neg/904_3.txt
# aclImdb/test/neg/903_4.txt
# aclImdb/test/neg/902_3.txt
# aclImdb/test/neg/901_1.txt
# aclImdb/test/neg/900_1.txt
# aclImdb/test/neg/899_3.txt
# aclImdb/test/neg/898_3.txt
# aclImdb/test/neg/897_1.txt
# aclImdb/test/neg/896_1.txt
# aclImdb/test/neg/1151_1.txt
# aclImdb/test/neg/1150_2.txt
# aclImdb/test/neg/1149_3.txt
# aclImdb/test/neg/1148_4.txt
# aclImdb/test/neg/1147_1.txt
# aclImdb/test/neg/1146_4.txt
# aclImdb/test/neg/1145_2.txt
# aclImdb/test/neg/1144_1.txt
# aclImdb/test/neg/1143_1.txt
# aclImdb/test/neg/1142_1.txt
# aclImdb/test/neg/1141_1.txt
# aclImdb/test/neg/1140_1.txt
# aclImdb/test/neg/1139_1.txt
# aclImdb/test/neg/1138_1.txt
# aclImdb/test/neg/1137_1.txt
# aclImdb/test/neg/1136_1.txt
# aclImdb/test/neg/1135_1.txt
# aclImdb/test/neg/1134_1.txt
# aclImdb/test/neg/1133_1.txt
# aclImdb/test/neg/1132_1.txt
# aclImdb/test/neg/1131_2.txt
# aclImdb/test/neg/1130_1.txt
# aclImdb/test/neg/1129_2.txt
# aclImdb/test/neg/1128_1.txt
# aclImdb/test/neg/1127_1.txt
# aclImdb/test/neg/1126_1.txt
# aclImdb/test/neg/1125_1.txt
# aclImdb/test/neg/1124_1.txt
# aclImdb/test/neg/1123_1.txt
# aclImdb/test/neg/1122_1.txt
# aclImdb/test/neg/1121_1.txt
# aclImdb/test/neg/1120_3.txt
# aclImdb/test/neg/1119_2.txt
# aclImdb/test/neg/1118_1.txt
# aclImdb/test/neg/1117_2.txt
# aclImdb/test/neg/1116_1.txt
# aclImdb/test/neg/1115_3.txt
# aclImdb/test/neg/1114_4.txt
# aclImdb/test/neg/1113_3.txt
# aclImdb/test/neg/1112_3.txt
# aclImdb/test/neg/1111_3.txt
# aclImdb/test/neg/1110_4.txt
# aclImdb/test/neg/1109_1.txt
# aclImdb/test/neg/1108_3.txt
# aclImdb/test/neg/1107_2.txt
# aclImdb/test/neg/1106_1.txt
# aclImdb/test/neg/1105_3.txt
# aclImdb/test/neg/1104_4.txt
# aclImdb/test/neg/1103_4.txt
# aclImdb/test/neg/1102_3.txt
# aclImdb/test/neg/1101_4.txt
# aclImdb/test/neg/1100_4.txt
# aclImdb/test/neg/1099_2.txt
# aclImdb/test/neg/1098_4.txt
# aclImdb/test/neg/1097_3.txt
# aclImdb/test/neg/1096_3.txt
# aclImdb/test/neg/1095_2.txt
# aclImdb/test/neg/1094_3.txt
# aclImdb/test/neg/1093_4.txt
# aclImdb/test/neg/1092_4.txt
# aclImdb/test/neg/1091_1.txt
# aclImdb/test/neg/1090_1.txt
# aclImdb/test/neg/1089_1.txt
# aclImdb/test/neg/1088_3.txt
# aclImdb/test/neg/1087_2.txt
# aclImdb/test/neg/1086_2.txt
# aclImdb/test/neg/1085_1.txt
# aclImdb/test/neg/1084_1.txt
# aclImdb/test/neg/1083_3.txt
# aclImdb/test/neg/1082_1.txt
# aclImdb/test/neg/1081_3.txt
# aclImdb/test/neg/1080_1.txt
# aclImdb/test/neg/1079_1.txt
# aclImdb/test/neg/1078_4.txt
# aclImdb/test/neg/1077_3.txt
# aclImdb/test/neg/1076_3.txt
# aclImdb/test/neg/1075_2.txt
# aclImdb/test/neg/1074_2.txt
# aclImdb/test/neg/1073_4.txt
# aclImdb/test/neg/1072_2.txt
# aclImdb/test/neg/1071_2.txt
# aclImdb/test/neg/1070_1.txt
# aclImdb/test/neg/1069_4.txt
# aclImdb/test/neg/1068_3.txt
# aclImdb/test/neg/1067_1.txt
# aclImdb/test/neg/1066_1.txt
# aclImdb/test/neg/1065_1.txt
# aclImdb/test/neg/1064_1.txt
# aclImdb/test/neg/1063_2.txt
# aclImdb/test/neg/1062_2.txt
# aclImdb/test/neg/1061_1.txt
# aclImdb/test/neg/1060_2.txt
# aclImdb/test/neg/1059_1.txt
# aclImdb/test/neg/1058_1.txt
# aclImdb/test/neg/1057_2.txt
# aclImdb/test/neg/1056_3.txt
# aclImdb/test/neg/1055_3.txt
# aclImdb/test/neg/1054_2.txt
# aclImdb/test/neg/1053_4.txt
# aclImdb/test/neg/1052_3.txt
# aclImdb/test/neg/1051_1.txt
# aclImdb/test/neg/1050_4.txt
# aclImdb/test/neg/1049_3.txt
# aclImdb/test/neg/1048_4.txt
# aclImdb/test/neg/1047_4.txt
# aclImdb/test/neg/1046_1.txt
# aclImdb/test/neg/1045_3.txt
# aclImdb/test/neg/1044_3.txt
# aclImdb/test/neg/1043_4.txt
# aclImdb/test/neg/1042_3.txt
# aclImdb/test/neg/1041_2.txt
# aclImdb/test/neg/1040_4.txt
# aclImdb/test/neg/1039_1.txt
# aclImdb/test/neg/1038_1.txt
# aclImdb/test/neg/1037_1.txt
# aclImdb/test/neg/1036_3.txt
# aclImdb/test/neg/1035_3.txt
# aclImdb/test/neg/1034_2.txt
# aclImdb/test/neg/1033_2.txt
# aclImdb/test/neg/1032_1.txt
# aclImdb/test/neg/1031_1.txt
# aclImdb/test/neg/1030_2.txt
# aclImdb/test/neg/1029_2.txt
# aclImdb/test/neg/1028_4.txt
# aclImdb/test/neg/1027_4.txt
# aclImdb/test/neg/1026_2.txt
# aclImdb/test/neg/1025_3.txt
# aclImdb/test/neg/1024_4.txt
# aclImdb/test/neg/1279_3.txt
# aclImdb/test/neg/1278_1.txt
# aclImdb/test/neg/1277_2.txt
# aclImdb/test/neg/1276_3.txt
# aclImdb/test/neg/1275_3.txt
# aclImdb/test/neg/1274_2.txt
# aclImdb/test/neg/1273_3.txt
# aclImdb/test/neg/1272_4.txt
# aclImdb/test/neg/1271_2.txt
# aclImdb/test/neg/1270_4.txt
# aclImdb/test/neg/1269_1.txt
# aclImdb/test/neg/1268_2.txt
# aclImdb/test/neg/1267_3.txt
# aclImdb/test/neg/1266_4.txt
# aclImdb/test/neg/1265_2.txt
# aclImdb/test/neg/1264_1.txt
# aclImdb/test/neg/1263_1.txt
# aclImdb/test/neg/1262_1.txt
# aclImdb/test/neg/1261_1.txt
# aclImdb/test/neg/1260_3.txt
# aclImdb/test/neg/1259_1.txt
# aclImdb/test/neg/1258_3.txt
# aclImdb/test/neg/1257_1.txt
# aclImdb/test/neg/1256_4.txt
# aclImdb/test/neg/1255_4.txt
# aclImdb/test/neg/1254_2.txt
# aclImdb/test/neg/1253_1.txt
# aclImdb/test/neg/1252_4.txt
# aclImdb/test/neg/1251_4.txt
# aclImdb/test/neg/1250_2.txt
# aclImdb/test/neg/1249_1.txt
# aclImdb/test/neg/1248_3.txt
# aclImdb/test/neg/1247_1.txt
# aclImdb/test/neg/1246_1.txt
# aclImdb/test/neg/1245_2.txt
# aclImdb/test/neg/1244_1.txt
# aclImdb/test/neg/1243_2.txt
# aclImdb/test/neg/1242_1.txt
# aclImdb/test/neg/1241_4.txt
# aclImdb/test/neg/1240_1.txt
# aclImdb/test/neg/1239_4.txt
# aclImdb/test/neg/1238_4.txt
# aclImdb/test/neg/1237_2.txt
# aclImdb/test/neg/1236_2.txt
# aclImdb/test/neg/1235_2.txt
# aclImdb/test/neg/1234_3.txt
# aclImdb/test/neg/1233_1.txt
# aclImdb/test/neg/1232_1.txt
# aclImdb/test/neg/1231_4.txt
# aclImdb/test/neg/1230_2.txt
# aclImdb/test/neg/1229_4.txt
# aclImdb/test/neg/1228_4.txt
# aclImdb/test/neg/1227_3.txt
# aclImdb/test/neg/1226_1.txt
# aclImdb/test/neg/1225_1.txt
# aclImdb/test/neg/1224_3.txt
# aclImdb/test/neg/1223_3.txt
# aclImdb/test/neg/1222_2.txt
# aclImdb/test/neg/1221_1.txt
# aclImdb/test/neg/1220_3.txt
# aclImdb/test/neg/1219_1.txt
# aclImdb/test/neg/1218_1.txt
# aclImdb/test/neg/1217_2.txt
# aclImdb/test/neg/1216_1.txt
# aclImdb/test/neg/1215_1.txt
# aclImdb/test/neg/1214_2.txt
# aclImdb/test/neg/1213_3.txt
# aclImdb/test/neg/1212_4.txt
# aclImdb/test/neg/1211_1.txt
# aclImdb/test/neg/1210_1.txt
# aclImdb/test/neg/1209_3.txt
# aclImdb/test/neg/1208_3.txt
# aclImdb/test/neg/1207_4.txt
# aclImdb/test/neg/1206_3.txt
# aclImdb/test/neg/1205_3.txt
# aclImdb/test/neg/1204_1.txt
# aclImdb/test/neg/1203_1.txt
# aclImdb/test/neg/1202_4.txt
# aclImdb/test/neg/1201_2.txt
# aclImdb/test/neg/1200_1.txt
# aclImdb/test/neg/1199_1.txt
# aclImdb/test/neg/1198_4.txt
# aclImdb/test/neg/1197_3.txt
# aclImdb/test/neg/1196_2.txt
# aclImdb/test/neg/1195_3.txt
# aclImdb/test/neg/1194_2.txt
# aclImdb/test/neg/1193_2.txt
# aclImdb/test/neg/1192_1.txt
# aclImdb/test/neg/1191_1.txt
# aclImdb/test/neg/1190_1.txt
# aclImdb/test/neg/1189_3.txt
# aclImdb/test/neg/1188_2.txt
# aclImdb/test/neg/1187_1.txt
# aclImdb/test/neg/1186_1.txt
# aclImdb/test/neg/1185_1.txt
# aclImdb/test/neg/1184_3.txt
# aclImdb/test/neg/1183_2.txt
# aclImdb/test/neg/1182_2.txt
# aclImdb/test/neg/1181_1.txt
# aclImdb/test/neg/1180_1.txt
# aclImdb/test/neg/1179_3.txt
# aclImdb/test/neg/1178_4.txt
# aclImdb/test/neg/1177_3.txt
# aclImdb/test/neg/1176_4.txt
# aclImdb/test/neg/1175_2.txt
# aclImdb/test/neg/1174_1.txt
# aclImdb/test/neg/1173_1.txt
# aclImdb/test/neg/1172_1.txt
# aclImdb/test/neg/1171_1.txt
# aclImdb/test/neg/1170_1.txt
# aclImdb/test/neg/1169_1.txt
# aclImdb/test/neg/1168_1.txt
# aclImdb/test/neg/1167_4.txt
# aclImdb/test/neg/1166_1.txt
# aclImdb/test/neg/1165_2.txt
# aclImdb/test/neg/1164_1.txt
# aclImdb/test/neg/1163_1.txt
# aclImdb/test/neg/1162_1.txt
# aclImdb/test/neg/1161_1.txt
# aclImdb/test/neg/1160_1.txt
# aclImdb/test/neg/1159_1.txt
# aclImdb/test/neg/1158_3.txt
# aclImdb/test/neg/1157_1.txt
# aclImdb/test/neg/1156_2.txt
# aclImdb/test/neg/1155_2.txt
# aclImdb/test/neg/1154_4.txt
# aclImdb/test/neg/1153_4.txt
# aclImdb/test/neg/1152_3.txt
# aclImdb/test/neg/1407_4.txt
# aclImdb/test/neg/1406_4.txt
# aclImdb/test/neg/1405_2.txt
# aclImdb/test/neg/1404_4.txt
# aclImdb/test/neg/1403_4.txt
# aclImdb/test/neg/1402_4.txt
# aclImdb/test/neg/1401_4.txt
# aclImdb/test/neg/1400_4.txt
# aclImdb/test/neg/1399_1.txt
# aclImdb/test/neg/1398_1.txt
# aclImdb/test/neg/1397_1.txt
# aclImdb/test/neg/1396_1.txt
# aclImdb/test/neg/1395_1.txt
# aclImdb/test/neg/1394_1.txt
# aclImdb/test/neg/1393_1.txt
# aclImdb/test/neg/1392_1.txt
# aclImdb/test/neg/1391_1.txt
# aclImdb/test/neg/1390_1.txt
# aclImdb/test/neg/1389_3.txt
# aclImdb/test/neg/1388_1.txt
# aclImdb/test/neg/1387_1.txt
# aclImdb/test/neg/1386_1.txt
# aclImdb/test/neg/1385_1.txt
# aclImdb/test/neg/1384_2.txt
# aclImdb/test/neg/1383_1.txt
# aclImdb/test/neg/1382_1.txt
# aclImdb/test/neg/1381_1.txt
# aclImdb/test/neg/1380_2.txt
# aclImdb/test/neg/1379_1.txt
# aclImdb/test/neg/1378_1.txt
# aclImdb/test/neg/1377_2.txt
# aclImdb/test/neg/1376_3.txt
# aclImdb/test/neg/1375_1.txt
# aclImdb/test/neg/1374_1.txt
# aclImdb/test/neg/1373_1.txt
# aclImdb/test/neg/1372_4.txt
# aclImdb/test/neg/1371_1.txt
# aclImdb/test/neg/1370_4.txt
# aclImdb/test/neg/1369_3.txt
# aclImdb/test/neg/1368_1.txt
# aclImdb/test/neg/1367_3.txt
# aclImdb/test/neg/1366_3.txt
# aclImdb/test/neg/1365_4.txt
# aclImdb/test/neg/1364_3.txt
# aclImdb/test/neg/1363_1.txt
# aclImdb/test/neg/1362_3.txt
# aclImdb/test/neg/1361_3.txt
# aclImdb/test/neg/1360_3.txt
# aclImdb/test/neg/1359_2.txt
# aclImdb/test/neg/1358_3.txt
# aclImdb/test/neg/1357_4.txt
# aclImdb/test/neg/1356_4.txt
# aclImdb/test/neg/1355_2.txt
# aclImdb/test/neg/1354_4.txt
# aclImdb/test/neg/1353_1.txt
# aclImdb/test/neg/1352_2.txt
# aclImdb/test/neg/1351_1.txt
# aclImdb/test/neg/1350_3.txt
# aclImdb/test/neg/1349_4.txt
# aclImdb/test/neg/1348_1.txt
# aclImdb/test/neg/1347_3.txt
# aclImdb/test/neg/1346_1.txt
# aclImdb/test/neg/1345_1.txt
# aclImdb/test/neg/1344_3.txt
# aclImdb/test/neg/1343_2.txt
# aclImdb/test/neg/1342_2.txt
# aclImdb/test/neg/1341_3.txt
# aclImdb/test/neg/1340_3.txt
# aclImdb/test/neg/1339_2.txt
# aclImdb/test/neg/1338_1.txt
# aclImdb/test/neg/1337_4.txt
# aclImdb/test/neg/1336_1.txt
# aclImdb/test/neg/1335_4.txt
# aclImdb/test/neg/1334_3.txt
# aclImdb/test/neg/1333_3.txt
# aclImdb/test/neg/1332_1.txt
# aclImdb/test/neg/1331_1.txt
# aclImdb/test/neg/1330_1.txt
# aclImdb/test/neg/1329_4.txt
# aclImdb/test/neg/1328_1.txt
# aclImdb/test/neg/1327_3.txt
# aclImdb/test/neg/1326_4.txt
# aclImdb/test/neg/1325_3.txt
# aclImdb/test/neg/1324_1.txt
# aclImdb/test/neg/1323_3.txt
# aclImdb/test/neg/1322_1.txt
# aclImdb/test/neg/1321_4.txt
# aclImdb/test/neg/1320_1.txt
# aclImdb/test/neg/1319_3.txt
# aclImdb/test/neg/1318_2.txt
# aclImdb/test/neg/1317_2.txt
# aclImdb/test/neg/1316_2.txt
# aclImdb/test/neg/1315_4.txt
# aclImdb/test/neg/1314_1.txt
# aclImdb/test/neg/1313_3.txt
# aclImdb/test/neg/1312_1.txt
# aclImdb/test/neg/1311_2.txt
# aclImdb/test/neg/1310_2.txt
# aclImdb/test/neg/1309_2.txt
# aclImdb/test/neg/1308_3.txt
# aclImdb/test/neg/1307_1.txt
# aclImdb/test/neg/1306_1.txt
# aclImdb/test/neg/1305_1.txt
# aclImdb/test/neg/1304_3.txt
# aclImdb/test/neg/1303_3.txt
# aclImdb/test/neg/1302_1.txt
# aclImdb/test/neg/1301_1.txt
# aclImdb/test/neg/1300_1.txt
# aclImdb/test/neg/1299_1.txt
# aclImdb/test/neg/1298_1.txt
# aclImdb/test/neg/1297_2.txt
# aclImdb/test/neg/1296_1.txt
# aclImdb/test/neg/1295_1.txt
# aclImdb/test/neg/1294_4.txt
# aclImdb/test/neg/1293_1.txt
# aclImdb/test/neg/1292_3.txt
# aclImdb/test/neg/1291_1.txt
# aclImdb/test/neg/1290_2.txt
# aclImdb/test/neg/1289_1.txt
# aclImdb/test/neg/1288_1.txt
# aclImdb/test/neg/1287_1.txt
# aclImdb/test/neg/1286_1.txt
# aclImdb/test/neg/1285_1.txt
# aclImdb/test/neg/1284_1.txt
# aclImdb/test/neg/1283_1.txt
# aclImdb/test/neg/1282_3.txt
# aclImdb/test/neg/1281_2.txt
# aclImdb/test/neg/1280_3.txt
# aclImdb/test/neg/1535_3.txt
# aclImdb/test/neg/1534_4.txt
# aclImdb/test/neg/1533_4.txt
# aclImdb/test/neg/1532_4.txt
# aclImdb/test/neg/1531_3.txt
# aclImdb/test/neg/1530_1.txt
# aclImdb/test/neg/1529_4.txt
# aclImdb/test/neg/1528_2.txt
# aclImdb/test/neg/1527_3.txt
# aclImdb/test/neg/1526_3.txt
# aclImdb/test/neg/1525_1.txt
# aclImdb/test/neg/1524_3.txt
# aclImdb/test/neg/1523_4.txt
# aclImdb/test/neg/1522_1.txt
# aclImdb/test/neg/1521_1.txt
# aclImdb/test/neg/1520_2.txt
# aclImdb/test/neg/1519_1.txt
# aclImdb/test/neg/1518_1.txt
# aclImdb/test/neg/1517_1.txt
# aclImdb/test/neg/1516_1.txt
# aclImdb/test/neg/1515_1.txt
# aclImdb/test/neg/1514_1.txt
# aclImdb/test/neg/1513_3.txt
# aclImdb/test/neg/1512_1.txt
# aclImdb/test/neg/1511_2.txt
# aclImdb/test/neg/1510_1.txt
# aclImdb/test/neg/1509_2.txt
# aclImdb/test/neg/1508_2.txt
# aclImdb/test/neg/1507_1.txt
# aclImdb/test/neg/1506_2.txt
# aclImdb/test/neg/1505_3.txt
# aclImdb/test/neg/1504_1.txt
# aclImdb/test/neg/1503_1.txt
# aclImdb/test/neg/1502_1.txt
# aclImdb/test/neg/1501_1.txt
# aclImdb/test/neg/1500_2.txt
# aclImdb/test/neg/1499_3.txt
# aclImdb/test/neg/1498_1.txt
# aclImdb/test/neg/1497_1.txt
# aclImdb/test/neg/1496_1.txt
# aclImdb/test/neg/1495_1.txt
# aclImdb/test/neg/1494_4.txt
# aclImdb/test/neg/1493_4.txt
# aclImdb/test/neg/1492_3.txt
# aclImdb/test/neg/1491_1.txt
# aclImdb/test/neg/1490_3.txt
# aclImdb/test/neg/1489_4.txt
# aclImdb/test/neg/1488_4.txt
# aclImdb/test/neg/1487_3.txt
# aclImdb/test/neg/1486_4.txt
# aclImdb/test/neg/1485_3.txt
# aclImdb/test/neg/1484_4.txt
# aclImdb/test/neg/1483_3.txt
# aclImdb/test/neg/1482_4.txt
# aclImdb/test/neg/1481_1.txt
# aclImdb/test/neg/1480_1.txt
# aclImdb/test/neg/1479_4.txt
# aclImdb/test/neg/1478_4.txt
# aclImdb/test/neg/1477_4.txt
# aclImdb/test/neg/1476_3.txt
# aclImdb/test/neg/1475_1.txt
# aclImdb/test/neg/1474_4.txt
# aclImdb/test/neg/1473_3.txt
# aclImdb/test/neg/1472_1.txt
# aclImdb/test/neg/1471_2.txt
# aclImdb/test/neg/1470_1.txt
# aclImdb/test/neg/1469_1.txt
# aclImdb/test/neg/1468_1.txt
# aclImdb/test/neg/1467_1.txt
# aclImdb/test/neg/1466_3.txt
# aclImdb/test/neg/1465_3.txt
# aclImdb/test/neg/1464_1.txt
# aclImdb/test/neg/1463_4.txt
# aclImdb/test/neg/1462_1.txt
# aclImdb/test/neg/1461_3.txt
# aclImdb/test/neg/1460_2.txt
# aclImdb/test/neg/1459_4.txt
# aclImdb/test/neg/1458_2.txt
# aclImdb/test/neg/1457_1.txt
# aclImdb/test/neg/1456_4.txt
# aclImdb/test/neg/1455_4.txt
# aclImdb/test/neg/1454_4.txt
# aclImdb/test/neg/1453_2.txt
# aclImdb/test/neg/1452_3.txt
# aclImdb/test/neg/1451_1.txt
# aclImdb/test/neg/1450_3.txt
# aclImdb/test/neg/1449_4.txt
# aclImdb/test/neg/1448_2.txt
# aclImdb/test/neg/1447_1.txt
# aclImdb/test/neg/1446_3.txt
# aclImdb/test/neg/1445_4.txt
# aclImdb/test/neg/1444_1.txt
# aclImdb/test/neg/1443_2.txt
# aclImdb/test/neg/1442_1.txt
# aclImdb/test/neg/1441_1.txt
# aclImdb/test/neg/1440_1.txt
# aclImdb/test/neg/1439_1.txt
# aclImdb/test/neg/1438_1.txt
# aclImdb/test/neg/1437_1.txt
# aclImdb/test/neg/1436_1.txt
# aclImdb/test/neg/1435_3.txt
# aclImdb/test/neg/1434_4.txt
# aclImdb/test/neg/1433_3.txt
# aclImdb/test/neg/1432_3.txt
# aclImdb/test/neg/1431_3.txt
# aclImdb/test/neg/1430_3.txt
# aclImdb/test/neg/1429_3.txt
# aclImdb/test/neg/1428_3.txt
# aclImdb/test/neg/1427_4.txt
# aclImdb/test/neg/1426_1.txt
# aclImdb/test/neg/1425_1.txt
# aclImdb/test/neg/1424_4.txt
# aclImdb/test/neg/1423_1.txt
# aclImdb/test/neg/1422_4.txt
# aclImdb/test/neg/1421_1.txt
# aclImdb/test/neg/1420_4.txt
# aclImdb/test/neg/1419_4.txt
# aclImdb/test/neg/1418_3.txt
# aclImdb/test/neg/1417_4.txt
# aclImdb/test/neg/1416_1.txt
# aclImdb/test/neg/1415_1.txt
# aclImdb/test/neg/1414_4.txt
# aclImdb/test/neg/1413_3.txt
# aclImdb/test/neg/1412_3.txt
# aclImdb/test/neg/1411_4.txt
# aclImdb/test/neg/1410_2.txt
# aclImdb/test/neg/1409_4.txt
# aclImdb/test/neg/1408_3.txt
# aclImdb/test/neg/1663_1.txt
# aclImdb/test/neg/1662_1.txt
# aclImdb/test/neg/1661_1.txt
# aclImdb/test/neg/1660_1.txt
# aclImdb/test/neg/1659_1.txt
# aclImdb/test/neg/1658_2.txt
# aclImdb/test/neg/1657_4.txt
# aclImdb/test/neg/1656_4.txt
# aclImdb/test/neg/1655_1.txt
# aclImdb/test/neg/1654_1.txt
# aclImdb/test/neg/1653_1.txt
# aclImdb/test/neg/1652_1.txt
# aclImdb/test/neg/1651_2.txt
# aclImdb/test/neg/1650_4.txt
# aclImdb/test/neg/1649_2.txt
# aclImdb/test/neg/1648_3.txt
# aclImdb/test/neg/1647_1.txt
# aclImdb/test/neg/1646_1.txt
# aclImdb/test/neg/1645_2.txt
# aclImdb/test/neg/1644_4.txt
# aclImdb/test/neg/1643_1.txt
# aclImdb/test/neg/1642_2.txt
# aclImdb/test/neg/1641_1.txt
# aclImdb/test/neg/1640_1.txt
# aclImdb/test/neg/1639_1.txt
# aclImdb/test/neg/1638_1.txt
# aclImdb/test/neg/1637_2.txt
# aclImdb/test/neg/1636_2.txt
# aclImdb/test/neg/1635_1.txt
# aclImdb/test/neg/1634_2.txt
# aclImdb/test/neg/1633_1.txt
# aclImdb/test/neg/1632_1.txt
# aclImdb/test/neg/1631_1.txt
# aclImdb/test/neg/1630_1.txt
# aclImdb/test/neg/1629_1.txt
# aclImdb/test/neg/1628_1.txt
# aclImdb/test/neg/1627_1.txt
# aclImdb/test/neg/1626_3.txt
# aclImdb/test/neg/1625_3.txt
# aclImdb/test/neg/1624_1.txt
# aclImdb/test/neg/1623_2.txt
# aclImdb/test/neg/1622_1.txt
# aclImdb/test/neg/1621_1.txt
# aclImdb/test/neg/1620_1.txt
# aclImdb/test/neg/1619_3.txt
# aclImdb/test/neg/1618_4.txt
# aclImdb/test/neg/1617_1.txt
# aclImdb/test/neg/1616_3.txt
# aclImdb/test/neg/1615_1.txt
# aclImdb/test/neg/1614_4.txt
# aclImdb/test/neg/1613_3.txt
# aclImdb/test/neg/1612_2.txt
# aclImdb/test/neg/1611_2.txt
# aclImdb/test/neg/1610_4.txt
# aclImdb/test/neg/1609_1.txt
# aclImdb/test/neg/1608_1.txt
# aclImdb/test/neg/1607_3.txt
# aclImdb/test/neg/1606_1.txt
# aclImdb/test/neg/1605_3.txt
# aclImdb/test/neg/1604_1.txt
# aclImdb/test/neg/1603_4.txt
# aclImdb/test/neg/1602_1.txt
# aclImdb/test/neg/1601_4.txt
# aclImdb/test/neg/1600_2.txt
# aclImdb/test/neg/1599_1.txt
# aclImdb/test/neg/1598_1.txt
# aclImdb/test/neg/1597_1.txt
# aclImdb/test/neg/1596_3.txt
# aclImdb/test/neg/1595_1.txt
# aclImdb/test/neg/1594_4.txt
# aclImdb/test/neg/1593_4.txt
# aclImdb/test/neg/1592_2.txt
# aclImdb/test/neg/1591_2.txt
# aclImdb/test/neg/1590_1.txt
# aclImdb/test/neg/1589_1.txt
# aclImdb/test/neg/1588_3.txt
# aclImdb/test/neg/1587_3.txt
# aclImdb/test/neg/1586_1.txt
# aclImdb/test/neg/1585_1.txt
# aclImdb/test/neg/1584_1.txt
# aclImdb/test/neg/1583_2.txt
# aclImdb/test/neg/1582_2.txt
# aclImdb/test/neg/1581_1.txt
# aclImdb/test/neg/1580_1.txt
# aclImdb/test/neg/1579_4.txt
# aclImdb/test/neg/1578_4.txt
# aclImdb/test/neg/1577_4.txt
# aclImdb/test/neg/1576_2.txt
# aclImdb/test/neg/1575_1.txt
# aclImdb/test/neg/1574_1.txt
# aclImdb/test/neg/1573_3.txt
# aclImdb/test/neg/1572_3.txt
# aclImdb/test/neg/1571_4.txt
# aclImdb/test/neg/1570_2.txt
# aclImdb/test/neg/1569_3.txt
# aclImdb/test/neg/1568_4.txt
# aclImdb/test/neg/1567_1.txt
# aclImdb/test/neg/1566_4.txt
# aclImdb/test/neg/1565_4.txt
# aclImdb/test/neg/1564_1.txt
# aclImdb/test/neg/1563_2.txt
# aclImdb/test/neg/1562_4.txt
# aclImdb/test/neg/1561_3.txt
# aclImdb/test/neg/1560_4.txt
# aclImdb/test/neg/1559_2.txt
# aclImdb/test/neg/1558_2.txt
# aclImdb/test/neg/1557_2.txt
# aclImdb/test/neg/1556_1.txt
# aclImdb/test/neg/1555_2.txt
# aclImdb/test/neg/1554_1.txt
# aclImdb/test/neg/1553_3.txt
# aclImdb/test/neg/1552_1.txt
# aclImdb/test/neg/1551_4.txt
# aclImdb/test/neg/1550_2.txt
# aclImdb/test/neg/1549_1.txt
# aclImdb/test/neg/1548_1.txt
# aclImdb/test/neg/1547_1.txt
# aclImdb/test/neg/1546_1.txt
# aclImdb/test/neg/1545_1.txt
# aclImdb/test/neg/1544_3.txt
# aclImdb/test/neg/1543_3.txt
# aclImdb/test/neg/1542_3.txt
# aclImdb/test/neg/1541_2.txt
# aclImdb/test/neg/1540_3.txt
# aclImdb/test/neg/1539_2.txt
# aclImdb/test/neg/1538_2.txt
# aclImdb/test/neg/1537_2.txt
# aclImdb/test/neg/1536_3.txt
# aclImdb/test/neg/1791_1.txt
# aclImdb/test/neg/1790_2.txt
# aclImdb/test/neg/1789_2.txt
# aclImdb/test/neg/1788_1.txt
# aclImdb/test/neg/1787_1.txt
# aclImdb/test/neg/1786_3.txt
# aclImdb/test/neg/1785_1.txt
# aclImdb/test/neg/1784_2.txt
# aclImdb/test/neg/1783_4.txt
# aclImdb/test/neg/1782_1.txt
# aclImdb/test/neg/1781_1.txt
# aclImdb/test/neg/1780_3.txt
# aclImdb/test/neg/1779_1.txt
# aclImdb/test/neg/1778_1.txt
# aclImdb/test/neg/1777_4.txt
# aclImdb/test/neg/1776_4.txt
# aclImdb/test/neg/1775_4.txt
# aclImdb/test/neg/1774_4.txt
# aclImdb/test/neg/1773_1.txt
# aclImdb/test/neg/1772_1.txt
# aclImdb/test/neg/1771_4.txt
# aclImdb/test/neg/1770_2.txt
# aclImdb/test/neg/1769_4.txt
# aclImdb/test/neg/1768_3.txt
# aclImdb/test/neg/1767_2.txt
# aclImdb/test/neg/1766_2.txt
# aclImdb/test/neg/1765_1.txt
# aclImdb/test/neg/1764_1.txt
# aclImdb/test/neg/1763_1.txt
# aclImdb/test/neg/1762_1.txt
# aclImdb/test/neg/1761_1.txt
# aclImdb/test/neg/1760_1.txt
# aclImdb/test/neg/1759_3.txt
# aclImdb/test/neg/1758_2.txt
# aclImdb/test/neg/1757_1.txt
# aclImdb/test/neg/1756_1.txt
# aclImdb/test/neg/1755_1.txt
# aclImdb/test/neg/1754_1.txt
# aclImdb/test/neg/1753_1.txt
# aclImdb/test/neg/1752_3.txt
# aclImdb/test/neg/1751_4.txt
# aclImdb/test/neg/1750_4.txt
# aclImdb/test/neg/1749_4.txt
# aclImdb/test/neg/1748_1.txt
# aclImdb/test/neg/1747_1.txt
# aclImdb/test/neg/1746_3.txt
# aclImdb/test/neg/1745_1.txt
# aclImdb/test/neg/1744_1.txt
# aclImdb/test/neg/1743_4.txt
# aclImdb/test/neg/1742_3.txt
# aclImdb/test/neg/1741_4.txt
# aclImdb/test/neg/1740_3.txt
# aclImdb/test/neg/1739_3.txt
# aclImdb/test/neg/1738_4.txt
# aclImdb/test/neg/1737_1.txt
# aclImdb/test/neg/1736_1.txt
# aclImdb/test/neg/1735_1.txt
# ...
# aclImdb/test/pos/1020_7.txt
# aclImdb/test/pos/1019_10.txt
# aclImdb/test/pos/1018_7.txt
# aclImdb/test/pos/1017_7.txt
# aclImdb/test/pos/1016_7.txt
# aclImdb/test/pos/1015_8.txt
# aclImdb/test/pos/1014_8.txt
# aclImdb/test/pos/1013_7.txt
# aclImdb/test/pos/1012_8.txt
# aclImdb/test/pos/1011_8.txt
# aclImdb/test/pos/1010_9.txt
# aclImdb/test/pos/1009_8.txt
# aclImdb/test/pos/1008_10.txt
# aclImdb/test/pos/1007_9.txt
# aclImdb/test/pos/1006_8.txt
# aclImdb/test/pos/1005_7.txt
# aclImdb/test/pos/1004_10.txt
# aclImdb/test/pos/1003_8.txt
# aclImdb/test/pos/1002_9.txt
# aclImdb/test/pos/1001_10.txt
# aclImdb/test/pos/1000_9.txt
# aclImdb/test/pos/999_8.txt
# aclImdb/test/pos/998_7.txt
# aclImdb/test/pos/997_7.txt
# aclImdb/test/pos/996_7.txt
# aclImdb/test/pos/995_7.txt
# aclImdb/test/pos/994_7.txt
# aclImdb/test/pos/993_8.txt
# aclImdb/test/pos/992_7.txt
# aclImdb/test/pos/991_7.txt
# aclImdb/test/pos/990_7.txt
# aclImdb/test/pos/989_7.txt
# aclImdb/test/pos/988_8.txt
# aclImdb/test/pos/987_7.txt
# aclImdb/test/pos/986_10.txt
# aclImdb/test/pos/985_10.txt
# aclImdb/test/pos/984_8.txt
# aclImdb/test/pos/983_7.txt
# aclImdb/test/pos/982_8.txt
# aclImdb/test/pos/981_9.txt
# aclImdb/test/pos/980_7.txt
# aclImdb/test/pos/979_10.txt
# aclImdb/test/pos/978_7.txt
# aclImdb/test/pos/977_9.txt
# aclImdb/test/pos/976_8.txt
# aclImdb/test/pos/975_7.txt
# aclImdb/test/pos/974_10.txt
# aclImdb/test/pos/973_10.txt
# aclImdb/test/pos/972_7.txt
# aclImdb/test/pos/971_10.txt
# aclImdb/test/pos/970_7.txt
# aclImdb/test/pos/969_9.txt
# aclImdb/test/pos/968_8.txt
# aclImdb/test/pos/967_7.txt
# aclImdb/test/pos/966_10.txt
# aclImdb/test/pos/965_9.txt
# aclImdb/test/pos/964_7.txt
# aclImdb/test/pos/963_8.txt
# aclImdb/test/pos/962_9.txt
# aclImdb/test/pos/961_8.txt
# aclImdb/test/pos/960_8.txt
# aclImdb/test/pos/959_8.txt
# aclImdb/test/pos/958_10.txt
# aclImdb/test/pos/957_10.txt
# aclImdb/test/pos/956_10.txt
# aclImdb/test/pos/955_10.txt
# aclImdb/test/pos/954_8.txt
# aclImdb/test/pos/953_10.txt
# aclImdb/test/pos/952_10.txt
# aclImdb/test/pos/951_10.txt
# aclImdb/test/pos/950_10.txt
# aclImdb/test/pos/949_8.txt
# aclImdb/test/pos/948_8.txt
# aclImdb/test/pos/947_8.txt
# aclImdb/test/pos/946_7.txt
# aclImdb/test/pos/945_7.txt
# aclImdb/test/pos/944_8.txt
# aclImdb/test/pos/943_8.txt
# aclImdb/test/pos/942_10.txt
# aclImdb/test/pos/941_10.txt
# aclImdb/test/pos/940_7.txt
# aclImdb/test/pos/939_8.txt
# aclImdb/test/pos/938_10.txt
# aclImdb/test/pos/937_10.txt
# aclImdb/test/pos/936_9.txt
# aclImdb/test/pos/935_10.txt
# aclImdb/test/pos/934_10.txt
# aclImdb/test/pos/933_10.txt
# aclImdb/test/pos/932_9.txt
# aclImdb/test/pos/931_9.txt
# aclImdb/test/pos/930_10.txt
# aclImdb/test/pos/929_10.txt
# aclImdb/test/pos/928_10.txt
# aclImdb/test/pos/927_10.txt
# aclImdb/test/pos/926_10.txt
# aclImdb/test/pos/925_10.txt
# aclImdb/test/pos/924_10.txt
# aclImdb/test/pos/923_10.txt
# aclImdb/test/pos/922_8.txt
# aclImdb/test/pos/921_9.txt
# aclImdb/test/pos/920_10.txt
# aclImdb/test/pos/919_10.txt
# aclImdb/test/pos/918_10.txt
# aclImdb/test/pos/917_9.txt
# aclImdb/test/pos/916_10.txt
# aclImdb/test/pos/915_10.txt
# aclImdb/test/pos/914_10.txt
# aclImdb/test/pos/913_10.txt
# aclImdb/test/pos/912_10.txt
# aclImdb/test/pos/911_10.txt
# aclImdb/test/pos/910_10.txt
# aclImdb/test/pos/909_10.txt
# aclImdb/test/pos/908_9.txt
# aclImdb/test/pos/907_7.txt
# aclImdb/test/pos/906_7.txt
# aclImdb/test/pos/905_10.txt
# aclImdb/test/pos/904_10.txt
# aclImdb/test/pos/903_10.txt
# aclImdb/test/pos/902_10.txt
# aclImdb/test/pos/901_9.txt
# aclImdb/test/pos/900_9.txt
# aclImdb/test/pos/899_9.txt
# aclImdb/test/pos/898_9.txt
# aclImdb/test/pos/897_8.txt
# aclImdb/test/pos/896_8.txt
# aclImdb/test/pos/1151_9.txt
# aclImdb/test/pos/1150_9.txt
# aclImdb/test/pos/1149_8.txt
# aclImdb/test/pos/1148_8.txt
# aclImdb/test/pos/1147_10.txt
# aclImdb/test/pos/1146_10.txt
# aclImdb/test/pos/1145_9.txt
# aclImdb/test/pos/1144_10.txt
# aclImdb/test/pos/1143_8.txt
# aclImdb/test/pos/1142_7.txt
# aclImdb/test/pos/1141_10.txt
# aclImdb/test/pos/1140_9.txt
# aclImdb/test/pos/1139_10.txt
# aclImdb/test/pos/1138_8.txt
# aclImdb/test/pos/1137_10.txt
# aclImdb/test/pos/1136_8.txt
# aclImdb/test/pos/1135_8.txt
# aclImdb/test/pos/1134_8.txt
# aclImdb/test/pos/1133_8.txt
# aclImdb/test/pos/1132_8.txt
# aclImdb/test/pos/1131_10.txt
# aclImdb/test/pos/1130_8.txt
# aclImdb/test/pos/1129_9.txt
# aclImdb/test/pos/1128_10.txt
# aclImdb/test/pos/1127_10.txt
# aclImdb/test/pos/1126_10.txt
# aclImdb/test/pos/1125_10.txt
# aclImdb/test/pos/1124_8.txt
# aclImdb/test/pos/1123_10.txt
# aclImdb/test/pos/1122_8.txt
# aclImdb/test/pos/1121_7.txt
# aclImdb/test/pos/1120_9.txt
# aclImdb/test/pos/1119_8.txt
# aclImdb/test/pos/1118_7.txt
# aclImdb/test/pos/1117_9.txt
# aclImdb/test/pos/1116_7.txt
# aclImdb/test/pos/1115_9.txt
# aclImdb/test/pos/1114_10.txt
# aclImdb/test/pos/1113_8.txt
# aclImdb/test/pos/1112_8.txt
# aclImdb/test/pos/1111_7.txt
# aclImdb/test/pos/1110_7.txt
# aclImdb/test/pos/1109_10.txt
# aclImdb/test/pos/1108_8.txt
# aclImdb/test/pos/1107_9.txt
# aclImdb/test/pos/1106_9.txt
# aclImdb/test/pos/1105_10.txt
# aclImdb/test/pos/1104_9.txt
# aclImdb/test/pos/1103_10.txt
# aclImdb/test/pos/1102_9.txt
# aclImdb/test/pos/1101_8.txt
# aclImdb/test/pos/1100_9.txt
# aclImdb/test/pos/1099_7.txt
# aclImdb/test/pos/1098_9.txt
# aclImdb/test/pos/1097_9.txt
# aclImdb/test/pos/1096_7.txt
# aclImdb/test/pos/1095_8.txt
# aclImdb/test/pos/1094_7.txt
# aclImdb/test/pos/1093_8.txt
# aclImdb/test/pos/1092_9.txt
# aclImdb/test/pos/1091_7.txt
# aclImdb/test/pos/1090_8.txt
# aclImdb/test/pos/1089_10.txt
# aclImdb/test/pos/1088_8.txt
# aclImdb/test/pos/1087_10.txt
# aclImdb/test/pos/1086_10.txt
# aclImdb/test/pos/1085_9.txt
# aclImdb/test/pos/1084_8.txt
# aclImdb/test/pos/1083_7.txt
# aclImdb/test/pos/1082_9.txt
# aclImdb/test/pos/1081_10.txt
# aclImdb/test/pos/1080_8.txt
# aclImdb/test/pos/1079_8.txt
# aclImdb/test/pos/1078_9.txt
# aclImdb/test/pos/1077_10.txt
# aclImdb/test/pos/1076_8.txt
# aclImdb/test/pos/1075_9.txt
# aclImdb/test/pos/1074_7.txt
# aclImdb/test/pos/1073_8.txt
# aclImdb/test/pos/1072_8.txt
# aclImdb/test/pos/1071_9.txt
# aclImdb/test/pos/1070_10.txt
# aclImdb/test/pos/1069_10.txt
# aclImdb/test/pos/1068_10.txt
# aclImdb/test/pos/1067_9.txt
# aclImdb/test/pos/1066_8.txt
# aclImdb/test/pos/1065_9.txt
# aclImdb/test/pos/1064_8.txt
# aclImdb/test/pos/1063_10.txt
# aclImdb/test/pos/1062_8.txt
# aclImdb/test/pos/1061_8.txt
# aclImdb/test/pos/1060_8.txt
# aclImdb/test/pos/1059_10.txt
# aclImdb/test/pos/1058_10.txt
# aclImdb/test/pos/1057_8.txt
# aclImdb/test/pos/1056_8.txt
# aclImdb/test/pos/1055_10.txt
# aclImdb/test/pos/1054_9.txt
# aclImdb/test/pos/1053_10.txt
# aclImdb/test/pos/1052_10.txt
# aclImdb/test/pos/1051_10.txt
# aclImdb/test/pos/1050_9.txt
# aclImdb/test/pos/1049_9.txt
# aclImdb/test/pos/1048_8.txt
# aclImdb/test/pos/1047_8.txt
# aclImdb/test/pos/1046_9.txt
# aclImdb/test/pos/1045_9.txt
# aclImdb/test/pos/1044_8.txt
# aclImdb/test/pos/1043_9.txt
# aclImdb/test/pos/1042_7.txt
# aclImdb/test/pos/1041_10.txt
# aclImdb/test/pos/1040_9.txt
# aclImdb/test/pos/1039_10.txt
# aclImdb/test/pos/1038_10.txt
# aclImdb/test/pos/1037_10.txt
# aclImdb/test/pos/1036_10.txt
# aclImdb/test/pos/1035_9.txt
# aclImdb/test/pos/1034_10.txt
# aclImdb/test/pos/1033_9.txt
# aclImdb/test/pos/1032_10.txt
# aclImdb/test/pos/1031_10.txt
# aclImdb/test/pos/1030_9.txt
# aclImdb/test/pos/1029_10.txt
# aclImdb/test/pos/1028_10.txt
# aclImdb/test/pos/1027_9.txt
# aclImdb/test/pos/1026_10.txt
# aclImdb/test/pos/1025_10.txt
# aclImdb/test/pos/1024_9.txt
# aclImdb/test/pos/1279_8.txt
# aclImdb/test/pos/1278_10.txt
# aclImdb/test/pos/1277_7.txt
# aclImdb/test/pos/1276_9.txt
# aclImdb/test/pos/1275_7.txt
# aclImdb/test/pos/1274_7.txt
# aclImdb/test/pos/1273_7.txt
# aclImdb/test/pos/1272_8.txt
# aclImdb/test/pos/1271_9.txt
# aclImdb/test/pos/1270_8.txt
# aclImdb/test/pos/1269_10.txt
# aclImdb/test/pos/1268_8.txt
# aclImdb/test/pos/1267_8.txt
# aclImdb/test/pos/1266_8.txt
# aclImdb/test/pos/1265_10.txt
# aclImdb/test/pos/1264_9.txt
# aclImdb/test/pos/1263_9.txt
# aclImdb/test/pos/1262_8.txt
# aclImdb/test/pos/1261_7.txt
# aclImdb/test/pos/1260_10.txt
# aclImdb/test/pos/1259_10.txt
# aclImdb/test/pos/1258_10.txt
# aclImdb/test/pos/1257_10.txt
# aclImdb/test/pos/1256_7.txt
# aclImdb/test/pos/1255_8.txt
# aclImdb/test/pos/1254_10.txt
# aclImdb/test/pos/1253_9.txt
# aclImdb/test/pos/1252_7.txt
# aclImdb/test/pos/1251_10.txt
# aclImdb/test/pos/1250_9.txt
# aclImdb/test/pos/1249_9.txt
# aclImdb/test/pos/1248_8.txt
# aclImdb/test/pos/1247_9.txt
# aclImdb/test/pos/1246_9.txt
# aclImdb/test/pos/1245_8.txt
# aclImdb/test/pos/1244_9.txt
# aclImdb/test/pos/1243_7.txt
# aclImdb/test/pos/1242_7.txt
# aclImdb/test/pos/1241_7.txt
# aclImdb/test/pos/1240_9.txt
# aclImdb/test/pos/1239_10.txt
# aclImdb/test/pos/1238_8.txt
# aclImdb/test/pos/1237_7.txt
# aclImdb/test/pos/1236_7.txt
# aclImdb/test/pos/1235_8.txt
# aclImdb/test/pos/1234_10.txt
# aclImdb/test/pos/1233_10.txt
# aclImdb/test/pos/1232_8.txt
# aclImdb/test/pos/1231_7.txt
# aclImdb/test/pos/1230_10.txt
# aclImdb/test/pos/1229_7.txt
# aclImdb/test/pos/1228_7.txt
# aclImdb/test/pos/1227_7.txt
# aclImdb/test/pos/1226_7.txt
# aclImdb/test/pos/1225_7.txt
# aclImdb/test/pos/1224_8.txt
# aclImdb/test/pos/1223_8.txt
# aclImdb/test/pos/1222_8.txt
# aclImdb/test/pos/1221_10.txt
# aclImdb/test/pos/1220_10.txt
# aclImdb/test/pos/1219_9.txt
# aclImdb/test/pos/1218_10.txt
# aclImdb/test/pos/1217_7.txt
# aclImdb/test/pos/1216_10.txt
# aclImdb/test/pos/1215_10.txt
# aclImdb/test/pos/1214_7.txt
# aclImdb/test/pos/1213_7.txt
# aclImdb/test/pos/1212_7.txt
# aclImdb/test/pos/1211_8.txt
# aclImdb/test/pos/1210_8.txt
# aclImdb/test/pos/1209_7.txt
# aclImdb/test/pos/1208_10.txt
# aclImdb/test/pos/1207_10.txt
# aclImdb/test/pos/1206_10.txt
# aclImdb/test/pos/1205_10.txt
# aclImdb/test/pos/1204_8.txt
# aclImdb/test/pos/1203_7.txt
# aclImdb/test/pos/1202_9.txt
# aclImdb/test/pos/1201_10.txt
# aclImdb/test/pos/1200_10.txt
# aclImdb/test/pos/1199_10.txt
# aclImdb/test/pos/1198_10.txt
# aclImdb/test/pos/1197_9.txt
# aclImdb/test/pos/1196_9.txt
# aclImdb/test/pos/1195_10.txt
# aclImdb/test/pos/1194_10.txt
# aclImdb/test/pos/1193_10.txt
# aclImdb/test/pos/1192_10.txt
# aclImdb/test/pos/1191_7.txt
# aclImdb/test/pos/1190_10.txt
# aclImdb/test/pos/1189_10.txt
# aclImdb/test/pos/1188_10.txt
# aclImdb/test/pos/1187_7.txt
# aclImdb/test/pos/1186_10.txt
# aclImdb/test/pos/1185_10.txt
# aclImdb/test/pos/1184_10.txt
# aclImdb/test/pos/1183_10.txt
# aclImdb/test/pos/1182_7.txt
# aclImdb/test/pos/1181_10.txt
# aclImdb/test/pos/1180_7.txt
# aclImdb/test/pos/1179_7.txt
# aclImdb/test/pos/1178_10.txt
# aclImdb/test/pos/1177_8.txt
# aclImdb/test/pos/1176_9.txt
# aclImdb/test/pos/1175_8.txt
# aclImdb/test/pos/1174_7.txt
# aclImdb/test/pos/1173_7.txt
# aclImdb/test/pos/1172_7.txt
# aclImdb/test/pos/1171_8.txt
# aclImdb/test/pos/1170_10.txt
# aclImdb/test/pos/1169_10.txt
# aclImdb/test/pos/1168_10.txt
# aclImdb/test/pos/1167_10.txt
# aclImdb/test/pos/1166_10.txt
# aclImdb/test/pos/1165_7.txt
# aclImdb/test/pos/1164_9.txt
# aclImdb/test/pos/1163_10.txt
# aclImdb/test/pos/1162_10.txt
# aclImdb/test/pos/1161_10.txt
# aclImdb/test/pos/1160_10.txt
# aclImdb/test/pos/1159_8.txt
# aclImdb/test/pos/1158_7.txt
# aclImdb/test/pos/1157_9.txt
# aclImdb/test/pos/1156_9.txt
# aclImdb/test/pos/1155_7.txt
# aclImdb/test/pos/1154_10.txt
# aclImdb/test/pos/1153_8.txt
# aclImdb/test/pos/1152_8.txt
# aclImdb/test/pos/1407_7.txt
# aclImdb/test/pos/1406_10.txt
# aclImdb/test/pos/1405_10.txt
# aclImdb/test/pos/1404_10.txt
# aclImdb/test/pos/1403_7.txt
# aclImdb/test/pos/1402_8.txt
# aclImdb/test/pos/1401_10.txt
# aclImdb/test/pos/1400_7.txt
# aclImdb/test/pos/1399_7.txt
# aclImdb/test/pos/1398_8.txt
# aclImdb/test/pos/1397_10.txt
# aclImdb/test/pos/1396_8.txt
# aclImdb/test/pos/1395_7.txt
# aclImdb/test/pos/1394_9.txt
# aclImdb/test/pos/1393_8.txt
# aclImdb/test/pos/1392_7.txt
# aclImdb/test/pos/1391_7.txt
# aclImdb/test/pos/1390_8.txt
# aclImdb/test/pos/1389_7.txt
# aclImdb/test/pos/1388_8.txt
# aclImdb/test/pos/1387_8.txt
# aclImdb/test/pos/1386_10.txt
# aclImdb/test/pos/1385_7.txt
# aclImdb/test/pos/1384_9.txt
# aclImdb/test/pos/1383_10.txt
# aclImdb/test/pos/1382_10.txt
# aclImdb/test/pos/1381_7.txt
# aclImdb/test/pos/1380_9.txt
# aclImdb/test/pos/1379_10.txt
# aclImdb/test/pos/1378_10.txt
# aclImdb/test/pos/1377_10.txt
# aclImdb/test/pos/1376_8.txt
# aclImdb/test/pos/1375_10.txt
# aclImdb/test/pos/1374_9.txt
# aclImdb/test/pos/1373_10.txt
# aclImdb/test/pos/1372_10.txt
# aclImdb/test/pos/1371_8.txt
# aclImdb/test/pos/1370_10.txt
# aclImdb/test/pos/1369_7.txt
# aclImdb/test/pos/1368_8.txt
# aclImdb/test/pos/1367_10.txt
# aclImdb/test/pos/1366_10.txt
# aclImdb/test/pos/1365_8.txt
# aclImdb/test/pos/1364_10.txt
# aclImdb/test/pos/1363_10.txt
# aclImdb/test/pos/1362_9.txt
# aclImdb/test/pos/1361_9.txt
# aclImdb/test/pos/1360_7.txt
# aclImdb/test/pos/1359_10.txt
# aclImdb/test/pos/1358_10.txt
# aclImdb/test/pos/1357_9.txt
# aclImdb/test/pos/1356_8.txt
# aclImdb/test/pos/1355_7.txt
# aclImdb/test/pos/1354_7.txt
# aclImdb/test/pos/1353_7.txt
# aclImdb/test/pos/1352_7.txt
# aclImdb/test/pos/1351_7.txt
# aclImdb/test/pos/1350_8.txt
# aclImdb/test/pos/1349_9.txt
# aclImdb/test/pos/1348_8.txt
# aclImdb/test/pos/1347_8.txt
# aclImdb/test/pos/1346_7.txt
# aclImdb/test/pos/1345_9.txt
# aclImdb/test/pos/1344_10.txt
# aclImdb/test/pos/1343_10.txt
# aclImdb/test/pos/1342_10.txt
# aclImdb/test/pos/1341_10.txt
# aclImdb/test/pos/1340_10.txt
# aclImdb/test/pos/1339_8.txt
# aclImdb/test/pos/1338_7.txt
# aclImdb/test/pos/1337_10.txt
# aclImdb/test/pos/1336_10.txt
# aclImdb/test/pos/1335_7.txt
# aclImdb/test/pos/1334_10.txt
# aclImdb/test/pos/1333_7.txt
# aclImdb/test/pos/1332_7.txt
# aclImdb/test/pos/1331_9.txt
# aclImdb/test/pos/1330_10.txt
# aclImdb/test/pos/1329_7.txt
# aclImdb/test/pos/1328_9.txt
# aclImdb/test/pos/1327_9.txt
# aclImdb/test/pos/1326_8.txt
# aclImdb/test/pos/1325_9.txt
# aclImdb/test/pos/1324_10.txt
# aclImdb/test/pos/1323_9.txt
# aclImdb/test/pos/1322_9.txt
# aclImdb/test/pos/1321_10.txt
# aclImdb/test/pos/1320_9.txt
# aclImdb/test/pos/1319_10.txt
# aclImdb/test/pos/1318_8.txt
# aclImdb/test/pos/1317_10.txt
# aclImdb/test/pos/1316_10.txt
# aclImdb/test/pos/1315_10.txt
# aclImdb/test/pos/1314_8.txt
# aclImdb/test/pos/1313_9.txt
# aclImdb/test/pos/1312_10.txt
# aclImdb/test/pos/1311_9.txt
# aclImdb/test/pos/1310_8.txt
# aclImdb/test/pos/1309_7.txt
# aclImdb/test/pos/1308_8.txt
# aclImdb/test/pos/1307_10.txt
# aclImdb/test/pos/1306_8.txt
# aclImdb/test/pos/1305_9.txt
# aclImdb/test/pos/1304_8.txt
# aclImdb/test/pos/1303_10.txt
# aclImdb/test/pos/1302_8.txt
# aclImdb/test/pos/1301_9.txt
# aclImdb/test/pos/1300_9.txt
# aclImdb/test/pos/1299_9.txt
# aclImdb/test/pos/1298_8.txt
# aclImdb/test/pos/1297_7.txt
# aclImdb/test/pos/1296_8.txt
# aclImdb/test/pos/1295_8.txt
# aclImdb/test/pos/1294_7.txt
# aclImdb/test/pos/1293_10.txt
# aclImdb/test/pos/1292_8.txt
# aclImdb/test/pos/1291_7.txt
# aclImdb/test/pos/1290_10.txt
# aclImdb/test/pos/1289_8.txt
# aclImdb/test/pos/1288_8.txt
# aclImdb/test/pos/1287_8.txt
# aclImdb/test/pos/1286_8.txt
# aclImdb/test/pos/1285_9.txt
# aclImdb/test/pos/1284_9.txt
# aclImdb/test/pos/1283_10.txt
# aclImdb/test/pos/1282_10.txt
# aclImdb/test/pos/1281_9.txt
# aclImdb/test/pos/1280_9.txt
# aclImdb/test/pos/1535_7.txt
# aclImdb/test/pos/1534_10.txt
# aclImdb/test/pos/1533_10.txt
# aclImdb/test/pos/1532_10.txt
# aclImdb/test/pos/1531_9.txt
# aclImdb/test/pos/1530_10.txt
# aclImdb/test/pos/1529_10.txt
# aclImdb/test/pos/1528_9.txt
# aclImdb/test/pos/1527_10.txt
# aclImdb/test/pos/1526_7.txt
# aclImdb/test/pos/1525_10.txt
# aclImdb/test/pos/1524_10.txt
# aclImdb/test/pos/1523_10.txt
# aclImdb/test/pos/1522_10.txt
# aclImdb/test/pos/1521_8.txt
# aclImdb/test/pos/1520_8.txt
# aclImdb/test/pos/1519_9.txt
# aclImdb/test/pos/1518_10.txt
# aclImdb/test/pos/1517_9.txt
# aclImdb/test/pos/1516_7.txt
# aclImdb/test/pos/1515_7.txt
# aclImdb/test/pos/1514_7.txt
# aclImdb/test/pos/1513_8.txt
# aclImdb/test/pos/1512_9.txt
# aclImdb/test/pos/1511_9.txt
# aclImdb/test/pos/1510_8.txt
# aclImdb/test/pos/1509_8.txt
# aclImdb/test/pos/1508_7.txt
# aclImdb/test/pos/1507_8.txt
# aclImdb/test/pos/1506_7.txt
# aclImdb/test/pos/1505_7.txt
# aclImdb/test/pos/1504_9.txt
# aclImdb/test/pos/1503_8.txt
# aclImdb/test/pos/1502_10.txt
# aclImdb/test/pos/1501_9.txt
# aclImdb/test/pos/1500_9.txt
# aclImdb/test/pos/1499_9.txt
# aclImdb/test/pos/1498_10.txt
# aclImdb/test/pos/1497_10.txt
# aclImdb/test/pos/1496_10.txt
# aclImdb/test/pos/1495_9.txt
# aclImdb/test/pos/1494_10.txt
# aclImdb/test/pos/1493_10.txt
# aclImdb/test/pos/1492_9.txt
# aclImdb/test/pos/1491_10.txt
# aclImdb/test/pos/1490_9.txt
# aclImdb/test/pos/1489_10.txt
# aclImdb/test/pos/1488_10.txt
# aclImdb/test/pos/1487_9.txt
# aclImdb/test/pos/1486_9.txt
# aclImdb/test/pos/1485_10.txt
# aclImdb/test/pos/1484_10.txt
# aclImdb/test/pos/1483_8.txt
# aclImdb/test/pos/1482_10.txt
# aclImdb/test/pos/1481_10.txt
# aclImdb/test/pos/1480_7.txt
# aclImdb/test/pos/1479_8.txt
# aclImdb/test/pos/1478_8.txt

# %%
train_pos_files = glob.glob('aclImdb/train/pos/*.txt')
train_neg_files = glob.glob('aclImdb/train/neg/*.txt')

# %%
len(train_pos_files), len(train_neg_files)
# Out:
# (12500, 12500)

# %% [markdown]
# We will use 2000 samples from the train set for validation. Let's choose 1000 postive reviews and 1000 negative reviews for validation and save them in the val directory

# %%
# !mkdir aclImdb/val aclImdb/val/pos aclImdb/val/neg

# %%
random.shuffle(train_pos_files)
random.shuffle(train_neg_files)

val_pos_files = train_pos_files[:1000]
val_neg_files = train_neg_files[:1000]

# %%
import shutil

# %%
for f in val_pos_files:
  shutil.move(f,  'aclImdb/val/pos')
for f in val_neg_files:
  shutil.move(f,  'aclImdb/val/neg')

# %% [markdown]
# ### Prepare Dataset

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# INFO:filelock:Lock 139780871368544 acquired on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpgy9lk1eo
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model in cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:filelock:Lock 139780871368544 released on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %%
ids_neg = tokenizer.encode('negative </s>')
ids_pos = tokenizer.encode('positive </s>')
len(ids_neg), len(ids_pos)
# Out:
# (2, 2)

# %% [markdown]
# All the examples are converted in the text-2-text format as shown in the paper. However I didn't use any task prefix here. The examples are encoded as follows,
# if the review is positive then the target is 'positive' else 'negative'
#
# **input**:  I went to see this
# movie with my husband, and we both
# thought the acting was terrible!"
#
# **target**: negative
#
# **input**:  Despite what others say,
# I thought this movie was funny.
#
# **target**: positive

# %% [markdown]
# The dataset below takes care of reading the review files and processing the examples in text-2-text format.
#
# It cleans the review text by removing the html tags. It also appends the eos token `</s>` at the end of input and target as required by the T5 model
#
# For T5 max input length is 512 and we can choose the max length for target sequence depending upon our dataset. The `T5Tokenizer` encodes both 'postive' and 'negative' as a single ids so I chose the max target length 2, extra 1 for the `</s>` token

# %%
class ImdbDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.pos_file_path = os.path.join(data_dir, type_path, 'pos')
    self.neg_file_path = os.path.join(data_dir, type_path, 'neg')
    
    self.pos_files = glob.glob("%s/*.txt" % self.pos_file_path)
    self.neg_files = glob.glob("%s/*.txt" % self.neg_file_path)
    
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self._build()
  
  def __len__(self):
    return len(self.inputs)
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def _build(self):
    self._buil_examples_from_files(self.pos_files, 'positive')
    self._buil_examples_from_files(self.neg_files, 'negative')
  
  def _buil_examples_from_files(self, files, sentiment):
    REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
    REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

    for path in files:
      with open(path, 'r') as f:
        text = f.read()
      
      line = text.strip()
      line = REPLACE_NO_SPACE.sub("", line) 
      line = REPLACE_WITH_SPACE.sub("", line)
      line = line + ' </s>'

      target = sentiment + " </s>"

       # tokenize inputs
      tokenized_inputs = self.tokenizer.batch_encode_plus(
          [line], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
      )
       # tokenize targets
      tokenized_targets = self.tokenizer.batch_encode_plus(
          [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
      )

      self.inputs.append(tokenized_inputs)
      self.targets.append(tokenized_targets)

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'val',  max_len=512)
len(dataset)
# Out:
# 2000

# %%
data = dataset[28]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# To quote Flik that was my reaction exactly Wowyoure perfect This is the best movie I think I can even say its become my favorite movie ever even Wow I tell you what wow
# positive

# %% [markdown]
# ### Train

# %%
# !mkdir -p t5_imdb_sentiment

# %%
args_dict.update({'data_dir': 'aclImdb', 'output_dir': 't5_imdb_sentiment', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %% [markdown]
# Define the `get_dataset` function to return the dataset. The model calls this function to get the train and val datasets. We are defining a dataset function so that we won't need to modify the model code at all. Redefine the function to return different dataset according to the problem. While this is not the best solution for now this works

# %%
def get_dataset(tokenizer, type_path, args):
  return ImdbDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %% [markdown]
# **Initialize model**

# %%
model = T5FineTuner(args)
# Out:
# INFO:filelock:Lock 139780702227256 acquired on /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp5_6vo8c2
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1199.0, style=ProgressStyle(description…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json in cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:filelock:Lock 139780702227256 released on /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b.lock
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json from cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.configuration_utils:Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "vocab_size": 32128
# }
# INFO:filelock:Lock 139780702189776 acquired on /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa.lock
# INFO:transformers.file_utils:https://cdn.huggingface.co/t5-base-pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmps92w5ati
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691430.0, style=ProgressStyle(descri…
# INFO:transformers.file_utils:storing https://cdn.huggingface.co/t5-base-pytorch_model.bin in cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:filelock:Lock 139780702189776 released on /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa.lock
# INFO:transformers.modeling_utils:loading weights file https://cdn.huggingface.co/t5-base-pytorch_model.bin from cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.modeling_utils:Weights of T5ForConditionalGeneration not initialized from pretrained model: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %% [markdown]
# **Initialize trainer**

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# **start fine-tuning**

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                  | Type                       | Params
# -----------------------------------------------------------------------------------------------------------------
# 0   | model                                                                 | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                          | Embedding                  | 24 M
# 2   | model.encoder                                                         | T5Stack                    | 109 M
# 3   | model.encoder.block                                                   | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                                 | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                           | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                         | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 21  | model.encoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 22  | model.encoder.block.1                                                 | T5Block                    | 7 M
# 23  | model.encoder.block.1.layer                                           | ModuleList                 | 7 M
# 24  | model.encoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 25  | model.encoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 27  | model.encoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 31  | model.encoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 32  | model.encoder.block.1.layer.1                                         | T5LayerFF                  | 4 M
# 33  | model.encoder.block.1.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 37  | model.encoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 38  | model.encoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 39  | model.encoder.block.2                                                 | T5Block                    | 7 M
# 40  | model.encoder.block.2.layer                                           | ModuleList                 | 7 M
# 41  | model.encoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 42  | model.encoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 43  | model.encoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 44  | model.encoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 45  | model.encoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 48  | model.encoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 49  | model.encoder.block.2.layer.1                                         | T5LayerFF                  | 4 M
# 50  | model.encoder.block.2.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 51  | model.encoder.block.2.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 54  | model.encoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 55  | model.encoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 56  | model.encoder.block.3                                                 | T5Block                    | 7 M
# 57  | model.encoder.block.3.layer                                           | ModuleList                 | 7 M
# 58  | model.encoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 59  | model.encoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 60  | model.encoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 61  | model.encoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 62  | model.encoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 63  | model.encoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 65  | model.encoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 66  | model.encoder.block.3.layer.1                                         | T5LayerFF                  | 4 M
# 67  | model.encoder.block.3.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 68  | model.encoder.block.3.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 69  | model.encoder.block.3.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 71  | model.encoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 72  | model.encoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 73  | model.encoder.block.4                                                 | T5Block                    | 7 M
# 74  | model.encoder.block.4.layer                                           | ModuleList                 | 7 M
# 75  | model.encoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 76  | model.encoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 77  | model.encoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 78  | model.encoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 79  | model.encoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 80  | model.encoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 81  | model.encoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 82  | model.encoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 83  | model.encoder.block.4.layer.1                                         | T5LayerFF                  | 4 M
# 84  | model.encoder.block.4.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 85  | model.encoder.block.4.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 86  | model.encoder.block.4.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 87  | model.encoder.block.4.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 88  | model.encoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 89  | model.encoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 90  | model.encoder.block.5                                                 | T5Block                    | 7 M
# 91  | model.encoder.block.5.layer                                           | ModuleList                 | 7 M
# 92  | model.encoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 93  | model.encoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 94  | model.encoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 95  | model.encoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 96  | model.encoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 97  | model.encoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 98  | model.encoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 99  | model.encoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 100 | model.encoder.block.5.layer.1                                         | T5LayerFF                  | 4 M
# 101 | model.encoder.block.5.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 102 | model.encoder.block.5.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 103 | model.encoder.block.5.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 104 | model.encoder.block.5.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 106 | model.encoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 107 | model.encoder.block.6                                                 | T5Block                    | 7 M
# 108 | model.encoder.block.6.layer                                           | ModuleList                 | 7 M
# 109 | model.encoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 110 | model.encoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 111 | model.encoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 112 | model.encoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 113 | model.encoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 114 | model.encoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 115 | model.encoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 116 | model.encoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 117 | model.encoder.block.6.layer.1                                         | T5LayerFF                  | 4 M
# 118 | model.encoder.block.6.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 119 | model.encoder.block.6.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 120 | model.encoder.block.6.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 121 | model.encoder.block.6.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 122 | model.encoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 123 | model.encoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 124 | model.encoder.block.7                                                 | T5Block                    | 7 M
# 125 | model.encoder.block.7.layer                                           | ModuleList                 | 7 M
# 126 | model.encoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 127 | model.encoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 128 | model.encoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 129 | model.encoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 130 | model.encoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 131 | model.encoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 132 | model.encoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 133 | model.encoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 134 | model.encoder.block.7.layer.1                                         | T5LayerFF                  | 4 M
# 135 | model.encoder.block.7.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 136 | model.encoder.block.7.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 137 | model.encoder.block.7.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 138 | model.encoder.block.7.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 139 | model.encoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 141 | model.encoder.block.8                                                 | T5Block                    | 7 M
# 142 | model.encoder.block.8.layer                                           | ModuleList                 | 7 M
# 143 | model.encoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 144 | model.encoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 145 | model.encoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 146 | model.encoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 147 | model.encoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 148 | model.encoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 149 | model.encoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 150 | model.encoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 151 | model.encoder.block.8.layer.1                                         | T5LayerFF                  | 4 M
# 152 | model.encoder.block.8.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 153 | model.encoder.block.8.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 154 | model.encoder.block.8.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 155 | model.encoder.block.8.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 156 | model.encoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 157 | model.encoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 158 | model.encoder.block.9                                                 | T5Block                    | 7 M
# 159 | model.encoder.block.9.layer                                           | ModuleList                 | 7 M
# 160 | model.encoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 161 | model.encoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 162 | model.encoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 163 | model.encoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 164 | model.encoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 165 | model.encoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 166 | model.encoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 167 | model.encoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 168 | model.encoder.block.9.layer.1                                         | T5LayerFF                  | 4 M
# 169 | model.encoder.block.9.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 170 | model.encoder.block.9.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 171 | model.encoder.block.9.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 172 | model.encoder.block.9.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 173 | model.encoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 174 | model.encoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 175 | model.encoder.block.10                                                | T5Block                    | 7 M
# 176 | model.encoder.block.10.layer                                          | ModuleList                 | 7 M
# 177 | model.encoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 178 | model.encoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 179 | model.encoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 180 | model.encoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 181 | model.encoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 182 | model.encoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 183 | model.encoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 184 | model.encoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 185 | model.encoder.block.10.layer.1                                        | T5LayerFF                  | 4 M
# 186 | model.encoder.block.10.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 187 | model.encoder.block.10.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 188 | model.encoder.block.10.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 189 | model.encoder.block.10.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 190 | model.encoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 191 | model.encoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 192 | model.encoder.block.11                                                | T5Block                    | 7 M
# 193 | model.encoder.block.11.layer                                          | ModuleList                 | 7 M
# 194 | model.encoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 195 | model.encoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 196 | model.encoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 197 | model.encoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 198 | model.encoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 199 | model.encoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 200 | model.encoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 201 | model.encoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 202 | model.encoder.block.11.layer.1                                        | T5LayerFF                  | 4 M
# 203 | model.encoder.block.11.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 204 | model.encoder.block.11.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 205 | model.encoder.block.11.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 206 | model.encoder.block.11.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 207 | model.encoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 208 | model.encoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 209 | model.encoder.final_layer_norm                                        | T5LayerNorm                | 768
# 210 | model.encoder.dropout                                                 | Dropout                    | 0
# 211 | model.decoder                                                         | T5Stack                    | 137 M
# 212 | model.decoder.block                                                   | ModuleList                 | 113 M
# 213 | model.decoder.block.0                                                 | T5Block                    | 9 M
# 214 | model.decoder.block.0.layer                                           | ModuleList                 | 9 M
# 215 | model.decoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 216 | model.decoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 217 | model.decoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 218 | model.decoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 219 | model.decoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 220 | model.decoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 221 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 222 | model.decoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 223 | model.decoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 224 | model.decoder.block.0.layer.1                                         | T5LayerCrossAttention      | 2 M
# 225 | model.decoder.block.0.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 226 | model.decoder.block.0.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 227 | model.decoder.block.0.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 228 | model.decoder.block.0.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 229 | model.decoder.block.0.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.1.EncDecAttention.relative_attention_bias | Embedding                  | 384
# 231 | model.decoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 232 | model.decoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 233 | model.decoder.block.0.layer.2                                         | T5LayerFF                  | 4 M
# 234 | model.decoder.block.0.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 235 | model.decoder.block.0.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 236 | model.decoder.block.0.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 237 | model.decoder.block.0.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 238 | model.decoder.block.0.layer.2.layer_norm                              | T5LayerNorm                | 768
# 239 | model.decoder.block.0.layer.2.dropout                                 | Dropout                    | 0
# 240 | model.decoder.block.1                                                 | T5Block                    | 9 M
# 241 | model.decoder.block.1.layer                                           | ModuleList                 | 9 M
# 242 | model.decoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 243 | model.decoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 244 | model.decoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 245 | model.decoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 246 | model.decoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 247 | model.decoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 248 | model.decoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 249 | model.decoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 250 | model.decoder.block.1.layer.1                                         | T5LayerCrossAttention      | 2 M
# 251 | model.decoder.block.1.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 252 | model.decoder.block.1.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 253 | model.decoder.block.1.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 254 | model.decoder.block.1.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 255 | model.decoder.block.1.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 256 | model.decoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 257 | model.decoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 258 | model.decoder.block.1.layer.2                                         | T5LayerFF                  | 4 M
# 259 | model.decoder.block.1.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 260 | model.decoder.block.1.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 261 | model.decoder.block.1.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 262 | model.decoder.block.1.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 263 | model.decoder.block.1.layer.2.layer_norm                              | T5LayerNorm                | 768
# 264 | model.decoder.block.1.layer.2.dropout                                 | Dropout                    | 0
# 265 | model.decoder.block.2                                                 | T5Block                    | 9 M
# 266 | model.decoder.block.2.layer                                           | ModuleList                 | 9 M
# 267 | model.decoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 268 | model.decoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 269 | model.decoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 270 | model.decoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 271 | model.decoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 272 | model.decoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 273 | model.decoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 274 | model.decoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 275 | model.decoder.block.2.layer.1                                         | T5LayerCrossAttention      | 2 M
# 276 | model.decoder.block.2.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 277 | model.decoder.block.2.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 278 | model.decoder.block.2.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 279 | model.decoder.block.2.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 280 | model.decoder.block.2.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 281 | model.decoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 282 | model.decoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 283 | model.decoder.block.2.layer.2                                         | T5LayerFF                  | 4 M
# 284 | model.decoder.block.2.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 285 | model.decoder.block.2.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 286 | model.decoder.block.2.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 287 | model.decoder.block.2.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 288 | model.decoder.block.2.layer.2.layer_norm                              | T5LayerNorm                | 768
# 289 | model.decoder.block.2.layer.2.dropout                                 | Dropout                    | 0
# 290 | model.decoder.block.3                                                 | T5Block                    | 9 M
# 291 | model.decoder.block.3.layer                                           | ModuleList                 | 9 M
# 292 | model.decoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 293 | model.decoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 294 | model.decoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 295 | model.decoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 296 | model.decoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 297 | model.decoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 298 | model.decoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 299 | model.decoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 300 | model.decoder.block.3.layer.1                                         | T5LayerCrossAttention      | 2 M
# 301 | model.decoder.block.3.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 302 | model.decoder.block.3.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 303 | model.decoder.block.3.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 304 | model.decoder.block.3.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 305 | model.decoder.block.3.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 306 | model.decoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 307 | model.decoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 308 | model.decoder.block.3.layer.2                                         | T5LayerFF                  | 4 M
# 309 | model.decoder.block.3.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 310 | model.decoder.block.3.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 311 | model.decoder.block.3.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 312 | model.decoder.block.3.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 313 | model.decoder.block.3.layer.2.layer_norm                              | T5LayerNorm                | 768
# 314 | model.decoder.block.3.layer.2.dropout                                 | Dropout                    | 0
# 315 | model.decoder.block.4                                                 | T5Block                    | 9 M
# 316 | model.decoder.block.4.layer                                           | ModuleList                 | 9 M
# 317 | model.decoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 318 | model.decoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 319 | model.decoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 320 | model.decoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 321 | model.decoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 322 | model.decoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 323 | model.decoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 324 | model.decoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 325 | model.decoder.block.4.layer.1                                         | T5LayerCrossAttention      | 2 M
# 326 | model.decoder.block.4.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 327 | model.decoder.block.4.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 328 | model.decoder.block.4.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 329 | model.decoder.block.4.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 330 | model.decoder.block.4.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 331 | model.decoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 332 | model.decoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 333 | model.decoder.block.4.layer.2                                         | T5LayerFF                  | 4 M
# 334 | model.decoder.block.4.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 335 | model.decoder.block.4.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 336 | model.decoder.block.4.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 337 | model.decoder.block.4.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 338 | model.decoder.block.4.layer.2.layer_norm                              | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.2.dropout                                 | Dropout                    | 0
# 340 | model.decoder.block.5                                                 | T5Block                    | 9 M
# 341 | model.decoder.block.5.layer                                           | ModuleList                 | 9 M
# 342 | model.decoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 343 | model.decoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 344 | model.decoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 345 | model.decoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 346 | model.decoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 347 | model.decoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 348 | model.decoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 349 | model.decoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 350 | model.decoder.block.5.layer.1                                         | T5LayerCrossAttention      | 2 M
# 351 | model.decoder.block.5.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 352 | model.decoder.block.5.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 353 | model.decoder.block.5.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 354 | model.decoder.block.5.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 355 | model.decoder.block.5.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 356 | model.decoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 357 | model.decoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 358 | model.decoder.block.5.layer.2                                         | T5LayerFF                  | 4 M
# 359 | model.decoder.block.5.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 360 | model.decoder.block.5.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 361 | model.decoder.block.5.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 362 | model.decoder.block.5.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 363 | model.decoder.block.5.layer.2.layer_norm                              | T5LayerNorm                | 768
# 364 | model.decoder.block.5.layer.2.dropout                                 | Dropout                    | 0
# 365 | model.decoder.block.6                                                 | T5Block                    | 9 M
# 366 | model.decoder.block.6.layer                                           | ModuleList                 | 9 M
# 367 | model.decoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 368 | model.decoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 369 | model.decoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 370 | model.decoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 371 | model.decoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 372 | model.decoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 373 | model.decoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 374 | model.decoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 375 | model.decoder.block.6.layer.1                                         | T5LayerCrossAttention      | 2 M
# 376 | model.decoder.block.6.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 377 | model.decoder.block.6.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 378 | model.decoder.block.6.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 379 | model.decoder.block.6.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 380 | model.decoder.block.6.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 381 | model.decoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 382 | model.decoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 383 | model.decoder.block.6.layer.2                                         | T5LayerFF                  | 4 M
# 384 | model.decoder.block.6.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 385 | model.decoder.block.6.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 386 | model.decoder.block.6.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 387 | model.decoder.block.6.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 388 | model.decoder.block.6.layer.2.layer_norm                              | T5LayerNorm                | 768
# 389 | model.decoder.block.6.layer.2.dropout                                 | Dropout                    | 0
# 390 | model.decoder.block.7                                                 | T5Block                    | 9 M
# 391 | model.decoder.block.7.layer                                           | ModuleList                 | 9 M
# 392 | model.decoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 393 | model.decoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 394 | model.decoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 395 | model.decoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 396 | model.decoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 397 | model.decoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 398 | model.decoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 399 | model.decoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 400 | model.decoder.block.7.layer.1                                         | T5LayerCrossAttention      | 2 M
# 401 | model.decoder.block.7.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 402 | model.decoder.block.7.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 403 | model.decoder.block.7.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 404 | model.decoder.block.7.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 405 | model.decoder.block.7.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 406 | model.decoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 407 | model.decoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 408 | model.decoder.block.7.layer.2                                         | T5LayerFF                  | 4 M
# 409 | model.decoder.block.7.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 410 | model.decoder.block.7.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 411 | model.decoder.block.7.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 412 | model.decoder.block.7.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 413 | model.decoder.block.7.layer.2.layer_norm                              | T5LayerNorm                | 768
# 414 | model.decoder.block.7.layer.2.dropout                                 | Dropout                    | 0
# 415 | model.decoder.block.8                                                 | T5Block                    | 9 M
# 416 | model.decoder.block.8.layer                                           | ModuleList                 | 9 M
# 417 | model.decoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 418 | model.decoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 419 | model.decoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 420 | model.decoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 421 | model.decoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 422 | model.decoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 423 | model.decoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 424 | model.decoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 425 | model.decoder.block.8.layer.1                                         | T5LayerCrossAttention      | 2 M
# 426 | model.decoder.block.8.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 427 | model.decoder.block.8.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 428 | model.decoder.block.8.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 429 | model.decoder.block.8.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 430 | model.decoder.block.8.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 431 | model.decoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 432 | model.decoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 433 | model.decoder.block.8.layer.2                                         | T5LayerFF                  | 4 M
# 434 | model.decoder.block.8.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 435 | model.decoder.block.8.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 436 | model.decoder.block.8.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 437 | model.decoder.block.8.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 438 | model.decoder.block.8.layer.2.layer_norm                              | T5LayerNorm                | 768
# 439 | model.decoder.block.8.layer.2.dropout                                 | Dropout                    | 0
# 440 | model.decoder.block.9                                                 | T5Block                    | 9 M
# 441 | model.decoder.block.9.layer                                           | ModuleList                 | 9 M
# 442 | model.decoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 443 | model.decoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 444 | model.decoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 445 | model.decoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 446 | model.decoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 447 | model.decoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 448 | model.decoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 449 | model.decoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 450 | model.decoder.block.9.layer.1                                         | T5LayerCrossAttention      | 2 M
# 451 | model.decoder.block.9.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 452 | model.decoder.block.9.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 453 | model.decoder.block.9.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 454 | model.decoder.block.9.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 455 | model.decoder.block.9.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 456 | model.decoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 457 | model.decoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 458 | model.decoder.block.9.layer.2                                         | T5LayerFF                  | 4 M
# 459 | model.decoder.block.9.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 460 | model.decoder.block.9.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 461 | model.decoder.block.9.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 462 | model.decoder.block.9.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 463 | model.decoder.block.9.layer.2.layer_norm                              | T5LayerNorm                | 768
# 464 | model.decoder.block.9.layer.2.dropout                                 | Dropout                    | 0
# 465 | model.decoder.block.10                                                | T5Block                    | 9 M
# 466 | model.decoder.block.10.layer                                          | ModuleList                 | 9 M
# 467 | model.decoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 468 | model.decoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 469 | model.decoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 470 | model.decoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 471 | model.decoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 472 | model.decoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 473 | model.decoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 474 | model.decoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 475 | model.decoder.block.10.layer.1                                        | T5LayerCrossAttention      | 2 M
# 476 | model.decoder.block.10.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 477 | model.decoder.block.10.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 478 | model.decoder.block.10.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 479 | model.decoder.block.10.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 480 | model.decoder.block.10.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 481 | model.decoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 482 | model.decoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 483 | model.decoder.block.10.layer.2                                        | T5LayerFF                  | 4 M
# 484 | model.decoder.block.10.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 485 | model.decoder.block.10.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 486 | model.decoder.block.10.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 487 | model.decoder.block.10.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 488 | model.decoder.block.10.layer.2.layer_norm                             | T5LayerNorm                | 768
# 489 | model.decoder.block.10.layer.2.dropout                                | Dropout                    | 0
# 490 | model.decoder.block.11                                                | T5Block                    | 9 M
# 491 | model.decoder.block.11.layer                                          | ModuleList                 | 9 M
# 492 | model.decoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 493 | model.decoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 494 | model.decoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 495 | model.decoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 496 | model.decoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 497 | model.decoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 498 | model.decoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 499 | model.decoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 500 | model.decoder.block.11.layer.1                                        | T5LayerCrossAttention      | 2 M
# 501 | model.decoder.block.11.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 502 | model.decoder.block.11.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 503 | model.decoder.block.11.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 504 | model.decoder.block.11.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 505 | model.decoder.block.11.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 506 | model.decoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 507 | model.decoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 508 | model.decoder.block.11.layer.2                                        | T5LayerFF                  | 4 M
# 509 | model.decoder.block.11.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 510 | model.decoder.block.11.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 511 | model.decoder.block.11.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 512 | model.decoder.block.11.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 513 | model.decoder.block.11.layer.2.layer_norm                             | T5LayerNorm                | 768
# 514 | model.decoder.block.11.layer.2.dropout                                | Dropout                    | 0
# 515 | model.decoder.final_layer_norm                                        | T5LayerNorm                | 768
# 516 | model.decoder.dropout                                                 | Dropout                    | 0
# 517 | model.lm_head                                                         | Linear                     | 24 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_val_loss = tensor(0.0839, device='cuda:0')
#
# INFO:__main__:loss = tensor(0.0199, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0199, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0839, device='cuda:0')
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_train_loss = tensor(0.2954, device='cuda:0')
#
# INFO:__main__:avg_val_loss = tensor(0.0874, device='cuda:0')
#
# INFO:__main__:epoch = 0
#
# INFO:__main__:loss = tensor(0.0066, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0066, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0874, device='cuda:0')
# 1

# %%
# !mkdir t5_base_imdb_sentiment

# %%
## save the model this way so next time you can load it using T5ForConditionalGeneration.from_pretrained
model.model.save_pretrained('t5_base_imdb_sentiment')
# Out:
# INFO:transformers.configuration_utils:Configuration saved in t5_base_imdb_sentiment/config.json
# INFO:transformers.modeling_utils:Model weights saved in t5_base_imdb_sentiment/pytorch_model.bin

# %%
# !cp -r t5_base_imdb_sentiment drive/My\ Drive/

# %% [markdown]
# ### Eval

# %% [markdown]
# For inference we will use the `generate` method with greedy decoding with max length 2.

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %% [markdown]
# Let's visualize few predictions on test dataset

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'test',  max_len=512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
it = iter(loader)

# %%
batch = next(it)
batch["source_ids"].shape
# Out:
# torch.Size([32, 512])

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    lines = textwrap.wrap("Review:\n%s\n" % texts[i], width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("Predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# Review: I dont know where to begin Perhaps the whole idea of this movie was just a disaster waiting
# to happen There is nothing slightly humorous about a kidnapping I dont know what was more
# offensivethe subject matter or David Arquettes performance It was like watching a bull get its penis
# cut off although I think the bull felt better afterwards The filmmakers should find something about
# Sinatra other than his sons kidnapping to show like I dont know his TALENT AS A SINGER His family
# shouldnt have to relive that horror Thank GOD it was just shown on HBO and not released in theaters
# Please dont watch this if you have any self respect
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: A fine performance by Vittorio Mezzogiorno and a masterful one by JeanHugues Anglade adorn
# this stange tale of lust desire and alienation in France The work of the two lead performers is
# strikingsubtle intense and passionate Alas the script is deliberately turgid and sordid and the
# overall effect leaves one with a downcast spirit Still those who can appreciate fine quality acting
# will be able to savor the courageous work of the leads in this often difficult film journey of
# Gallic low life
#
# Actual sentiment: positive
# Predicted sentiment: negative
# =====================================================================
#
# Review: I almost stopped watching Hindi movies because of the mediocre quality and story lines One
# exception for this is Ramgopal Verma movies This is a nice movie with great performances from the
# star cast This is must see movie for those who are sick of watching stupid dancing and love stories
# The adaptation of the story and characterization was exceptional goodYou should watch this movie for
# Nana Patekar based on the life of Mumbai cop Daya Naik this movie deals in a more realistic way The
# film delves into the life of the common man which he has apart from being an encounter specialist I
# rate this as one of the best movie of the year
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This was a really interesting Halloween film I wasnt to thrilled with the whole Thorn theory
# but it still makes for a good film I liked getting to see Tommy Doyle back but sadly Donald
# Pleasance died right after shooting The film had a really REALLY bad director who didnt give a flip
# about the series from what I heard treated Donald bad and wouldnt let Danielle Harris come back as
# Jamie Its like he was just trying to bring down the film but I still liked it There were alot of
# cuts and music changes and if youre lucky you can get the Producers Cut which features over 40 min
# of never before scenes With those scenes it turns into a whole new movie Check it out if you have
# the chance
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Cheerleader Massacre was supposed to be the fourth installment of the Slumber Party Massacre
# series if thats what they were doing which it is considering ONE actress from the original returns
# in a small cameo role they have failed miserably and made by far the worst installment of the
# quadrilogy Cheerleader Massacre seamlessly combines bad acting a horrible plot a dumb killer dull
# and boring deaths boring scenery and hideous camera work to make it one of the worst films ever made
# Did I already mention how bad it was Dont get me wrong this cheesy and retarded excuse for a horror
# film is nowhere near as bad as Napoleon Dynamite but it is undeniably a horrible movieCheerleader
# Massacre is an exact polar opposite of the original Slumber Party Massacre Stay away by all means
# This movie is utter garbage
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie will give me nightmares I will wake up drenched in sweat screaming I didnt make
# this film please dont blame me I honestly think it would have been more entertaining to watch a fat
# guy eating lard in his moms basement for a hour or two than to watch this crap I understand money
# was tight but goddamn what the hell were they thinking there was no thought plot or effort put into
# this This movie needs a warning Please for the love of god dont fund the drama department a the
# local JC On an other note these are the least likable characters I have ever seen and I have seen
# movies with Hitler in them So lastly take my advice the next time you even think about renting this
# just pop a few hundred Adivl and let the sleep come
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: In this movie Virtual Sexuality the 17 year old Justine is not lucky in love One day when
# she is stood up she goes with her friend to a virual reality conference there she is introduced with
# a machine that can change your look dody and whatever you like in Virtual Reality She decides to try
# it out but begins to make a boyfriend of her own her dreamdate Then suddenly there is an explosion
# in a gas pipe and her creation comes to life Ill say no more youll have to watch the movie which is
# quite fun to watch
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Why does C Thomas Howell do these movies Cruise Howells one time costar does a huge
# blockbuster of WOTW and Howell follows with this lame effortWhere do I start here Production Values
# Ill start with the good stuff The look and feel of some of the scenes in this movie are not too bad
# to be honest The setups are okay in spots and the direction not too badScript Terrible A series of
# clunky scenes that could have been put in any order you like permeate throughout the movie The
# amount of times the scene faded to black and reemerged a second later in the same room was
# uncountable Very poor storyline but so was the Cruise WOTW takes some blame but an abysmal
# screenplay kills it offSpecial FX Okay I dont want to be too harsh here as I imagine the budget was
# smaller than Cruises lunch bill but in the overall context of the film the effects are badly done
# Some shots are quite impressive mainly far off destruction shots of bridges Washington liner But in
# the main the alien machines and tentacles themselves are dreadful Also the camera quality is fuzzy
# on some shots and cuts away entirely on othersActing Im a fan of Howell but as he has reduced
# himself to acting in these lowbudget flicks he has succumbed to the overacting bug a long time ago
# Look at his performance in The Hitcher and compare it to this movie There is no comparison He
# overdoes his facial expressions his flailing arms and legs where did he get that running style and
# for a final coupdegras look at the scene where he loses the photo of his family Hysterical But after
# saying all that he is still the best actor on show here Busey is embarrassing to look at and Peter
# Green Zed is truly dead now baby mumbles incoherently through his one and only scene I honestly
# could not understand one word he said I even went so far as trying to enable the subtitles on that
# scene but the DVD did not have subtitles This seems to be a real keepitinthefamily affair too as
# Howells son the directors wife and the line producer all make it into the film None of them are
# goodDirection not bad but not good eitherScore DismalOverall a lame duck effort that will don'thing
# for Howell in his
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Another Asian horror movie packed with intense and creepy moments Another Asian horror
# trademark is the complexity of the plot which is here as well MAJOR SPOILER WARNINGThe movie starts
# pretty simple two sisters go to live with their dad and stepmother after being put in a mental
# institution after their mother hanged herself The sisters seem very hostile towards their mother
# especially the elder one and they seem to ignore their father All goes smoothly until the mother
# locks the young sister in the wardrobe and the elder sister tells her father Then it hits you your
# sister has been dead for years now It turns out the older sister is still not recovered from the
# death of her mother and what we didnt know is that the wardrobe the mother was hanged in fell on the
# younger sister and killed her as wellAs for the stepmother she is the alter ego of the older sister
# revealed when the stepmother actually the sisters alter ego is sitting on a couch when the real
# stepmother walks in I hope it has been made clearer for confused Asian horror fans out thereFinally
# my favourite scene is the scene where the father invites friends over for dinner and one of the
# friends starts to choke which erupts into a panic attack Very creepy 7 out of 10
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: As a native of New Orleans I can state that almost everything in this movie from the
# atrocious NAwlins dialect to the highly creative manipulation of Crescent City geography is horrible
# This is another one of those Big Hollywood movies that decides to stereotype New Orleans as 1 A city
# full of Frenchsounding idiots 2 A city full of people who sound as if theyve just returned from
# Blanche Dubois summer home 3 A city of drunkards where every day is Mardi Gras 4 A city of deep
# mystery where almost everyone practices or is a victim of voodoo I admit that maybe we are a city of
# drunkards although every day is NOT Mardi Gras The Big Easy is one of the worst films about New
# Orleans I wouldnt recommend it to anybody
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This selfimportant confusing b+w film watches like an infant on a very bad acid trip Youre
# dealing with something that reminds you of a piece of rotting lettuce that accidentally fell out of
# the back of a garbage truck no one cares to touch it because it will probably be washed away on its
# own down the storm drain Theres no room for plot when youve got visceral imagery and subtle allegory
# To me it seems like the director tries to make the next great art movie while begging for
# intellectual accolades I didnt bring my beret either Watching this I felt almost insulted since the
# film does such an effective job of distancing itself from you
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Mercy the movie actually starts out as a somewhat decent film and ellen barkin does give a
# strong performance But if you have read the book and actually got to know the characters and cared
# who done it the movie just does not compare It is always hard to brink a book onto film and
# unfortunatley this one ends up failing 3 out of 10
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: What in the world This piece of gambling cinema would have been suitable for the Lifetime
# Network Michael Imperoli is a good actor but I think his portrayal as Stu fell short The montages
# were unbearable and too many The supporting cast where are you Whoever did the casting should be
# partially at fault The cinematography was useless A gambling story with an after school feel to it
# Stories of this sort should be left for the Oliver Stones of the world It would still suck ass but
# at least it would be fun to watch It was an attempt that lost its wheels before the race ever begun
# Mario Andretti in the 1982 Indy 500 came to mind
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie definitely made me laugh but that doesnt mean it was exactly funny Well then
# again me and my friends had a lot of fun watching itI doubt there is anything about this movie that
# hasnt been done at least twice before just like the plot itself All of the characters are overused
# movie cliché cardboardbox roles that dont even require acting skills accordingly such skills are not
# delivered We have the corrupt cop a ruthless killer who claims to care about his men and their
# families whilst caring nothing about people he shoots in the forehead at so close a range as to have
# blood spat on his face We have the wornout cop on the edge so nicely pointed at in the discussion
# boards of this movie we have the old onedayawayfromretirementcop who just about everyone must have
# immediately identified as the most likely man on the inside since he had most to gain and he didnt
# utter a trustworthy word throughout the movie About as seethrough as a glass house on a sunny day
# The big black gangster king was a copy of all previous big black gangster kings in movie history
# they couldve just called him Marcellus Wallace but just slightly tougher and more ruthless because
# something has to emphasize that we also know Laurence Fishburne from actually good movies Then we
# finally have the HIGHLY EDUCATED doctor who cant think of anything reasonable to do as soon as the
# situation differs from her ordinary life and who spends the majority of the movie sitting in a
# corner helplessly trying to figure out how to hold on to the weapon she was given NOT USING ITThe
# whole siege story is not interesting not original having been used twice before and this movie
# manages to add absolutely nothing interesting to it There is the initial probe then the laying of
# the siege then the assault then the escape attempts Meanwhile a bunch of strained stressed freaked
# out cops and thugs manage to hold off a Police assault team with hightech equipment and the quite
# important advantage of VISION Then again in deep night with the power cut and with a snow storm
# raging overhead there is definitely a lot of light coming in so who really cares about night
# visionBut the best part comes right at the end In the first scenes showing Precinct 13 we see it is
# situated in an outskirt of an industrial city factories and office buildings surround it on all
# sides From this point
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Some people say this show was good in its early years I disagree with all of em The show is
# just plain stupid and pathetic My mum hates it I hate it my dad hates it I dont know about my sister
# but oh well Here some reasons why1 THE CHARACTERS Babies being used as grown up style characters are
# stupid The babies are just precocious and annoying The grown ups and adults are dumb and unappealing
# The worst character is that Angelica Pickles she really does it in for your ear drums when you had a
# long hard and miserable day at the office and also that Kimi Finster who appears later on she is too
# over optimistic and a pain in the butt She cant decided whither she is French or Japanese it doesnt
# matter know you are a American Citizen know and thats that Oh what am I talking about all the
# characters from this show suck2 THE STORIES The stories are unoriginal and dumb The make it like the
# babies go off on a great adventure yeah to the back yard shed In one episode that little goofy brat
# Tommy Pickles the Leader broke in to a televisions control room and literally almost destroyed it
# Dont give kids any idea to smash up normal TV Stations control rooms they pay a awful lot of money
# for them in real life I can imagine what the broadcasters must of felt like airing this episode they
# will probably start staring at their machines throughout the day scared that a baby will brake in
# Sad3 OVER RATED The show has been dragging on for years now and people are still making up stories
# and new series and spinoffs for this Get off The Simpsons have been going for nearly the same amount
# of time as this but they are much better and funnier than babies The show is just plain over rated
# People where is your common senseAnyway I surprised TV Stations across the world want to air this
# series even off today The show is utter junk and should have never been produced The two movies for
# this cartoons sucked just the same 210
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: What can I saynot much to this one at all Pretty dull and uninterestingThe actors
# performances are just OK The only one that shines in any way is Simmons but he only has maybe 3
# scenes I understand that by keeping his screen time to a minimum he retains the mysterious psychic
# aura he has but I cant help but feel his talent was wasted No one else rose above mediocreThe story
# itself seems like it may be intriguing at the beginning but then just doesnt go anywhere There wasnt
# a single scene in the movie that impressed me or made me feel like I had just seen something special
# The cinematography was fairly blandI mean desert in a washed out sort of sepianot very inspiringThe
# story of his childhood pal back outta prison seemed only partially thought out and didnt really add
# anything to the story other than making an average Twilight Zone script into a full length
# featureDrab
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: I kept watching it because it seemed like the plot was going somewhere When it ambiguously
# got there I was very disappointed Im going to tell you what really happened in the next sentence But
# maybe I wont Maybe Ill just imply something will happen The writers lacked any imagination This is
# not even a B movie its a made for TV B movie
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Straight up I love this film I love everything about it It has a great soundtrack it has a
# lot of recognizable faces and it is funny as hell There are so many plots in this film and every one
# of them is funny in one way or anotherWhere as Spicolli lit up the screen two years back Drake is
# almost as memorable of a character All he wants to do is have fun He moves out of the house without
# his parents consent he skips work whenever he feels like it he is obsessed with sex he loves his
# drugs and booze and he tries to be a good friend It is his lacksidaisical attitude that makes him
# such a joy to watch And he comes out with some great lines And there are so many tiny observations
# that you dont see coming but they make you laugh at the sheer velocity when it hits you One
# particular moment is when Tommy and Bill are talking about Bills ex girlfriend dating someone else
# now At the end of the conversation Tommy takes his huge beer bottle and just throws it over his
# shoulder casually He then says good night and the scene ends It is a perfect scene Tommys world is
# his own He really lives to party and have fun When the conversation is over his time is over and he
# doesnt care who he offends in the process He has an innocence about him Its casual is his favourite
# sayingAnother such classic scene is Reggie handing Bill a donut He says something to him that me and
# my friends will never forget because we rewound the film ten times and watched that part over and
# over again and hurt ourselves laughing It has to be seen to be appreciatedWild Life is a throw back
# to when teen comedies were funny raunchy had a good ear entertained us and just wanted us to get
# lost in their world for 90 minutes Wild Life does all those things perfectly If this is a film that
# you havent seen give it a chance It is a classicAlso check out the army store guy that Jim has
# problems with He is a very familiar face now and it is his first role on the big screen
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This movie is a real shame not just for the plotthe empty performance of the characters it
# is for the lack of creativity from the director and all the crew this is maybe one of the worst
# movies of all timesand it is hard to believe that is the sequel of one of the most famous movies of
# the 90sI am a great fan of The Mask when I went to see this movie I was expecting to a movie with a
# good sense of humor a movie with a acceptable plot instead I saw a really bad copy of Chuck Jones
# and Tex Avery cartoons the movie was not funny even for my 7 years old sister so I wonderWhat was
# wrong New Line CinemaWas it trying to repeat the success of the first movie or was it trying to
# create another masterpiece like The Lord of the RingsBecause if they did they were completely out of
# their minds
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: eXistenZ is simply David Cronenbergs best movie All the people compare it to the Matrix
# Theyre not even similar If you enjoyed Cronenbergs other works just a little bit youll love this one
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: First time I ever felt I needed to write a reviewI have seen thousands of movies in my life
# and I like a wide range of movies I am reasonably opened minded and can easily say I enjoyed a movie
# while still saying yeah it was not good but I enjoyed it I can appreciate the mastery of great
# movies like The Shaw shank redemption the godfather and American history X I can like good movies in
# a genre like horror or comedy even if the movie might not be that great I can even enjoy a bad movie
# that just happens to entertain me Bloodsport I also will try to rate movie fairly even if I did not
# like it City lights by Charlie Chapin was not a movie I enjoyed but I can appreciate the acting and
# story lines for the timeI think some people when they go on this site instead of randomly click a
# rating should take a few ideas into account Try to rate the movie based on how good it actually was
# Do not let your personal bias affect the rating Also look at other moves you rated and compare the
# movie you are going to rateThis movie was the worst piece of trash I have ever seen 2 hours of my
# life where just stolen The acting was awful across the board The scenes where choppy at best However
# the real disgrace was the story The first 20 minutes we actually had a story that tried to make
# sense and take the viewer from point A to B However after that it was a nightmare They kept trying
# to add new elements but nothing was every explained Nothing really ever made sense was steward dead
# is he alive did he hit by lighting was it really lighting was it aliens is he an alien etc The
# ending tied nothing together and really did not answer any questions The only positive was nobody
# cared we where just happy to leave the theater6510 What is wrong with some of you I will admit that
# the 8 of us where so mad about seeing this we did think what would make it better and we decide to
# tell a few of our friends that this movie was good so they would have to suffer and see this movie
# What can I say misery loves company That is really the only reason I can see for a 65 ratingDo not
# waste your life
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: My main criticism with the movie is the animation I totally agree with everyone else it was
# very poor Some of the characters seemed to have darker skin tones than they did in the first film
# which is much better Also the background colours looked rushed and somewhat static It is also a
# shame that Michael JFox didnt voice Milo he did such a good job and James Arnold Taylor wasnt sure
# whether he was supposed to sound like Milo or Aladdin I have also taken into consideration the lack
# of a good storyline the third story was confusing and clumsily told and the second story suffered
# from poor scripting To make things worse the first one I cant even remember other than a fishing
# village being haunted or something like that However there was some nice music and good voice
# talents from John Mahoney Cree Summer Clancy Brown and Tom Wilson that saved the film from total
# disaster All in all a disappointing sequel to a surprisingly good film 410 Bethany Cox
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Giant Robot was the most popular Japanese TV serial ever seen on Indian TV It was targeted
# to children and we saw a robot for the first time in our life Many Indian children must have even
# seen a machine for the first time outside the school textbooks The serial also showed a child in an
# adults organization fighting evil No doubt many of us who have seen Giant Robot in our childhood
# long for our own robots and as a stopgap arrangement look upon our computers in the same way This
# show also portrayed ideal adults referring at Jerry Johnnys buddy friend and Unicorn chief Azuma We
# grew to respect Japanese progress and still view Japan as the ideal Asian nationBTW at that time
# there were no satellite TV channels in India and the govt owned broadcaster did not show much of
# Disney cartoons I guess that was how child serials like giant Robot got appreciated Nowadays there
# is Pokemon etc but they are no so fascinating or alluring as Giant robot
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This might sound weird but I only got to see the first movie The Emperors New Groove
# yaddayadda a week ago and only because of one episode of the TV show I simply adore Kuzcos character
# but Kronk isnt that bad either Anyway eventually I decided to watch the second film just so I
# wouldve seen it Hoped it would be as good as the first one but Im sorry to tell this but the more
# the humour got American the more I yawned I agreed with Kuzco when he started crying seeing all the
# cheesy footageStill younger kids and probably veterans too will love this movie to bits if they like
# the old school moralising Disney that is but I just had expectations that were an eensy teensy
# little bit hell of a lot higher than they shouldve been Kronk is a lovely character being good
# hearted and dumb all at once but it were Pacha and Kuzco in drag that woke me up at the end of the
# movie Ill ignore Rudy for as far thats possibleAnyway great movie just not my style and as they say
# you always have to be true to your groove
#
# Actual sentiment: negative
# Predicted sentiment: positive
# =====================================================================
#
# Review: The problem I have as a Finn is that most of the actors in this movie are in every Finnish
# movie I have a feeling that Finland has only like five actors I think that if youre not from Finland
# you really like this movie as a refreshing noveltyThis movie is about a dreadful chain of events
# that affects a few people quite harshly Alcoholism cold climate and darkness may all be clichés but
# theyre still very real in todays Finnish society A lot of people in Finland have depression
# especially during winterThe tone of the movie is very melancholic I enjoyed it and Louhimes
# directing was again very solid I liked this movie a lot only negative thing is that you see the same
# faces that youve seen over and over again
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Most of the criticism of Attack of Show is from people who are unfairly comparing it to an
# old computer TV program called The Screen Savers People are upset because G4 decided to cancel the
# Screen Savers and replace it with the pop culture based Attack of the Show To compare the two shows
# is like comparing apples to orangesAttack of the Show is a unique hour long program that covers
# current Generation XY culture It features segments on moviestelevision panel discussions video games
# new DVD releases sex advice new gadgets MP3 players cell phones etc comic booksgraphic novels
# magazines and internet fads Its a fun show definitely worth checking out you are in your 20s or 30s
# I give it an 8 out of 10
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This is the best comedy period It is so underrated Clever witty humor Great casting Jerry
# Stiller is the jewel in the show he is so incredibly funny and quirky simply a comical genius Doug
# and Carrie have great chemistry I so don't see what the hype is about when it comes to Everybody
# loves Raymond it is SO overrated with lame jokes mostly forced humor and just not the witty show I
# cant remember laughing in more than 1 episode King of Queens is a rare comedy that has all the right
# ingredients to give you serious belly laughs which is normally caused by Arthur Spooner I think its
# about time this comedy gets the hype it deserves and not the lame Raymond & CO
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Running Out of Time rests somewhere in the middle of Johnny Tos cannon in the solid good
# category As a crime thriller its not terribly original or overwhelming and the action scenes will
# not blow you away but it has something else going for it Its a Johnny To film after all it has
# toAndy Lau has 72 hours to live He decides to play a strange catandmouse game with a hostage
# negotiator of the HK police played by Lau Ching Wan Thats the plot in a nutshell On top of that To
# piles layers of twists and turns that keep proceedings interesting throughout It occasionally
# becomes too convoluted for its own sake but never lets it get the best of it However just as Johnny
# To is about to hand over a slick and wellmade crime flick which lets face it are dimeadozen he slips
# in bits and pieces that bring Running Out of Time alive as a full emotional experience providing the
# soul and heart to the welloiled skeletonThe concepts of synchronism and minimalism staples in his
# work are explored in great effect here Always subtle letting the images speak for themselves giving
# them time to develop with long takes and slow tracking shots exemplary cutting to the score its all
# here A small love story in a bus between Andy Lau and a girl is among the highlights of the film and
# part of the heart Im talking about So simple yet so powerful Ditto for Laus and Lau Ching Wans car
# scenes and the bowlingroom showdownHowever something stops me from claiming Running Out of Time is a
# masterpiece To has all the ability and craftmanship down to a notch but he can also be too
# workmanlike or bland at times When hes good hes REAL good There are even isolated moment of pure
# brilliance that are just TOO good for their own sake leaving a bittersweet aftertaste for the rest
# of the movie Im convinced that if he puts his heart to it he can make a really great film As it is
# this is another one of his films that is flawed but enjoyable Underneath the slick HK style its the
# black humour and heartfelt drama that makes this a compelling film Worth watching definitely
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Will there be please coming an end to hyping movies that are dealing about social conflicts
# or other human disasters Okay Care is about childabuse Care is about perverts misusing boys in a
# school and how disgusting it might be if its a movie with a poor script and made with bad playing
# actors then it stays a bad movie Care is a movie that could have been but is it because it was a
# tvmovie I dont know but everything seemed so limited that it comes over as some cheap movie that
# will be seen by some housewifes and fathers who decide not to go to bed There are so many unanswered
# things in this moviethe relation with his mother for instance or the death of some abused boy from
# which we know nothing more Care should have been much much better
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie appears to have been overlooked by everyone Someone should bring it out on VHS
# and DVD It is an excellent film and far superior to the one with Brooke Shields which was terrible
# Jean Simmons deserves more credit than she is getting now days It would be nice if all her films
# were offered on VHS or DVD Jean Simmons was and still is a very good actress She certainly was a
# beauty In fact she is still a beauty She also has done extremely well on TV She is so much better
# than many of the actors today
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: When I heard there was to be an ABC Australian Broadcasting Corporation miniseries based on
# life in Changi WWII POW camp with a focus on elements of comedy I was deeply sceptical and somewhat
# criticalMy father had served in the second world war Such was the barbarity of the Japanese he was
# able to talk about the horrors in and around Labuan where he was stationed until only quite recently
# Along with my father I had been awarded the fortune of knowing many great men of stronger character
# and spirit than I shall ever have who had witnessed acts of unspeakable barbarity at the hands of
# the Empire of Japan and had never completely recovered The name Changi is destined to conjure
# horrific images for ages to comeBut upon viewing I was highly impressed with the cast the characters
# and the complex plotlines of this wonderful series I now regard Changi as the highlight of my week
# bear in mind I have viewed only three episodes so far I hope the remaining episodes adhere to the
# standards set by the first threeThe black humour works uncannily well however the flatulence jokes
# are a little overdone and while much of the horror has been suppressed the series comes quite close
# in relaying the undaunted spirit of the survivors who were able to later continue with their lives
# in spite of the inhibiting memoriesThe flashback format of this series will be difficult for some to
# followbut I can not think of no better way to do adequate justice to the men who suffered deep
# emotional scarring proceeding internment when painfully suppressed experiences are remembered
# sometimes years after the horrorOne of the darkest chapters of the Second World War the 20th century
# and I would go so far as to say in the history of mankind is being relayed to a new generation
# through this series and I hope it serves to relay the overwhelming adversity borne by the wartime
# generationProceeding Changi I dont think I shall ever be able to listen to the poignant tune on the
# road to Gundagai in the same way again Tune in
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: I was pretty enthusiastic about seeing this movie when it came out Commercials for it made
# it look quirky and I generally like Morgan Freeman and Chris Rock and the combination of the two
# seemed like an interesting idea Sadly I was terribly disappointed with Nurse BettyPersonally Ive
# usually found that graphic violence and comedy dont go all that well together and the only directors
# that have ever combined the two successfully in my opinion are Tarantino and the Coens There isnt
# that much violence in Nurse Betty but what violence is in it made me feel kind of weird when I was
# supposed to laugh Of course for me part of the problem was also that there didnt seem to be many
# places where I was being asked toThe film doesnt much work as a drama either Renee Zellwegers Betty
# the storys protagonist is clinically insane and impossible to relate to in any real way I will say
# Zellweger acts the role quite well and Freeman Rock and Greg Kinnear all do good jobs too The
# problem is in the writing Freeman is the only person that gets to play an interesting character Its
# really too bad 310
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================

# %% [markdown]
# Now predict on all the test dataset

# %%
loader = DataLoader(dataset, batch_size=32, num_workers=4)
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))

# %% [markdown]
# Let's check if the model generates any invalid text

# %%
for i, out in enumerate(outputs):
  if out not in ['positive', 'negative']:
    print(i, 'detected invalid prediction')

# %% [markdown]
# This great is great! Our model hasn't generated any invalid prediction. Let's calculate accuarcy and other metrics

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.94712

# %%
print(metrics.classification_report(targets, outputs))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.95      0.95      0.95     12500
#     positive       0.95      0.95      0.95     12500
#
#     accuracy                           0.95     25000
#    macro avg       0.95      0.95      0.95     25000
# weighted avg       0.95      0.95      0.95     25000

# %% [markdown]
# ## Emotion classification
#
# While most of the sentiment-analysis datasets are binary with 'postive' and 'negative' sentiments, [Elvis Saravia](https://twitter.com/omarsar0)  has put together a great [dataset](https://github.com/dair-ai/emotion_dataset) for emotion recognition. The task is given some text classifiy the text into one of the following six emotions
#
# 'sadness', 'joy', 'anger', 'fear', 'surprise', 'love'.
#
# Here's the [original notebook](https://colab.research.google.com/drive/1nwCE6b9PXIKhv2hvbqf1oZKIGkXMTi1X#scrollTo=pSzoz9InH0Ta) which trains ROBERTa model to classify the text

# %% [markdown]
# ### Download and view data

# %%
# !wget https://www.dropbox.com/s/ikkqxfdbdec3fuj/test.txt
# !wget https://www.dropbox.com/s/1pzkadrvffbqw6o/train.txt
# !wget https://www.dropbox.com/s/2mzialpsgf9k5l3/val.txt
# Out:
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/ikkqxfdbdec3fuj/test.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/ikkqxfdbdec3fuj/test.txt [following]
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/raw/ikkqxfdbdec3fuj/test.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:02 ERROR 404: Not Found.
#
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/1pzkadrvffbqw6o/train.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/1pzkadrvffbqw6o/train.txt [following]
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/raw/1pzkadrvffbqw6o/train.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:03 ERROR 404: Not Found.
#
# --2024-01-27 19:56:03--  https://www.dropbox.com/s/2mzialpsgf9k5l3/val.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/2mzialpsgf9k5l3/val.txt [following]
# --2024-01-27 19:56:03--  https://www.dropbox.com/s/raw/2mzialpsgf9k5l3/val.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:03 ERROR 404: Not Found.

# %%
# !mkdir emotion_data
# !mv *.txt emotion_data

# %%
train_path = "emotion_data/train.txt"
test_path = "emotion_data/test.txt"
val_path = "emotion_data/val.txt"

## emotion labels
label2int = {
  "sadness": 0,
  "joy": 1,
  "love": 2,
  "anger": 3,
  "fear": 4,
  "surprise": 5
}

# %%
data = pd.read_csv(train_path, sep=";", header=None, names=['text', 'emotion'],
                               engine="python")
data.emotion.value_counts().plot.bar()

# %%
train.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
train.count()
# Out:
# text       16000
# emotion    16000
# dtype: int64

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# INFO:filelock:Lock 139955425093728 acquired on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpsnkx0l2g
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model in cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:filelock:Lock 139955425093728 released on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %% [markdown]
# ### Dataset

# %% [markdown]
# Here also we will process the examples in the same way we did above. If the label is 'love' we will ask the model to predict the text 'love'

# %% [markdown]
# Lets check how t5 encodes the following labels

# %%
emotions = [ "sadness", "joy", "love", "anger", "fear", "surprise"]
for em in emotions:
  print(len(tokenizer.encode(em)))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# Here also all the labels are encoded as single ids

# %%
class EmotionDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.path = os.path.join(data_dir, type_path + '.txt')

    self.data_column = "text"
    self.class_column = "emotion"
    self.data = pd.read_csv(self.path, sep=";", header=None, names=[self.data_column, self.class_column],
                            engine="python")
    
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self._build()
  
  def __len__(self):
    return len(self.inputs)
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def _build(self):
    for idx in range(len(self.data)):
      input_, target = self.data.loc[idx, self.data_column], self.data.loc[idx, self.class_column]      
      
      input_ = input_ + ' </s>'
      target = target + " </s>"

       # tokenize inputs
      tokenized_inputs = self.tokenizer.batch_encode_plus(
          [input_], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
      )
       # tokenize targets
      tokenized_targets = self.tokenizer.batch_encode_plus(
          [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
      )

      self.inputs.append(tokenized_inputs)
      self.targets.append(tokenized_targets)

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'val', 512)
len(dataset)
# Out:
# 2000

# %%
data = dataset[42]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# i honestly don't feel discouraged today as i usually do
# sadness

# %% [markdown]
# ### Train

# %% [markdown]
# As I said above there's no need to change the model or add task specific head or any other hyperparameters, we'll just change the dataset and that's it!

# %%
# !mkdir -p t5_emotion

# %%
args_dict.update({'data_dir': 'emotion_data', 'output_dir': 't5_emotion', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)
print(args_dict)
# Out:
# {'data_dir': 'emotion_data', 'output_dir': 't5_emotion', 'model_name_or_path': 't5-base', 'tokenizer_name_or_path': 't5-base', 'max_seq_length': 512, 'learning_rate': 0.0003, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'warmup_steps': 0, 'train_batch_size': 8, 'eval_batch_size': 8, 'num_train_epochs': 2, 'gradient_accumulation_steps': 16, 'n_gpu': 1, 'early_stop_callback': False, 'fp_16': False, 'opt_level': 'O1', 'max_grad_norm': 1.0, 'seed': 42}

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return EmotionDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json from cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.configuration_utils:Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "vocab_size": 32128
# }
#
# INFO:transformers.modeling_utils:loading weights file https://cdn.huggingface.co/t5-base-pytorch_model.bin from cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.modeling_utils:Weights of T5ForConditionalGeneration not initialized from pretrained model: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                  | Type                       | Params
# -----------------------------------------------------------------------------------------------------------------
# 0   | model                                                                 | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                          | Embedding                  | 24 M
# 2   | model.encoder                                                         | T5Stack                    | 109 M
# 3   | model.encoder.block                                                   | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                                 | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                           | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                         | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 21  | model.encoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 22  | model.encoder.block.1                                                 | T5Block                    | 7 M
# 23  | model.encoder.block.1.layer                                           | ModuleList                 | 7 M
# 24  | model.encoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 25  | model.encoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 27  | model.encoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 31  | model.encoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 32  | model.encoder.block.1.layer.1                                         | T5LayerFF                  | 4 M
# 33  | model.encoder.block.1.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 37  | model.encoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 38  | model.encoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 39  | model.encoder.block.2                                                 | T5Block                    | 7 M
# 40  | model.encoder.block.2.layer                                           | ModuleList                 | 7 M
# 41  | model.encoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 42  | model.encoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 43  | model.encoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 44  | model.encoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 45  | model.encoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 48  | model.encoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 49  | model.encoder.block.2.layer.1                                         | T5LayerFF                  | 4 M
# 50  | model.encoder.block.2.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 51  | model.encoder.block.2.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 54  | model.encoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 55  | model.encoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 56  | model.encoder.block.3                                                 | T5Block                    | 7 M
# 57  | model.encoder.block.3.layer                                           | ModuleList                 | 7 M
# 58  | model.encoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 59  | model.encoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 60  | model.encoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 61  | model.encoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 62  | model.encoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 63  | model.encoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 65  | model.encoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 66  | model.encoder.block.3.layer.1                                         | T5LayerFF                  | 4 M
# 67  | model.encoder.block.3.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 68  | model.encoder.block.3.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 69  | model.encoder.block.3.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 71  | model.encoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 72  | model.encoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 73  | model.encoder.block.4                                                 | T5Block                    | 7 M
# 74  | model.encoder.block.4.layer                                           | ModuleList                 | 7 M
# 75  | model.encoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 76  | model.encoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 77  | model.encoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 78  | model.encoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 79  | model.encoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 80  | model.encoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 81  | model.encoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 82  | model.encoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 83  | model.encoder.block.4.layer.1                                         | T5LayerFF                  | 4 M
# 84  | model.encoder.block.4.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 85  | model.encoder.block.4.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 86  | model.encoder.block.4.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 87  | model.encoder.block.4.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 88  | model.encoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 89  | model.encoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 90  | model.encoder.block.5                                                 | T5Block                    | 7 M
# 91  | model.encoder.block.5.layer                                           | ModuleList                 | 7 M
# 92  | model.encoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 93  | model.encoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 94  | model.encoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 95  | model.encoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 96  | model.encoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 97  | model.encoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 98  | model.encoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 99  | model.encoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 100 | model.encoder.block.5.layer.1                                         | T5LayerFF                  | 4 M
# 101 | model.encoder.block.5.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 102 | model.encoder.block.5.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 103 | model.encoder.block.5.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 104 | model.encoder.block.5.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 106 | model.encoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 107 | model.encoder.block.6                                                 | T5Block                    | 7 M
# 108 | model.encoder.block.6.layer                                           | ModuleList                 | 7 M
# 109 | model.encoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 110 | model.encoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 111 | model.encoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 112 | model.encoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 113 | model.encoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 114 | model.encoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 115 | model.encoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 116 | model.encoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 117 | model.encoder.block.6.layer.1                                         | T5LayerFF                  | 4 M
# 118 | model.encoder.block.6.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 119 | model.encoder.block.6.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 120 | model.encoder.block.6.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 121 | model.encoder.block.6.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 122 | model.encoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 123 | model.encoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 124 | model.encoder.block.7                                                 | T5Block                    | 7 M
# 125 | model.encoder.block.7.layer                                           | ModuleList                 | 7 M
# 126 | model.encoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 127 | model.encoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 128 | model.encoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 129 | model.encoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 130 | model.encoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 131 | model.encoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 132 | model.encoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 133 | model.encoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 134 | model.encoder.block.7.layer.1                                         | T5LayerFF                  | 4 M
# 135 | model.encoder.block.7.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 136 | model.encoder.block.7.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 137 | model.encoder.block.7.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 138 | model.encoder.block.7.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 139 | model.encoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 141 | model.encoder.block.8                                                 | T5Block                    | 7 M
# 142 | model.encoder.block.8.layer                                           | ModuleList                 | 7 M
# 143 | model.encoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 144 | model.encoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 145 | model.encoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 146 | model.encoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 147 | model.encoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 148 | model.encoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 149 | model.encoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 150 | model.encoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 151 | model.encoder.block.8.layer.1                                         | T5LayerFF                  | 4 M
# 152 | model.encoder.block.8.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 153 | model.encoder.block.8.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 154 | model.encoder.block.8.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 155 | model.encoder.block.8.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 156 | model.encoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 157 | model.encoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 158 | model.encoder.block.9                                                 | T5Block                    | 7 M
# 159 | model.encoder.block.9.layer                                           | ModuleList                 | 7 M
# 160 | model.encoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 161 | model.encoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 162 | model.encoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 163 | model.encoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 164 | model.encoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 165 | model.encoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 166 | model.encoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 167 | model.encoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 168 | model.encoder.block.9.layer.1                                         | T5LayerFF                  | 4 M
# 169 | model.encoder.block.9.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 170 | model.encoder.block.9.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 171 | model.encoder.block.9.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 172 | model.encoder.block.9.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 173 | model.encoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 174 | model.encoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 175 | model.encoder.block.10                                                | T5Block                    | 7 M
# 176 | model.encoder.block.10.layer                                          | ModuleList                 | 7 M
# 177 | model.encoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 178 | model.encoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 179 | model.encoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 180 | model.encoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 181 | model.encoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 182 | model.encoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 183 | model.encoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 184 | model.encoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 185 | model.encoder.block.10.layer.1                                        | T5LayerFF                  | 4 M
# 186 | model.encoder.block.10.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 187 | model.encoder.block.10.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 188 | model.encoder.block.10.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 189 | model.encoder.block.10.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 190 | model.encoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 191 | model.encoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 192 | model.encoder.block.11                                                | T5Block                    | 7 M
# 193 | model.encoder.block.11.layer                                          | ModuleList                 | 7 M
# 194 | model.encoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 195 | model.encoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 196 | model.encoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 197 | model.encoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 198 | model.encoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 199 | model.encoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 200 | model.encoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 201 | model.encoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 202 | model.encoder.block.11.layer.1                                        | T5LayerFF                  | 4 M
# 203 | model.encoder.block.11.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 204 | model.encoder.block.11.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 205 | model.encoder.block.11.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 206 | model.encoder.block.11.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 207 | model.encoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 208 | model.encoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 209 | model.encoder.final_layer_norm                                        | T5LayerNorm                | 768
# 210 | model.encoder.dropout                                                 | Dropout                    | 0
# 211 | model.decoder                                                         | T5Stack                    | 137 M
# 212 | model.decoder.block                                                   | ModuleList                 | 113 M
# 213 | model.decoder.block.0                                                 | T5Block                    | 9 M
# 214 | model.decoder.block.0.layer                                           | ModuleList                 | 9 M
# 215 | model.decoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 216 | model.decoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 217 | model.decoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 218 | model.decoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 219 | model.decoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 220 | model.decoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 221 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 222 | model.decoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 223 | model.decoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 224 | model.decoder.block.0.layer.1                                         | T5LayerCrossAttention      | 2 M
# 225 | model.decoder.block.0.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 226 | model.decoder.block.0.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 227 | model.decoder.block.0.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 228 | model.decoder.block.0.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 229 | model.decoder.block.0.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.1.EncDecAttention.relative_attention_bias | Embedding                  | 384
# 231 | model.decoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 232 | model.decoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 233 | model.decoder.block.0.layer.2                                         | T5LayerFF                  | 4 M
# 234 | model.decoder.block.0.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 235 | model.decoder.block.0.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 236 | model.decoder.block.0.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 237 | model.decoder.block.0.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 238 | model.decoder.block.0.layer.2.layer_norm                              | T5LayerNorm                | 768
# 239 | model.decoder.block.0.layer.2.dropout                                 | Dropout                    | 0
# 240 | model.decoder.block.1                                                 | T5Block                    | 9 M
# 241 | model.decoder.block.1.layer                                           | ModuleList                 | 9 M
# 242 | model.decoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 243 | model.decoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 244 | model.decoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 245 | model.decoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 246 | model.decoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 247 | model.decoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 248 | model.decoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 249 | model.decoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 250 | model.decoder.block.1.layer.1                                         | T5LayerCrossAttention      | 2 M
# 251 | model.decoder.block.1.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 252 | model.decoder.block.1.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 253 | model.decoder.block.1.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 254 | model.decoder.block.1.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 255 | model.decoder.block.1.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 256 | model.decoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 257 | model.decoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 258 | model.decoder.block.1.layer.2                                         | T5LayerFF                  | 4 M
# 259 | model.decoder.block.1.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 260 | model.decoder.block.1.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 261 | model.decoder.block.1.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 262 | model.decoder.block.1.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 263 | model.decoder.block.1.layer.2.layer_norm                              | T5LayerNorm                | 768
# 264 | model.decoder.block.1.layer.2.dropout                                 | Dropout                    | 0
# 265 | model.decoder.block.2                                                 | T5Block                    | 9 M
# 266 | model.decoder.block.2.layer                                           | ModuleList                 | 9 M
# 267 | model.decoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 268 | model.decoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 269 | model.decoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 270 | model.decoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 271 | model.decoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 272 | model.decoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 273 | model.decoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 274 | model.decoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 275 | model.decoder.block.2.layer.1                                         | T5LayerCrossAttention      | 2 M
# 276 | model.decoder.block.2.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 277 | model.decoder.block.2.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 278 | model.decoder.block.2.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 279 | model.decoder.block.2.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 280 | model.decoder.block.2.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 281 | model.decoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 282 | model.decoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 283 | model.decoder.block.2.layer.2                                         | T5LayerFF                  | 4 M
# 284 | model.decoder.block.2.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 285 | model.decoder.block.2.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 286 | model.decoder.block.2.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 287 | model.decoder.block.2.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 288 | model.decoder.block.2.layer.2.layer_norm                              | T5LayerNorm                | 768
# 289 | model.decoder.block.2.layer.2.dropout                                 | Dropout                    | 0
# 290 | model.decoder.block.3                                                 | T5Block                    | 9 M
# 291 | model.decoder.block.3.layer                                           | ModuleList                 | 9 M
# 292 | model.decoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 293 | model.decoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 294 | model.decoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 295 | model.decoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 296 | model.decoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 297 | model.decoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 298 | model.decoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 299 | model.decoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 300 | model.decoder.block.3.layer.1                                         | T5LayerCrossAttention      | 2 M
# 301 | model.decoder.block.3.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 302 | model.decoder.block.3.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 303 | model.decoder.block.3.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 304 | model.decoder.block.3.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 305 | model.decoder.block.3.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 306 | model.decoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 307 | model.decoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 308 | model.decoder.block.3.layer.2                                         | T5LayerFF                  | 4 M
# 309 | model.decoder.block.3.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 310 | model.decoder.block.3.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 311 | model.decoder.block.3.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 312 | model.decoder.block.3.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 313 | model.decoder.block.3.layer.2.layer_norm                              | T5LayerNorm                | 768
# 314 | model.decoder.block.3.layer.2.dropout                                 | Dropout                    | 0
# 315 | model.decoder.block.4                                                 | T5Block                    | 9 M
# 316 | model.decoder.block.4.layer                                           | ModuleList                 | 9 M
# 317 | model.decoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 318 | model.decoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 319 | model.decoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 320 | model.decoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 321 | model.decoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 322 | model.decoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 323 | model.decoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 324 | model.decoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 325 | model.decoder.block.4.layer.1                                         | T5LayerCrossAttention      | 2 M
# 326 | model.decoder.block.4.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 327 | model.decoder.block.4.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 328 | model.decoder.block.4.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 329 | model.decoder.block.4.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 330 | model.decoder.block.4.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 331 | model.decoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 332 | model.decoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 333 | model.decoder.block.4.layer.2                                         | T5LayerFF                  | 4 M
# 334 | model.decoder.block.4.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 335 | model.decoder.block.4.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 336 | model.decoder.block.4.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 337 | model.decoder.block.4.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 338 | model.decoder.block.4.layer.2.layer_norm                              | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.2.dropout                                 | Dropout                    | 0
# 340 | model.decoder.block.5                                                 | T5Block                    | 9 M
# 341 | model.decoder.block.5.layer                                           | ModuleList                 | 9 M
# 342 | model.decoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 343 | model.decoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 344 | model.decoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 345 | model.decoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 346 | model.decoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 347 | model.decoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 348 | model.decoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 349 | model.decoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 350 | model.decoder.block.5.layer.1                                         | T5LayerCrossAttention      | 2 M
# 351 | model.decoder.block.5.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 352 | model.decoder.block.5.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 353 | model.decoder.block.5.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 354 | model.decoder.block.5.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 355 | model.decoder.block.5.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 356 | model.decoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 357 | model.decoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 358 | model.decoder.block.5.layer.2                                         | T5LayerFF                  | 4 M
# 359 | model.decoder.block.5.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 360 | model.decoder.block.5.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 361 | model.decoder.block.5.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 362 | model.decoder.block.5.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 363 | model.decoder.block.5.layer.2.layer_norm                              | T5LayerNorm                | 768
# 364 | model.decoder.block.5.layer.2.dropout                                 | Dropout                    | 0
# 365 | model.decoder.block.6                                                 | T5Block                    | 9 M
# 366 | model.decoder.block.6.layer                                           | ModuleList                 | 9 M
# 367 | model.decoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 368 | model.decoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 369 | model.decoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 370 | model.decoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 371 | model.decoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 372 | model.decoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 373 | model.decoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 374 | model.decoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 375 | model.decoder.block.6.layer.1                                         | T5LayerCrossAttention      | 2 M
# 376 | model.decoder.block.6.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 377 | model.decoder.block.6.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 378 | model.decoder.block.6.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 379 | model.decoder.block.6.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 380 | model.decoder.block.6.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 381 | model.decoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 382 | model.decoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 383 | model.decoder.block.6.layer.2                                         | T5LayerFF                  | 4 M
# 384 | model.decoder.block.6.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 385 | model.decoder.block.6.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 386 | model.decoder.block.6.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 387 | model.decoder.block.6.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 388 | model.decoder.block.6.layer.2.layer_norm                              | T5LayerNorm                | 768
# 389 | model.decoder.block.6.layer.2.dropout                                 | Dropout                    | 0
# 390 | model.decoder.block.7                                                 | T5Block                    | 9 M
# 391 | model.decoder.block.7.layer                                           | ModuleList                 | 9 M
# 392 | model.decoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 393 | model.decoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 394 | model.decoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 395 | model.decoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 396 | model.decoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 397 | model.decoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 398 | model.decoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 399 | model.decoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 400 | model.decoder.block.7.layer.1                                         | T5LayerCrossAttention      | 2 M
# 401 | model.decoder.block.7.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 402 | model.decoder.block.7.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 403 | model.decoder.block.7.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 404 | model.decoder.block.7.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 405 | model.decoder.block.7.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 406 | model.decoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 407 | model.decoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 408 | model.decoder.block.7.layer.2                                         | T5LayerFF                  | 4 M
# 409 | model.decoder.block.7.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 410 | model.decoder.block.7.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 411 | model.decoder.block.7.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 412 | model.decoder.block.7.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 413 | model.decoder.block.7.layer.2.layer_norm                              | T5LayerNorm                | 768
# 414 | model.decoder.block.7.layer.2.dropout                                 | Dropout                    | 0
# 415 | model.decoder.block.8                                                 | T5Block                    | 9 M
# 416 | model.decoder.block.8.layer                                           | ModuleList                 | 9 M
# 417 | model.decoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 418 | model.decoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 419 | model.decoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 420 | model.decoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 421 | model.decoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 422 | model.decoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 423 | model.decoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 424 | model.decoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 425 | model.decoder.block.8.layer.1                                         | T5LayerCrossAttention      | 2 M
# 426 | model.decoder.block.8.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 427 | model.decoder.block.8.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 428 | model.decoder.block.8.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 429 | model.decoder.block.8.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 430 | model.decoder.block.8.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 431 | model.decoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 432 | model.decoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 433 | model.decoder.block.8.layer.2                                         | T5LayerFF                  | 4 M
# 434 | model.decoder.block.8.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 435 | model.decoder.block.8.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 436 | model.decoder.block.8.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 437 | model.decoder.block.8.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 438 | model.decoder.block.8.layer.2.layer_norm                              | T5LayerNorm                | 768
# 439 | model.decoder.block.8.layer.2.dropout                                 | Dropout                    | 0
# 440 | model.decoder.block.9                                                 | T5Block                    | 9 M
# 441 | model.decoder.block.9.layer                                           | ModuleList                 | 9 M
# 442 | model.decoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 443 | model.decoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 444 | model.decoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 445 | model.decoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 446 | model.decoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 447 | model.decoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 448 | model.decoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 449 | model.decoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 450 | model.decoder.block.9.layer.1                                         | T5LayerCrossAttention      | 2 M
# 451 | model.decoder.block.9.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 452 | model.decoder.block.9.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 453 | model.decoder.block.9.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 454 | model.decoder.block.9.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 455 | model.decoder.block.9.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 456 | model.decoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 457 | model.decoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 458 | model.decoder.block.9.layer.2                                         | T5LayerFF                  | 4 M
# 459 | model.decoder.block.9.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 460 | model.decoder.block.9.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 461 | model.decoder.block.9.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 462 | model.decoder.block.9.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 463 | model.decoder.block.9.layer.2.layer_norm                              | T5LayerNorm                | 768
# 464 | model.decoder.block.9.layer.2.dropout                                 | Dropout                    | 0
# 465 | model.decoder.block.10                                                | T5Block                    | 9 M
# 466 | model.decoder.block.10.layer                                          | ModuleList                 | 9 M
# 467 | model.decoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 468 | model.decoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 469 | model.decoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 470 | model.decoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 471 | model.decoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 472 | model.decoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 473 | model.decoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 474 | model.decoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 475 | model.decoder.block.10.layer.1                                        | T5LayerCrossAttention      | 2 M
# 476 | model.decoder.block.10.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 477 | model.decoder.block.10.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 478 | model.decoder.block.10.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 479 | model.decoder.block.10.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 480 | model.decoder.block.10.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 481 | model.decoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 482 | model.decoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 483 | model.decoder.block.10.layer.2                                        | T5LayerFF                  | 4 M
# 484 | model.decoder.block.10.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 485 | model.decoder.block.10.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 486 | model.decoder.block.10.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 487 | model.decoder.block.10.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 488 | model.decoder.block.10.layer.2.layer_norm                             | T5LayerNorm                | 768
# 489 | model.decoder.block.10.layer.2.dropout                                | Dropout                    | 0
# 490 | model.decoder.block.11                                                | T5Block                    | 9 M
# 491 | model.decoder.block.11.layer                                          | ModuleList                 | 9 M
# 492 | model.decoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 493 | model.decoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 494 | model.decoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 495 | model.decoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 496 | model.decoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 497 | model.decoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 498 | model.decoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 499 | model.decoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 500 | model.decoder.block.11.layer.1                                        | T5LayerCrossAttention      | 2 M
# 501 | model.decoder.block.11.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 502 | model.decoder.block.11.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 503 | model.decoder.block.11.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 504 | model.decoder.block.11.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 505 | model.decoder.block.11.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 506 | model.decoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 507 | model.decoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 508 | model.decoder.block.11.layer.2                                        | T5LayerFF                  | 4 M
# 509 | model.decoder.block.11.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 510 | model.decoder.block.11.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 511 | model.decoder.block.11.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 512 | model.decoder.block.11.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 513 | model.decoder.block.11.layer.2.layer_norm                             | T5LayerNorm                | 768
# 514 | model.decoder.block.11.layer.2.dropout                                | Dropout                    | 0
# 515 | model.decoder.final_layer_norm                                        | T5LayerNorm                | 768
# 516 | model.decoder.dropout                                                 | Dropout                    | 0
# 517 | model.lm_head                                                         | Linear                     | 24 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_val_loss = tensor(0.0846, device='cuda:0')
#
# INFO:__main__:loss = tensor(0.0290, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0290, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0846, device='cuda:0')
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_train_loss = tensor(0.5601, device='cuda:0')
#
# INFO:__main__:avg_val_loss = tensor(0.0696, device='cuda:0')
#
# INFO:__main__:epoch = 0
#
# INFO:__main__:loss = tensor(0.0134, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0134, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0696, device='cuda:0')
# 1

# %% [markdown]
# ### Eval

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'test', 512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
it = iter(loader)

# %%
batch = next(it)
batch["source_ids"].shape
# Out:
# torch.Size([32, 512])

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    c = texts[i]
    lines = textwrap.wrap("text:\n%s\n" % c, width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# text: i feel like ive come a long way and im proud of what ive achieved not only this week but this
# year as well
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel unfathomably rich in having had a healthy pregnancy so far
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: im just feeling emo and bitchy atm
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i always feel troubled when we re on the road touring living in a van or more recently in the
# circus buses no place to hang my hat as the song lyric has it
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i still feel confused and guilty about the whole thing
#
# Actual sentiment: fear
# predicted sentiment: fear
# =====================================================================
#
# text: i feel immensely distracted by the barrage of media i receive solicit
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: im feeling too tortured to write today
#
# Actual sentiment: fear
# predicted sentiment: anger
# =====================================================================
#
# text: i have the joy of allowing kids to feel like the valued treasures that they are and to just
# have a blast being a kid alongside with them but can i just say its an incredibly humbling
# experience to have influence into a childs life and to know that what you do and say is being
# internalized
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i dont want flowers or candy but the kind of guy that knows i like thinly sliced limes in my
# mineral water because it makes me feel glamorous and is humored by how pretentious that is
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i just was expressing myself and her unexpected and kind gesture made me feel bad for a short
# moment as that was not my intent but for a larger moment which remains with me it reminded me of my
# blessings like having good friends that have your back
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: im feeling brave ill snatch him to on my lap and after a few seconds of struggling he
# completely relaxes and submits to mommy scratches
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: im sick of feeling unimportant like nobody needs me
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel like these unfortunate events fit in with my thought quote i posted above
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel like they don t think it s sincere when it really is she told us exclusively
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel a little low about being in japan and i always feel pangs of guilt when i fail to
# appreciate my living situation and decisions
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i couldn t help but feel pissed off at both sides of the debate and the unnecessary dichotomy
# itself
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i felt so bad for the bad grade and feeling like having to hide it that i didnt know what to
# say except to declare in all my frustration that i hated school
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i do feel proud and happy and also very grateful to all who read me
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i am going to have to check on in just a few minutes but there is this clock up above the
# screen that keeps ticking down the minutes i have left so am feeling a bit frantic
#
# Actual sentiment: fear
# predicted sentiment: fear
# =====================================================================
#
# text: i am feeling bitchy this evening
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i feel like my room is messy if theyre open
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: im starting to feel really pathetic giving the bulk of my enthusiasm these days to the
# kardashians us weekly and roseanne marathons and completely ignoring this blog
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i am feeling content and happy with myself
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel slightly saddened to know that some of the kids have also resigned during my absence
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel that passionate about
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i too feel a sense of melancholy for them
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i can t quite figure out how i feel i m not devastated like i was with lucy and i m not sure
# if that s because it s easier to do after the first time or what
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel ashamed of you
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i like the fresh feeling of sweet he gave me
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel so jaded and bored
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel fake because i think if you really want to have a good conversation and make good
# contact you have to appear especially self confident and even risk talking to some people which are
# no good to talk to at all until you meet one person which you have a good connection to
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i am feeling pretty fearless
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================

# %% [markdown]
# #### Test Metrics

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'test', 512)
loader = DataLoader(dataset, batch_size=32, num_workers=4)
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=63.0), HTML(value='')))

# %%
for i, out in enumerate(outputs):
  if out not in emotions:
    print(i, 'detected invalid prediction')

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.929

# %%
print(metrics.classification_report(targets, outputs))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.94      0.93      0.93       275
#         fear       0.86      0.92      0.89       224
#          joy       0.97      0.93      0.95       695
#         love       0.79      0.89      0.84       159
#      sadness       0.97      0.96      0.97       581
#     surprise       0.75      0.74      0.75        66
#
#     accuracy                           0.93      2000
#    macro avg       0.88      0.90      0.89      2000
# weighted avg       0.93      0.93      0.93      2000

# %% [markdown]
# Now lets plot  the confusion matrix and see for which classes our model is getting confused

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
cm = metrics.confusion_matrix(targets, outputs)

# %%
df_cm = pd.DataFrame(cm, index = ["anger", "fear", "joy", "love", "sadness", "surprise"], columns = ["anger", "fear", "joy", "love", "sadness", "surprise"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap='Purples', fmt='g')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %% [markdown]
# From the above plot we can see that the most confused classes are 'joy' and 'love' which seems obivous as these two emotions are really close. We can say the same thing 'surprise' and 'anger' as well. So our model is doing pretty well.

# %% [markdown]
# ## SWAG
#
# Now lets try a more challenging task and see how it performs.
#
# SWAG is a natural language inference and commonsense reasoning task proposed in this [paper](https://arxiv.org/pdf/1808.05326.pdf).
#
# The basic task is that  a model is
# given a context **c = (s, n)**: a complete sentence
# **s** and a noun phrase **n** that begins a second sentence, as well as a list of possible verb phrase sentence endings **V**. The model must then
# select the most appropriate verb phrase **v** in **V**. For example
#
# On stage, a woman takes a seat at the piano. She
#
# a) sits on a bench as her sister plays with the doll.
#
# b) smiles with someone as the music plays.
#
# c) is in the crowd, watching the dancers.
#
# **d) nervously sets her fingers on the keys.**
#
# The correct answer is bolded. Given the above example the model should select **nervously sets her fingers on the keys** as the most appropriate verb phrase
#
# To frame this task in text-2-text setting the example is processed as below.
#
# context: context_text options: 1: option_1 2: option_2 3: option_3 4: option_4
#
# and if the actual label is 1 then the model is asked to predict the text '1'. Here's how the above example will be processed
#
# **Input**
#
# context: On stage, a woman takes a seat at the piano. She  options: 1: sits on a bench as her sister plays with the doll. 2: smiles with someone as the music plays. 3: is in the crowd, watching the dancers. 4: nervously sets her fingers on the keys.
#
# **Target**
#
# 4
#
# This is just one possible way to process these examples, there are various other ways we can formulate this problem in text-2-text setting but that's for later.

# %% [markdown]
# ### Dataset

# %%
import csv
from dataclasses import dataclass

from enum import Enum
from typing import List, Optional
from transformers import PreTrainedTokenizer

# %%
# !wget https://raw.githubusercontent.com/rowanz/swagaf/master/data/train.csv
# !wget https://raw.githubusercontent.com/rowanz/swagaf/master/data/val.csv

# !mkdir swag_data
# !mv *.csv swag_data
# Out:
# --2024-01-27 20:28:41--  https://raw.githubusercontent.com/rowanz/swagaf/master/data/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28243333 (27M) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  26.93M   104MB/s    in 0.3s
#
# 2024-01-27 20:28:41 (104 MB/s) - ‘train.csv’ saved [28243333/28243333]
#
# --2024-01-27 20:28:42--  https://raw.githubusercontent.com/rowanz/swagaf/master/data/val.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7893588 (7.5M) [text/plain]
# Saving to: ‘val.csv’
#
# val.csv             100%[===================>]   7.53M  --.-KB/s    in 0.06s
#
# 2024-01-27 20:28:42 (120 MB/s) - ‘val.csv’ saved [7893588/7893588]
#
# mkdir: cannot create directory ‘swag_data’: File exists

# %%
# below code is adapted from https://github.com/huggingface/transformers/blob/master/examples/multiple-choice/utils_multiple_choice.py

@dataclass(frozen=True)
class InputExample:
    """
    A single training/test example for multiple choice
    Args:
        example_id: Unique id for the example.
        question: string. The untokenized text of the second sequence (question).
        contexts: list of str. The untokenized text of the first sequence (context of corresponding question).
        endings: list of str. multiple choice's options. Its length must be equal to contexts' length.
        label: (Optional) string. The label of the example. This should be
        specified for train and dev examples, but not for test examples.
    """

    example_id: str
    context: str
    endings: List[str]
    label: Optional[str]

class Split(Enum):
    train = "train"
    dev = "dev"
    test = "test"

class DataProcessor:
    """Base class for data converters for multiple choice data sets."""

    def get_train_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the train set."""
        raise NotImplementedError()

    def get_dev_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the dev set."""
        raise NotImplementedError()

    def get_test_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the test set."""
        raise NotImplementedError()

    def get_labels(self):
        """Gets the list of labels for this data set."""
        raise NotImplementedError()

class SwagProcessor(DataProcessor):
    """Processor for the SWAG data set."""

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "train.csv")), "train")

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "val.csv")), "dev")

    def get_test_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        raise ValueError(
            "For swag testing, the input file does not contain a label column. It can not be tested in current code"
            "setting!"
        )
        return self._create_examples(self._read_csv(os.path.join(data_dir, "test.csv")), "test")

    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3"]

    def _read_csv(self, input_file):
        with open(input_file, "r", encoding="utf-8") as f:
            return list(csv.reader(f))

    def _create_examples(self, lines: List[List[str]], type: str):
        """Creates examples for the training and dev sets."""
        if type == "train" and lines[0][-1] != "label":
            raise ValueError("For training, the input file must contain a label column.")

        examples = [
            InputExample(
                example_id=line[2],
                # common beginning of each
                # choice is stored in "sent2".
                context=line[3],
                endings=[line[7], line[8], line[9], line[10]],
                label=line[11],
            )
            for line in lines[1:]  # we skip the line with the column names
        ]

        return examples

# %%
class SwagDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.data_dir = data_dir
    self.type_path = type_path
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self.proc = SwagProcessor()

    self._build()
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def __len__(self):
    return len(self.inputs)
  
  def _build(self):
    if self.type_path == 'train':
      examples = self.proc.get_train_examples(self.data_dir)
    else:
      examples = self.proc.get_dev_examples(self.data_dir)
    
    for example in examples:
      self._create_features(example)
  
  def _create_features(self, example):
    input_ = example.context
    options = ['%s: %s' % (i, option) for i, option in zip('1234', example.endings)]
    options = " ".join(options)
    input_ = "context: %s  options: %s </s>" % (input_, options)
    target = "%s </s>" % str(int(example.label) + 1)

    # tokenize inputs
    tokenized_inputs = self.tokenizer.batch_encode_plus(
        [input_], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
    )
    # tokenize targets
    tokenized_targets = self.tokenizer.batch_encode_plus(
        [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
    )

    self.inputs.append(tokenized_inputs)
    self.targets.append(tokenized_targets)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
dataset = SwagDataset(tokenizer, data_dir='swag_data', type_path='val')
len(dataset)
# Out:
# INFO:__main__:LOOKING AT swag_data dev
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2619: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5.py:303: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# 20006

# %%
data = dataset[69]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# context: A little girl plays softly the drums holding two sticks while she is singing on a microphone. The, the girl options: 1: take in the greeting and an asian girl followed by two people standing on stage. 2: holds the microphone up and begins to girl dance an entire time. 3: claps the girls hands anxiously. 4: plays more fast the drums.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# 4</s>

# %% [markdown]
# ### Train

# %%
# !mkdir -p t5_swag

# %%
args_dict.update({'data_dir': 'swag_data', 'output_dir': 't5_swag', 'num_train_epochs': 3})
args = argparse.Namespace(**args_dict)
print(args_dict)
# Out:
# {'data_dir': 'swag_data', 'output_dir': 't5_swag', 'model_name_or_path': 't5-base', 'tokenizer_name_or_path': 't5-base', 'max_seq_length': 512, 'learning_rate': 0.0003, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'warmup_steps': 0, 'train_batch_size': 8, 'eval_batch_size': 8, 'num_train_epochs': 3, 'gradient_accumulation_steps': 16, 'n_gpu': 1, 'early_stop_callback': False, 'fp_16': False, 'opt_level': 'O1', 'max_grad_norm': 1.0, 'seed': 42}

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
    #dirpath=args.output_dir, filename="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return SwagDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                | Type                       | Params
# ---------------------------------------------------------------------------------------------------------------
# 0   | model                                                               | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                        | Embedding                  | 24 M
# 2   | model.encoder                                                       | T5Stack                    | 109 M
# 3   | model.encoder.block                                                 | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                               | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                         | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                       | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 21  | model.encoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 768
# 22  | model.encoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 23  | model.encoder.block.1                                               | T5Block                    | 7 M
# 24  | model.encoder.block.1.layer                                         | ModuleList                 | 7 M
# 25  | model.encoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 27  | model.encoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 31  | model.encoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 768
# 32  | model.encoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 33  | model.encoder.block.1.layer.1                                       | T5LayerFF                  | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 37  | model.encoder.block.1.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 38  | model.encoder.block.1.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 39  | model.encoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 768
# 40  | model.encoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 41  | model.encoder.block.2                                               | T5Block                    | 7 M
# 42  | model.encoder.block.2.layer                                         | ModuleList                 | 7 M
# 43  | model.encoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 44  | model.encoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 45  | model.encoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 48  | model.encoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 49  | model.encoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 768
# 50  | model.encoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 51  | model.encoder.block.2.layer.1                                       | T5LayerFF                  | 4 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 54  | model.encoder.block.2.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 55  | model.encoder.block.2.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 56  | model.encoder.block.2.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 57  | model.encoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 768
# 58  | model.encoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 59  | model.encoder.block.3                                               | T5Block                    | 7 M
# 60  | model.encoder.block.3.layer                                         | ModuleList                 | 7 M
# 61  | model.encoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 62  | model.encoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 63  | model.encoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 65  | model.encoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 66  | model.encoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 67  | model.encoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 768
# 68  | model.encoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 69  | model.encoder.block.3.layer.1                                       | T5LayerFF                  | 4 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 71  | model.encoder.block.3.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 72  | model.encoder.block.3.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 73  | model.encoder.block.3.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 74  | model.encoder.block.3.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 75  | model.encoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 768
# 76  | model.encoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 77  | model.encoder.block.4                                               | T5Block                    | 7 M
# 78  | model.encoder.block.4.layer                                         | ModuleList                 | 7 M
# 79  | model.encoder.block.4.layer.0                                       | T5LayerSelfAttention       | 2 M
# 80  | model.encoder.block.4.layer.0.SelfAttention                         | T5Attention                | 2 M
# 81  | model.encoder.block.4.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 82  | model.encoder.block.4.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 83  | model.encoder.block.4.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 84  | model.encoder.block.4.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 85  | model.encoder.block.4.layer.0.layer_norm                            | T5LayerNorm                | 768
# 86  | model.encoder.block.4.layer.0.dropout                               | Dropout                    | 0
# 87  | model.encoder.block.4.layer.1                                       | T5LayerFF                  | 4 M
# 88  | model.encoder.block.4.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 89  | model.encoder.block.4.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 90  | model.encoder.block.4.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 91  | model.encoder.block.4.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 92  | model.encoder.block.4.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 93  | model.encoder.block.4.layer.1.layer_norm                            | T5LayerNorm                | 768
# 94  | model.encoder.block.4.layer.1.dropout                               | Dropout                    | 0
# 95  | model.encoder.block.5                                               | T5Block                    | 7 M
# 96  | model.encoder.block.5.layer                                         | ModuleList                 | 7 M
# 97  | model.encoder.block.5.layer.0                                       | T5LayerSelfAttention       | 2 M
# 98  | model.encoder.block.5.layer.0.SelfAttention                         | T5Attention                | 2 M
# 99  | model.encoder.block.5.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 100 | model.encoder.block.5.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 101 | model.encoder.block.5.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 102 | model.encoder.block.5.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 103 | model.encoder.block.5.layer.0.layer_norm                            | T5LayerNorm                | 768
# 104 | model.encoder.block.5.layer.0.dropout                               | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1                                       | T5LayerFF                  | 4 M
# 106 | model.encoder.block.5.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 107 | model.encoder.block.5.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 108 | model.encoder.block.5.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 109 | model.encoder.block.5.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 110 | model.encoder.block.5.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 111 | model.encoder.block.5.layer.1.layer_norm                            | T5LayerNorm                | 768
# 112 | model.encoder.block.5.layer.1.dropout                               | Dropout                    | 0
# 113 | model.encoder.block.6                                               | T5Block                    | 7 M
# 114 | model.encoder.block.6.layer                                         | ModuleList                 | 7 M
# 115 | model.encoder.block.6.layer.0                                       | T5LayerSelfAttention       | 2 M
# 116 | model.encoder.block.6.layer.0.SelfAttention                         | T5Attention                | 2 M
# 117 | model.encoder.block.6.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 118 | model.encoder.block.6.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 119 | model.encoder.block.6.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 120 | model.encoder.block.6.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 121 | model.encoder.block.6.layer.0.layer_norm                            | T5LayerNorm                | 768
# 122 | model.encoder.block.6.layer.0.dropout                               | Dropout                    | 0
# 123 | model.encoder.block.6.layer.1                                       | T5LayerFF                  | 4 M
# 124 | model.encoder.block.6.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 125 | model.encoder.block.6.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 126 | model.encoder.block.6.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 127 | model.encoder.block.6.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 128 | model.encoder.block.6.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 129 | model.encoder.block.6.layer.1.layer_norm                            | T5LayerNorm                | 768
# 130 | model.encoder.block.6.layer.1.dropout                               | Dropout                    | 0
# 131 | model.encoder.block.7                                               | T5Block                    | 7 M
# 132 | model.encoder.block.7.layer                                         | ModuleList                 | 7 M
# 133 | model.encoder.block.7.layer.0                                       | T5LayerSelfAttention       | 2 M
# 134 | model.encoder.block.7.layer.0.SelfAttention                         | T5Attention                | 2 M
# 135 | model.encoder.block.7.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 136 | model.encoder.block.7.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 137 | model.encoder.block.7.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 138 | model.encoder.block.7.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 139 | model.encoder.block.7.layer.0.layer_norm                            | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.0.dropout                               | Dropout                    | 0
# 141 | model.encoder.block.7.layer.1                                       | T5LayerFF                  | 4 M
# 142 | model.encoder.block.7.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 143 | model.encoder.block.7.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 144 | model.encoder.block.7.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 145 | model.encoder.block.7.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 146 | model.encoder.block.7.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 147 | model.encoder.block.7.layer.1.layer_norm                            | T5LayerNorm                | 768
# 148 | model.encoder.block.7.layer.1.dropout                               | Dropout                    | 0
# 149 | model.encoder.block.8                                               | T5Block                    | 7 M
# 150 | model.encoder.block.8.layer                                         | ModuleList                 | 7 M
# 151 | model.encoder.block.8.layer.0                                       | T5LayerSelfAttention       | 2 M
# 152 | model.encoder.block.8.layer.0.SelfAttention                         | T5Attention                | 2 M
# 153 | model.encoder.block.8.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 154 | model.encoder.block.8.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 155 | model.encoder.block.8.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 156 | model.encoder.block.8.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 157 | model.encoder.block.8.layer.0.layer_norm                            | T5LayerNorm                | 768
# 158 | model.encoder.block.8.layer.0.dropout                               | Dropout                    | 0
# 159 | model.encoder.block.8.layer.1                                       | T5LayerFF                  | 4 M
# 160 | model.encoder.block.8.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 161 | model.encoder.block.8.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 162 | model.encoder.block.8.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 163 | model.encoder.block.8.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 164 | model.encoder.block.8.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 165 | model.encoder.block.8.layer.1.layer_norm                            | T5LayerNorm                | 768
# 166 | model.encoder.block.8.layer.1.dropout                               | Dropout                    | 0
# 167 | model.encoder.block.9                                               | T5Block                    | 7 M
# 168 | model.encoder.block.9.layer                                         | ModuleList                 | 7 M
# 169 | model.encoder.block.9.layer.0                                       | T5LayerSelfAttention       | 2 M
# 170 | model.encoder.block.9.layer.0.SelfAttention                         | T5Attention                | 2 M
# 171 | model.encoder.block.9.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 172 | model.encoder.block.9.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 173 | model.encoder.block.9.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 174 | model.encoder.block.9.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 175 | model.encoder.block.9.layer.0.layer_norm                            | T5LayerNorm                | 768
# 176 | model.encoder.block.9.layer.0.dropout                               | Dropout                    | 0
# 177 | model.encoder.block.9.layer.1                                       | T5LayerFF                  | 4 M
# 178 | model.encoder.block.9.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 179 | model.encoder.block.9.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 180 | model.encoder.block.9.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 181 | model.encoder.block.9.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 182 | model.encoder.block.9.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 183 | model.encoder.block.9.layer.1.layer_norm                            | T5LayerNorm                | 768
# 184 | model.encoder.block.9.layer.1.dropout                               | Dropout                    | 0
# 185 | model.encoder.block.10                                              | T5Block                    | 7 M
# 186 | model.encoder.block.10.layer                                        | ModuleList                 | 7 M
# 187 | model.encoder.block.10.layer.0                                      | T5LayerSelfAttention       | 2 M
# 188 | model.encoder.block.10.layer.0.SelfAttention                        | T5Attention                | 2 M
# 189 | model.encoder.block.10.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 190 | model.encoder.block.10.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 191 | model.encoder.block.10.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 192 | model.encoder.block.10.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 193 | model.encoder.block.10.layer.0.layer_norm                           | T5LayerNorm                | 768
# 194 | model.encoder.block.10.layer.0.dropout                              | Dropout                    | 0
# 195 | model.encoder.block.10.layer.1                                      | T5LayerFF                  | 4 M
# 196 | model.encoder.block.10.layer.1.DenseReluDense                       | T5DenseActDense            | 4 M
# 197 | model.encoder.block.10.layer.1.DenseReluDense.wi                    | Linear                     | 2 M
# 198 | model.encoder.block.10.layer.1.DenseReluDense.wo                    | Linear                     | 2 M
# 199 | model.encoder.block.10.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 200 | model.encoder.block.10.layer.1.DenseReluDense.act                   | ReLU                       | 0
# 201 | model.encoder.block.10.layer.1.layer_norm                           | T5LayerNorm                | 768
# 202 | model.encoder.block.10.layer.1.dropout                              | Dropout                    | 0
# 203 | model.encoder.block.11                                              | T5Block                    | 7 M
# 204 | model.encoder.block.11.layer                                        | ModuleList                 | 7 M
# 205 | model.encoder.block.11.layer.0                                      | T5LayerSelfAttention       | 2 M
# 206 | model.encoder.block.11.layer.0.SelfAttention                        | T5Attention                | 2 M
# 207 | model.encoder.block.11.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 208 | model.encoder.block.11.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 209 | model.encoder.block.11.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 210 | model.encoder.block.11.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 211 | model.encoder.block.11.layer.0.layer_norm                           | T5LayerNorm                | 768
# 212 | model.encoder.block.11.layer.0.dropout                              | Dropout                    | 0
# 213 | model.encoder.block.11.layer.1                                      | T5LayerFF                  | 4 M
# 214 | model.encoder.block.11.layer.1.DenseReluDense                       | T5DenseActDense            | 4 M
# 215 | model.encoder.block.11.layer.1.DenseReluDense.wi                    | Linear                     | 2 M
# 216 | model.encoder.block.11.layer.1.DenseReluDense.wo                    | Linear                     | 2 M
# 217 | model.encoder.block.11.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 218 | model.encoder.block.11.layer.1.DenseReluDense.act                   | ReLU                       | 0
# 219 | model.encoder.block.11.layer.1.layer_norm                           | T5LayerNorm                | 768
# 220 | model.encoder.block.11.layer.1.dropout                              | Dropout                    | 0
# 221 | model.encoder.final_layer_norm                                      | T5LayerNorm                | 768
# 222 | model.encoder.dropout                                               | Dropout                    | 0
# 223 | model.decoder                                                       | T5Stack                    | 137 M
# 224 | model.decoder.block                                                 | ModuleList                 | 113 M
# 225 | model.decoder.block.0                                               | T5Block                    | 9 M
# 226 | model.decoder.block.0.layer                                         | ModuleList                 | 9 M
# 227 | model.decoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 228 | model.decoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 229 | model.decoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 231 | model.decoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 232 | model.decoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 233 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 384
# 234 | model.decoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 768
# 235 | model.decoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 236 | model.decoder.block.0.layer.1                                       | T5LayerCrossAttention      | 2 M
# 237 | model.decoder.block.0.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 238 | model.decoder.block.0.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 239 | model.decoder.block.0.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 240 | model.decoder.block.0.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 241 | model.decoder.block.0.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 242 | model.decoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 768
# 243 | model.decoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 244 | model.decoder.block.0.layer.2                                       | T5LayerFF                  | 4 M
# 245 | model.decoder.block.0.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 246 | model.decoder.block.0.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 247 | model.decoder.block.0.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 248 | model.decoder.block.0.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 249 | model.decoder.block.0.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 250 | model.decoder.block.0.layer.2.layer_norm                            | T5LayerNorm                | 768
# 251 | model.decoder.block.0.layer.2.dropout                               | Dropout                    | 0
# 252 | model.decoder.block.1                                               | T5Block                    | 9 M
# 253 | model.decoder.block.1.layer                                         | ModuleList                 | 9 M
# 254 | model.decoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 255 | model.decoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 256 | model.decoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 257 | model.decoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 258 | model.decoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 259 | model.decoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 260 | model.decoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 768
# 261 | model.decoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 262 | model.decoder.block.1.layer.1                                       | T5LayerCrossAttention      | 2 M
# 263 | model.decoder.block.1.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 264 | model.decoder.block.1.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 265 | model.decoder.block.1.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 266 | model.decoder.block.1.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 267 | model.decoder.block.1.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 268 | model.decoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 768
# 269 | model.decoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 270 | model.decoder.block.1.layer.2                                       | T5LayerFF                  | 4 M
# 271 | model.decoder.block.1.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 272 | model.decoder.block.1.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 273 | model.decoder.block.1.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 274 | model.decoder.block.1.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 275 | model.decoder.block.1.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 276 | model.decoder.block.1.layer.2.layer_norm                            | T5LayerNorm                | 768
# 277 | model.decoder.block.1.layer.2.dropout                               | Dropout                    | 0
# 278 | model.decoder.block.2                                               | T5Block                    | 9 M
# 279 | model.decoder.block.2.layer                                         | ModuleList                 | 9 M
# 280 | model.decoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 281 | model.decoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 282 | model.decoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 283 | model.decoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 284 | model.decoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 285 | model.decoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 286 | model.decoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 768
# 287 | model.decoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 288 | model.decoder.block.2.layer.1                                       | T5LayerCrossAttention      | 2 M
# 289 | model.decoder.block.2.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 290 | model.decoder.block.2.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 291 | model.decoder.block.2.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 292 | model.decoder.block.2.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 293 | model.decoder.block.2.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 294 | model.decoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 768
# 295 | model.decoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 296 | model.decoder.block.2.layer.2                                       | T5LayerFF                  | 4 M
# 297 | model.decoder.block.2.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 298 | model.decoder.block.2.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 299 | model.decoder.block.2.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 300 | model.decoder.block.2.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 301 | model.decoder.block.2.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 302 | model.decoder.block.2.layer.2.layer_norm                            | T5LayerNorm                | 768
# 303 | model.decoder.block.2.layer.2.dropout                               | Dropout                    | 0
# 304 | model.decoder.block.3                                               | T5Block                    | 9 M
# 305 | model.decoder.block.3.layer                                         | ModuleList                 | 9 M
# 306 | model.decoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 307 | model.decoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 308 | model.decoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 309 | model.decoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 310 | model.decoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 311 | model.decoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 312 | model.decoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 768
# 313 | model.decoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 314 | model.decoder.block.3.layer.1                                       | T5LayerCrossAttention      | 2 M
# 315 | model.decoder.block.3.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 316 | model.decoder.block.3.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 317 | model.decoder.block.3.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 318 | model.decoder.block.3.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 319 | model.decoder.block.3.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 320 | model.decoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 768
# 321 | model.decoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 322 | model.decoder.block.3.layer.2                                       | T5LayerFF                  | 4 M
# 323 | model.decoder.block.3.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 324 | model.decoder.block.3.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 325 | model.decoder.block.3.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 326 | model.decoder.block.3.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 327 | model.decoder.block.3.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 328 | model.decoder.block.3.layer.2.layer_norm                            | T5LayerNorm                | 768
# 329 | model.decoder.block.3.layer.2.dropout                               | Dropout                    | 0
# 330 | model.decoder.block.4                                               | T5Block                    | 9 M
# 331 | model.decoder.block.4.layer                                         | ModuleList                 | 9 M
# 332 | model.decoder.block.4.layer.0                                       | T5LayerSelfAttention       | 2 M
# 333 | model.decoder.block.4.layer.0.SelfAttention                         | T5Attention                | 2 M
# 334 | model.decoder.block.4.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 335 | model.decoder.block.4.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 336 | model.decoder.block.4.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 337 | model.decoder.block.4.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 338 | model.decoder.block.4.layer.0.layer_norm                            | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.0.dropout                               | Dropout                    | 0
# 340 | model.decoder.block.4.layer.1                                       | T5LayerCrossAttention      | 2 M
# 341 | model.decoder.block.4.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 342 | model.decoder.block.4.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 343 | model.decoder.block.4.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 344 | model.decoder.block.4.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 345 | model.decoder.block.4.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 346 | model.decoder.block.4.layer.1.layer_norm                            | T5LayerNorm                | 768
# 347 | model.decoder.block.4.layer.1.dropout                               | Dropout                    | 0
# 348 | model.decoder.block.4.layer.2                                       | T5LayerFF                  | 4 M
# 349 | model.decoder.block.4.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 350 | model.decoder.block.4.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 351 | model.decoder.block.4.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 352 | model.decoder.block.4.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 353 | model.decoder.block.4.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 354 | model.decoder.block.4.layer.2.layer_norm                            | T5LayerNorm                | 768
# 355 | model.decoder.block.4.layer.2.dropout                               | Dropout                    | 0
# 356 | model.decoder.block.5                                               | T5Block                    | 9 M
# 357 | model.decoder.block.5.layer                                         | ModuleList                 | 9 M
# 358 | model.decoder.block.5.layer.0                                       | T5LayerSelfAttention       | 2 M
# 359 | model.decoder.block.5.layer.0.SelfAttention                         | T5Attention                | 2 M
# 360 | model.decoder.block.5.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 361 | model.decoder.block.5.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 362 | model.decoder.block.5.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 363 | model.decoder.block.5.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 364 | model.decoder.block.5.layer.0.layer_norm                            | T5LayerNorm                | 768
# 365 | model.decoder.block.5.layer.0.dropout                               | Dropout                    | 0
# 366 | model.decoder.block.5.layer.1                                       | T5LayerCrossAttention      | 2 M
# 367 | model.decoder.block.5.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 368 | model.decoder.block.5.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 369 | model.decoder.block.5.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 370 | model.decoder.block.5.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 371 | model.decoder.block.5.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 372 | model.decoder.block.5.layer.1.layer_norm                            | T5LayerNorm                | 768
# 373 | model.decoder.block.5.layer.1.dropout                               | Dropout                    | 0
# 374 | model.decoder.block.5.layer.2                                       | T5LayerFF                  | 4 M
# 375 | model.decoder.block.5.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 376 | model.decoder.block.5.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 377 | model.decoder.block.5.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 378 | model.decoder.block.5.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 379 | model.decoder.block.5.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 380 | model.decoder.block.5.layer.2.layer_norm                            | T5LayerNorm                | 768
# 381 | model.decoder.block.5.layer.2.dropout                               | Dropout                    | 0
# 382 | model.decoder.block.6                                               | T5Block                    | 9 M
# 383 | model.decoder.block.6.layer                                         | ModuleList                 | 9 M
# 384 | model.decoder.block.6.layer.0                                       | T5LayerSelfAttention       | 2 M
# 385 | model.decoder.block.6.layer.0.SelfAttention                         | T5Attention                | 2 M
# 386 | model.decoder.block.6.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 387 | model.decoder.block.6.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 388 | model.decoder.block.6.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 389 | model.decoder.block.6.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 390 | model.decoder.block.6.layer.0.layer_norm                            | T5LayerNorm                | 768
# 391 | model.decoder.block.6.layer.0.dropout                               | Dropout                    | 0
# 392 | model.decoder.block.6.layer.1                                       | T5LayerCrossAttention      | 2 M
# 393 | model.decoder.block.6.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 394 | model.decoder.block.6.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 395 | model.decoder.block.6.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 396 | model.decoder.block.6.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 397 | model.decoder.block.6.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 398 | model.decoder.block.6.layer.1.layer_norm                            | T5LayerNorm                | 768
# 399 | model.decoder.block.6.layer.1.dropout                               | Dropout                    | 0
# 400 | model.decoder.block.6.layer.2                                       | T5LayerFF                  | 4 M
# 401 | model.decoder.block.6.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 402 | model.decoder.block.6.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 403 | model.decoder.block.6.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 404 | model.decoder.block.6.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 405 | model.decoder.block.6.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 406 | model.decoder.block.6.layer.2.layer_norm                            | T5LayerNorm                | 768
# 407 | model.decoder.block.6.layer.2.dropout                               | Dropout                    | 0
# 408 | model.decoder.block.7                                               | T5Block                    | 9 M
# 409 | model.decoder.block.7.layer                                         | ModuleList                 | 9 M
# 410 | model.decoder.block.7.layer.0                                       | T5LayerSelfAttention       | 2 M
# 411 | model.decoder.block.7.layer.0.SelfAttention                         | T5Attention                | 2 M
# 412 | model.decoder.block.7.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 413 | model.decoder.block.7.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 414 | model.decoder.block.7.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 415 | model.decoder.block.7.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 416 | model.decoder.block.7.layer.0.layer_norm                            | T5LayerNorm                | 768
# 417 | model.decoder.block.7.layer.0.dropout                               | Dropout                    | 0
# 418 | model.decoder.block.7.layer.1                                       | T5LayerCrossAttention      | 2 M
# 419 | model.decoder.block.7.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 420 | model.decoder.block.7.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 421 | model.decoder.block.7.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 422 | model.decoder.block.7.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 423 | model.decoder.block.7.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 424 | model.decoder.block.7.layer.1.layer_norm                            | T5LayerNorm                | 768
# 425 | model.decoder.block.7.layer.1.dropout                               | Dropout                    | 0
# 426 | model.decoder.block.7.layer.2                                       | T5LayerFF                  | 4 M
# 427 | model.decoder.block.7.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 428 | model.decoder.block.7.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 429 | model.decoder.block.7.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 430 | model.decoder.block.7.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 431 | model.decoder.block.7.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 432 | model.decoder.block.7.layer.2.layer_norm                            | T5LayerNorm                | 768
# 433 | model.decoder.block.7.layer.2.dropout                               | Dropout                    | 0
# 434 | model.decoder.block.8                                               | T5Block                    | 9 M
# 435 | model.decoder.block.8.layer                                         | ModuleList                 | 9 M
# 436 | model.decoder.block.8.layer.0                                       | T5LayerSelfAttention       | 2 M
# 437 | model.decoder.block.8.layer.0.SelfAttention                         | T5Attention                | 2 M
# 438 | model.decoder.block.8.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 439 | model.decoder.block.8.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 440 | model.decoder.block.8.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 441 | model.decoder.block.8.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 442 | model.decoder.block.8.layer.0.layer_norm                            | T5LayerNorm                | 768
# 443 | model.decoder.block.8.layer.0.dropout                               | Dropout                    | 0
# 444 | model.decoder.block.8.layer.1                                       | T5LayerCrossAttention      | 2 M
# 445 | model.decoder.block.8.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 446 | model.decoder.block.8.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 447 | model.decoder.block.8.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 448 | model.decoder.block.8.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 449 | model.decoder.block.8.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 450 | model.decoder.block.8.layer.1.layer_norm                            | T5LayerNorm                | 768
# 451 | model.decoder.block.8.layer.1.dropout                               | Dropout                    | 0
# 452 | model.decoder.block.8.layer.2                                       | T5LayerFF                  | 4 M
# 453 | model.decoder.block.8.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 454 | model.decoder.block.8.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 455 | model.decoder.block.8.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 456 | model.decoder.block.8.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 457 | model.decoder.block.8.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 458 | model.decoder.block.8.layer.2.layer_norm                            | T5LayerNorm                | 768
# 459 | model.decoder.block.8.layer.2.dropout                               | Dropout                    | 0
# 460 | model.decoder.block.9                                               | T5Block                    | 9 M
# 461 | model.decoder.block.9.layer                                         | ModuleList                 | 9 M
# 462 | model.decoder.block.9.layer.0                                       | T5LayerSelfAttention       | 2 M
# 463 | model.decoder.block.9.layer.0.SelfAttention                         | T5Attention                | 2 M
# 464 | model.decoder.block.9.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 465 | model.decoder.block.9.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 466 | model.decoder.block.9.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 467 | model.decoder.block.9.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 468 | model.decoder.block.9.layer.0.layer_norm                            | T5LayerNorm                | 768
# 469 | model.decoder.block.9.layer.0.dropout                               | Dropout                    | 0
# 470 | model.decoder.block.9.layer.1                                       | T5LayerCrossAttention      | 2 M
# 471 | model.decoder.block.9.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 472 | model.decoder.block.9.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 473 | model.decoder.block.9.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 474 | model.decoder.block.9.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 475 | model.decoder.block.9.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 476 | model.decoder.block.9.layer.1.layer_norm                            | T5LayerNorm                | 768
# 477 | model.decoder.block.9.layer.1.dropout                               | Dropout                    | 0
# 478 | model.decoder.block.9.layer.2                                       | T5LayerFF                  | 4 M
# 479 | model.decoder.block.9.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 480 | model.decoder.block.9.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 481 | model.decoder.block.9.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 482 | model.decoder.block.9.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 483 | model.decoder.block.9.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 484 | model.decoder.block.9.layer.2.layer_norm                            | T5LayerNorm                | 768
# 485 | model.decoder.block.9.layer.2.dropout                               | Dropout                    | 0
# 486 | model.decoder.block.10                                              | T5Block                    | 9 M
# 487 | model.decoder.block.10.layer                                        | ModuleList                 | 9 M
# 488 | model.decoder.block.10.layer.0                                      | T5LayerSelfAttention       | 2 M
# 489 | model.decoder.block.10.layer.0.SelfAttention                        | T5Attention                | 2 M
# 490 | model.decoder.block.10.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 491 | model.decoder.block.10.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 492 | model.decoder.block.10.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 493 | model.decoder.block.10.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 494 | model.decoder.block.10.layer.0.layer_norm                           | T5LayerNorm                | 768
# 495 | model.decoder.block.10.layer.0.dropout                              | Dropout                    | 0
# 496 | model.decoder.block.10.layer.1                                      | T5LayerCrossAttention      | 2 M
# 497 | model.decoder.block.10.layer.1.EncDecAttention                      | T5Attention                | 2 M
# 498 | model.decoder.block.10.layer.1.EncDecAttention.q                    | Linear                     | 589 K
# 499 | model.decoder.block.10.layer.1.EncDecAttention.k                    | Linear                     | 589 K
# 500 | model.decoder.block.10.layer.1.EncDecAttention.v                    | Linear                     | 589 K
# 501 | model.decoder.block.10.layer.1.EncDecAttention.o                    | Linear                     | 589 K
# 502 | model.decoder.block.10.layer.1.layer_norm                           | T5LayerNorm                | 768
# 503 | model.decoder.block.10.layer.1.dropout                              | Dropout                    | 0
# 504 | model.decoder.block.10.layer.2                                      | T5LayerFF                  | 4 M
# 505 | model.decoder.block.10.layer.2.DenseReluDense                       | T5DenseActDense            | 4 M
# 506 | model.decoder.block.10.layer.2.DenseReluDense.wi                    | Linear                     | 2 M
# 507 | model.decoder.block.10.layer.2.DenseReluDense.wo                    | Linear                     | 2 M
# 508 | model.decoder.block.10.layer.2.DenseReluDense.dropout               | Dropout                    | 0
# 509 | model.decoder.block.10.layer.2.DenseReluDense.act                   | ReLU                       | 0
# 510 | model.decoder.block.10.layer.2.layer_norm                           | T5LayerNorm                | 768
# 511 | model.decoder.block.10.layer.2.dropout                              | Dropout                    | 0
# 512 | model.decoder.block.11                                              | T5Block                    | 9 M
# 513 | model.decoder.block.11.layer                                        | ModuleList                 | 9 M
# 514 | model.decoder.block.11.layer.0                                      | T5LayerSelfAttention       | 2 M
# 515 | model.decoder.block.11.layer.0.SelfAttention                        | T5Attention                | 2 M
# 516 | model.decoder.block.11.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 517 | model.decoder.block.11.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 518 | model.decoder.block.11.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 519 | model.decoder.block.11.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 520 | model.decoder.block.11.layer.0.layer_norm                           | T5LayerNorm                | 768
# 521 | model.decoder.block.11.layer.0.dropout                              | Dropout                    | 0
# 522 | model.decoder.block.11.layer.1                                      | T5LayerCrossAttention      | 2 M
# 523 | model.decoder.block.11.layer.1.EncDecAttention                      | T5Attention                | 2 M
# 524 | model.decoder.block.11.layer.1.EncDecAttention.q                    | Linear                     | 589 K
# 525 | model.decoder.block.11.layer.1.EncDecAttention.k                    | Linear                     | 589 K
# 526 | model.decoder.block.11.layer.1.EncDecAttention.v                    | Linear                     | 589 K
# 527 | model.decoder.block.11.layer.1.EncDecAttention.o                    | Linear                     | 589 K
# 528 | model.decoder.block.11.layer.1.layer_norm                           | T5LayerNorm                | 768
# 529 | model.decoder.block.11.layer.1.dropout                              | Dropout                    | 0
# 530 | model.decoder.block.11.layer.2                                      | T5LayerFF                  | 4 M
# 531 | model.decoder.block.11.layer.2.DenseReluDense                       | T5DenseActDense            | 4 M
# 532 | model.decoder.block.11.layer.2.DenseReluDense.wi                    | Linear                     | 2 M
# 533 | model.decoder.block.11.layer.2.DenseReluDense.wo                    | Linear                     | 2 M
# 534 | model.decoder.block.11.layer.2.DenseReluDense.dropout               | Dropout                    | 0
# 535 | model.decoder.block.11.layer.2.DenseReluDense.act                   | ReLU                       | 0
# 536 | model.decoder.block.11.layer.2.layer_norm                           | T5LayerNorm                | 768
# 537 | model.decoder.block.11.layer.2.dropout                              | Dropout                    | 0
# 538 | model.decoder.final_layer_norm                                      | T5LayerNorm                | 768
# 539 | model.decoder.dropout                                               | Dropout                    | 0
# 540 | model.lm_head                                                       | Linear                     | 24 M
# INFO:__main__:LOOKING AT swag_data dev
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Validation sanity check: 0it [00:00, ?it/s]
# INFO:__main__:LOOKING AT swag_data train
# INFO:__main__:LOOKING AT swag_data dev
# Training: 0it [00:00, ?it/s]

# %% [markdown]
# ### Eval

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset =  SwagDataset(tokenizer, data_dir='swag_data', type_path='val')
loader = DataLoader(dataset, batch_size=32, num_workers=4)
# Out:
# INFO:__main__:LOOKING AT swag_data dev

# %%
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=626.0), HTML(value='')))

# %%
for i, out in enumerate(outputs):
  if out not in "1234":
    print(i, 'detected invalid prediction')

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.7397280815755274

# %% [markdown]
# This is great! We have achieved almost 74% accuracy with this simple formulation. This is great becuase with BERT like models to make a prediction on single example the model needs to do 4 forward passes, one for each possible endings and then the logits are concatenated together for all 4 passes and then passed through final softmax layer to produce 4 probabilities. This approach needs only a single pass for one example.

# %%
print('hello, world')
# Out:
# hello, world

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !nvidia-smi
# Out:
# Sat Jan 27 20:28:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A10                     On  | 00000000:07:00.0 Off |                    0 |
# |  0%   28C    P8              16W / 150W |      4MiB / 23028MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# Instal apex if you want to do 16 bit training. You'll probably need to restart the notebook after installing apex

# %%
# !export CUDA_HOME=/usr/local/cuda-10.1
# !git clone https://github.com/NVIDIA/apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./apex

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/ubuntu/.local/lib/python3.10/site-packages (23.3.2)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
# !pip uninstall transformers -y
# !pip uninstall pytorch_lightning -y
# !pip uninstall datasets -y
# !pip uninstall nltk -y
# !pip uninstall SentencePiece -y
# Out:
# WARNING: Skipping transformers as it is not installed.
# Found existing installation: pytorch-lightning 0.7.5
# Uninstalling pytorch-lightning-0.7.5:
#   Successfully uninstalled pytorch-lightning-0.7.5
# Found existing installation: datasets 2.16.1
# Uninstalling datasets-2.16.1:
#   Successfully uninstalled datasets-2.16.1
# Found existing installation: nltk 3.8.1
# Uninstalling nltk-3.8.1:
#   Successfully uninstalled nltk-3.8.1
# Found existing installation: sentencepiece 0.1.99
# Uninstalling sentencepiece-0.1.99:
#   Successfully uninstalled sentencepiece-0.1.99

# %%
# !pip install transformers==2.11.0

# %%
# !pip install transformers
# !pip install pytorch_lightning==0.7.5
# !pip install datasets
# !pip install nltk
# !pip install SentencePiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Using cached transformers-4.37.1-py3-none-any.whl.metadata (129 kB)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/ubuntu/.local/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->transformers) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->transformers) (2020.6.20)
# Using cached transformers-4.37.1-py3-none-any.whl (8.4 MB)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: transformers
# Successfully installed transformers-4.37.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytorch_lightning==0.7.5
#   Using cached pytorch_lightning-0.7.5-py3-none-any.whl (233 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from pytorch_lightning==0.7.5) (4.66.1)
# Requirement already satisfied: numpy>=1.16.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from pytorch_lightning==0.7.5) (1.25.2)
# Requirement already satisfied: torch>=1.1 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (2.0.1)
# Requirement already satisfied: tensorboard>=1.14 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (2.13.0)
# Requirement already satisfied: future>=0.17.1 in /usr/lib/python3/dist-packages (from pytorch_lightning==0.7.5) (0.18.2)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: pytorch_lightning
# Successfully installed pytorch_lightning-0.7.5
# Defaulting to user installation because normal site-packages is not writeable
# Collecting datasets
#   Using cached datasets-2.16.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /home/ubuntu/.local/lib/python3.10/site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ubuntu/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.19.0->datasets) (2020.6.20)
# Using cached datasets-2.16.1-py3-none-any.whl (507 kB)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: datasets
# Successfully installed datasets-2.16.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.0.3)
# Requirement already satisfied: joblib in /usr/lib/python3/dist-packages (from nltk) (0.17.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.10/site-packages (from nltk) (4.66.1)
# DEPRECATION: flatbuffers 1.12.1-git20200711.33e2d80-dfsg1-0.6 has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of flatbuffers or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting SentencePiece
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)

# %% [markdown]
# ## T5 fine-tuning
#
# This notebook is to showcase how to fine-tune [T5 model](https://arxiv.org/abs/1910.10683) with Huggigface's [Transformers](https://github.com/huggingface/transformers/) to solve different NLP tasks using text-2-text approach proposed in the T5 paper. For demo I chose 3 non text-2-text problems just to reiterate the fact from the paper that how widely applicable this text-2-text framework is and how it can be used for different tasks without changing the model at all.
#
# This is a rough draft so if you find any issues with this notebook or have any  questions reach out to me via [Twitter](https://twitter.com/psuraj28).

# %%
import argparse
import glob
import os
import json
import time
import logging
import random
import re
from itertools import chain
from string import punctuation

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl


from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)

# %%
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %% [markdown]
# ## Model
#
# We'll be using the awesome [pytorch-lightning](https://github.com/PytorchLightning/pytorch-lightning) library for training. Most of the below code is adapted from here https://github.com/huggingface/transformers/blob/master/examples/lightning_base.py
#
# The trainer is generic and can be used for any text-2-text task. You'll just need to change the dataset. Rest of the code will stay unchanged for all the tasks.
#
# This is the most intresting and powerfull thing about the text-2-text format. You can fine-tune the model on variety of NLP tasks by just formulating the problem in text-2-text setting. No need to change hyperparameters, learning rate, optimizer or loss function. Just plug in your dataset and you are ready to go!

# %%
class T5FineTuner(pl.LightningModule):
  def __init__(self, hparams):
    super(T5FineTuner, self).__init__()
    self.hparams = hparams
    
    self.model = T5ForConditionalGeneration.from_pretrained(hparams.model_name_or_path)
    self.tokenizer = T5Tokenizer.from_pretrained(hparams.tokenizer_name_or_path)
  
  def is_logger(self):
    return self.trainer.proc_rank <= 0
  
  def forward(
      self, input_ids, attention_mask=None, decoder_input_ids=None, decoder_attention_mask=None, labels=None, # lm_labels=None
  ):
    return self.model(
        input_ids,
        attention_mask=attention_mask,
        decoder_input_ids=decoder_input_ids,
        decoder_attention_mask=decoder_attention_mask,
        labels=labels,
        #lm_labels=lm_labels,
    )

  def _step(self, batch):
    lm_labels = batch["target_ids"]
    lm_labels[lm_labels[:, :] == self.tokenizer.pad_token_id] = -100

    outputs = self(
        input_ids=batch["source_ids"],
        attention_mask=batch["source_mask"],
        #lm_labels=lm_labels,
        labels=lm_labels,
        decoder_attention_mask=batch['target_mask']
    )

    loss = outputs[0]

    return loss

  def training_step(self, batch, batch_idx):
    loss = self._step(batch)

    tensorboard_logs = {"train_loss": loss}
    return {"loss": loss, "log": tensorboard_logs}
  
  def training_epoch_end(self, outputs):
    avg_train_loss = torch.stack([x["loss"] for x in outputs]).mean()
    tensorboard_logs = {"avg_train_loss": avg_train_loss}
    return {"avg_train_loss": avg_train_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def validation_step(self, batch, batch_idx):
    loss = self._step(batch)
    return {"val_loss": loss}
  
  def validation_epoch_end(self, outputs):
    avg_loss = torch.stack([x["val_loss"] for x in outputs]).mean()
    tensorboard_logs = {"val_loss": avg_loss}
    return {"avg_val_loss": avg_loss, "log": tensorboard_logs, 'progress_bar': tensorboard_logs}

  def configure_optimizers(self):
    "Prepare optimizer and schedule (linear warmup and decay)"

    model = self.model
    no_decay = ["bias", "LayerNorm.weight"]
    optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": self.hparams.weight_decay,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
    optimizer = AdamW(optimizer_grouped_parameters, lr=self.hparams.learning_rate, eps=self.hparams.adam_epsilon)
    self.opt = optimizer
    return [optimizer]
  
  def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, second_order_closure=None):
    if self.trainer.use_tpu:
      xm.optimizer_step(optimizer)
    else:
      optimizer.step()
    optimizer.zero_grad()
    self.lr_scheduler.step()
  
  def get_tqdm_dict(self):
    tqdm_dict = {"loss": "{:.3f}".format(self.trainer.avg_loss), "lr": self.lr_scheduler.get_last_lr()[-1]}

    return tqdm_dict

  def train_dataloader(self):
    train_dataset = get_dataset(tokenizer=self.tokenizer, type_path="train", args=self.hparams)
    dataloader = DataLoader(train_dataset, batch_size=self.hparams.train_batch_size, drop_last=True, shuffle=True, num_workers=4)
    t_total = (
        (len(dataloader.dataset) // (self.hparams.train_batch_size * max(1, self.hparams.n_gpu)))
        // self.hparams.gradient_accumulation_steps
        * float(self.hparams.num_train_epochs)
    )
    scheduler = get_linear_schedule_with_warmup(
        self.opt, num_warmup_steps=self.hparams.warmup_steps, num_training_steps=t_total
    )
    self.lr_scheduler = scheduler
    return dataloader

  def val_dataloader(self):
    val_dataset = get_dataset(tokenizer=self.tokenizer, type_path="val", args=self.hparams)
    return DataLoader(val_dataset, batch_size=self.hparams.eval_batch_size, num_workers=4)

# %%
logger = logging.getLogger(__name__)

class LoggingCallback(pl.Callback):
  def on_validation_end(self, trainer, pl_module):
    logger.info("***** Validation results *****")
    if pl_module.is_logger():
      metrics = trainer.callback_metrics
      # Log results
      for key in sorted(metrics):
        if key not in ["log", "progress_bar"]:
          logger.info("{} = {}\n".format(key, str(metrics[key])))

  def on_test_end(self, trainer, pl_module):
    logger.info("***** Test results *****")

    if pl_module.is_logger():
      metrics = trainer.callback_metrics

      # Log and save results to file
      output_test_results_file = os.path.join(pl_module.hparams.output_dir, "test_results.txt")
      with open(output_test_results_file, "w") as writer:
        for key in sorted(metrics):
          if key not in ["log", "progress_bar"]:
            logger.info("{} = {}\n".format(key, str(metrics[key])))
            writer.write("{} = {}\n".format(key, str(metrics[key])))

# %% [markdown]
# Let's define the hyperparameters and other arguments. You can overide this `dict` for specific task as needed. While in most of cases you'll only need to change the `data_dir`and `output_dir`.
#
# Here the batch size is 8 and gradient_accumulation_steps are 16 so the effective batch size is 128

# %%
args_dict = dict(
    data_dir="", # path for data files
    output_dir="", # path to save the checkpoints
    model_name_or_path='t5-base',
    tokenizer_name_or_path='t5-base',
    max_seq_length=512,
    learning_rate=3e-4,
    weight_decay=0.0,
    adam_epsilon=1e-8,
    warmup_steps=0,
    train_batch_size=8,
    eval_batch_size=8,
    num_train_epochs=2,
    gradient_accumulation_steps=16,
    n_gpu=1,
    early_stop_callback=False,
    fp_16=False, # if you want to enable 16-bit training then install apex and set this to true
    opt_level='O1', # you can find out more on optimisation levels here https://nvidia.github.io/apex/amp.html#opt-levels-and-properties
    max_grad_norm=1.0, # if you enable 16-bit training then set this to a sensible value, 0.5 is a good default
    seed=42,
)

# %% [markdown]
# ## IMDB review classification

# %% [markdown]
# ### Download IMDB Data

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xvf aclImdb_v1.tar.gz
# Out:
# --2024-01-27 19:33:27--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  9.13MB/s    in 9.1s
#
# 2024-01-27 19:33:37 (8.83 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]
#
# aclImdb/
# aclImdb/test/
# aclImdb/train/
# aclImdb/test/neg/
# aclImdb/test/pos/
# aclImdb/train/neg/
# aclImdb/train/pos/
# aclImdb/train/unsup/
# aclImdb/imdbEr.txt
# aclImdb/imdb.vocab
# aclImdb/README
# aclImdb/test/labeledBow.feat
# aclImdb/test/urls_neg.txt
# aclImdb/test/urls_pos.txt
# aclImdb/train/unsupBow.feat
# aclImdb/train/labeledBow.feat
# aclImdb/train/urls_neg.txt
# aclImdb/train/urls_pos.txt
# aclImdb/train/urls_unsup.txt
# aclImdb/test/neg/127_3.txt
# aclImdb/test/neg/126_4.txt
# aclImdb/test/neg/125_3.txt
# aclImdb/test/neg/124_2.txt
# aclImdb/test/neg/123_4.txt
# aclImdb/test/neg/122_4.txt
# aclImdb/test/neg/121_4.txt
# aclImdb/test/neg/120_2.txt
# aclImdb/test/neg/119_3.txt
# aclImdb/test/neg/118_1.txt
# aclImdb/test/neg/117_1.txt
# aclImdb/test/neg/116_4.txt
# aclImdb/test/neg/115_3.txt
# aclImdb/test/neg/114_2.txt
# aclImdb/test/neg/113_3.txt
# aclImdb/test/neg/112_2.txt
# aclImdb/test/neg/111_3.txt
# aclImdb/test/neg/110_1.txt
# aclImdb/test/neg/109_4.txt
# aclImdb/test/neg/108_2.txt
# aclImdb/test/neg/107_4.txt
# aclImdb/test/neg/106_3.txt
# aclImdb/test/neg/105_3.txt
# aclImdb/test/neg/104_1.txt
# aclImdb/test/neg/103_3.txt
# aclImdb/test/neg/102_4.txt
# aclImdb/test/neg/101_3.txt
# aclImdb/test/neg/100_4.txt
# aclImdb/test/neg/99_3.txt
# aclImdb/test/neg/98_1.txt
# aclImdb/test/neg/97_1.txt
# aclImdb/test/neg/96_1.txt
# aclImdb/test/neg/95_3.txt
# aclImdb/test/neg/94_2.txt
# aclImdb/test/neg/93_1.txt
# aclImdb/test/neg/92_1.txt
# aclImdb/test/neg/91_4.txt
# aclImdb/test/neg/90_2.txt
# aclImdb/test/neg/89_3.txt
# aclImdb/test/neg/88_3.txt
# aclImdb/test/neg/87_1.txt
# aclImdb/test/neg/86_3.txt
# aclImdb/test/neg/85_2.txt
# aclImdb/test/neg/84_3.txt
# aclImdb/test/neg/83_1.txt
# aclImdb/test/neg/82_3.txt
# aclImdb/test/neg/81_3.txt
# aclImdb/test/neg/80_4.txt
# aclImdb/test/neg/79_2.txt
# aclImdb/test/neg/78_1.txt
# aclImdb/test/neg/77_2.txt
# aclImdb/test/neg/76_4.txt
# aclImdb/test/neg/75_1.txt
# aclImdb/test/neg/74_4.txt
# aclImdb/test/neg/73_4.txt
# aclImdb/test/neg/72_4.txt
# aclImdb/test/neg/71_4.txt
# aclImdb/test/neg/70_1.txt
# aclImdb/test/neg/69_4.txt
# aclImdb/test/neg/68_1.txt
# aclImdb/test/neg/67_3.txt
# aclImdb/test/neg/66_3.txt
# aclImdb/test/neg/65_2.txt
# aclImdb/test/neg/64_3.txt
# aclImdb/test/neg/63_1.txt
# aclImdb/test/neg/62_2.txt
# aclImdb/test/neg/61_1.txt
# aclImdb/test/neg/60_1.txt
# aclImdb/test/neg/59_3.txt
# aclImdb/test/neg/58_3.txt
# aclImdb/test/neg/57_4.txt
# aclImdb/test/neg/56_3.txt
# aclImdb/test/neg/55_4.txt
# aclImdb/test/neg/54_3.txt
# aclImdb/test/neg/53_4.txt
# aclImdb/test/neg/52_4.txt
# aclImdb/test/neg/51_4.txt
# aclImdb/test/neg/50_3.txt
# aclImdb/test/neg/49_4.txt
# aclImdb/test/neg/48_4.txt
# aclImdb/test/neg/47_2.txt
# aclImdb/test/neg/46_2.txt
# aclImdb/test/neg/45_2.txt
# aclImdb/test/neg/44_4.txt
# aclImdb/test/neg/43_1.txt
# aclImdb/test/neg/42_4.txt
# aclImdb/test/neg/41_4.txt
# aclImdb/test/neg/40_4.txt
# aclImdb/test/neg/39_3.txt
# aclImdb/test/neg/38_1.txt
# aclImdb/test/neg/37_1.txt
# aclImdb/test/neg/36_3.txt
# aclImdb/test/neg/35_1.txt
# aclImdb/test/neg/34_1.txt
# aclImdb/test/neg/33_3.txt
# aclImdb/test/neg/32_3.txt
# aclImdb/test/neg/31_4.txt
# aclImdb/test/neg/30_4.txt
# aclImdb/test/neg/29_3.txt
# aclImdb/test/neg/28_3.txt
# aclImdb/test/neg/27_4.txt
# aclImdb/test/neg/26_3.txt
# aclImdb/test/neg/25_3.txt
# aclImdb/test/neg/24_4.txt
# aclImdb/test/neg/23_4.txt
# aclImdb/test/neg/22_3.txt
# aclImdb/test/neg/21_1.txt
# aclImdb/test/neg/20_1.txt
# aclImdb/test/neg/19_1.txt
# aclImdb/test/neg/18_1.txt
# aclImdb/test/neg/17_3.txt
# aclImdb/test/neg/16_1.txt
# aclImdb/test/neg/15_2.txt
# aclImdb/test/neg/14_1.txt
# aclImdb/test/neg/13_1.txt
# aclImdb/test/neg/12_4.txt
# aclImdb/test/neg/11_3.txt
# aclImdb/test/neg/10_3.txt
# aclImdb/test/neg/9_4.txt
# aclImdb/test/neg/8_2.txt
# aclImdb/test/neg/7_1.txt
# aclImdb/test/neg/6_3.txt
# aclImdb/test/neg/5_4.txt
# aclImdb/test/neg/4_4.txt
# aclImdb/test/neg/3_4.txt
# aclImdb/test/neg/2_3.txt
# aclImdb/test/neg/1_3.txt
# aclImdb/test/neg/0_2.txt
# aclImdb/test/neg/255_4.txt
# aclImdb/test/neg/254_3.txt
# aclImdb/test/neg/253_3.txt
# aclImdb/test/neg/252_3.txt
# aclImdb/test/neg/251_2.txt
# aclImdb/test/neg/250_1.txt
# aclImdb/test/neg/249_2.txt
# aclImdb/test/neg/248_2.txt
# aclImdb/test/neg/247_2.txt
# aclImdb/test/neg/246_2.txt
# aclImdb/test/neg/245_2.txt
# aclImdb/test/neg/244_2.txt
# aclImdb/test/neg/243_4.txt
# aclImdb/test/neg/242_3.txt
# aclImdb/test/neg/241_1.txt
# aclImdb/test/neg/240_4.txt
# aclImdb/test/neg/239_2.txt
# aclImdb/test/neg/238_1.txt
# aclImdb/test/neg/237_1.txt
# aclImdb/test/neg/236_3.txt
# aclImdb/test/neg/235_4.txt
# aclImdb/test/neg/234_3.txt
# aclImdb/test/neg/233_2.txt
# aclImdb/test/neg/232_4.txt
# aclImdb/test/neg/231_1.txt
# aclImdb/test/neg/230_1.txt
# aclImdb/test/neg/229_1.txt
# aclImdb/test/neg/228_1.txt
# aclImdb/test/neg/227_1.txt
# aclImdb/test/neg/226_4.txt
# aclImdb/test/neg/225_3.txt
# aclImdb/test/neg/224_3.txt
# aclImdb/test/neg/223_3.txt
# aclImdb/test/neg/222_3.txt
# aclImdb/test/neg/221_3.txt
# aclImdb/test/neg/220_4.txt
# aclImdb/test/neg/219_1.txt
# aclImdb/test/neg/218_3.txt
# aclImdb/test/neg/217_3.txt
# aclImdb/test/neg/216_2.txt
# aclImdb/test/neg/215_4.txt
# aclImdb/test/neg/214_1.txt
# aclImdb/test/neg/213_3.txt
# aclImdb/test/neg/212_4.txt
# aclImdb/test/neg/211_3.txt
# aclImdb/test/neg/210_4.txt
# aclImdb/test/neg/209_4.txt
# aclImdb/test/neg/208_3.txt
# aclImdb/test/neg/207_3.txt
# aclImdb/test/neg/206_2.txt
# aclImdb/test/neg/205_2.txt
# aclImdb/test/neg/204_1.txt
# aclImdb/test/neg/203_3.txt
# aclImdb/test/neg/202_4.txt
# aclImdb/test/neg/201_2.txt
# aclImdb/test/neg/200_4.txt
# aclImdb/test/neg/199_4.txt
# aclImdb/test/neg/198_3.txt
# aclImdb/test/neg/197_1.txt
# aclImdb/test/neg/196_4.txt
# aclImdb/test/neg/195_4.txt
# aclImdb/test/neg/194_1.txt
# aclImdb/test/neg/193_4.txt
# aclImdb/test/neg/192_2.txt
# aclImdb/test/neg/191_3.txt
# aclImdb/test/neg/190_2.txt
# aclImdb/test/neg/189_4.txt
# aclImdb/test/neg/188_3.txt
# aclImdb/test/neg/187_1.txt
# aclImdb/test/neg/186_1.txt
# aclImdb/test/neg/185_4.txt
# aclImdb/test/neg/184_3.txt
# aclImdb/test/neg/183_4.txt
# aclImdb/test/neg/182_3.txt
# aclImdb/test/neg/181_3.txt
# aclImdb/test/neg/180_3.txt
# aclImdb/test/neg/179_1.txt
# aclImdb/test/neg/178_2.txt
# aclImdb/test/neg/177_1.txt
# aclImdb/test/neg/176_3.txt
# aclImdb/test/neg/175_4.txt
# aclImdb/test/neg/174_2.txt
# aclImdb/test/neg/173_4.txt
# aclImdb/test/neg/172_4.txt
# aclImdb/test/neg/171_2.txt
# aclImdb/test/neg/170_2.txt
# aclImdb/test/neg/169_4.txt
# aclImdb/test/neg/168_1.txt
# aclImdb/test/neg/167_2.txt
# aclImdb/test/neg/166_4.txt
# aclImdb/test/neg/165_4.txt
# aclImdb/test/neg/164_2.txt
# aclImdb/test/neg/163_1.txt
# aclImdb/test/neg/162_3.txt
# aclImdb/test/neg/161_3.txt
# aclImdb/test/neg/160_1.txt
# aclImdb/test/neg/159_1.txt
# aclImdb/test/neg/158_1.txt
# aclImdb/test/neg/157_3.txt
# aclImdb/test/neg/156_3.txt
# aclImdb/test/neg/155_2.txt
# aclImdb/test/neg/154_2.txt
# aclImdb/test/neg/153_4.txt
# aclImdb/test/neg/152_4.txt
# aclImdb/test/neg/151_2.txt
# aclImdb/test/neg/150_4.txt
# aclImdb/test/neg/149_1.txt
# aclImdb/test/neg/148_1.txt
# aclImdb/test/neg/147_4.txt
# aclImdb/test/neg/146_1.txt
# aclImdb/test/neg/145_1.txt
# aclImdb/test/neg/144_2.txt
# aclImdb/test/neg/143_4.txt
# aclImdb/test/neg/142_1.txt
# aclImdb/test/neg/141_1.txt
# aclImdb/test/neg/140_2.txt
# aclImdb/test/neg/139_4.txt
# aclImdb/test/neg/138_1.txt
# aclImdb/test/neg/137_3.txt
# aclImdb/test/neg/136_2.txt
# aclImdb/test/neg/135_3.txt
# aclImdb/test/neg/134_1.txt
# aclImdb/test/neg/133_1.txt
# aclImdb/test/neg/132_1.txt
# aclImdb/test/neg/131_1.txt
# aclImdb/test/neg/130_4.txt
# aclImdb/test/neg/129_1.txt
# aclImdb/test/neg/128_4.txt
# aclImdb/test/neg/383_1.txt
# aclImdb/test/neg/382_4.txt
# aclImdb/test/neg/381_1.txt
# aclImdb/test/neg/380_2.txt
# aclImdb/test/neg/379_1.txt
# aclImdb/test/neg/378_1.txt
# aclImdb/test/neg/377_1.txt
# aclImdb/test/neg/376_2.txt
# aclImdb/test/neg/375_1.txt
# aclImdb/test/neg/374_4.txt
# aclImdb/test/neg/373_2.txt
# aclImdb/test/neg/372_2.txt
# aclImdb/test/neg/371_4.txt
# aclImdb/test/neg/370_2.txt
# aclImdb/test/neg/369_1.txt
# aclImdb/test/neg/368_4.txt
# aclImdb/test/neg/367_3.txt
# aclImdb/test/neg/366_1.txt
# aclImdb/test/neg/365_1.txt
# aclImdb/test/neg/364_1.txt
# aclImdb/test/neg/363_3.txt
# aclImdb/test/neg/362_2.txt
# aclImdb/test/neg/361_1.txt
# aclImdb/test/neg/360_3.txt
# aclImdb/test/neg/359_4.txt
# aclImdb/test/neg/358_4.txt
# aclImdb/test/neg/357_1.txt
# aclImdb/test/neg/356_3.txt
# aclImdb/test/neg/355_4.txt
# aclImdb/test/neg/354_4.txt
# aclImdb/test/neg/353_3.txt
# aclImdb/test/neg/352_4.txt
# aclImdb/test/neg/351_4.txt
# aclImdb/test/neg/350_4.txt
# aclImdb/test/neg/349_2.txt
# aclImdb/test/neg/348_1.txt
# aclImdb/test/neg/347_1.txt
# aclImdb/test/neg/346_2.txt
# aclImdb/test/neg/345_3.txt
# aclImdb/test/neg/344_4.txt
# aclImdb/test/neg/343_1.txt
# aclImdb/test/neg/342_1.txt
# aclImdb/test/neg/341_1.txt
# aclImdb/test/neg/340_2.txt
# aclImdb/test/neg/339_1.txt
# aclImdb/test/neg/338_1.txt
# aclImdb/test/neg/337_1.txt
# aclImdb/test/neg/336_1.txt
# aclImdb/test/neg/335_2.txt
# aclImdb/test/neg/334_2.txt
# aclImdb/test/neg/333_3.txt
# aclImdb/test/neg/332_1.txt
# aclImdb/test/neg/331_4.txt
# aclImdb/test/neg/330_1.txt
# aclImdb/test/neg/329_1.txt
# aclImdb/test/neg/328_4.txt
# aclImdb/test/neg/327_1.txt
# aclImdb/test/neg/326_1.txt
# aclImdb/test/neg/325_1.txt
# aclImdb/test/neg/324_3.txt
# aclImdb/test/neg/323_2.txt
# aclImdb/test/neg/322_1.txt
# aclImdb/test/neg/321_1.txt
# aclImdb/test/neg/320_3.txt
# aclImdb/test/neg/319_1.txt
# aclImdb/test/neg/318_3.txt
# aclImdb/test/neg/317_2.txt
# aclImdb/test/neg/316_1.txt
# aclImdb/test/neg/315_4.txt
# aclImdb/test/neg/314_2.txt
# aclImdb/test/neg/313_1.txt
# aclImdb/test/neg/312_4.txt
# aclImdb/test/neg/311_3.txt
# aclImdb/test/neg/310_1.txt
# aclImdb/test/neg/309_3.txt
# aclImdb/test/neg/308_1.txt
# aclImdb/test/neg/307_1.txt
# aclImdb/test/neg/306_1.txt
# aclImdb/test/neg/305_2.txt
# aclImdb/test/neg/304_2.txt
# aclImdb/test/neg/303_2.txt
# aclImdb/test/neg/302_3.txt
# aclImdb/test/neg/301_4.txt
# aclImdb/test/neg/300_1.txt
# aclImdb/test/neg/299_1.txt
# aclImdb/test/neg/298_1.txt
# aclImdb/test/neg/297_2.txt
# aclImdb/test/neg/296_4.txt
# aclImdb/test/neg/295_1.txt
# aclImdb/test/neg/294_1.txt
# aclImdb/test/neg/293_1.txt
# aclImdb/test/neg/292_3.txt
# aclImdb/test/neg/291_3.txt
# aclImdb/test/neg/290_1.txt
# aclImdb/test/neg/289_1.txt
# aclImdb/test/neg/288_1.txt
# aclImdb/test/neg/287_1.txt
# aclImdb/test/neg/286_1.txt
# aclImdb/test/neg/285_4.txt
# aclImdb/test/neg/284_2.txt
# aclImdb/test/neg/283_1.txt
# aclImdb/test/neg/282_1.txt
# aclImdb/test/neg/281_1.txt
# aclImdb/test/neg/280_1.txt
# aclImdb/test/neg/279_1.txt
# aclImdb/test/neg/278_1.txt
# aclImdb/test/neg/277_1.txt
# aclImdb/test/neg/276_1.txt
# aclImdb/test/neg/275_1.txt
# aclImdb/test/neg/274_1.txt
# aclImdb/test/neg/273_1.txt
# aclImdb/test/neg/272_1.txt
# aclImdb/test/neg/271_4.txt
# aclImdb/test/neg/270_1.txt
# aclImdb/test/neg/269_2.txt
# aclImdb/test/neg/268_3.txt
# aclImdb/test/neg/267_1.txt
# aclImdb/test/neg/266_4.txt
# aclImdb/test/neg/265_1.txt
# aclImdb/test/neg/264_1.txt
# aclImdb/test/neg/263_1.txt
# aclImdb/test/neg/262_1.txt
# aclImdb/test/neg/261_3.txt
# aclImdb/test/neg/260_1.txt
# aclImdb/test/neg/259_2.txt
# aclImdb/test/neg/258_1.txt
# aclImdb/test/neg/257_3.txt
# aclImdb/test/neg/256_4.txt
# aclImdb/test/neg/511_3.txt
# aclImdb/test/neg/510_2.txt
# aclImdb/test/neg/509_3.txt
# aclImdb/test/neg/508_4.txt
# aclImdb/test/neg/507_1.txt
# aclImdb/test/neg/506_2.txt
# aclImdb/test/neg/505_1.txt
# aclImdb/test/neg/504_1.txt
# aclImdb/test/neg/503_2.txt
# aclImdb/test/neg/502_4.txt
# aclImdb/test/neg/501_1.txt
# aclImdb/test/neg/500_1.txt
# aclImdb/test/neg/499_2.txt
# aclImdb/test/neg/498_1.txt
# aclImdb/test/neg/497_2.txt
# aclImdb/test/neg/496_3.txt
# aclImdb/test/neg/495_2.txt
# aclImdb/test/neg/494_2.txt
# aclImdb/test/neg/493_1.txt
# aclImdb/test/neg/492_1.txt
# aclImdb/test/neg/491_2.txt
# aclImdb/test/neg/490_2.txt
# aclImdb/test/neg/489_1.txt
# aclImdb/test/neg/488_4.txt
# aclImdb/test/neg/487_3.txt
# aclImdb/test/neg/486_4.txt
# aclImdb/test/neg/485_4.txt
# aclImdb/test/neg/484_1.txt
# aclImdb/test/neg/483_2.txt
# aclImdb/test/neg/482_1.txt
# aclImdb/test/neg/481_2.txt
# aclImdb/test/neg/480_3.txt
# aclImdb/test/neg/479_3.txt
# aclImdb/test/neg/478_3.txt
# aclImdb/test/neg/477_2.txt
# aclImdb/test/neg/476_1.txt
# aclImdb/test/neg/475_1.txt
# aclImdb/test/neg/474_4.txt
# aclImdb/test/neg/473_1.txt
# aclImdb/test/neg/472_4.txt
# aclImdb/test/neg/471_3.txt
# aclImdb/test/neg/470_4.txt
# aclImdb/test/neg/469_2.txt
# aclImdb/test/neg/468_1.txt
# aclImdb/test/neg/467_3.txt
# aclImdb/test/neg/466_1.txt
# aclImdb/test/neg/465_4.txt
# aclImdb/test/neg/464_4.txt
# aclImdb/test/neg/463_1.txt
# aclImdb/test/neg/462_4.txt
# aclImdb/test/neg/461_1.txt
# aclImdb/test/neg/460_1.txt
# aclImdb/test/neg/459_4.txt
# aclImdb/test/neg/458_4.txt
# aclImdb/test/neg/457_2.txt
# aclImdb/test/neg/456_1.txt
# aclImdb/test/neg/455_1.txt
# aclImdb/test/neg/454_1.txt
# aclImdb/test/neg/453_4.txt
# aclImdb/test/neg/452_2.txt
# aclImdb/test/neg/451_2.txt
# aclImdb/test/neg/450_2.txt
# aclImdb/test/neg/449_3.txt
# aclImdb/test/neg/448_2.txt
# aclImdb/test/neg/447_4.txt
# aclImdb/test/neg/446_1.txt
# aclImdb/test/neg/445_3.txt
# aclImdb/test/neg/444_2.txt
# aclImdb/test/neg/443_2.txt
# aclImdb/test/neg/442_3.txt
# aclImdb/test/neg/441_4.txt
# aclImdb/test/neg/440_1.txt
# aclImdb/test/neg/439_1.txt
# aclImdb/test/neg/438_2.txt
# aclImdb/test/neg/437_2.txt
# aclImdb/test/neg/436_4.txt
# aclImdb/test/neg/435_1.txt
# aclImdb/test/neg/434_1.txt
# aclImdb/test/neg/433_1.txt
# aclImdb/test/neg/432_3.txt
# aclImdb/test/neg/431_2.txt
# aclImdb/test/neg/430_4.txt
# aclImdb/test/neg/429_3.txt
# aclImdb/test/neg/428_3.txt
# aclImdb/test/neg/427_3.txt
# aclImdb/test/neg/426_4.txt
# aclImdb/test/neg/425_2.txt
# aclImdb/test/neg/424_2.txt
# aclImdb/test/neg/423_2.txt
# aclImdb/test/neg/422_3.txt
# aclImdb/test/neg/421_1.txt
# aclImdb/test/neg/420_3.txt
# aclImdb/test/neg/419_4.txt
# aclImdb/test/neg/418_4.txt
# aclImdb/test/neg/417_1.txt
# aclImdb/test/neg/416_2.txt
# aclImdb/test/neg/415_1.txt
# aclImdb/test/neg/414_2.txt
# aclImdb/test/neg/413_4.txt
# aclImdb/test/neg/412_2.txt
# aclImdb/test/neg/411_3.txt
# aclImdb/test/neg/410_2.txt
# aclImdb/test/neg/409_4.txt
# aclImdb/test/neg/408_3.txt
# aclImdb/test/neg/407_4.txt
# aclImdb/test/neg/406_1.txt
# aclImdb/test/neg/405_3.txt
# aclImdb/test/neg/404_1.txt
# aclImdb/test/neg/403_1.txt
# aclImdb/test/neg/402_1.txt
# aclImdb/test/neg/401_1.txt
# aclImdb/test/neg/400_1.txt
# aclImdb/test/neg/399_1.txt
# aclImdb/test/neg/398_4.txt
# aclImdb/test/neg/397_3.txt
# aclImdb/test/neg/396_2.txt
# aclImdb/test/neg/395_2.txt
# aclImdb/test/neg/394_4.txt
# aclImdb/test/neg/393_1.txt
# aclImdb/test/neg/392_2.txt
# aclImdb/test/neg/391_1.txt
# aclImdb/test/neg/390_4.txt
# aclImdb/test/neg/389_1.txt
# aclImdb/test/neg/388_1.txt
# aclImdb/test/neg/387_1.txt
# aclImdb/test/neg/386_1.txt
# aclImdb/test/neg/385_1.txt
# aclImdb/test/neg/384_4.txt
# aclImdb/test/neg/639_1.txt
# aclImdb/test/neg/638_1.txt
# aclImdb/test/neg/637_3.txt
# aclImdb/test/neg/636_1.txt
# aclImdb/test/neg/635_2.txt
# aclImdb/test/neg/634_1.txt
# aclImdb/test/neg/633_1.txt
# aclImdb/test/neg/632_1.txt
# aclImdb/test/neg/631_4.txt
# aclImdb/test/neg/630_3.txt
# aclImdb/test/neg/629_4.txt
# aclImdb/test/neg/628_1.txt
# aclImdb/test/neg/627_1.txt
# aclImdb/test/neg/626_4.txt
# aclImdb/test/neg/625_2.txt
# aclImdb/test/neg/624_3.txt
# aclImdb/test/neg/623_2.txt
# aclImdb/test/neg/622_1.txt
# aclImdb/test/neg/621_2.txt
# aclImdb/test/neg/620_2.txt
# aclImdb/test/neg/619_1.txt
# aclImdb/test/neg/618_1.txt
# aclImdb/test/neg/617_4.txt
# aclImdb/test/neg/616_1.txt
# aclImdb/test/neg/615_3.txt
# aclImdb/test/neg/614_2.txt
# aclImdb/test/neg/613_4.txt
# aclImdb/test/neg/612_3.txt
# aclImdb/test/neg/611_1.txt
# aclImdb/test/neg/610_1.txt
# aclImdb/test/neg/609_1.txt
# aclImdb/test/neg/608_1.txt
# aclImdb/test/neg/607_1.txt
# aclImdb/test/neg/606_1.txt
# aclImdb/test/neg/605_4.txt
# aclImdb/test/neg/604_3.txt
# aclImdb/test/neg/603_4.txt
# aclImdb/test/neg/602_1.txt
# aclImdb/test/neg/601_3.txt
# aclImdb/test/neg/600_1.txt
# aclImdb/test/neg/599_1.txt
# aclImdb/test/neg/598_1.txt
# aclImdb/test/neg/597_4.txt
# aclImdb/test/neg/596_1.txt
# aclImdb/test/neg/595_1.txt
# aclImdb/test/neg/594_1.txt
# aclImdb/test/neg/593_1.txt
# aclImdb/test/neg/592_3.txt
# aclImdb/test/neg/591_1.txt
# aclImdb/test/neg/590_1.txt
# aclImdb/test/neg/589_2.txt
# aclImdb/test/neg/588_2.txt
# aclImdb/test/neg/587_3.txt
# aclImdb/test/neg/586_2.txt
# aclImdb/test/neg/585_1.txt
# aclImdb/test/neg/584_3.txt
# aclImdb/test/neg/583_2.txt
# aclImdb/test/neg/582_4.txt
# aclImdb/test/neg/581_4.txt
# aclImdb/test/neg/580_3.txt
# aclImdb/test/neg/579_1.txt
# aclImdb/test/neg/578_2.txt
# aclImdb/test/neg/577_3.txt
# aclImdb/test/neg/576_4.txt
# aclImdb/test/neg/575_4.txt
# aclImdb/test/neg/574_4.txt
# aclImdb/test/neg/573_3.txt
# aclImdb/test/neg/572_3.txt
# aclImdb/test/neg/571_1.txt
# aclImdb/test/neg/570_1.txt
# aclImdb/test/neg/569_4.txt
# aclImdb/test/neg/568_4.txt
# aclImdb/test/neg/567_3.txt
# aclImdb/test/neg/566_3.txt
# aclImdb/test/neg/565_2.txt
# aclImdb/test/neg/564_4.txt
# aclImdb/test/neg/563_4.txt
# aclImdb/test/neg/562_1.txt
# aclImdb/test/neg/561_1.txt
# aclImdb/test/neg/560_3.txt
# aclImdb/test/neg/559_4.txt
# aclImdb/test/neg/558_2.txt
# aclImdb/test/neg/557_4.txt
# aclImdb/test/neg/556_1.txt
# aclImdb/test/neg/555_4.txt
# aclImdb/test/neg/554_4.txt
# aclImdb/test/neg/553_1.txt
# aclImdb/test/neg/552_2.txt
# aclImdb/test/neg/551_4.txt
# aclImdb/test/neg/550_3.txt
# aclImdb/test/neg/549_3.txt
# aclImdb/test/neg/548_4.txt
# aclImdb/test/neg/547_4.txt
# aclImdb/test/neg/546_3.txt
# aclImdb/test/neg/545_4.txt
# aclImdb/test/neg/544_4.txt
# aclImdb/test/neg/543_4.txt
# aclImdb/test/neg/542_4.txt
# aclImdb/test/neg/541_1.txt
# aclImdb/test/neg/540_1.txt
# aclImdb/test/neg/539_3.txt
# aclImdb/test/neg/538_4.txt
# aclImdb/test/neg/537_2.txt
# aclImdb/test/neg/536_3.txt
# aclImdb/test/neg/535_4.txt
# aclImdb/test/neg/534_4.txt
# aclImdb/test/neg/533_1.txt
# aclImdb/test/neg/532_3.txt
# aclImdb/test/neg/531_2.txt
# aclImdb/test/neg/530_2.txt
# aclImdb/test/neg/529_1.txt
# aclImdb/test/neg/528_1.txt
# aclImdb/test/neg/527_2.txt
# aclImdb/test/neg/526_3.txt
# aclImdb/test/neg/525_3.txt
# aclImdb/test/neg/524_1.txt
# aclImdb/test/neg/523_1.txt
# aclImdb/test/neg/522_2.txt
# aclImdb/test/neg/521_1.txt
# aclImdb/test/neg/520_2.txt
# aclImdb/test/neg/519_1.txt
# aclImdb/test/neg/518_4.txt
# aclImdb/test/neg/517_1.txt
# aclImdb/test/neg/516_1.txt
# aclImdb/test/neg/515_1.txt
# aclImdb/test/neg/514_3.txt
# aclImdb/test/neg/513_1.txt
# aclImdb/test/neg/512_2.txt
# aclImdb/test/neg/767_1.txt
# aclImdb/test/neg/766_2.txt
# aclImdb/test/neg/765_2.txt
# aclImdb/test/neg/764_2.txt
# aclImdb/test/neg/763_2.txt
# aclImdb/test/neg/762_3.txt
# aclImdb/test/neg/761_2.txt
# aclImdb/test/neg/760_1.txt
# aclImdb/test/neg/759_1.txt
# aclImdb/test/neg/758_3.txt
# aclImdb/test/neg/757_1.txt
# aclImdb/test/neg/756_1.txt
# aclImdb/test/neg/755_1.txt
# aclImdb/test/neg/754_2.txt
# aclImdb/test/neg/753_2.txt
# aclImdb/test/neg/752_4.txt
# aclImdb/test/neg/751_1.txt
# aclImdb/test/neg/750_2.txt
# aclImdb/test/neg/749_1.txt
# aclImdb/test/neg/748_1.txt
# aclImdb/test/neg/747_3.txt
# aclImdb/test/neg/746_1.txt
# aclImdb/test/neg/745_1.txt
# aclImdb/test/neg/744_1.txt
# aclImdb/test/neg/743_2.txt
# aclImdb/test/neg/742_2.txt
# aclImdb/test/neg/741_1.txt
# aclImdb/test/neg/740_3.txt
# aclImdb/test/neg/739_1.txt
# aclImdb/test/neg/738_1.txt
# aclImdb/test/neg/737_1.txt
# aclImdb/test/neg/736_2.txt
# aclImdb/test/neg/735_1.txt
# aclImdb/test/neg/734_1.txt
# aclImdb/test/neg/733_1.txt
# aclImdb/test/neg/732_3.txt
# aclImdb/test/neg/731_4.txt
# aclImdb/test/neg/730_1.txt
# aclImdb/test/neg/729_1.txt
# aclImdb/test/neg/728_1.txt
# aclImdb/test/neg/727_3.txt
# aclImdb/test/neg/726_1.txt
# aclImdb/test/neg/725_2.txt
# aclImdb/test/neg/724_3.txt
# aclImdb/test/neg/723_2.txt
# aclImdb/test/neg/722_3.txt
# aclImdb/test/neg/721_4.txt
# aclImdb/test/neg/720_1.txt
# aclImdb/test/neg/719_1.txt
# aclImdb/test/neg/718_3.txt
# aclImdb/test/neg/717_4.txt
# aclImdb/test/neg/716_2.txt
# aclImdb/test/neg/715_4.txt
# aclImdb/test/neg/714_4.txt
# aclImdb/test/neg/713_1.txt
# aclImdb/test/neg/712_3.txt
# aclImdb/test/neg/711_4.txt
# aclImdb/test/neg/710_3.txt
# aclImdb/test/neg/709_4.txt
# aclImdb/test/neg/708_3.txt
# aclImdb/test/neg/707_3.txt
# aclImdb/test/neg/706_1.txt
# aclImdb/test/neg/705_2.txt
# aclImdb/test/neg/704_2.txt
# aclImdb/test/neg/703_2.txt
# aclImdb/test/neg/702_1.txt
# aclImdb/test/neg/701_4.txt
# aclImdb/test/neg/700_4.txt
# aclImdb/test/neg/699_1.txt
# aclImdb/test/neg/698_1.txt
# aclImdb/test/neg/697_4.txt
# aclImdb/test/neg/696_4.txt
# aclImdb/test/neg/695_4.txt
# aclImdb/test/neg/694_4.txt
# aclImdb/test/neg/693_4.txt
# aclImdb/test/neg/692_4.txt
# aclImdb/test/neg/691_2.txt
# aclImdb/test/neg/690_3.txt
# aclImdb/test/neg/689_3.txt
# aclImdb/test/neg/688_4.txt
# aclImdb/test/neg/687_3.txt
# aclImdb/test/neg/686_4.txt
# aclImdb/test/neg/685_1.txt
# aclImdb/test/neg/684_1.txt
# aclImdb/test/neg/683_2.txt
# aclImdb/test/neg/682_4.txt
# aclImdb/test/neg/681_3.txt
# aclImdb/test/neg/680_2.txt
# aclImdb/test/neg/679_4.txt
# aclImdb/test/neg/678_1.txt
# aclImdb/test/neg/677_1.txt
# aclImdb/test/neg/676_1.txt
# aclImdb/test/neg/675_2.txt
# aclImdb/test/neg/674_3.txt
# aclImdb/test/neg/673_2.txt
# aclImdb/test/neg/672_4.txt
# aclImdb/test/neg/671_3.txt
# aclImdb/test/neg/670_3.txt
# aclImdb/test/neg/669_2.txt
# aclImdb/test/neg/668_4.txt
# aclImdb/test/neg/667_4.txt
# aclImdb/test/neg/666_4.txt
# aclImdb/test/neg/665_1.txt
# aclImdb/test/neg/664_3.txt
# aclImdb/test/neg/663_1.txt
# aclImdb/test/neg/662_4.txt
# aclImdb/test/neg/661_1.txt
# aclImdb/test/neg/660_2.txt
# aclImdb/test/neg/659_1.txt
# aclImdb/test/neg/658_3.txt
# aclImdb/test/neg/657_1.txt
# aclImdb/test/neg/656_4.txt
# aclImdb/test/neg/655_3.txt
# aclImdb/test/neg/654_3.txt
# aclImdb/test/neg/653_1.txt
# aclImdb/test/neg/652_1.txt
# aclImdb/test/neg/651_1.txt
# aclImdb/test/neg/650_3.txt
# aclImdb/test/neg/649_2.txt
# aclImdb/test/neg/648_3.txt
# aclImdb/test/neg/647_1.txt
# aclImdb/test/neg/646_1.txt
# aclImdb/test/neg/645_1.txt
# aclImdb/test/neg/644_2.txt
# aclImdb/test/neg/643_4.txt
# aclImdb/test/neg/642_2.txt
# aclImdb/test/neg/641_1.txt
# aclImdb/test/neg/640_1.txt
# aclImdb/test/neg/895_1.txt
# aclImdb/test/neg/894_1.txt
# aclImdb/test/neg/893_1.txt
# aclImdb/test/neg/892_1.txt
# aclImdb/test/neg/891_1.txt
# aclImdb/test/neg/890_1.txt
# aclImdb/test/neg/889_3.txt
# aclImdb/test/neg/888_1.txt
# aclImdb/test/neg/887_2.txt
# aclImdb/test/neg/886_2.txt
# aclImdb/test/neg/885_3.txt
# aclImdb/test/neg/884_1.txt
# aclImdb/test/neg/883_4.txt
# aclImdb/test/neg/882_2.txt
# aclImdb/test/neg/881_4.txt
# aclImdb/test/neg/880_3.txt
# aclImdb/test/neg/879_3.txt
# aclImdb/test/neg/878_2.txt
# aclImdb/test/neg/877_1.txt
# aclImdb/test/neg/876_3.txt
# aclImdb/test/neg/875_4.txt
# aclImdb/test/neg/874_4.txt
# aclImdb/test/neg/873_3.txt
# aclImdb/test/neg/872_1.txt
# aclImdb/test/neg/871_1.txt
# aclImdb/test/neg/870_4.txt
# aclImdb/test/neg/869_1.txt
# aclImdb/test/neg/868_4.txt
# aclImdb/test/neg/867_2.txt
# aclImdb/test/neg/866_2.txt
# aclImdb/test/neg/865_3.txt
# aclImdb/test/neg/864_2.txt
# aclImdb/test/neg/863_4.txt
# aclImdb/test/neg/862_3.txt
# aclImdb/test/neg/861_4.txt
# aclImdb/test/neg/860_4.txt
# aclImdb/test/neg/859_1.txt
# aclImdb/test/neg/858_4.txt
# aclImdb/test/neg/857_1.txt
# aclImdb/test/neg/856_3.txt
# aclImdb/test/neg/855_4.txt
# aclImdb/test/neg/854_1.txt
# aclImdb/test/neg/853_1.txt
# aclImdb/test/neg/852_4.txt
# aclImdb/test/neg/851_1.txt
# aclImdb/test/neg/850_4.txt
# aclImdb/test/neg/849_1.txt
# aclImdb/test/neg/848_2.txt
# aclImdb/test/neg/847_2.txt
# aclImdb/test/neg/846_2.txt
# aclImdb/test/neg/845_2.txt
# aclImdb/test/neg/844_1.txt
# aclImdb/test/neg/843_1.txt
# aclImdb/test/neg/842_1.txt
# aclImdb/test/neg/841_1.txt
# aclImdb/test/neg/840_2.txt
# aclImdb/test/neg/839_4.txt
# aclImdb/test/neg/838_4.txt
# aclImdb/test/neg/837_4.txt
# aclImdb/test/neg/836_4.txt
# aclImdb/test/neg/835_4.txt
# aclImdb/test/neg/834_4.txt
# aclImdb/test/neg/833_3.txt
# aclImdb/test/neg/832_4.txt
# aclImdb/test/neg/831_4.txt
# aclImdb/test/neg/830_4.txt
# aclImdb/test/neg/829_2.txt
# aclImdb/test/neg/828_3.txt
# aclImdb/test/neg/827_1.txt
# aclImdb/test/neg/826_3.txt
# aclImdb/test/neg/825_1.txt
# aclImdb/test/neg/824_4.txt
# aclImdb/test/neg/823_1.txt
# aclImdb/test/neg/822_1.txt
# aclImdb/test/neg/821_1.txt
# aclImdb/test/neg/820_1.txt
# aclImdb/test/neg/819_1.txt
# aclImdb/test/neg/818_1.txt
# aclImdb/test/neg/817_1.txt
# aclImdb/test/neg/816_3.txt
# aclImdb/test/neg/815_3.txt
# aclImdb/test/neg/814_4.txt
# aclImdb/test/neg/813_1.txt
# aclImdb/test/neg/812_3.txt
# aclImdb/test/neg/811_1.txt
# aclImdb/test/neg/810_1.txt
# aclImdb/test/neg/809_1.txt
# aclImdb/test/neg/808_3.txt
# aclImdb/test/neg/807_3.txt
# aclImdb/test/neg/806_1.txt
# aclImdb/test/neg/805_1.txt
# aclImdb/test/neg/804_1.txt
# aclImdb/test/neg/803_3.txt
# aclImdb/test/neg/802_1.txt
# aclImdb/test/neg/801_2.txt
# aclImdb/test/neg/800_3.txt
# aclImdb/test/neg/799_4.txt
# aclImdb/test/neg/798_1.txt
# aclImdb/test/neg/797_1.txt
# aclImdb/test/neg/796_4.txt
# aclImdb/test/neg/795_3.txt
# aclImdb/test/neg/794_1.txt
# aclImdb/test/neg/793_1.txt
# aclImdb/test/neg/792_2.txt
# aclImdb/test/neg/791_4.txt
# aclImdb/test/neg/790_1.txt
# aclImdb/test/neg/789_1.txt
# aclImdb/test/neg/788_1.txt
# aclImdb/test/neg/787_1.txt
# aclImdb/test/neg/786_3.txt
# aclImdb/test/neg/785_2.txt
# aclImdb/test/neg/784_4.txt
# aclImdb/test/neg/783_1.txt
# aclImdb/test/neg/782_3.txt
# aclImdb/test/neg/781_4.txt
# aclImdb/test/neg/780_3.txt
# aclImdb/test/neg/779_1.txt
# aclImdb/test/neg/778_1.txt
# aclImdb/test/neg/777_2.txt
# aclImdb/test/neg/776_1.txt
# aclImdb/test/neg/775_1.txt
# aclImdb/test/neg/774_4.txt
# aclImdb/test/neg/773_1.txt
# aclImdb/test/neg/772_1.txt
# aclImdb/test/neg/771_4.txt
# aclImdb/test/neg/770_3.txt
# aclImdb/test/neg/769_3.txt
# aclImdb/test/neg/768_2.txt
# aclImdb/test/neg/1023_3.txt
# aclImdb/test/neg/1022_3.txt
# aclImdb/test/neg/1021_2.txt
# aclImdb/test/neg/1020_2.txt
# aclImdb/test/neg/1019_3.txt
# aclImdb/test/neg/1018_4.txt
# aclImdb/test/neg/1017_1.txt
# aclImdb/test/neg/1016_3.txt
# aclImdb/test/neg/1015_4.txt
# aclImdb/test/neg/1014_4.txt
# aclImdb/test/neg/1013_1.txt
# aclImdb/test/neg/1012_1.txt
# aclImdb/test/neg/1011_4.txt
# aclImdb/test/neg/1010_1.txt
# aclImdb/test/neg/1009_3.txt
# aclImdb/test/neg/1008_2.txt
# aclImdb/test/neg/1007_4.txt
# aclImdb/test/neg/1006_3.txt
# aclImdb/test/neg/1005_2.txt
# aclImdb/test/neg/1004_4.txt
# aclImdb/test/neg/1003_4.txt
# aclImdb/test/neg/1002_3.txt
# aclImdb/test/neg/1001_4.txt
# aclImdb/test/neg/1000_3.txt
# aclImdb/test/neg/999_3.txt
# aclImdb/test/neg/998_2.txt
# aclImdb/test/neg/997_3.txt
# aclImdb/test/neg/996_3.txt
# aclImdb/test/neg/995_1.txt
# aclImdb/test/neg/994_3.txt
# aclImdb/test/neg/993_3.txt
# aclImdb/test/neg/992_1.txt
# aclImdb/test/neg/991_4.txt
# aclImdb/test/neg/990_1.txt
# aclImdb/test/neg/989_4.txt
# aclImdb/test/neg/988_3.txt
# aclImdb/test/neg/987_4.txt
# aclImdb/test/neg/986_3.txt
# aclImdb/test/neg/985_4.txt
# aclImdb/test/neg/984_3.txt
# aclImdb/test/neg/983_4.txt
# aclImdb/test/neg/982_4.txt
# aclImdb/test/neg/981_1.txt
# aclImdb/test/neg/980_2.txt
# aclImdb/test/neg/979_3.txt
# aclImdb/test/neg/978_1.txt
# aclImdb/test/neg/977_4.txt
# aclImdb/test/neg/976_3.txt
# aclImdb/test/neg/975_4.txt
# aclImdb/test/neg/974_4.txt
# aclImdb/test/neg/973_4.txt
# aclImdb/test/neg/972_1.txt
# aclImdb/test/neg/971_3.txt
# aclImdb/test/neg/970_4.txt
# aclImdb/test/neg/969_4.txt
# aclImdb/test/neg/968_2.txt
# aclImdb/test/neg/967_2.txt
# aclImdb/test/neg/966_4.txt
# aclImdb/test/neg/965_3.txt
# aclImdb/test/neg/964_3.txt
# aclImdb/test/neg/963_2.txt
# aclImdb/test/neg/962_4.txt
# aclImdb/test/neg/961_1.txt
# aclImdb/test/neg/960_3.txt
# aclImdb/test/neg/959_4.txt
# aclImdb/test/neg/958_4.txt
# aclImdb/test/neg/957_2.txt
# aclImdb/test/neg/956_3.txt
# aclImdb/test/neg/955_4.txt
# aclImdb/test/neg/954_4.txt
# aclImdb/test/neg/953_2.txt
# aclImdb/test/neg/952_1.txt
# aclImdb/test/neg/951_1.txt
# aclImdb/test/neg/950_1.txt
# aclImdb/test/neg/949_3.txt
# aclImdb/test/neg/948_1.txt
# aclImdb/test/neg/947_3.txt
# aclImdb/test/neg/946_1.txt
# aclImdb/test/neg/945_2.txt
# aclImdb/test/neg/944_2.txt
# aclImdb/test/neg/943_3.txt
# aclImdb/test/neg/942_1.txt
# aclImdb/test/neg/941_2.txt
# aclImdb/test/neg/940_3.txt
# aclImdb/test/neg/939_4.txt
# aclImdb/test/neg/938_1.txt
# aclImdb/test/neg/937_4.txt
# aclImdb/test/neg/936_2.txt
# aclImdb/test/neg/935_4.txt
# aclImdb/test/neg/934_1.txt
# aclImdb/test/neg/933_3.txt
# aclImdb/test/neg/932_2.txt
# aclImdb/test/neg/931_4.txt
# aclImdb/test/neg/930_3.txt
# aclImdb/test/neg/929_2.txt
# aclImdb/test/neg/928_1.txt
# aclImdb/test/neg/927_3.txt
# aclImdb/test/neg/926_4.txt
# aclImdb/test/neg/925_2.txt
# aclImdb/test/neg/924_4.txt
# aclImdb/test/neg/923_4.txt
# aclImdb/test/neg/922_3.txt
# aclImdb/test/neg/921_1.txt
# aclImdb/test/neg/920_1.txt
# aclImdb/test/neg/919_4.txt
# aclImdb/test/neg/918_4.txt
# aclImdb/test/neg/917_4.txt
# aclImdb/test/neg/916_3.txt
# aclImdb/test/neg/915_4.txt
# aclImdb/test/neg/914_1.txt
# aclImdb/test/neg/913_1.txt
# aclImdb/test/neg/912_1.txt
# aclImdb/test/neg/911_1.txt
# aclImdb/test/neg/910_4.txt
# aclImdb/test/neg/909_4.txt
# aclImdb/test/neg/908_3.txt
# aclImdb/test/neg/907_3.txt
# aclImdb/test/neg/906_4.txt
# aclImdb/test/neg/905_3.txt
# aclImdb/test/neg/904_3.txt
# aclImdb/test/neg/903_4.txt
# aclImdb/test/neg/902_3.txt
# aclImdb/test/neg/901_1.txt
# aclImdb/test/neg/900_1.txt
# aclImdb/test/neg/899_3.txt
# aclImdb/test/neg/898_3.txt
# aclImdb/test/neg/897_1.txt
# aclImdb/test/neg/896_1.txt
# aclImdb/test/neg/1151_1.txt
# aclImdb/test/neg/1150_2.txt
# aclImdb/test/neg/1149_3.txt
# aclImdb/test/neg/1148_4.txt
# aclImdb/test/neg/1147_1.txt
# aclImdb/test/neg/1146_4.txt
# aclImdb/test/neg/1145_2.txt
# aclImdb/test/neg/1144_1.txt
# aclImdb/test/neg/1143_1.txt
# aclImdb/test/neg/1142_1.txt
# aclImdb/test/neg/1141_1.txt
# aclImdb/test/neg/1140_1.txt
# aclImdb/test/neg/1139_1.txt
# aclImdb/test/neg/1138_1.txt
# aclImdb/test/neg/1137_1.txt
# aclImdb/test/neg/1136_1.txt
# aclImdb/test/neg/1135_1.txt
# aclImdb/test/neg/1134_1.txt
# aclImdb/test/neg/1133_1.txt
# aclImdb/test/neg/1132_1.txt
# aclImdb/test/neg/1131_2.txt
# aclImdb/test/neg/1130_1.txt
# aclImdb/test/neg/1129_2.txt
# aclImdb/test/neg/1128_1.txt
# aclImdb/test/neg/1127_1.txt
# aclImdb/test/neg/1126_1.txt
# aclImdb/test/neg/1125_1.txt
# aclImdb/test/neg/1124_1.txt
# aclImdb/test/neg/1123_1.txt
# aclImdb/test/neg/1122_1.txt
# aclImdb/test/neg/1121_1.txt
# aclImdb/test/neg/1120_3.txt
# aclImdb/test/neg/1119_2.txt
# aclImdb/test/neg/1118_1.txt
# aclImdb/test/neg/1117_2.txt
# aclImdb/test/neg/1116_1.txt
# aclImdb/test/neg/1115_3.txt
# aclImdb/test/neg/1114_4.txt
# aclImdb/test/neg/1113_3.txt
# aclImdb/test/neg/1112_3.txt
# aclImdb/test/neg/1111_3.txt
# aclImdb/test/neg/1110_4.txt
# aclImdb/test/neg/1109_1.txt
# aclImdb/test/neg/1108_3.txt
# aclImdb/test/neg/1107_2.txt
# aclImdb/test/neg/1106_1.txt
# aclImdb/test/neg/1105_3.txt
# aclImdb/test/neg/1104_4.txt
# aclImdb/test/neg/1103_4.txt
# aclImdb/test/neg/1102_3.txt
# aclImdb/test/neg/1101_4.txt
# aclImdb/test/neg/1100_4.txt
# aclImdb/test/neg/1099_2.txt
# aclImdb/test/neg/1098_4.txt
# aclImdb/test/neg/1097_3.txt
# aclImdb/test/neg/1096_3.txt
# aclImdb/test/neg/1095_2.txt
# aclImdb/test/neg/1094_3.txt
# aclImdb/test/neg/1093_4.txt
# aclImdb/test/neg/1092_4.txt
# aclImdb/test/neg/1091_1.txt
# aclImdb/test/neg/1090_1.txt
# aclImdb/test/neg/1089_1.txt
# aclImdb/test/neg/1088_3.txt
# aclImdb/test/neg/1087_2.txt
# aclImdb/test/neg/1086_2.txt
# aclImdb/test/neg/1085_1.txt
# aclImdb/test/neg/1084_1.txt
# aclImdb/test/neg/1083_3.txt
# aclImdb/test/neg/1082_1.txt
# aclImdb/test/neg/1081_3.txt
# aclImdb/test/neg/1080_1.txt
# aclImdb/test/neg/1079_1.txt
# aclImdb/test/neg/1078_4.txt
# aclImdb/test/neg/1077_3.txt
# aclImdb/test/neg/1076_3.txt
# aclImdb/test/neg/1075_2.txt
# aclImdb/test/neg/1074_2.txt
# aclImdb/test/neg/1073_4.txt
# aclImdb/test/neg/1072_2.txt
# aclImdb/test/neg/1071_2.txt
# aclImdb/test/neg/1070_1.txt
# aclImdb/test/neg/1069_4.txt
# aclImdb/test/neg/1068_3.txt
# aclImdb/test/neg/1067_1.txt
# aclImdb/test/neg/1066_1.txt
# aclImdb/test/neg/1065_1.txt
# aclImdb/test/neg/1064_1.txt
# aclImdb/test/neg/1063_2.txt
# aclImdb/test/neg/1062_2.txt
# aclImdb/test/neg/1061_1.txt
# aclImdb/test/neg/1060_2.txt
# aclImdb/test/neg/1059_1.txt
# aclImdb/test/neg/1058_1.txt
# aclImdb/test/neg/1057_2.txt
# aclImdb/test/neg/1056_3.txt
# aclImdb/test/neg/1055_3.txt
# aclImdb/test/neg/1054_2.txt
# aclImdb/test/neg/1053_4.txt
# aclImdb/test/neg/1052_3.txt
# aclImdb/test/neg/1051_1.txt
# aclImdb/test/neg/1050_4.txt
# aclImdb/test/neg/1049_3.txt
# aclImdb/test/neg/1048_4.txt
# aclImdb/test/neg/1047_4.txt
# aclImdb/test/neg/1046_1.txt
# aclImdb/test/neg/1045_3.txt
# aclImdb/test/neg/1044_3.txt
# aclImdb/test/neg/1043_4.txt
# aclImdb/test/neg/1042_3.txt
# aclImdb/test/neg/1041_2.txt
# aclImdb/test/neg/1040_4.txt
# aclImdb/test/neg/1039_1.txt
# aclImdb/test/neg/1038_1.txt
# aclImdb/test/neg/1037_1.txt
# aclImdb/test/neg/1036_3.txt
# aclImdb/test/neg/1035_3.txt
# aclImdb/test/neg/1034_2.txt
# aclImdb/test/neg/1033_2.txt
# aclImdb/test/neg/1032_1.txt
# aclImdb/test/neg/1031_1.txt
# aclImdb/test/neg/1030_2.txt
# aclImdb/test/neg/1029_2.txt
# aclImdb/test/neg/1028_4.txt
# aclImdb/test/neg/1027_4.txt
# aclImdb/test/neg/1026_2.txt
# aclImdb/test/neg/1025_3.txt
# aclImdb/test/neg/1024_4.txt
# aclImdb/test/neg/1279_3.txt
# aclImdb/test/neg/1278_1.txt
# aclImdb/test/neg/1277_2.txt
# aclImdb/test/neg/1276_3.txt
# aclImdb/test/neg/1275_3.txt
# aclImdb/test/neg/1274_2.txt
# aclImdb/test/neg/1273_3.txt
# aclImdb/test/neg/1272_4.txt
# aclImdb/test/neg/1271_2.txt
# aclImdb/test/neg/1270_4.txt
# aclImdb/test/neg/1269_1.txt
# aclImdb/test/neg/1268_2.txt
# aclImdb/test/neg/1267_3.txt
# aclImdb/test/neg/1266_4.txt
# aclImdb/test/neg/1265_2.txt
# aclImdb/test/neg/1264_1.txt
# aclImdb/test/neg/1263_1.txt
# aclImdb/test/neg/1262_1.txt
# aclImdb/test/neg/1261_1.txt
# aclImdb/test/neg/1260_3.txt
# aclImdb/test/neg/1259_1.txt
# aclImdb/test/neg/1258_3.txt
# aclImdb/test/neg/1257_1.txt
# aclImdb/test/neg/1256_4.txt
# aclImdb/test/neg/1255_4.txt
# aclImdb/test/neg/1254_2.txt
# aclImdb/test/neg/1253_1.txt
# aclImdb/test/neg/1252_4.txt
# aclImdb/test/neg/1251_4.txt
# aclImdb/test/neg/1250_2.txt
# aclImdb/test/neg/1249_1.txt
# aclImdb/test/neg/1248_3.txt
# aclImdb/test/neg/1247_1.txt
# aclImdb/test/neg/1246_1.txt
# aclImdb/test/neg/1245_2.txt
# aclImdb/test/neg/1244_1.txt
# aclImdb/test/neg/1243_2.txt
# aclImdb/test/neg/1242_1.txt
# aclImdb/test/neg/1241_4.txt
# aclImdb/test/neg/1240_1.txt
# aclImdb/test/neg/1239_4.txt
# aclImdb/test/neg/1238_4.txt
# aclImdb/test/neg/1237_2.txt
# aclImdb/test/neg/1236_2.txt
# aclImdb/test/neg/1235_2.txt
# aclImdb/test/neg/1234_3.txt
# aclImdb/test/neg/1233_1.txt
# aclImdb/test/neg/1232_1.txt
# aclImdb/test/neg/1231_4.txt
# aclImdb/test/neg/1230_2.txt
# aclImdb/test/neg/1229_4.txt
# aclImdb/test/neg/1228_4.txt
# aclImdb/test/neg/1227_3.txt
# aclImdb/test/neg/1226_1.txt
# aclImdb/test/neg/1225_1.txt
# aclImdb/test/neg/1224_3.txt
# aclImdb/test/neg/1223_3.txt
# aclImdb/test/neg/1222_2.txt
# aclImdb/test/neg/1221_1.txt
# aclImdb/test/neg/1220_3.txt
# aclImdb/test/neg/1219_1.txt
# aclImdb/test/neg/1218_1.txt
# aclImdb/test/neg/1217_2.txt
# aclImdb/test/neg/1216_1.txt
# aclImdb/test/neg/1215_1.txt
# aclImdb/test/neg/1214_2.txt
# aclImdb/test/neg/1213_3.txt
# aclImdb/test/neg/1212_4.txt
# aclImdb/test/neg/1211_1.txt
# aclImdb/test/neg/1210_1.txt
# aclImdb/test/neg/1209_3.txt
# aclImdb/test/neg/1208_3.txt
# aclImdb/test/neg/1207_4.txt
# aclImdb/test/neg/1206_3.txt
# aclImdb/test/neg/1205_3.txt
# aclImdb/test/neg/1204_1.txt
# aclImdb/test/neg/1203_1.txt
# aclImdb/test/neg/1202_4.txt
# aclImdb/test/neg/1201_2.txt
# aclImdb/test/neg/1200_1.txt
# aclImdb/test/neg/1199_1.txt
# aclImdb/test/neg/1198_4.txt
# aclImdb/test/neg/1197_3.txt
# aclImdb/test/neg/1196_2.txt
# aclImdb/test/neg/1195_3.txt
# aclImdb/test/neg/1194_2.txt
# aclImdb/test/neg/1193_2.txt
# aclImdb/test/neg/1192_1.txt
# aclImdb/test/neg/1191_1.txt
# aclImdb/test/neg/1190_1.txt
# aclImdb/test/neg/1189_3.txt
# aclImdb/test/neg/1188_2.txt
# aclImdb/test/neg/1187_1.txt
# aclImdb/test/neg/1186_1.txt
# aclImdb/test/neg/1185_1.txt
# aclImdb/test/neg/1184_3.txt
# aclImdb/test/neg/1183_2.txt
# aclImdb/test/neg/1182_2.txt
# aclImdb/test/neg/1181_1.txt
# aclImdb/test/neg/1180_1.txt
# aclImdb/test/neg/1179_3.txt
# aclImdb/test/neg/1178_4.txt
# aclImdb/test/neg/1177_3.txt
# aclImdb/test/neg/1176_4.txt
# aclImdb/test/neg/1175_2.txt
# aclImdb/test/neg/1174_1.txt
# aclImdb/test/neg/1173_1.txt
# aclImdb/test/neg/1172_1.txt
# aclImdb/test/neg/1171_1.txt
# aclImdb/test/neg/1170_1.txt
# aclImdb/test/neg/1169_1.txt
# aclImdb/test/neg/1168_1.txt
# aclImdb/test/neg/1167_4.txt
# aclImdb/test/neg/1166_1.txt
# aclImdb/test/neg/1165_2.txt
# aclImdb/test/neg/1164_1.txt
# aclImdb/test/neg/1163_1.txt
# aclImdb/test/neg/1162_1.txt
# aclImdb/test/neg/1161_1.txt
# aclImdb/test/neg/1160_1.txt
# aclImdb/test/neg/1159_1.txt
# aclImdb/test/neg/1158_3.txt
# aclImdb/test/neg/1157_1.txt
# aclImdb/test/neg/1156_2.txt
# aclImdb/test/neg/1155_2.txt
# aclImdb/test/neg/1154_4.txt
# aclImdb/test/neg/1153_4.txt
# aclImdb/test/neg/1152_3.txt
# aclImdb/test/neg/1407_4.txt
# aclImdb/test/neg/1406_4.txt
# aclImdb/test/neg/1405_2.txt
# aclImdb/test/neg/1404_4.txt
# aclImdb/test/neg/1403_4.txt
# aclImdb/test/neg/1402_4.txt
# aclImdb/test/neg/1401_4.txt
# aclImdb/test/neg/1400_4.txt
# aclImdb/test/neg/1399_1.txt
# aclImdb/test/neg/1398_1.txt
# aclImdb/test/neg/1397_1.txt
# aclImdb/test/neg/1396_1.txt
# aclImdb/test/neg/1395_1.txt
# aclImdb/test/neg/1394_1.txt
# aclImdb/test/neg/1393_1.txt
# aclImdb/test/neg/1392_1.txt
# aclImdb/test/neg/1391_1.txt
# aclImdb/test/neg/1390_1.txt
# aclImdb/test/neg/1389_3.txt
# aclImdb/test/neg/1388_1.txt
# aclImdb/test/neg/1387_1.txt
# aclImdb/test/neg/1386_1.txt
# aclImdb/test/neg/1385_1.txt
# aclImdb/test/neg/1384_2.txt
# aclImdb/test/neg/1383_1.txt
# aclImdb/test/neg/1382_1.txt
# aclImdb/test/neg/1381_1.txt
# aclImdb/test/neg/1380_2.txt
# aclImdb/test/neg/1379_1.txt
# aclImdb/test/neg/1378_1.txt
# aclImdb/test/neg/1377_2.txt
# aclImdb/test/neg/1376_3.txt
# aclImdb/test/neg/1375_1.txt
# aclImdb/test/neg/1374_1.txt
# aclImdb/test/neg/1373_1.txt
# aclImdb/test/neg/1372_4.txt
# aclImdb/test/neg/1371_1.txt
# aclImdb/test/neg/1370_4.txt
# aclImdb/test/neg/1369_3.txt
# aclImdb/test/neg/1368_1.txt
# aclImdb/test/neg/1367_3.txt
# aclImdb/test/neg/1366_3.txt
# aclImdb/test/neg/1365_4.txt
# aclImdb/test/neg/1364_3.txt
# aclImdb/test/neg/1363_1.txt
# aclImdb/test/neg/1362_3.txt
# aclImdb/test/neg/1361_3.txt
# aclImdb/test/neg/1360_3.txt
# aclImdb/test/neg/1359_2.txt
# aclImdb/test/neg/1358_3.txt
# aclImdb/test/neg/1357_4.txt
# aclImdb/test/neg/1356_4.txt
# aclImdb/test/neg/1355_2.txt
# aclImdb/test/neg/1354_4.txt
# aclImdb/test/neg/1353_1.txt
# aclImdb/test/neg/1352_2.txt
# aclImdb/test/neg/1351_1.txt
# aclImdb/test/neg/1350_3.txt
# aclImdb/test/neg/1349_4.txt
# aclImdb/test/neg/1348_1.txt
# aclImdb/test/neg/1347_3.txt
# aclImdb/test/neg/1346_1.txt
# aclImdb/test/neg/1345_1.txt
# aclImdb/test/neg/1344_3.txt
# aclImdb/test/neg/1343_2.txt
# aclImdb/test/neg/1342_2.txt
# aclImdb/test/neg/1341_3.txt
# aclImdb/test/neg/1340_3.txt
# aclImdb/test/neg/1339_2.txt
# aclImdb/test/neg/1338_1.txt
# aclImdb/test/neg/1337_4.txt
# aclImdb/test/neg/1336_1.txt
# aclImdb/test/neg/1335_4.txt
# aclImdb/test/neg/1334_3.txt
# aclImdb/test/neg/1333_3.txt
# aclImdb/test/neg/1332_1.txt
# aclImdb/test/neg/1331_1.txt
# aclImdb/test/neg/1330_1.txt
# aclImdb/test/neg/1329_4.txt
# aclImdb/test/neg/1328_1.txt
# aclImdb/test/neg/1327_3.txt
# aclImdb/test/neg/1326_4.txt
# aclImdb/test/neg/1325_3.txt
# aclImdb/test/neg/1324_1.txt
# aclImdb/test/neg/1323_3.txt
# aclImdb/test/neg/1322_1.txt
# aclImdb/test/neg/1321_4.txt
# aclImdb/test/neg/1320_1.txt
# aclImdb/test/neg/1319_3.txt
# aclImdb/test/neg/1318_2.txt
# aclImdb/test/neg/1317_2.txt
# aclImdb/test/neg/1316_2.txt
# aclImdb/test/neg/1315_4.txt
# aclImdb/test/neg/1314_1.txt
# aclImdb/test/neg/1313_3.txt
# aclImdb/test/neg/1312_1.txt
# aclImdb/test/neg/1311_2.txt
# aclImdb/test/neg/1310_2.txt
# aclImdb/test/neg/1309_2.txt
# aclImdb/test/neg/1308_3.txt
# aclImdb/test/neg/1307_1.txt
# aclImdb/test/neg/1306_1.txt
# aclImdb/test/neg/1305_1.txt
# aclImdb/test/neg/1304_3.txt
# aclImdb/test/neg/1303_3.txt
# aclImdb/test/neg/1302_1.txt
# aclImdb/test/neg/1301_1.txt
# aclImdb/test/neg/1300_1.txt
# aclImdb/test/neg/1299_1.txt
# aclImdb/test/neg/1298_1.txt
# aclImdb/test/neg/1297_2.txt
# aclImdb/test/neg/1296_1.txt
# aclImdb/test/neg/1295_1.txt
# aclImdb/test/neg/1294_4.txt
# aclImdb/test/neg/1293_1.txt
# aclImdb/test/neg/1292_3.txt
# aclImdb/test/neg/1291_1.txt
# aclImdb/test/neg/1290_2.txt
# aclImdb/test/neg/1289_1.txt
# aclImdb/test/neg/1288_1.txt
# aclImdb/test/neg/1287_1.txt
# aclImdb/test/neg/1286_1.txt
# aclImdb/test/neg/1285_1.txt
# aclImdb/test/neg/1284_1.txt
# aclImdb/test/neg/1283_1.txt
# aclImdb/test/neg/1282_3.txt
# aclImdb/test/neg/1281_2.txt
# aclImdb/test/neg/1280_3.txt
# aclImdb/test/neg/1535_3.txt
# aclImdb/test/neg/1534_4.txt
# aclImdb/test/neg/1533_4.txt
# aclImdb/test/neg/1532_4.txt
# aclImdb/test/neg/1531_3.txt
# aclImdb/test/neg/1530_1.txt
# aclImdb/test/neg/1529_4.txt
# aclImdb/test/neg/1528_2.txt
# aclImdb/test/neg/1527_3.txt
# aclImdb/test/neg/1526_3.txt
# aclImdb/test/neg/1525_1.txt
# aclImdb/test/neg/1524_3.txt
# aclImdb/test/neg/1523_4.txt
# aclImdb/test/neg/1522_1.txt
# aclImdb/test/neg/1521_1.txt
# aclImdb/test/neg/1520_2.txt
# aclImdb/test/neg/1519_1.txt
# aclImdb/test/neg/1518_1.txt
# aclImdb/test/neg/1517_1.txt
# aclImdb/test/neg/1516_1.txt
# aclImdb/test/neg/1515_1.txt
# aclImdb/test/neg/1514_1.txt
# aclImdb/test/neg/1513_3.txt
# aclImdb/test/neg/1512_1.txt
# aclImdb/test/neg/1511_2.txt
# aclImdb/test/neg/1510_1.txt
# aclImdb/test/neg/1509_2.txt
# aclImdb/test/neg/1508_2.txt
# aclImdb/test/neg/1507_1.txt
# aclImdb/test/neg/1506_2.txt
# aclImdb/test/neg/1505_3.txt
# aclImdb/test/neg/1504_1.txt
# aclImdb/test/neg/1503_1.txt
# aclImdb/test/neg/1502_1.txt
# aclImdb/test/neg/1501_1.txt
# aclImdb/test/neg/1500_2.txt
# aclImdb/test/neg/1499_3.txt
# aclImdb/test/neg/1498_1.txt
# aclImdb/test/neg/1497_1.txt
# aclImdb/test/neg/1496_1.txt
# aclImdb/test/neg/1495_1.txt
# aclImdb/test/neg/1494_4.txt
# aclImdb/test/neg/1493_4.txt
# aclImdb/test/neg/1492_3.txt
# aclImdb/test/neg/1491_1.txt
# aclImdb/test/neg/1490_3.txt
# aclImdb/test/neg/1489_4.txt
# aclImdb/test/neg/1488_4.txt
# aclImdb/test/neg/1487_3.txt
# aclImdb/test/neg/1486_4.txt
# aclImdb/test/neg/1485_3.txt
# aclImdb/test/neg/1484_4.txt
# aclImdb/test/neg/1483_3.txt
# aclImdb/test/neg/1482_4.txt
# aclImdb/test/neg/1481_1.txt
# aclImdb/test/neg/1480_1.txt
# aclImdb/test/neg/1479_4.txt
# aclImdb/test/neg/1478_4.txt
# aclImdb/test/neg/1477_4.txt
# aclImdb/test/neg/1476_3.txt
# aclImdb/test/neg/1475_1.txt
# aclImdb/test/neg/1474_4.txt
# aclImdb/test/neg/1473_3.txt
# aclImdb/test/neg/1472_1.txt
# aclImdb/test/neg/1471_2.txt
# aclImdb/test/neg/1470_1.txt
# aclImdb/test/neg/1469_1.txt
# aclImdb/test/neg/1468_1.txt
# aclImdb/test/neg/1467_1.txt
# aclImdb/test/neg/1466_3.txt
# aclImdb/test/neg/1465_3.txt
# aclImdb/test/neg/1464_1.txt
# aclImdb/test/neg/1463_4.txt
# aclImdb/test/neg/1462_1.txt
# aclImdb/test/neg/1461_3.txt
# aclImdb/test/neg/1460_2.txt
# aclImdb/test/neg/1459_4.txt
# aclImdb/test/neg/1458_2.txt
# aclImdb/test/neg/1457_1.txt
# aclImdb/test/neg/1456_4.txt
# aclImdb/test/neg/1455_4.txt
# aclImdb/test/neg/1454_4.txt
# aclImdb/test/neg/1453_2.txt
# aclImdb/test/neg/1452_3.txt
# aclImdb/test/neg/1451_1.txt
# aclImdb/test/neg/1450_3.txt
# aclImdb/test/neg/1449_4.txt
# aclImdb/test/neg/1448_2.txt
# aclImdb/test/neg/1447_1.txt
# aclImdb/test/neg/1446_3.txt
# aclImdb/test/neg/1445_4.txt
# aclImdb/test/neg/1444_1.txt
# aclImdb/test/neg/1443_2.txt
# aclImdb/test/neg/1442_1.txt
# aclImdb/test/neg/1441_1.txt
# aclImdb/test/neg/1440_1.txt
# aclImdb/test/neg/1439_1.txt
# aclImdb/test/neg/1438_1.txt
# aclImdb/test/neg/1437_1.txt
# aclImdb/test/neg/1436_1.txt
# aclImdb/test/neg/1435_3.txt
# aclImdb/test/neg/1434_4.txt
# aclImdb/test/neg/1433_3.txt
# aclImdb/test/neg/1432_3.txt
# aclImdb/test/neg/1431_3.txt
# aclImdb/test/neg/1430_3.txt
# aclImdb/test/neg/1429_3.txt
# aclImdb/test/neg/1428_3.txt
# aclImdb/test/neg/1427_4.txt
# aclImdb/test/neg/1426_1.txt
# aclImdb/test/neg/1425_1.txt
# aclImdb/test/neg/1424_4.txt
# aclImdb/test/neg/1423_1.txt
# aclImdb/test/neg/1422_4.txt
# aclImdb/test/neg/1421_1.txt
# aclImdb/test/neg/1420_4.txt
# aclImdb/test/neg/1419_4.txt
# aclImdb/test/neg/1418_3.txt
# aclImdb/test/neg/1417_4.txt
# aclImdb/test/neg/1416_1.txt
# aclImdb/test/neg/1415_1.txt
# aclImdb/test/neg/1414_4.txt
# aclImdb/test/neg/1413_3.txt
# aclImdb/test/neg/1412_3.txt
# aclImdb/test/neg/1411_4.txt
# aclImdb/test/neg/1410_2.txt
# aclImdb/test/neg/1409_4.txt
# aclImdb/test/neg/1408_3.txt
# aclImdb/test/neg/1663_1.txt
# aclImdb/test/neg/1662_1.txt
# aclImdb/test/neg/1661_1.txt
# aclImdb/test/neg/1660_1.txt
# aclImdb/test/neg/1659_1.txt
# aclImdb/test/neg/1658_2.txt
# aclImdb/test/neg/1657_4.txt
# aclImdb/test/neg/1656_4.txt
# aclImdb/test/neg/1655_1.txt
# aclImdb/test/neg/1654_1.txt
# aclImdb/test/neg/1653_1.txt
# aclImdb/test/neg/1652_1.txt
# aclImdb/test/neg/1651_2.txt
# aclImdb/test/neg/1650_4.txt
# aclImdb/test/neg/1649_2.txt
# aclImdb/test/neg/1648_3.txt
# aclImdb/test/neg/1647_1.txt
# aclImdb/test/neg/1646_1.txt
# aclImdb/test/neg/1645_2.txt
# aclImdb/test/neg/1644_4.txt
# aclImdb/test/neg/1643_1.txt
# aclImdb/test/neg/1642_2.txt
# aclImdb/test/neg/1641_1.txt
# aclImdb/test/neg/1640_1.txt
# aclImdb/test/neg/1639_1.txt
# aclImdb/test/neg/1638_1.txt
# aclImdb/test/neg/1637_2.txt
# aclImdb/test/neg/1636_2.txt
# aclImdb/test/neg/1635_1.txt
# aclImdb/test/neg/1634_2.txt
# aclImdb/test/neg/1633_1.txt
# aclImdb/test/neg/1632_1.txt
# aclImdb/test/neg/1631_1.txt
# aclImdb/test/neg/1630_1.txt
# aclImdb/test/neg/1629_1.txt
# aclImdb/test/neg/1628_1.txt
# aclImdb/test/neg/1627_1.txt
# aclImdb/test/neg/1626_3.txt
# aclImdb/test/neg/1625_3.txt
# aclImdb/test/neg/1624_1.txt
# aclImdb/test/neg/1623_2.txt
# aclImdb/test/neg/1622_1.txt
# aclImdb/test/neg/1621_1.txt
# aclImdb/test/neg/1620_1.txt
# aclImdb/test/neg/1619_3.txt
# aclImdb/test/neg/1618_4.txt
# aclImdb/test/neg/1617_1.txt
# aclImdb/test/neg/1616_3.txt
# aclImdb/test/neg/1615_1.txt
# aclImdb/test/neg/1614_4.txt
# aclImdb/test/neg/1613_3.txt
# aclImdb/test/neg/1612_2.txt
# aclImdb/test/neg/1611_2.txt
# aclImdb/test/neg/1610_4.txt
# aclImdb/test/neg/1609_1.txt
# aclImdb/test/neg/1608_1.txt
# aclImdb/test/neg/1607_3.txt
# aclImdb/test/neg/1606_1.txt
# aclImdb/test/neg/1605_3.txt
# aclImdb/test/neg/1604_1.txt
# aclImdb/test/neg/1603_4.txt
# aclImdb/test/neg/1602_1.txt
# aclImdb/test/neg/1601_4.txt
# aclImdb/test/neg/1600_2.txt
# aclImdb/test/neg/1599_1.txt
# aclImdb/test/neg/1598_1.txt
# aclImdb/test/neg/1597_1.txt
# aclImdb/test/neg/1596_3.txt
# aclImdb/test/neg/1595_1.txt
# aclImdb/test/neg/1594_4.txt
# aclImdb/test/neg/1593_4.txt
# aclImdb/test/neg/1592_2.txt
# aclImdb/test/neg/1591_2.txt
# aclImdb/test/neg/1590_1.txt
# aclImdb/test/neg/1589_1.txt
# aclImdb/test/neg/1588_3.txt
# aclImdb/test/neg/1587_3.txt
# aclImdb/test/neg/1586_1.txt
# aclImdb/test/neg/1585_1.txt
# aclImdb/test/neg/1584_1.txt
# aclImdb/test/neg/1583_2.txt
# aclImdb/test/neg/1582_2.txt
# aclImdb/test/neg/1581_1.txt
# aclImdb/test/neg/1580_1.txt
# aclImdb/test/neg/1579_4.txt
# aclImdb/test/neg/1578_4.txt
# aclImdb/test/neg/1577_4.txt
# aclImdb/test/neg/1576_2.txt
# aclImdb/test/neg/1575_1.txt
# aclImdb/test/neg/1574_1.txt
# aclImdb/test/neg/1573_3.txt
# aclImdb/test/neg/1572_3.txt
# aclImdb/test/neg/1571_4.txt
# aclImdb/test/neg/1570_2.txt
# aclImdb/test/neg/1569_3.txt
# aclImdb/test/neg/1568_4.txt
# aclImdb/test/neg/1567_1.txt
# aclImdb/test/neg/1566_4.txt
# aclImdb/test/neg/1565_4.txt
# aclImdb/test/neg/1564_1.txt
# aclImdb/test/neg/1563_2.txt
# aclImdb/test/neg/1562_4.txt
# aclImdb/test/neg/1561_3.txt
# aclImdb/test/neg/1560_4.txt
# aclImdb/test/neg/1559_2.txt
# aclImdb/test/neg/1558_2.txt
# aclImdb/test/neg/1557_2.txt
# aclImdb/test/neg/1556_1.txt
# aclImdb/test/neg/1555_2.txt
# aclImdb/test/neg/1554_1.txt
# aclImdb/test/neg/1553_3.txt
# aclImdb/test/neg/1552_1.txt
# aclImdb/test/neg/1551_4.txt
# aclImdb/test/neg/1550_2.txt
# aclImdb/test/neg/1549_1.txt
# aclImdb/test/neg/1548_1.txt
# aclImdb/test/neg/1547_1.txt
# aclImdb/test/neg/1546_1.txt
# aclImdb/test/neg/1545_1.txt
# aclImdb/test/neg/1544_3.txt
# aclImdb/test/neg/1543_3.txt
# aclImdb/test/neg/1542_3.txt
# aclImdb/test/neg/1541_2.txt
# aclImdb/test/neg/1540_3.txt
# aclImdb/test/neg/1539_2.txt
# aclImdb/test/neg/1538_2.txt
# aclImdb/test/neg/1537_2.txt
# aclImdb/test/neg/1536_3.txt
# aclImdb/test/neg/1791_1.txt
# aclImdb/test/neg/1790_2.txt
# aclImdb/test/neg/1789_2.txt
# aclImdb/test/neg/1788_1.txt
# aclImdb/test/neg/1787_1.txt
# aclImdb/test/neg/1786_3.txt
# aclImdb/test/neg/1785_1.txt
# aclImdb/test/neg/1784_2.txt
# aclImdb/test/neg/1783_4.txt
# aclImdb/test/neg/1782_1.txt
# aclImdb/test/neg/1781_1.txt
# aclImdb/test/neg/1780_3.txt
# aclImdb/test/neg/1779_1.txt
# aclImdb/test/neg/1778_1.txt
# aclImdb/test/neg/1777_4.txt
# aclImdb/test/neg/1776_4.txt
# aclImdb/test/neg/1775_4.txt
# aclImdb/test/neg/1774_4.txt
# aclImdb/test/neg/1773_1.txt
# aclImdb/test/neg/1772_1.txt
# aclImdb/test/neg/1771_4.txt
# aclImdb/test/neg/1770_2.txt
# aclImdb/test/neg/1769_4.txt
# aclImdb/test/neg/1768_3.txt
# aclImdb/test/neg/1767_2.txt
# aclImdb/test/neg/1766_2.txt
# aclImdb/test/neg/1765_1.txt
# aclImdb/test/neg/1764_1.txt
# aclImdb/test/neg/1763_1.txt
# aclImdb/test/neg/1762_1.txt
# aclImdb/test/neg/1761_1.txt
# aclImdb/test/neg/1760_1.txt
# aclImdb/test/neg/1759_3.txt
# aclImdb/test/neg/1758_2.txt
# aclImdb/test/neg/1757_1.txt
# aclImdb/test/neg/1756_1.txt
# aclImdb/test/neg/1755_1.txt
# aclImdb/test/neg/1754_1.txt
# aclImdb/test/neg/1753_1.txt
# aclImdb/test/neg/1752_3.txt
# aclImdb/test/neg/1751_4.txt
# aclImdb/test/neg/1750_4.txt
# aclImdb/test/neg/1749_4.txt
# aclImdb/test/neg/1748_1.txt
# aclImdb/test/neg/1747_1.txt
# aclImdb/test/neg/1746_3.txt
# aclImdb/test/neg/1745_1.txt
# aclImdb/test/neg/1744_1.txt
# aclImdb/test/neg/1743_4.txt
# aclImdb/test/neg/1742_3.txt
# aclImdb/test/neg/1741_4.txt
# aclImdb/test/neg/1740_3.txt
# aclImdb/test/neg/1739_3.txt
# aclImdb/test/neg/1738_4.txt
# aclImdb/test/neg/1737_1.txt
# aclImdb/test/neg/1736_1.txt
# aclImdb/test/neg/1735_1.txt
# ...
# aclImdb/test/pos/1020_7.txt
# aclImdb/test/pos/1019_10.txt
# aclImdb/test/pos/1018_7.txt
# aclImdb/test/pos/1017_7.txt
# aclImdb/test/pos/1016_7.txt
# aclImdb/test/pos/1015_8.txt
# aclImdb/test/pos/1014_8.txt
# aclImdb/test/pos/1013_7.txt
# aclImdb/test/pos/1012_8.txt
# aclImdb/test/pos/1011_8.txt
# aclImdb/test/pos/1010_9.txt
# aclImdb/test/pos/1009_8.txt
# aclImdb/test/pos/1008_10.txt
# aclImdb/test/pos/1007_9.txt
# aclImdb/test/pos/1006_8.txt
# aclImdb/test/pos/1005_7.txt
# aclImdb/test/pos/1004_10.txt
# aclImdb/test/pos/1003_8.txt
# aclImdb/test/pos/1002_9.txt
# aclImdb/test/pos/1001_10.txt
# aclImdb/test/pos/1000_9.txt
# aclImdb/test/pos/999_8.txt
# aclImdb/test/pos/998_7.txt
# aclImdb/test/pos/997_7.txt
# aclImdb/test/pos/996_7.txt
# aclImdb/test/pos/995_7.txt
# aclImdb/test/pos/994_7.txt
# aclImdb/test/pos/993_8.txt
# aclImdb/test/pos/992_7.txt
# aclImdb/test/pos/991_7.txt
# aclImdb/test/pos/990_7.txt
# aclImdb/test/pos/989_7.txt
# aclImdb/test/pos/988_8.txt
# aclImdb/test/pos/987_7.txt
# aclImdb/test/pos/986_10.txt
# aclImdb/test/pos/985_10.txt
# aclImdb/test/pos/984_8.txt
# aclImdb/test/pos/983_7.txt
# aclImdb/test/pos/982_8.txt
# aclImdb/test/pos/981_9.txt
# aclImdb/test/pos/980_7.txt
# aclImdb/test/pos/979_10.txt
# aclImdb/test/pos/978_7.txt
# aclImdb/test/pos/977_9.txt
# aclImdb/test/pos/976_8.txt
# aclImdb/test/pos/975_7.txt
# aclImdb/test/pos/974_10.txt
# aclImdb/test/pos/973_10.txt
# aclImdb/test/pos/972_7.txt
# aclImdb/test/pos/971_10.txt
# aclImdb/test/pos/970_7.txt
# aclImdb/test/pos/969_9.txt
# aclImdb/test/pos/968_8.txt
# aclImdb/test/pos/967_7.txt
# aclImdb/test/pos/966_10.txt
# aclImdb/test/pos/965_9.txt
# aclImdb/test/pos/964_7.txt
# aclImdb/test/pos/963_8.txt
# aclImdb/test/pos/962_9.txt
# aclImdb/test/pos/961_8.txt
# aclImdb/test/pos/960_8.txt
# aclImdb/test/pos/959_8.txt
# aclImdb/test/pos/958_10.txt
# aclImdb/test/pos/957_10.txt
# aclImdb/test/pos/956_10.txt
# aclImdb/test/pos/955_10.txt
# aclImdb/test/pos/954_8.txt
# aclImdb/test/pos/953_10.txt
# aclImdb/test/pos/952_10.txt
# aclImdb/test/pos/951_10.txt
# aclImdb/test/pos/950_10.txt
# aclImdb/test/pos/949_8.txt
# aclImdb/test/pos/948_8.txt
# aclImdb/test/pos/947_8.txt
# aclImdb/test/pos/946_7.txt
# aclImdb/test/pos/945_7.txt
# aclImdb/test/pos/944_8.txt
# aclImdb/test/pos/943_8.txt
# aclImdb/test/pos/942_10.txt
# aclImdb/test/pos/941_10.txt
# aclImdb/test/pos/940_7.txt
# aclImdb/test/pos/939_8.txt
# aclImdb/test/pos/938_10.txt
# aclImdb/test/pos/937_10.txt
# aclImdb/test/pos/936_9.txt
# aclImdb/test/pos/935_10.txt
# aclImdb/test/pos/934_10.txt
# aclImdb/test/pos/933_10.txt
# aclImdb/test/pos/932_9.txt
# aclImdb/test/pos/931_9.txt
# aclImdb/test/pos/930_10.txt
# aclImdb/test/pos/929_10.txt
# aclImdb/test/pos/928_10.txt
# aclImdb/test/pos/927_10.txt
# aclImdb/test/pos/926_10.txt
# aclImdb/test/pos/925_10.txt
# aclImdb/test/pos/924_10.txt
# aclImdb/test/pos/923_10.txt
# aclImdb/test/pos/922_8.txt
# aclImdb/test/pos/921_9.txt
# aclImdb/test/pos/920_10.txt
# aclImdb/test/pos/919_10.txt
# aclImdb/test/pos/918_10.txt
# aclImdb/test/pos/917_9.txt
# aclImdb/test/pos/916_10.txt
# aclImdb/test/pos/915_10.txt
# aclImdb/test/pos/914_10.txt
# aclImdb/test/pos/913_10.txt
# aclImdb/test/pos/912_10.txt
# aclImdb/test/pos/911_10.txt
# aclImdb/test/pos/910_10.txt
# aclImdb/test/pos/909_10.txt
# aclImdb/test/pos/908_9.txt
# aclImdb/test/pos/907_7.txt
# aclImdb/test/pos/906_7.txt
# aclImdb/test/pos/905_10.txt
# aclImdb/test/pos/904_10.txt
# aclImdb/test/pos/903_10.txt
# aclImdb/test/pos/902_10.txt
# aclImdb/test/pos/901_9.txt
# aclImdb/test/pos/900_9.txt
# aclImdb/test/pos/899_9.txt
# aclImdb/test/pos/898_9.txt
# aclImdb/test/pos/897_8.txt
# aclImdb/test/pos/896_8.txt
# aclImdb/test/pos/1151_9.txt
# aclImdb/test/pos/1150_9.txt
# aclImdb/test/pos/1149_8.txt
# aclImdb/test/pos/1148_8.txt
# aclImdb/test/pos/1147_10.txt
# aclImdb/test/pos/1146_10.txt
# aclImdb/test/pos/1145_9.txt
# aclImdb/test/pos/1144_10.txt
# aclImdb/test/pos/1143_8.txt
# aclImdb/test/pos/1142_7.txt
# aclImdb/test/pos/1141_10.txt
# aclImdb/test/pos/1140_9.txt
# aclImdb/test/pos/1139_10.txt
# aclImdb/test/pos/1138_8.txt
# aclImdb/test/pos/1137_10.txt
# aclImdb/test/pos/1136_8.txt
# aclImdb/test/pos/1135_8.txt
# aclImdb/test/pos/1134_8.txt
# aclImdb/test/pos/1133_8.txt
# aclImdb/test/pos/1132_8.txt
# aclImdb/test/pos/1131_10.txt
# aclImdb/test/pos/1130_8.txt
# aclImdb/test/pos/1129_9.txt
# aclImdb/test/pos/1128_10.txt
# aclImdb/test/pos/1127_10.txt
# aclImdb/test/pos/1126_10.txt
# aclImdb/test/pos/1125_10.txt
# aclImdb/test/pos/1124_8.txt
# aclImdb/test/pos/1123_10.txt
# aclImdb/test/pos/1122_8.txt
# aclImdb/test/pos/1121_7.txt
# aclImdb/test/pos/1120_9.txt
# aclImdb/test/pos/1119_8.txt
# aclImdb/test/pos/1118_7.txt
# aclImdb/test/pos/1117_9.txt
# aclImdb/test/pos/1116_7.txt
# aclImdb/test/pos/1115_9.txt
# aclImdb/test/pos/1114_10.txt
# aclImdb/test/pos/1113_8.txt
# aclImdb/test/pos/1112_8.txt
# aclImdb/test/pos/1111_7.txt
# aclImdb/test/pos/1110_7.txt
# aclImdb/test/pos/1109_10.txt
# aclImdb/test/pos/1108_8.txt
# aclImdb/test/pos/1107_9.txt
# aclImdb/test/pos/1106_9.txt
# aclImdb/test/pos/1105_10.txt
# aclImdb/test/pos/1104_9.txt
# aclImdb/test/pos/1103_10.txt
# aclImdb/test/pos/1102_9.txt
# aclImdb/test/pos/1101_8.txt
# aclImdb/test/pos/1100_9.txt
# aclImdb/test/pos/1099_7.txt
# aclImdb/test/pos/1098_9.txt
# aclImdb/test/pos/1097_9.txt
# aclImdb/test/pos/1096_7.txt
# aclImdb/test/pos/1095_8.txt
# aclImdb/test/pos/1094_7.txt
# aclImdb/test/pos/1093_8.txt
# aclImdb/test/pos/1092_9.txt
# aclImdb/test/pos/1091_7.txt
# aclImdb/test/pos/1090_8.txt
# aclImdb/test/pos/1089_10.txt
# aclImdb/test/pos/1088_8.txt
# aclImdb/test/pos/1087_10.txt
# aclImdb/test/pos/1086_10.txt
# aclImdb/test/pos/1085_9.txt
# aclImdb/test/pos/1084_8.txt
# aclImdb/test/pos/1083_7.txt
# aclImdb/test/pos/1082_9.txt
# aclImdb/test/pos/1081_10.txt
# aclImdb/test/pos/1080_8.txt
# aclImdb/test/pos/1079_8.txt
# aclImdb/test/pos/1078_9.txt
# aclImdb/test/pos/1077_10.txt
# aclImdb/test/pos/1076_8.txt
# aclImdb/test/pos/1075_9.txt
# aclImdb/test/pos/1074_7.txt
# aclImdb/test/pos/1073_8.txt
# aclImdb/test/pos/1072_8.txt
# aclImdb/test/pos/1071_9.txt
# aclImdb/test/pos/1070_10.txt
# aclImdb/test/pos/1069_10.txt
# aclImdb/test/pos/1068_10.txt
# aclImdb/test/pos/1067_9.txt
# aclImdb/test/pos/1066_8.txt
# aclImdb/test/pos/1065_9.txt
# aclImdb/test/pos/1064_8.txt
# aclImdb/test/pos/1063_10.txt
# aclImdb/test/pos/1062_8.txt
# aclImdb/test/pos/1061_8.txt
# aclImdb/test/pos/1060_8.txt
# aclImdb/test/pos/1059_10.txt
# aclImdb/test/pos/1058_10.txt
# aclImdb/test/pos/1057_8.txt
# aclImdb/test/pos/1056_8.txt
# aclImdb/test/pos/1055_10.txt
# aclImdb/test/pos/1054_9.txt
# aclImdb/test/pos/1053_10.txt
# aclImdb/test/pos/1052_10.txt
# aclImdb/test/pos/1051_10.txt
# aclImdb/test/pos/1050_9.txt
# aclImdb/test/pos/1049_9.txt
# aclImdb/test/pos/1048_8.txt
# aclImdb/test/pos/1047_8.txt
# aclImdb/test/pos/1046_9.txt
# aclImdb/test/pos/1045_9.txt
# aclImdb/test/pos/1044_8.txt
# aclImdb/test/pos/1043_9.txt
# aclImdb/test/pos/1042_7.txt
# aclImdb/test/pos/1041_10.txt
# aclImdb/test/pos/1040_9.txt
# aclImdb/test/pos/1039_10.txt
# aclImdb/test/pos/1038_10.txt
# aclImdb/test/pos/1037_10.txt
# aclImdb/test/pos/1036_10.txt
# aclImdb/test/pos/1035_9.txt
# aclImdb/test/pos/1034_10.txt
# aclImdb/test/pos/1033_9.txt
# aclImdb/test/pos/1032_10.txt
# aclImdb/test/pos/1031_10.txt
# aclImdb/test/pos/1030_9.txt
# aclImdb/test/pos/1029_10.txt
# aclImdb/test/pos/1028_10.txt
# aclImdb/test/pos/1027_9.txt
# aclImdb/test/pos/1026_10.txt
# aclImdb/test/pos/1025_10.txt
# aclImdb/test/pos/1024_9.txt
# aclImdb/test/pos/1279_8.txt
# aclImdb/test/pos/1278_10.txt
# aclImdb/test/pos/1277_7.txt
# aclImdb/test/pos/1276_9.txt
# aclImdb/test/pos/1275_7.txt
# aclImdb/test/pos/1274_7.txt
# aclImdb/test/pos/1273_7.txt
# aclImdb/test/pos/1272_8.txt
# aclImdb/test/pos/1271_9.txt
# aclImdb/test/pos/1270_8.txt
# aclImdb/test/pos/1269_10.txt
# aclImdb/test/pos/1268_8.txt
# aclImdb/test/pos/1267_8.txt
# aclImdb/test/pos/1266_8.txt
# aclImdb/test/pos/1265_10.txt
# aclImdb/test/pos/1264_9.txt
# aclImdb/test/pos/1263_9.txt
# aclImdb/test/pos/1262_8.txt
# aclImdb/test/pos/1261_7.txt
# aclImdb/test/pos/1260_10.txt
# aclImdb/test/pos/1259_10.txt
# aclImdb/test/pos/1258_10.txt
# aclImdb/test/pos/1257_10.txt
# aclImdb/test/pos/1256_7.txt
# aclImdb/test/pos/1255_8.txt
# aclImdb/test/pos/1254_10.txt
# aclImdb/test/pos/1253_9.txt
# aclImdb/test/pos/1252_7.txt
# aclImdb/test/pos/1251_10.txt
# aclImdb/test/pos/1250_9.txt
# aclImdb/test/pos/1249_9.txt
# aclImdb/test/pos/1248_8.txt
# aclImdb/test/pos/1247_9.txt
# aclImdb/test/pos/1246_9.txt
# aclImdb/test/pos/1245_8.txt
# aclImdb/test/pos/1244_9.txt
# aclImdb/test/pos/1243_7.txt
# aclImdb/test/pos/1242_7.txt
# aclImdb/test/pos/1241_7.txt
# aclImdb/test/pos/1240_9.txt
# aclImdb/test/pos/1239_10.txt
# aclImdb/test/pos/1238_8.txt
# aclImdb/test/pos/1237_7.txt
# aclImdb/test/pos/1236_7.txt
# aclImdb/test/pos/1235_8.txt
# aclImdb/test/pos/1234_10.txt
# aclImdb/test/pos/1233_10.txt
# aclImdb/test/pos/1232_8.txt
# aclImdb/test/pos/1231_7.txt
# aclImdb/test/pos/1230_10.txt
# aclImdb/test/pos/1229_7.txt
# aclImdb/test/pos/1228_7.txt
# aclImdb/test/pos/1227_7.txt
# aclImdb/test/pos/1226_7.txt
# aclImdb/test/pos/1225_7.txt
# aclImdb/test/pos/1224_8.txt
# aclImdb/test/pos/1223_8.txt
# aclImdb/test/pos/1222_8.txt
# aclImdb/test/pos/1221_10.txt
# aclImdb/test/pos/1220_10.txt
# aclImdb/test/pos/1219_9.txt
# aclImdb/test/pos/1218_10.txt
# aclImdb/test/pos/1217_7.txt
# aclImdb/test/pos/1216_10.txt
# aclImdb/test/pos/1215_10.txt
# aclImdb/test/pos/1214_7.txt
# aclImdb/test/pos/1213_7.txt
# aclImdb/test/pos/1212_7.txt
# aclImdb/test/pos/1211_8.txt
# aclImdb/test/pos/1210_8.txt
# aclImdb/test/pos/1209_7.txt
# aclImdb/test/pos/1208_10.txt
# aclImdb/test/pos/1207_10.txt
# aclImdb/test/pos/1206_10.txt
# aclImdb/test/pos/1205_10.txt
# aclImdb/test/pos/1204_8.txt
# aclImdb/test/pos/1203_7.txt
# aclImdb/test/pos/1202_9.txt
# aclImdb/test/pos/1201_10.txt
# aclImdb/test/pos/1200_10.txt
# aclImdb/test/pos/1199_10.txt
# aclImdb/test/pos/1198_10.txt
# aclImdb/test/pos/1197_9.txt
# aclImdb/test/pos/1196_9.txt
# aclImdb/test/pos/1195_10.txt
# aclImdb/test/pos/1194_10.txt
# aclImdb/test/pos/1193_10.txt
# aclImdb/test/pos/1192_10.txt
# aclImdb/test/pos/1191_7.txt
# aclImdb/test/pos/1190_10.txt
# aclImdb/test/pos/1189_10.txt
# aclImdb/test/pos/1188_10.txt
# aclImdb/test/pos/1187_7.txt
# aclImdb/test/pos/1186_10.txt
# aclImdb/test/pos/1185_10.txt
# aclImdb/test/pos/1184_10.txt
# aclImdb/test/pos/1183_10.txt
# aclImdb/test/pos/1182_7.txt
# aclImdb/test/pos/1181_10.txt
# aclImdb/test/pos/1180_7.txt
# aclImdb/test/pos/1179_7.txt
# aclImdb/test/pos/1178_10.txt
# aclImdb/test/pos/1177_8.txt
# aclImdb/test/pos/1176_9.txt
# aclImdb/test/pos/1175_8.txt
# aclImdb/test/pos/1174_7.txt
# aclImdb/test/pos/1173_7.txt
# aclImdb/test/pos/1172_7.txt
# aclImdb/test/pos/1171_8.txt
# aclImdb/test/pos/1170_10.txt
# aclImdb/test/pos/1169_10.txt
# aclImdb/test/pos/1168_10.txt
# aclImdb/test/pos/1167_10.txt
# aclImdb/test/pos/1166_10.txt
# aclImdb/test/pos/1165_7.txt
# aclImdb/test/pos/1164_9.txt
# aclImdb/test/pos/1163_10.txt
# aclImdb/test/pos/1162_10.txt
# aclImdb/test/pos/1161_10.txt
# aclImdb/test/pos/1160_10.txt
# aclImdb/test/pos/1159_8.txt
# aclImdb/test/pos/1158_7.txt
# aclImdb/test/pos/1157_9.txt
# aclImdb/test/pos/1156_9.txt
# aclImdb/test/pos/1155_7.txt
# aclImdb/test/pos/1154_10.txt
# aclImdb/test/pos/1153_8.txt
# aclImdb/test/pos/1152_8.txt
# aclImdb/test/pos/1407_7.txt
# aclImdb/test/pos/1406_10.txt
# aclImdb/test/pos/1405_10.txt
# aclImdb/test/pos/1404_10.txt
# aclImdb/test/pos/1403_7.txt
# aclImdb/test/pos/1402_8.txt
# aclImdb/test/pos/1401_10.txt
# aclImdb/test/pos/1400_7.txt
# aclImdb/test/pos/1399_7.txt
# aclImdb/test/pos/1398_8.txt
# aclImdb/test/pos/1397_10.txt
# aclImdb/test/pos/1396_8.txt
# aclImdb/test/pos/1395_7.txt
# aclImdb/test/pos/1394_9.txt
# aclImdb/test/pos/1393_8.txt
# aclImdb/test/pos/1392_7.txt
# aclImdb/test/pos/1391_7.txt
# aclImdb/test/pos/1390_8.txt
# aclImdb/test/pos/1389_7.txt
# aclImdb/test/pos/1388_8.txt
# aclImdb/test/pos/1387_8.txt
# aclImdb/test/pos/1386_10.txt
# aclImdb/test/pos/1385_7.txt
# aclImdb/test/pos/1384_9.txt
# aclImdb/test/pos/1383_10.txt
# aclImdb/test/pos/1382_10.txt
# aclImdb/test/pos/1381_7.txt
# aclImdb/test/pos/1380_9.txt
# aclImdb/test/pos/1379_10.txt
# aclImdb/test/pos/1378_10.txt
# aclImdb/test/pos/1377_10.txt
# aclImdb/test/pos/1376_8.txt
# aclImdb/test/pos/1375_10.txt
# aclImdb/test/pos/1374_9.txt
# aclImdb/test/pos/1373_10.txt
# aclImdb/test/pos/1372_10.txt
# aclImdb/test/pos/1371_8.txt
# aclImdb/test/pos/1370_10.txt
# aclImdb/test/pos/1369_7.txt
# aclImdb/test/pos/1368_8.txt
# aclImdb/test/pos/1367_10.txt
# aclImdb/test/pos/1366_10.txt
# aclImdb/test/pos/1365_8.txt
# aclImdb/test/pos/1364_10.txt
# aclImdb/test/pos/1363_10.txt
# aclImdb/test/pos/1362_9.txt
# aclImdb/test/pos/1361_9.txt
# aclImdb/test/pos/1360_7.txt
# aclImdb/test/pos/1359_10.txt
# aclImdb/test/pos/1358_10.txt
# aclImdb/test/pos/1357_9.txt
# aclImdb/test/pos/1356_8.txt
# aclImdb/test/pos/1355_7.txt
# aclImdb/test/pos/1354_7.txt
# aclImdb/test/pos/1353_7.txt
# aclImdb/test/pos/1352_7.txt
# aclImdb/test/pos/1351_7.txt
# aclImdb/test/pos/1350_8.txt
# aclImdb/test/pos/1349_9.txt
# aclImdb/test/pos/1348_8.txt
# aclImdb/test/pos/1347_8.txt
# aclImdb/test/pos/1346_7.txt
# aclImdb/test/pos/1345_9.txt
# aclImdb/test/pos/1344_10.txt
# aclImdb/test/pos/1343_10.txt
# aclImdb/test/pos/1342_10.txt
# aclImdb/test/pos/1341_10.txt
# aclImdb/test/pos/1340_10.txt
# aclImdb/test/pos/1339_8.txt
# aclImdb/test/pos/1338_7.txt
# aclImdb/test/pos/1337_10.txt
# aclImdb/test/pos/1336_10.txt
# aclImdb/test/pos/1335_7.txt
# aclImdb/test/pos/1334_10.txt
# aclImdb/test/pos/1333_7.txt
# aclImdb/test/pos/1332_7.txt
# aclImdb/test/pos/1331_9.txt
# aclImdb/test/pos/1330_10.txt
# aclImdb/test/pos/1329_7.txt
# aclImdb/test/pos/1328_9.txt
# aclImdb/test/pos/1327_9.txt
# aclImdb/test/pos/1326_8.txt
# aclImdb/test/pos/1325_9.txt
# aclImdb/test/pos/1324_10.txt
# aclImdb/test/pos/1323_9.txt
# aclImdb/test/pos/1322_9.txt
# aclImdb/test/pos/1321_10.txt
# aclImdb/test/pos/1320_9.txt
# aclImdb/test/pos/1319_10.txt
# aclImdb/test/pos/1318_8.txt
# aclImdb/test/pos/1317_10.txt
# aclImdb/test/pos/1316_10.txt
# aclImdb/test/pos/1315_10.txt
# aclImdb/test/pos/1314_8.txt
# aclImdb/test/pos/1313_9.txt
# aclImdb/test/pos/1312_10.txt
# aclImdb/test/pos/1311_9.txt
# aclImdb/test/pos/1310_8.txt
# aclImdb/test/pos/1309_7.txt
# aclImdb/test/pos/1308_8.txt
# aclImdb/test/pos/1307_10.txt
# aclImdb/test/pos/1306_8.txt
# aclImdb/test/pos/1305_9.txt
# aclImdb/test/pos/1304_8.txt
# aclImdb/test/pos/1303_10.txt
# aclImdb/test/pos/1302_8.txt
# aclImdb/test/pos/1301_9.txt
# aclImdb/test/pos/1300_9.txt
# aclImdb/test/pos/1299_9.txt
# aclImdb/test/pos/1298_8.txt
# aclImdb/test/pos/1297_7.txt
# aclImdb/test/pos/1296_8.txt
# aclImdb/test/pos/1295_8.txt
# aclImdb/test/pos/1294_7.txt
# aclImdb/test/pos/1293_10.txt
# aclImdb/test/pos/1292_8.txt
# aclImdb/test/pos/1291_7.txt
# aclImdb/test/pos/1290_10.txt
# aclImdb/test/pos/1289_8.txt
# aclImdb/test/pos/1288_8.txt
# aclImdb/test/pos/1287_8.txt
# aclImdb/test/pos/1286_8.txt
# aclImdb/test/pos/1285_9.txt
# aclImdb/test/pos/1284_9.txt
# aclImdb/test/pos/1283_10.txt
# aclImdb/test/pos/1282_10.txt
# aclImdb/test/pos/1281_9.txt
# aclImdb/test/pos/1280_9.txt
# aclImdb/test/pos/1535_7.txt
# aclImdb/test/pos/1534_10.txt
# aclImdb/test/pos/1533_10.txt
# aclImdb/test/pos/1532_10.txt
# aclImdb/test/pos/1531_9.txt
# aclImdb/test/pos/1530_10.txt
# aclImdb/test/pos/1529_10.txt
# aclImdb/test/pos/1528_9.txt
# aclImdb/test/pos/1527_10.txt
# aclImdb/test/pos/1526_7.txt
# aclImdb/test/pos/1525_10.txt
# aclImdb/test/pos/1524_10.txt
# aclImdb/test/pos/1523_10.txt
# aclImdb/test/pos/1522_10.txt
# aclImdb/test/pos/1521_8.txt
# aclImdb/test/pos/1520_8.txt
# aclImdb/test/pos/1519_9.txt
# aclImdb/test/pos/1518_10.txt
# aclImdb/test/pos/1517_9.txt
# aclImdb/test/pos/1516_7.txt
# aclImdb/test/pos/1515_7.txt
# aclImdb/test/pos/1514_7.txt
# aclImdb/test/pos/1513_8.txt
# aclImdb/test/pos/1512_9.txt
# aclImdb/test/pos/1511_9.txt
# aclImdb/test/pos/1510_8.txt
# aclImdb/test/pos/1509_8.txt
# aclImdb/test/pos/1508_7.txt
# aclImdb/test/pos/1507_8.txt
# aclImdb/test/pos/1506_7.txt
# aclImdb/test/pos/1505_7.txt
# aclImdb/test/pos/1504_9.txt
# aclImdb/test/pos/1503_8.txt
# aclImdb/test/pos/1502_10.txt
# aclImdb/test/pos/1501_9.txt
# aclImdb/test/pos/1500_9.txt
# aclImdb/test/pos/1499_9.txt
# aclImdb/test/pos/1498_10.txt
# aclImdb/test/pos/1497_10.txt
# aclImdb/test/pos/1496_10.txt
# aclImdb/test/pos/1495_9.txt
# aclImdb/test/pos/1494_10.txt
# aclImdb/test/pos/1493_10.txt
# aclImdb/test/pos/1492_9.txt
# aclImdb/test/pos/1491_10.txt
# aclImdb/test/pos/1490_9.txt
# aclImdb/test/pos/1489_10.txt
# aclImdb/test/pos/1488_10.txt
# aclImdb/test/pos/1487_9.txt
# aclImdb/test/pos/1486_9.txt
# aclImdb/test/pos/1485_10.txt
# aclImdb/test/pos/1484_10.txt
# aclImdb/test/pos/1483_8.txt
# aclImdb/test/pos/1482_10.txt
# aclImdb/test/pos/1481_10.txt
# aclImdb/test/pos/1480_7.txt
# aclImdb/test/pos/1479_8.txt
# aclImdb/test/pos/1478_8.txt

# %%
train_pos_files = glob.glob('aclImdb/train/pos/*.txt')
train_neg_files = glob.glob('aclImdb/train/neg/*.txt')

# %%
len(train_pos_files), len(train_neg_files)
# Out:
# (12500, 12500)

# %% [markdown]
# We will use 2000 samples from the train set for validation. Let's choose 1000 postive reviews and 1000 negative reviews for validation and save them in the val directory

# %%
# !mkdir aclImdb/val aclImdb/val/pos aclImdb/val/neg

# %%
random.shuffle(train_pos_files)
random.shuffle(train_neg_files)

val_pos_files = train_pos_files[:1000]
val_neg_files = train_neg_files[:1000]

# %%
import shutil

# %%
for f in val_pos_files:
  shutil.move(f,  'aclImdb/val/pos')
for f in val_neg_files:
  shutil.move(f,  'aclImdb/val/neg')

# %% [markdown]
# ### Prepare Dataset

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# INFO:filelock:Lock 139780871368544 acquired on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpgy9lk1eo
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model in cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:filelock:Lock 139780871368544 released on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %%
ids_neg = tokenizer.encode('negative </s>')
ids_pos = tokenizer.encode('positive </s>')
len(ids_neg), len(ids_pos)
# Out:
# (2, 2)

# %% [markdown]
# All the examples are converted in the text-2-text format as shown in the paper. However I didn't use any task prefix here. The examples are encoded as follows,
# if the review is positive then the target is 'positive' else 'negative'
#
# **input**:  I went to see this
# movie with my husband, and we both
# thought the acting was terrible!"
#
# **target**: negative
#
# **input**:  Despite what others say,
# I thought this movie was funny.
#
# **target**: positive

# %% [markdown]
# The dataset below takes care of reading the review files and processing the examples in text-2-text format.
#
# It cleans the review text by removing the html tags. It also appends the eos token `</s>` at the end of input and target as required by the T5 model
#
# For T5 max input length is 512 and we can choose the max length for target sequence depending upon our dataset. The `T5Tokenizer` encodes both 'postive' and 'negative' as a single ids so I chose the max target length 2, extra 1 for the `</s>` token

# %%
class ImdbDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.pos_file_path = os.path.join(data_dir, type_path, 'pos')
    self.neg_file_path = os.path.join(data_dir, type_path, 'neg')
    
    self.pos_files = glob.glob("%s/*.txt" % self.pos_file_path)
    self.neg_files = glob.glob("%s/*.txt" % self.neg_file_path)
    
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self._build()
  
  def __len__(self):
    return len(self.inputs)
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def _build(self):
    self._buil_examples_from_files(self.pos_files, 'positive')
    self._buil_examples_from_files(self.neg_files, 'negative')
  
  def _buil_examples_from_files(self, files, sentiment):
    REPLACE_NO_SPACE = re.compile("[.;:!\'?,\"()\[\]]")
    REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

    for path in files:
      with open(path, 'r') as f:
        text = f.read()
      
      line = text.strip()
      line = REPLACE_NO_SPACE.sub("", line) 
      line = REPLACE_WITH_SPACE.sub("", line)
      line = line + ' </s>'

      target = sentiment + " </s>"

       # tokenize inputs
      tokenized_inputs = self.tokenizer.batch_encode_plus(
          [line], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
      )
       # tokenize targets
      tokenized_targets = self.tokenizer.batch_encode_plus(
          [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
      )

      self.inputs.append(tokenized_inputs)
      self.targets.append(tokenized_targets)

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'val',  max_len=512)
len(dataset)
# Out:
# 2000

# %%
data = dataset[28]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# To quote Flik that was my reaction exactly Wowyoure perfect This is the best movie I think I can even say its become my favorite movie ever even Wow I tell you what wow
# positive

# %% [markdown]
# ### Train

# %%
# !mkdir -p t5_imdb_sentiment

# %%
args_dict.update({'data_dir': 'aclImdb', 'output_dir': 't5_imdb_sentiment', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)

checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %% [markdown]
# Define the `get_dataset` function to return the dataset. The model calls this function to get the train and val datasets. We are defining a dataset function so that we won't need to modify the model code at all. Redefine the function to return different dataset according to the problem. While this is not the best solution for now this works

# %%
def get_dataset(tokenizer, type_path, args):
  return ImdbDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %% [markdown]
# **Initialize model**

# %%
model = T5FineTuner(args)
# Out:
# INFO:filelock:Lock 139780702227256 acquired on /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmp5_6vo8c2
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1199.0, style=ProgressStyle(description…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json in cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:filelock:Lock 139780702227256 released on /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b.lock
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json from cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.configuration_utils:Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "vocab_size": 32128
# }
# INFO:filelock:Lock 139780702189776 acquired on /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa.lock
# INFO:transformers.file_utils:https://cdn.huggingface.co/t5-base-pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmps92w5ati
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691430.0, style=ProgressStyle(descri…
# INFO:transformers.file_utils:storing https://cdn.huggingface.co/t5-base-pytorch_model.bin in cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:filelock:Lock 139780702189776 released on /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa.lock
# INFO:transformers.modeling_utils:loading weights file https://cdn.huggingface.co/t5-base-pytorch_model.bin from cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.modeling_utils:Weights of T5ForConditionalGeneration not initialized from pretrained model: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %% [markdown]
# **Initialize trainer**

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# **start fine-tuning**

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                  | Type                       | Params
# -----------------------------------------------------------------------------------------------------------------
# 0   | model                                                                 | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                          | Embedding                  | 24 M
# 2   | model.encoder                                                         | T5Stack                    | 109 M
# 3   | model.encoder.block                                                   | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                                 | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                           | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                         | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 21  | model.encoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 22  | model.encoder.block.1                                                 | T5Block                    | 7 M
# 23  | model.encoder.block.1.layer                                           | ModuleList                 | 7 M
# 24  | model.encoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 25  | model.encoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 27  | model.encoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 31  | model.encoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 32  | model.encoder.block.1.layer.1                                         | T5LayerFF                  | 4 M
# 33  | model.encoder.block.1.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 37  | model.encoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 38  | model.encoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 39  | model.encoder.block.2                                                 | T5Block                    | 7 M
# 40  | model.encoder.block.2.layer                                           | ModuleList                 | 7 M
# 41  | model.encoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 42  | model.encoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 43  | model.encoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 44  | model.encoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 45  | model.encoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 48  | model.encoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 49  | model.encoder.block.2.layer.1                                         | T5LayerFF                  | 4 M
# 50  | model.encoder.block.2.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 51  | model.encoder.block.2.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 54  | model.encoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 55  | model.encoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 56  | model.encoder.block.3                                                 | T5Block                    | 7 M
# 57  | model.encoder.block.3.layer                                           | ModuleList                 | 7 M
# 58  | model.encoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 59  | model.encoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 60  | model.encoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 61  | model.encoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 62  | model.encoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 63  | model.encoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 65  | model.encoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 66  | model.encoder.block.3.layer.1                                         | T5LayerFF                  | 4 M
# 67  | model.encoder.block.3.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 68  | model.encoder.block.3.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 69  | model.encoder.block.3.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 71  | model.encoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 72  | model.encoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 73  | model.encoder.block.4                                                 | T5Block                    | 7 M
# 74  | model.encoder.block.4.layer                                           | ModuleList                 | 7 M
# 75  | model.encoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 76  | model.encoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 77  | model.encoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 78  | model.encoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 79  | model.encoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 80  | model.encoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 81  | model.encoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 82  | model.encoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 83  | model.encoder.block.4.layer.1                                         | T5LayerFF                  | 4 M
# 84  | model.encoder.block.4.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 85  | model.encoder.block.4.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 86  | model.encoder.block.4.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 87  | model.encoder.block.4.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 88  | model.encoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 89  | model.encoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 90  | model.encoder.block.5                                                 | T5Block                    | 7 M
# 91  | model.encoder.block.5.layer                                           | ModuleList                 | 7 M
# 92  | model.encoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 93  | model.encoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 94  | model.encoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 95  | model.encoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 96  | model.encoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 97  | model.encoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 98  | model.encoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 99  | model.encoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 100 | model.encoder.block.5.layer.1                                         | T5LayerFF                  | 4 M
# 101 | model.encoder.block.5.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 102 | model.encoder.block.5.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 103 | model.encoder.block.5.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 104 | model.encoder.block.5.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 106 | model.encoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 107 | model.encoder.block.6                                                 | T5Block                    | 7 M
# 108 | model.encoder.block.6.layer                                           | ModuleList                 | 7 M
# 109 | model.encoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 110 | model.encoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 111 | model.encoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 112 | model.encoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 113 | model.encoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 114 | model.encoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 115 | model.encoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 116 | model.encoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 117 | model.encoder.block.6.layer.1                                         | T5LayerFF                  | 4 M
# 118 | model.encoder.block.6.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 119 | model.encoder.block.6.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 120 | model.encoder.block.6.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 121 | model.encoder.block.6.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 122 | model.encoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 123 | model.encoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 124 | model.encoder.block.7                                                 | T5Block                    | 7 M
# 125 | model.encoder.block.7.layer                                           | ModuleList                 | 7 M
# 126 | model.encoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 127 | model.encoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 128 | model.encoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 129 | model.encoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 130 | model.encoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 131 | model.encoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 132 | model.encoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 133 | model.encoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 134 | model.encoder.block.7.layer.1                                         | T5LayerFF                  | 4 M
# 135 | model.encoder.block.7.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 136 | model.encoder.block.7.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 137 | model.encoder.block.7.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 138 | model.encoder.block.7.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 139 | model.encoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 141 | model.encoder.block.8                                                 | T5Block                    | 7 M
# 142 | model.encoder.block.8.layer                                           | ModuleList                 | 7 M
# 143 | model.encoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 144 | model.encoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 145 | model.encoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 146 | model.encoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 147 | model.encoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 148 | model.encoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 149 | model.encoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 150 | model.encoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 151 | model.encoder.block.8.layer.1                                         | T5LayerFF                  | 4 M
# 152 | model.encoder.block.8.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 153 | model.encoder.block.8.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 154 | model.encoder.block.8.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 155 | model.encoder.block.8.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 156 | model.encoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 157 | model.encoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 158 | model.encoder.block.9                                                 | T5Block                    | 7 M
# 159 | model.encoder.block.9.layer                                           | ModuleList                 | 7 M
# 160 | model.encoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 161 | model.encoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 162 | model.encoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 163 | model.encoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 164 | model.encoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 165 | model.encoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 166 | model.encoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 167 | model.encoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 168 | model.encoder.block.9.layer.1                                         | T5LayerFF                  | 4 M
# 169 | model.encoder.block.9.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 170 | model.encoder.block.9.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 171 | model.encoder.block.9.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 172 | model.encoder.block.9.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 173 | model.encoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 174 | model.encoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 175 | model.encoder.block.10                                                | T5Block                    | 7 M
# 176 | model.encoder.block.10.layer                                          | ModuleList                 | 7 M
# 177 | model.encoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 178 | model.encoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 179 | model.encoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 180 | model.encoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 181 | model.encoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 182 | model.encoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 183 | model.encoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 184 | model.encoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 185 | model.encoder.block.10.layer.1                                        | T5LayerFF                  | 4 M
# 186 | model.encoder.block.10.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 187 | model.encoder.block.10.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 188 | model.encoder.block.10.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 189 | model.encoder.block.10.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 190 | model.encoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 191 | model.encoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 192 | model.encoder.block.11                                                | T5Block                    | 7 M
# 193 | model.encoder.block.11.layer                                          | ModuleList                 | 7 M
# 194 | model.encoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 195 | model.encoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 196 | model.encoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 197 | model.encoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 198 | model.encoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 199 | model.encoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 200 | model.encoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 201 | model.encoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 202 | model.encoder.block.11.layer.1                                        | T5LayerFF                  | 4 M
# 203 | model.encoder.block.11.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 204 | model.encoder.block.11.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 205 | model.encoder.block.11.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 206 | model.encoder.block.11.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 207 | model.encoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 208 | model.encoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 209 | model.encoder.final_layer_norm                                        | T5LayerNorm                | 768
# 210 | model.encoder.dropout                                                 | Dropout                    | 0
# 211 | model.decoder                                                         | T5Stack                    | 137 M
# 212 | model.decoder.block                                                   | ModuleList                 | 113 M
# 213 | model.decoder.block.0                                                 | T5Block                    | 9 M
# 214 | model.decoder.block.0.layer                                           | ModuleList                 | 9 M
# 215 | model.decoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 216 | model.decoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 217 | model.decoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 218 | model.decoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 219 | model.decoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 220 | model.decoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 221 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 222 | model.decoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 223 | model.decoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 224 | model.decoder.block.0.layer.1                                         | T5LayerCrossAttention      | 2 M
# 225 | model.decoder.block.0.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 226 | model.decoder.block.0.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 227 | model.decoder.block.0.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 228 | model.decoder.block.0.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 229 | model.decoder.block.0.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.1.EncDecAttention.relative_attention_bias | Embedding                  | 384
# 231 | model.decoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 232 | model.decoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 233 | model.decoder.block.0.layer.2                                         | T5LayerFF                  | 4 M
# 234 | model.decoder.block.0.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 235 | model.decoder.block.0.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 236 | model.decoder.block.0.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 237 | model.decoder.block.0.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 238 | model.decoder.block.0.layer.2.layer_norm                              | T5LayerNorm                | 768
# 239 | model.decoder.block.0.layer.2.dropout                                 | Dropout                    | 0
# 240 | model.decoder.block.1                                                 | T5Block                    | 9 M
# 241 | model.decoder.block.1.layer                                           | ModuleList                 | 9 M
# 242 | model.decoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 243 | model.decoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 244 | model.decoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 245 | model.decoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 246 | model.decoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 247 | model.decoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 248 | model.decoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 249 | model.decoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 250 | model.decoder.block.1.layer.1                                         | T5LayerCrossAttention      | 2 M
# 251 | model.decoder.block.1.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 252 | model.decoder.block.1.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 253 | model.decoder.block.1.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 254 | model.decoder.block.1.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 255 | model.decoder.block.1.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 256 | model.decoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 257 | model.decoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 258 | model.decoder.block.1.layer.2                                         | T5LayerFF                  | 4 M
# 259 | model.decoder.block.1.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 260 | model.decoder.block.1.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 261 | model.decoder.block.1.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 262 | model.decoder.block.1.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 263 | model.decoder.block.1.layer.2.layer_norm                              | T5LayerNorm                | 768
# 264 | model.decoder.block.1.layer.2.dropout                                 | Dropout                    | 0
# 265 | model.decoder.block.2                                                 | T5Block                    | 9 M
# 266 | model.decoder.block.2.layer                                           | ModuleList                 | 9 M
# 267 | model.decoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 268 | model.decoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 269 | model.decoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 270 | model.decoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 271 | model.decoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 272 | model.decoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 273 | model.decoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 274 | model.decoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 275 | model.decoder.block.2.layer.1                                         | T5LayerCrossAttention      | 2 M
# 276 | model.decoder.block.2.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 277 | model.decoder.block.2.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 278 | model.decoder.block.2.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 279 | model.decoder.block.2.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 280 | model.decoder.block.2.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 281 | model.decoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 282 | model.decoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 283 | model.decoder.block.2.layer.2                                         | T5LayerFF                  | 4 M
# 284 | model.decoder.block.2.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 285 | model.decoder.block.2.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 286 | model.decoder.block.2.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 287 | model.decoder.block.2.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 288 | model.decoder.block.2.layer.2.layer_norm                              | T5LayerNorm                | 768
# 289 | model.decoder.block.2.layer.2.dropout                                 | Dropout                    | 0
# 290 | model.decoder.block.3                                                 | T5Block                    | 9 M
# 291 | model.decoder.block.3.layer                                           | ModuleList                 | 9 M
# 292 | model.decoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 293 | model.decoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 294 | model.decoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 295 | model.decoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 296 | model.decoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 297 | model.decoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 298 | model.decoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 299 | model.decoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 300 | model.decoder.block.3.layer.1                                         | T5LayerCrossAttention      | 2 M
# 301 | model.decoder.block.3.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 302 | model.decoder.block.3.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 303 | model.decoder.block.3.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 304 | model.decoder.block.3.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 305 | model.decoder.block.3.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 306 | model.decoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 307 | model.decoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 308 | model.decoder.block.3.layer.2                                         | T5LayerFF                  | 4 M
# 309 | model.decoder.block.3.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 310 | model.decoder.block.3.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 311 | model.decoder.block.3.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 312 | model.decoder.block.3.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 313 | model.decoder.block.3.layer.2.layer_norm                              | T5LayerNorm                | 768
# 314 | model.decoder.block.3.layer.2.dropout                                 | Dropout                    | 0
# 315 | model.decoder.block.4                                                 | T5Block                    | 9 M
# 316 | model.decoder.block.4.layer                                           | ModuleList                 | 9 M
# 317 | model.decoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 318 | model.decoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 319 | model.decoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 320 | model.decoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 321 | model.decoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 322 | model.decoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 323 | model.decoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 324 | model.decoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 325 | model.decoder.block.4.layer.1                                         | T5LayerCrossAttention      | 2 M
# 326 | model.decoder.block.4.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 327 | model.decoder.block.4.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 328 | model.decoder.block.4.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 329 | model.decoder.block.4.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 330 | model.decoder.block.4.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 331 | model.decoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 332 | model.decoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 333 | model.decoder.block.4.layer.2                                         | T5LayerFF                  | 4 M
# 334 | model.decoder.block.4.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 335 | model.decoder.block.4.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 336 | model.decoder.block.4.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 337 | model.decoder.block.4.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 338 | model.decoder.block.4.layer.2.layer_norm                              | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.2.dropout                                 | Dropout                    | 0
# 340 | model.decoder.block.5                                                 | T5Block                    | 9 M
# 341 | model.decoder.block.5.layer                                           | ModuleList                 | 9 M
# 342 | model.decoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 343 | model.decoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 344 | model.decoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 345 | model.decoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 346 | model.decoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 347 | model.decoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 348 | model.decoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 349 | model.decoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 350 | model.decoder.block.5.layer.1                                         | T5LayerCrossAttention      | 2 M
# 351 | model.decoder.block.5.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 352 | model.decoder.block.5.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 353 | model.decoder.block.5.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 354 | model.decoder.block.5.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 355 | model.decoder.block.5.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 356 | model.decoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 357 | model.decoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 358 | model.decoder.block.5.layer.2                                         | T5LayerFF                  | 4 M
# 359 | model.decoder.block.5.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 360 | model.decoder.block.5.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 361 | model.decoder.block.5.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 362 | model.decoder.block.5.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 363 | model.decoder.block.5.layer.2.layer_norm                              | T5LayerNorm                | 768
# 364 | model.decoder.block.5.layer.2.dropout                                 | Dropout                    | 0
# 365 | model.decoder.block.6                                                 | T5Block                    | 9 M
# 366 | model.decoder.block.6.layer                                           | ModuleList                 | 9 M
# 367 | model.decoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 368 | model.decoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 369 | model.decoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 370 | model.decoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 371 | model.decoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 372 | model.decoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 373 | model.decoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 374 | model.decoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 375 | model.decoder.block.6.layer.1                                         | T5LayerCrossAttention      | 2 M
# 376 | model.decoder.block.6.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 377 | model.decoder.block.6.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 378 | model.decoder.block.6.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 379 | model.decoder.block.6.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 380 | model.decoder.block.6.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 381 | model.decoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 382 | model.decoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 383 | model.decoder.block.6.layer.2                                         | T5LayerFF                  | 4 M
# 384 | model.decoder.block.6.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 385 | model.decoder.block.6.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 386 | model.decoder.block.6.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 387 | model.decoder.block.6.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 388 | model.decoder.block.6.layer.2.layer_norm                              | T5LayerNorm                | 768
# 389 | model.decoder.block.6.layer.2.dropout                                 | Dropout                    | 0
# 390 | model.decoder.block.7                                                 | T5Block                    | 9 M
# 391 | model.decoder.block.7.layer                                           | ModuleList                 | 9 M
# 392 | model.decoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 393 | model.decoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 394 | model.decoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 395 | model.decoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 396 | model.decoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 397 | model.decoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 398 | model.decoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 399 | model.decoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 400 | model.decoder.block.7.layer.1                                         | T5LayerCrossAttention      | 2 M
# 401 | model.decoder.block.7.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 402 | model.decoder.block.7.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 403 | model.decoder.block.7.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 404 | model.decoder.block.7.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 405 | model.decoder.block.7.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 406 | model.decoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 407 | model.decoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 408 | model.decoder.block.7.layer.2                                         | T5LayerFF                  | 4 M
# 409 | model.decoder.block.7.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 410 | model.decoder.block.7.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 411 | model.decoder.block.7.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 412 | model.decoder.block.7.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 413 | model.decoder.block.7.layer.2.layer_norm                              | T5LayerNorm                | 768
# 414 | model.decoder.block.7.layer.2.dropout                                 | Dropout                    | 0
# 415 | model.decoder.block.8                                                 | T5Block                    | 9 M
# 416 | model.decoder.block.8.layer                                           | ModuleList                 | 9 M
# 417 | model.decoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 418 | model.decoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 419 | model.decoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 420 | model.decoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 421 | model.decoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 422 | model.decoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 423 | model.decoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 424 | model.decoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 425 | model.decoder.block.8.layer.1                                         | T5LayerCrossAttention      | 2 M
# 426 | model.decoder.block.8.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 427 | model.decoder.block.8.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 428 | model.decoder.block.8.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 429 | model.decoder.block.8.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 430 | model.decoder.block.8.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 431 | model.decoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 432 | model.decoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 433 | model.decoder.block.8.layer.2                                         | T5LayerFF                  | 4 M
# 434 | model.decoder.block.8.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 435 | model.decoder.block.8.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 436 | model.decoder.block.8.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 437 | model.decoder.block.8.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 438 | model.decoder.block.8.layer.2.layer_norm                              | T5LayerNorm                | 768
# 439 | model.decoder.block.8.layer.2.dropout                                 | Dropout                    | 0
# 440 | model.decoder.block.9                                                 | T5Block                    | 9 M
# 441 | model.decoder.block.9.layer                                           | ModuleList                 | 9 M
# 442 | model.decoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 443 | model.decoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 444 | model.decoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 445 | model.decoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 446 | model.decoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 447 | model.decoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 448 | model.decoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 449 | model.decoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 450 | model.decoder.block.9.layer.1                                         | T5LayerCrossAttention      | 2 M
# 451 | model.decoder.block.9.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 452 | model.decoder.block.9.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 453 | model.decoder.block.9.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 454 | model.decoder.block.9.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 455 | model.decoder.block.9.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 456 | model.decoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 457 | model.decoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 458 | model.decoder.block.9.layer.2                                         | T5LayerFF                  | 4 M
# 459 | model.decoder.block.9.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 460 | model.decoder.block.9.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 461 | model.decoder.block.9.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 462 | model.decoder.block.9.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 463 | model.decoder.block.9.layer.2.layer_norm                              | T5LayerNorm                | 768
# 464 | model.decoder.block.9.layer.2.dropout                                 | Dropout                    | 0
# 465 | model.decoder.block.10                                                | T5Block                    | 9 M
# 466 | model.decoder.block.10.layer                                          | ModuleList                 | 9 M
# 467 | model.decoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 468 | model.decoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 469 | model.decoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 470 | model.decoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 471 | model.decoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 472 | model.decoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 473 | model.decoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 474 | model.decoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 475 | model.decoder.block.10.layer.1                                        | T5LayerCrossAttention      | 2 M
# 476 | model.decoder.block.10.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 477 | model.decoder.block.10.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 478 | model.decoder.block.10.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 479 | model.decoder.block.10.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 480 | model.decoder.block.10.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 481 | model.decoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 482 | model.decoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 483 | model.decoder.block.10.layer.2                                        | T5LayerFF                  | 4 M
# 484 | model.decoder.block.10.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 485 | model.decoder.block.10.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 486 | model.decoder.block.10.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 487 | model.decoder.block.10.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 488 | model.decoder.block.10.layer.2.layer_norm                             | T5LayerNorm                | 768
# 489 | model.decoder.block.10.layer.2.dropout                                | Dropout                    | 0
# 490 | model.decoder.block.11                                                | T5Block                    | 9 M
# 491 | model.decoder.block.11.layer                                          | ModuleList                 | 9 M
# 492 | model.decoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 493 | model.decoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 494 | model.decoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 495 | model.decoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 496 | model.decoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 497 | model.decoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 498 | model.decoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 499 | model.decoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 500 | model.decoder.block.11.layer.1                                        | T5LayerCrossAttention      | 2 M
# 501 | model.decoder.block.11.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 502 | model.decoder.block.11.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 503 | model.decoder.block.11.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 504 | model.decoder.block.11.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 505 | model.decoder.block.11.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 506 | model.decoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 507 | model.decoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 508 | model.decoder.block.11.layer.2                                        | T5LayerFF                  | 4 M
# 509 | model.decoder.block.11.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 510 | model.decoder.block.11.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 511 | model.decoder.block.11.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 512 | model.decoder.block.11.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 513 | model.decoder.block.11.layer.2.layer_norm                             | T5LayerNorm                | 768
# 514 | model.decoder.block.11.layer.2.dropout                                | Dropout                    | 0
# 515 | model.decoder.final_layer_norm                                        | T5LayerNorm                | 768
# 516 | model.decoder.dropout                                                 | Dropout                    | 0
# 517 | model.lm_head                                                         | Linear                     | 24 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_val_loss = tensor(0.0839, device='cuda:0')
#
# INFO:__main__:loss = tensor(0.0199, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0199, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0839, device='cuda:0')
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_train_loss = tensor(0.2954, device='cuda:0')
#
# INFO:__main__:avg_val_loss = tensor(0.0874, device='cuda:0')
#
# INFO:__main__:epoch = 0
#
# INFO:__main__:loss = tensor(0.0066, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0066, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0874, device='cuda:0')
# 1

# %%
# !mkdir t5_base_imdb_sentiment

# %%
## save the model this way so next time you can load it using T5ForConditionalGeneration.from_pretrained
model.model.save_pretrained('t5_base_imdb_sentiment')
# Out:
# INFO:transformers.configuration_utils:Configuration saved in t5_base_imdb_sentiment/config.json
# INFO:transformers.modeling_utils:Model weights saved in t5_base_imdb_sentiment/pytorch_model.bin

# %%
# !cp -r t5_base_imdb_sentiment drive/My\ Drive/

# %% [markdown]
# ### Eval

# %% [markdown]
# For inference we will use the `generate` method with greedy decoding with max length 2.

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %% [markdown]
# Let's visualize few predictions on test dataset

# %%
dataset = ImdbDataset(tokenizer, 'aclImdb', 'test',  max_len=512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
it = iter(loader)

# %%
batch = next(it)
batch["source_ids"].shape
# Out:
# torch.Size([32, 512])

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    lines = textwrap.wrap("Review:\n%s\n" % texts[i], width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("Predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# Review: I dont know where to begin Perhaps the whole idea of this movie was just a disaster waiting
# to happen There is nothing slightly humorous about a kidnapping I dont know what was more
# offensivethe subject matter or David Arquettes performance It was like watching a bull get its penis
# cut off although I think the bull felt better afterwards The filmmakers should find something about
# Sinatra other than his sons kidnapping to show like I dont know his TALENT AS A SINGER His family
# shouldnt have to relive that horror Thank GOD it was just shown on HBO and not released in theaters
# Please dont watch this if you have any self respect
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: A fine performance by Vittorio Mezzogiorno and a masterful one by JeanHugues Anglade adorn
# this stange tale of lust desire and alienation in France The work of the two lead performers is
# strikingsubtle intense and passionate Alas the script is deliberately turgid and sordid and the
# overall effect leaves one with a downcast spirit Still those who can appreciate fine quality acting
# will be able to savor the courageous work of the leads in this often difficult film journey of
# Gallic low life
#
# Actual sentiment: positive
# Predicted sentiment: negative
# =====================================================================
#
# Review: I almost stopped watching Hindi movies because of the mediocre quality and story lines One
# exception for this is Ramgopal Verma movies This is a nice movie with great performances from the
# star cast This is must see movie for those who are sick of watching stupid dancing and love stories
# The adaptation of the story and characterization was exceptional goodYou should watch this movie for
# Nana Patekar based on the life of Mumbai cop Daya Naik this movie deals in a more realistic way The
# film delves into the life of the common man which he has apart from being an encounter specialist I
# rate this as one of the best movie of the year
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This was a really interesting Halloween film I wasnt to thrilled with the whole Thorn theory
# but it still makes for a good film I liked getting to see Tommy Doyle back but sadly Donald
# Pleasance died right after shooting The film had a really REALLY bad director who didnt give a flip
# about the series from what I heard treated Donald bad and wouldnt let Danielle Harris come back as
# Jamie Its like he was just trying to bring down the film but I still liked it There were alot of
# cuts and music changes and if youre lucky you can get the Producers Cut which features over 40 min
# of never before scenes With those scenes it turns into a whole new movie Check it out if you have
# the chance
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Cheerleader Massacre was supposed to be the fourth installment of the Slumber Party Massacre
# series if thats what they were doing which it is considering ONE actress from the original returns
# in a small cameo role they have failed miserably and made by far the worst installment of the
# quadrilogy Cheerleader Massacre seamlessly combines bad acting a horrible plot a dumb killer dull
# and boring deaths boring scenery and hideous camera work to make it one of the worst films ever made
# Did I already mention how bad it was Dont get me wrong this cheesy and retarded excuse for a horror
# film is nowhere near as bad as Napoleon Dynamite but it is undeniably a horrible movieCheerleader
# Massacre is an exact polar opposite of the original Slumber Party Massacre Stay away by all means
# This movie is utter garbage
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie will give me nightmares I will wake up drenched in sweat screaming I didnt make
# this film please dont blame me I honestly think it would have been more entertaining to watch a fat
# guy eating lard in his moms basement for a hour or two than to watch this crap I understand money
# was tight but goddamn what the hell were they thinking there was no thought plot or effort put into
# this This movie needs a warning Please for the love of god dont fund the drama department a the
# local JC On an other note these are the least likable characters I have ever seen and I have seen
# movies with Hitler in them So lastly take my advice the next time you even think about renting this
# just pop a few hundred Adivl and let the sleep come
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: In this movie Virtual Sexuality the 17 year old Justine is not lucky in love One day when
# she is stood up she goes with her friend to a virual reality conference there she is introduced with
# a machine that can change your look dody and whatever you like in Virtual Reality She decides to try
# it out but begins to make a boyfriend of her own her dreamdate Then suddenly there is an explosion
# in a gas pipe and her creation comes to life Ill say no more youll have to watch the movie which is
# quite fun to watch
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Why does C Thomas Howell do these movies Cruise Howells one time costar does a huge
# blockbuster of WOTW and Howell follows with this lame effortWhere do I start here Production Values
# Ill start with the good stuff The look and feel of some of the scenes in this movie are not too bad
# to be honest The setups are okay in spots and the direction not too badScript Terrible A series of
# clunky scenes that could have been put in any order you like permeate throughout the movie The
# amount of times the scene faded to black and reemerged a second later in the same room was
# uncountable Very poor storyline but so was the Cruise WOTW takes some blame but an abysmal
# screenplay kills it offSpecial FX Okay I dont want to be too harsh here as I imagine the budget was
# smaller than Cruises lunch bill but in the overall context of the film the effects are badly done
# Some shots are quite impressive mainly far off destruction shots of bridges Washington liner But in
# the main the alien machines and tentacles themselves are dreadful Also the camera quality is fuzzy
# on some shots and cuts away entirely on othersActing Im a fan of Howell but as he has reduced
# himself to acting in these lowbudget flicks he has succumbed to the overacting bug a long time ago
# Look at his performance in The Hitcher and compare it to this movie There is no comparison He
# overdoes his facial expressions his flailing arms and legs where did he get that running style and
# for a final coupdegras look at the scene where he loses the photo of his family Hysterical But after
# saying all that he is still the best actor on show here Busey is embarrassing to look at and Peter
# Green Zed is truly dead now baby mumbles incoherently through his one and only scene I honestly
# could not understand one word he said I even went so far as trying to enable the subtitles on that
# scene but the DVD did not have subtitles This seems to be a real keepitinthefamily affair too as
# Howells son the directors wife and the line producer all make it into the film None of them are
# goodDirection not bad but not good eitherScore DismalOverall a lame duck effort that will don'thing
# for Howell in his
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Another Asian horror movie packed with intense and creepy moments Another Asian horror
# trademark is the complexity of the plot which is here as well MAJOR SPOILER WARNINGThe movie starts
# pretty simple two sisters go to live with their dad and stepmother after being put in a mental
# institution after their mother hanged herself The sisters seem very hostile towards their mother
# especially the elder one and they seem to ignore their father All goes smoothly until the mother
# locks the young sister in the wardrobe and the elder sister tells her father Then it hits you your
# sister has been dead for years now It turns out the older sister is still not recovered from the
# death of her mother and what we didnt know is that the wardrobe the mother was hanged in fell on the
# younger sister and killed her as wellAs for the stepmother she is the alter ego of the older sister
# revealed when the stepmother actually the sisters alter ego is sitting on a couch when the real
# stepmother walks in I hope it has been made clearer for confused Asian horror fans out thereFinally
# my favourite scene is the scene where the father invites friends over for dinner and one of the
# friends starts to choke which erupts into a panic attack Very creepy 7 out of 10
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: As a native of New Orleans I can state that almost everything in this movie from the
# atrocious NAwlins dialect to the highly creative manipulation of Crescent City geography is horrible
# This is another one of those Big Hollywood movies that decides to stereotype New Orleans as 1 A city
# full of Frenchsounding idiots 2 A city full of people who sound as if theyve just returned from
# Blanche Dubois summer home 3 A city of drunkards where every day is Mardi Gras 4 A city of deep
# mystery where almost everyone practices or is a victim of voodoo I admit that maybe we are a city of
# drunkards although every day is NOT Mardi Gras The Big Easy is one of the worst films about New
# Orleans I wouldnt recommend it to anybody
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This selfimportant confusing b+w film watches like an infant on a very bad acid trip Youre
# dealing with something that reminds you of a piece of rotting lettuce that accidentally fell out of
# the back of a garbage truck no one cares to touch it because it will probably be washed away on its
# own down the storm drain Theres no room for plot when youve got visceral imagery and subtle allegory
# To me it seems like the director tries to make the next great art movie while begging for
# intellectual accolades I didnt bring my beret either Watching this I felt almost insulted since the
# film does such an effective job of distancing itself from you
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Mercy the movie actually starts out as a somewhat decent film and ellen barkin does give a
# strong performance But if you have read the book and actually got to know the characters and cared
# who done it the movie just does not compare It is always hard to brink a book onto film and
# unfortunatley this one ends up failing 3 out of 10
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: What in the world This piece of gambling cinema would have been suitable for the Lifetime
# Network Michael Imperoli is a good actor but I think his portrayal as Stu fell short The montages
# were unbearable and too many The supporting cast where are you Whoever did the casting should be
# partially at fault The cinematography was useless A gambling story with an after school feel to it
# Stories of this sort should be left for the Oliver Stones of the world It would still suck ass but
# at least it would be fun to watch It was an attempt that lost its wheels before the race ever begun
# Mario Andretti in the 1982 Indy 500 came to mind
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie definitely made me laugh but that doesnt mean it was exactly funny Well then
# again me and my friends had a lot of fun watching itI doubt there is anything about this movie that
# hasnt been done at least twice before just like the plot itself All of the characters are overused
# movie cliché cardboardbox roles that dont even require acting skills accordingly such skills are not
# delivered We have the corrupt cop a ruthless killer who claims to care about his men and their
# families whilst caring nothing about people he shoots in the forehead at so close a range as to have
# blood spat on his face We have the wornout cop on the edge so nicely pointed at in the discussion
# boards of this movie we have the old onedayawayfromretirementcop who just about everyone must have
# immediately identified as the most likely man on the inside since he had most to gain and he didnt
# utter a trustworthy word throughout the movie About as seethrough as a glass house on a sunny day
# The big black gangster king was a copy of all previous big black gangster kings in movie history
# they couldve just called him Marcellus Wallace but just slightly tougher and more ruthless because
# something has to emphasize that we also know Laurence Fishburne from actually good movies Then we
# finally have the HIGHLY EDUCATED doctor who cant think of anything reasonable to do as soon as the
# situation differs from her ordinary life and who spends the majority of the movie sitting in a
# corner helplessly trying to figure out how to hold on to the weapon she was given NOT USING ITThe
# whole siege story is not interesting not original having been used twice before and this movie
# manages to add absolutely nothing interesting to it There is the initial probe then the laying of
# the siege then the assault then the escape attempts Meanwhile a bunch of strained stressed freaked
# out cops and thugs manage to hold off a Police assault team with hightech equipment and the quite
# important advantage of VISION Then again in deep night with the power cut and with a snow storm
# raging overhead there is definitely a lot of light coming in so who really cares about night
# visionBut the best part comes right at the end In the first scenes showing Precinct 13 we see it is
# situated in an outskirt of an industrial city factories and office buildings surround it on all
# sides From this point
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Some people say this show was good in its early years I disagree with all of em The show is
# just plain stupid and pathetic My mum hates it I hate it my dad hates it I dont know about my sister
# but oh well Here some reasons why1 THE CHARACTERS Babies being used as grown up style characters are
# stupid The babies are just precocious and annoying The grown ups and adults are dumb and unappealing
# The worst character is that Angelica Pickles she really does it in for your ear drums when you had a
# long hard and miserable day at the office and also that Kimi Finster who appears later on she is too
# over optimistic and a pain in the butt She cant decided whither she is French or Japanese it doesnt
# matter know you are a American Citizen know and thats that Oh what am I talking about all the
# characters from this show suck2 THE STORIES The stories are unoriginal and dumb The make it like the
# babies go off on a great adventure yeah to the back yard shed In one episode that little goofy brat
# Tommy Pickles the Leader broke in to a televisions control room and literally almost destroyed it
# Dont give kids any idea to smash up normal TV Stations control rooms they pay a awful lot of money
# for them in real life I can imagine what the broadcasters must of felt like airing this episode they
# will probably start staring at their machines throughout the day scared that a baby will brake in
# Sad3 OVER RATED The show has been dragging on for years now and people are still making up stories
# and new series and spinoffs for this Get off The Simpsons have been going for nearly the same amount
# of time as this but they are much better and funnier than babies The show is just plain over rated
# People where is your common senseAnyway I surprised TV Stations across the world want to air this
# series even off today The show is utter junk and should have never been produced The two movies for
# this cartoons sucked just the same 210
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: What can I saynot much to this one at all Pretty dull and uninterestingThe actors
# performances are just OK The only one that shines in any way is Simmons but he only has maybe 3
# scenes I understand that by keeping his screen time to a minimum he retains the mysterious psychic
# aura he has but I cant help but feel his talent was wasted No one else rose above mediocreThe story
# itself seems like it may be intriguing at the beginning but then just doesnt go anywhere There wasnt
# a single scene in the movie that impressed me or made me feel like I had just seen something special
# The cinematography was fairly blandI mean desert in a washed out sort of sepianot very inspiringThe
# story of his childhood pal back outta prison seemed only partially thought out and didnt really add
# anything to the story other than making an average Twilight Zone script into a full length
# featureDrab
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: I kept watching it because it seemed like the plot was going somewhere When it ambiguously
# got there I was very disappointed Im going to tell you what really happened in the next sentence But
# maybe I wont Maybe Ill just imply something will happen The writers lacked any imagination This is
# not even a B movie its a made for TV B movie
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Straight up I love this film I love everything about it It has a great soundtrack it has a
# lot of recognizable faces and it is funny as hell There are so many plots in this film and every one
# of them is funny in one way or anotherWhere as Spicolli lit up the screen two years back Drake is
# almost as memorable of a character All he wants to do is have fun He moves out of the house without
# his parents consent he skips work whenever he feels like it he is obsessed with sex he loves his
# drugs and booze and he tries to be a good friend It is his lacksidaisical attitude that makes him
# such a joy to watch And he comes out with some great lines And there are so many tiny observations
# that you dont see coming but they make you laugh at the sheer velocity when it hits you One
# particular moment is when Tommy and Bill are talking about Bills ex girlfriend dating someone else
# now At the end of the conversation Tommy takes his huge beer bottle and just throws it over his
# shoulder casually He then says good night and the scene ends It is a perfect scene Tommys world is
# his own He really lives to party and have fun When the conversation is over his time is over and he
# doesnt care who he offends in the process He has an innocence about him Its casual is his favourite
# sayingAnother such classic scene is Reggie handing Bill a donut He says something to him that me and
# my friends will never forget because we rewound the film ten times and watched that part over and
# over again and hurt ourselves laughing It has to be seen to be appreciatedWild Life is a throw back
# to when teen comedies were funny raunchy had a good ear entertained us and just wanted us to get
# lost in their world for 90 minutes Wild Life does all those things perfectly If this is a film that
# you havent seen give it a chance It is a classicAlso check out the army store guy that Jim has
# problems with He is a very familiar face now and it is his first role on the big screen
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This movie is a real shame not just for the plotthe empty performance of the characters it
# is for the lack of creativity from the director and all the crew this is maybe one of the worst
# movies of all timesand it is hard to believe that is the sequel of one of the most famous movies of
# the 90sI am a great fan of The Mask when I went to see this movie I was expecting to a movie with a
# good sense of humor a movie with a acceptable plot instead I saw a really bad copy of Chuck Jones
# and Tex Avery cartoons the movie was not funny even for my 7 years old sister so I wonderWhat was
# wrong New Line CinemaWas it trying to repeat the success of the first movie or was it trying to
# create another masterpiece like The Lord of the RingsBecause if they did they were completely out of
# their minds
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: eXistenZ is simply David Cronenbergs best movie All the people compare it to the Matrix
# Theyre not even similar If you enjoyed Cronenbergs other works just a little bit youll love this one
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: First time I ever felt I needed to write a reviewI have seen thousands of movies in my life
# and I like a wide range of movies I am reasonably opened minded and can easily say I enjoyed a movie
# while still saying yeah it was not good but I enjoyed it I can appreciate the mastery of great
# movies like The Shaw shank redemption the godfather and American history X I can like good movies in
# a genre like horror or comedy even if the movie might not be that great I can even enjoy a bad movie
# that just happens to entertain me Bloodsport I also will try to rate movie fairly even if I did not
# like it City lights by Charlie Chapin was not a movie I enjoyed but I can appreciate the acting and
# story lines for the timeI think some people when they go on this site instead of randomly click a
# rating should take a few ideas into account Try to rate the movie based on how good it actually was
# Do not let your personal bias affect the rating Also look at other moves you rated and compare the
# movie you are going to rateThis movie was the worst piece of trash I have ever seen 2 hours of my
# life where just stolen The acting was awful across the board The scenes where choppy at best However
# the real disgrace was the story The first 20 minutes we actually had a story that tried to make
# sense and take the viewer from point A to B However after that it was a nightmare They kept trying
# to add new elements but nothing was every explained Nothing really ever made sense was steward dead
# is he alive did he hit by lighting was it really lighting was it aliens is he an alien etc The
# ending tied nothing together and really did not answer any questions The only positive was nobody
# cared we where just happy to leave the theater6510 What is wrong with some of you I will admit that
# the 8 of us where so mad about seeing this we did think what would make it better and we decide to
# tell a few of our friends that this movie was good so they would have to suffer and see this movie
# What can I say misery loves company That is really the only reason I can see for a 65 ratingDo not
# waste your life
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: My main criticism with the movie is the animation I totally agree with everyone else it was
# very poor Some of the characters seemed to have darker skin tones than they did in the first film
# which is much better Also the background colours looked rushed and somewhat static It is also a
# shame that Michael JFox didnt voice Milo he did such a good job and James Arnold Taylor wasnt sure
# whether he was supposed to sound like Milo or Aladdin I have also taken into consideration the lack
# of a good storyline the third story was confusing and clumsily told and the second story suffered
# from poor scripting To make things worse the first one I cant even remember other than a fishing
# village being haunted or something like that However there was some nice music and good voice
# talents from John Mahoney Cree Summer Clancy Brown and Tom Wilson that saved the film from total
# disaster All in all a disappointing sequel to a surprisingly good film 410 Bethany Cox
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: Giant Robot was the most popular Japanese TV serial ever seen on Indian TV It was targeted
# to children and we saw a robot for the first time in our life Many Indian children must have even
# seen a machine for the first time outside the school textbooks The serial also showed a child in an
# adults organization fighting evil No doubt many of us who have seen Giant Robot in our childhood
# long for our own robots and as a stopgap arrangement look upon our computers in the same way This
# show also portrayed ideal adults referring at Jerry Johnnys buddy friend and Unicorn chief Azuma We
# grew to respect Japanese progress and still view Japan as the ideal Asian nationBTW at that time
# there were no satellite TV channels in India and the govt owned broadcaster did not show much of
# Disney cartoons I guess that was how child serials like giant Robot got appreciated Nowadays there
# is Pokemon etc but they are no so fascinating or alluring as Giant robot
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This might sound weird but I only got to see the first movie The Emperors New Groove
# yaddayadda a week ago and only because of one episode of the TV show I simply adore Kuzcos character
# but Kronk isnt that bad either Anyway eventually I decided to watch the second film just so I
# wouldve seen it Hoped it would be as good as the first one but Im sorry to tell this but the more
# the humour got American the more I yawned I agreed with Kuzco when he started crying seeing all the
# cheesy footageStill younger kids and probably veterans too will love this movie to bits if they like
# the old school moralising Disney that is but I just had expectations that were an eensy teensy
# little bit hell of a lot higher than they shouldve been Kronk is a lovely character being good
# hearted and dumb all at once but it were Pacha and Kuzco in drag that woke me up at the end of the
# movie Ill ignore Rudy for as far thats possibleAnyway great movie just not my style and as they say
# you always have to be true to your groove
#
# Actual sentiment: negative
# Predicted sentiment: positive
# =====================================================================
#
# Review: The problem I have as a Finn is that most of the actors in this movie are in every Finnish
# movie I have a feeling that Finland has only like five actors I think that if youre not from Finland
# you really like this movie as a refreshing noveltyThis movie is about a dreadful chain of events
# that affects a few people quite harshly Alcoholism cold climate and darkness may all be clichés but
# theyre still very real in todays Finnish society A lot of people in Finland have depression
# especially during winterThe tone of the movie is very melancholic I enjoyed it and Louhimes
# directing was again very solid I liked this movie a lot only negative thing is that you see the same
# faces that youve seen over and over again
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Most of the criticism of Attack of Show is from people who are unfairly comparing it to an
# old computer TV program called The Screen Savers People are upset because G4 decided to cancel the
# Screen Savers and replace it with the pop culture based Attack of the Show To compare the two shows
# is like comparing apples to orangesAttack of the Show is a unique hour long program that covers
# current Generation XY culture It features segments on moviestelevision panel discussions video games
# new DVD releases sex advice new gadgets MP3 players cell phones etc comic booksgraphic novels
# magazines and internet fads Its a fun show definitely worth checking out you are in your 20s or 30s
# I give it an 8 out of 10
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: This is the best comedy period It is so underrated Clever witty humor Great casting Jerry
# Stiller is the jewel in the show he is so incredibly funny and quirky simply a comical genius Doug
# and Carrie have great chemistry I so don't see what the hype is about when it comes to Everybody
# loves Raymond it is SO overrated with lame jokes mostly forced humor and just not the witty show I
# cant remember laughing in more than 1 episode King of Queens is a rare comedy that has all the right
# ingredients to give you serious belly laughs which is normally caused by Arthur Spooner I think its
# about time this comedy gets the hype it deserves and not the lame Raymond & CO
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Running Out of Time rests somewhere in the middle of Johnny Tos cannon in the solid good
# category As a crime thriller its not terribly original or overwhelming and the action scenes will
# not blow you away but it has something else going for it Its a Johnny To film after all it has
# toAndy Lau has 72 hours to live He decides to play a strange catandmouse game with a hostage
# negotiator of the HK police played by Lau Ching Wan Thats the plot in a nutshell On top of that To
# piles layers of twists and turns that keep proceedings interesting throughout It occasionally
# becomes too convoluted for its own sake but never lets it get the best of it However just as Johnny
# To is about to hand over a slick and wellmade crime flick which lets face it are dimeadozen he slips
# in bits and pieces that bring Running Out of Time alive as a full emotional experience providing the
# soul and heart to the welloiled skeletonThe concepts of synchronism and minimalism staples in his
# work are explored in great effect here Always subtle letting the images speak for themselves giving
# them time to develop with long takes and slow tracking shots exemplary cutting to the score its all
# here A small love story in a bus between Andy Lau and a girl is among the highlights of the film and
# part of the heart Im talking about So simple yet so powerful Ditto for Laus and Lau Ching Wans car
# scenes and the bowlingroom showdownHowever something stops me from claiming Running Out of Time is a
# masterpiece To has all the ability and craftmanship down to a notch but he can also be too
# workmanlike or bland at times When hes good hes REAL good There are even isolated moment of pure
# brilliance that are just TOO good for their own sake leaving a bittersweet aftertaste for the rest
# of the movie Im convinced that if he puts his heart to it he can make a really great film As it is
# this is another one of his films that is flawed but enjoyable Underneath the slick HK style its the
# black humour and heartfelt drama that makes this a compelling film Worth watching definitely
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: Will there be please coming an end to hyping movies that are dealing about social conflicts
# or other human disasters Okay Care is about childabuse Care is about perverts misusing boys in a
# school and how disgusting it might be if its a movie with a poor script and made with bad playing
# actors then it stays a bad movie Care is a movie that could have been but is it because it was a
# tvmovie I dont know but everything seemed so limited that it comes over as some cheap movie that
# will be seen by some housewifes and fathers who decide not to go to bed There are so many unanswered
# things in this moviethe relation with his mother for instance or the death of some abused boy from
# which we know nothing more Care should have been much much better
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================
#
# Review: This movie appears to have been overlooked by everyone Someone should bring it out on VHS
# and DVD It is an excellent film and far superior to the one with Brooke Shields which was terrible
# Jean Simmons deserves more credit than she is getting now days It would be nice if all her films
# were offered on VHS or DVD Jean Simmons was and still is a very good actress She certainly was a
# beauty In fact she is still a beauty She also has done extremely well on TV She is so much better
# than many of the actors today
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: When I heard there was to be an ABC Australian Broadcasting Corporation miniseries based on
# life in Changi WWII POW camp with a focus on elements of comedy I was deeply sceptical and somewhat
# criticalMy father had served in the second world war Such was the barbarity of the Japanese he was
# able to talk about the horrors in and around Labuan where he was stationed until only quite recently
# Along with my father I had been awarded the fortune of knowing many great men of stronger character
# and spirit than I shall ever have who had witnessed acts of unspeakable barbarity at the hands of
# the Empire of Japan and had never completely recovered The name Changi is destined to conjure
# horrific images for ages to comeBut upon viewing I was highly impressed with the cast the characters
# and the complex plotlines of this wonderful series I now regard Changi as the highlight of my week
# bear in mind I have viewed only three episodes so far I hope the remaining episodes adhere to the
# standards set by the first threeThe black humour works uncannily well however the flatulence jokes
# are a little overdone and while much of the horror has been suppressed the series comes quite close
# in relaying the undaunted spirit of the survivors who were able to later continue with their lives
# in spite of the inhibiting memoriesThe flashback format of this series will be difficult for some to
# followbut I can not think of no better way to do adequate justice to the men who suffered deep
# emotional scarring proceeding internment when painfully suppressed experiences are remembered
# sometimes years after the horrorOne of the darkest chapters of the Second World War the 20th century
# and I would go so far as to say in the history of mankind is being relayed to a new generation
# through this series and I hope it serves to relay the overwhelming adversity borne by the wartime
# generationProceeding Changi I dont think I shall ever be able to listen to the poignant tune on the
# road to Gundagai in the same way again Tune in
#
# Actual sentiment: positive
# Predicted sentiment: positive
# =====================================================================
#
# Review: I was pretty enthusiastic about seeing this movie when it came out Commercials for it made
# it look quirky and I generally like Morgan Freeman and Chris Rock and the combination of the two
# seemed like an interesting idea Sadly I was terribly disappointed with Nurse BettyPersonally Ive
# usually found that graphic violence and comedy dont go all that well together and the only directors
# that have ever combined the two successfully in my opinion are Tarantino and the Coens There isnt
# that much violence in Nurse Betty but what violence is in it made me feel kind of weird when I was
# supposed to laugh Of course for me part of the problem was also that there didnt seem to be many
# places where I was being asked toThe film doesnt much work as a drama either Renee Zellwegers Betty
# the storys protagonist is clinically insane and impossible to relate to in any real way I will say
# Zellweger acts the role quite well and Freeman Rock and Greg Kinnear all do good jobs too The
# problem is in the writing Freeman is the only person that gets to play an interesting character Its
# really too bad 310
#
# Actual sentiment: negative
# Predicted sentiment: negative
# =====================================================================

# %% [markdown]
# Now predict on all the test dataset

# %%
loader = DataLoader(dataset, batch_size=32, num_workers=4)
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=782.0), HTML(value='')))

# %% [markdown]
# Let's check if the model generates any invalid text

# %%
for i, out in enumerate(outputs):
  if out not in ['positive', 'negative']:
    print(i, 'detected invalid prediction')

# %% [markdown]
# This great is great! Our model hasn't generated any invalid prediction. Let's calculate accuarcy and other metrics

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.94712

# %%
print(metrics.classification_report(targets, outputs))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.95      0.95      0.95     12500
#     positive       0.95      0.95      0.95     12500
#
#     accuracy                           0.95     25000
#    macro avg       0.95      0.95      0.95     25000
# weighted avg       0.95      0.95      0.95     25000

# %% [markdown]
# ## Emotion classification
#
# While most of the sentiment-analysis datasets are binary with 'postive' and 'negative' sentiments, [Elvis Saravia](https://twitter.com/omarsar0)  has put together a great [dataset](https://github.com/dair-ai/emotion_dataset) for emotion recognition. The task is given some text classifiy the text into one of the following six emotions
#
# 'sadness', 'joy', 'anger', 'fear', 'surprise', 'love'.
#
# Here's the [original notebook](https://colab.research.google.com/drive/1nwCE6b9PXIKhv2hvbqf1oZKIGkXMTi1X#scrollTo=pSzoz9InH0Ta) which trains ROBERTa model to classify the text

# %% [markdown]
# ### Download and view data

# %%
# !wget https://www.dropbox.com/s/ikkqxfdbdec3fuj/test.txt
# !wget https://www.dropbox.com/s/1pzkadrvffbqw6o/train.txt
# !wget https://www.dropbox.com/s/2mzialpsgf9k5l3/val.txt
# Out:
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/ikkqxfdbdec3fuj/test.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/ikkqxfdbdec3fuj/test.txt [following]
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/raw/ikkqxfdbdec3fuj/test.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:02 ERROR 404: Not Found.
#
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/1pzkadrvffbqw6o/train.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/1pzkadrvffbqw6o/train.txt [following]
# --2024-01-27 19:56:02--  https://www.dropbox.com/s/raw/1pzkadrvffbqw6o/train.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:03 ERROR 404: Not Found.
#
# --2024-01-27 19:56:03--  https://www.dropbox.com/s/2mzialpsgf9k5l3/val.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/2mzialpsgf9k5l3/val.txt [following]
# --2024-01-27 19:56:03--  https://www.dropbox.com/s/raw/2mzialpsgf9k5l3/val.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-27 19:56:03 ERROR 404: Not Found.

# %%
# !mkdir emotion_data
# !mv *.txt emotion_data

# %%
train_path = "emotion_data/train.txt"
test_path = "emotion_data/test.txt"
val_path = "emotion_data/val.txt"

## emotion labels
label2int = {
  "sadness": 0,
  "joy": 1,
  "love": 2,
  "anger": 3,
  "fear": 4,
  "surprise": 5
}

# %%
data = pd.read_csv(train_path, sep=";", header=None, names=['text', 'emotion'],
                               engine="python")
data.emotion.value_counts().plot.bar()

# %%
train.head()
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
train.count()
# Out:
# text       16000
# emotion    16000
# dtype: int64

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# INFO:filelock:Lock 139955425093728 acquired on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpsnkx0l2g
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model in cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:transformers.file_utils:creating metadata file for /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# INFO:filelock:Lock 139955425093728 released on /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f.lock
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %% [markdown]
# ### Dataset

# %% [markdown]
# Here also we will process the examples in the same way we did above. If the label is 'love' we will ask the model to predict the text 'love'

# %% [markdown]
# Lets check how t5 encodes the following labels

# %%
emotions = [ "sadness", "joy", "love", "anger", "fear", "surprise"]
for em in emotions:
  print(len(tokenizer.encode(em)))
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# Here also all the labels are encoded as single ids

# %%
class EmotionDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.path = os.path.join(data_dir, type_path + '.txt')

    self.data_column = "text"
    self.class_column = "emotion"
    self.data = pd.read_csv(self.path, sep=";", header=None, names=[self.data_column, self.class_column],
                            engine="python")
    
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self._build()
  
  def __len__(self):
    return len(self.inputs)
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def _build(self):
    for idx in range(len(self.data)):
      input_, target = self.data.loc[idx, self.data_column], self.data.loc[idx, self.class_column]      
      
      input_ = input_ + ' </s>'
      target = target + " </s>"

       # tokenize inputs
      tokenized_inputs = self.tokenizer.batch_encode_plus(
          [input_], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
      )
       # tokenize targets
      tokenized_targets = self.tokenizer.batch_encode_plus(
          [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
      )

      self.inputs.append(tokenized_inputs)
      self.targets.append(tokenized_targets)

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'val', 512)
len(dataset)
# Out:
# 2000

# %%
data = dataset[42]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# i honestly don't feel discouraged today as i usually do
# sadness

# %% [markdown]
# ### Train

# %% [markdown]
# As I said above there's no need to change the model or add task specific head or any other hyperparameters, we'll just change the dataset and that's it!

# %%
# !mkdir -p t5_emotion

# %%
args_dict.update({'data_dir': 'emotion_data', 'output_dir': 't5_emotion', 'num_train_epochs':2})
args = argparse.Namespace(**args_dict)
print(args_dict)
# Out:
# {'data_dir': 'emotion_data', 'output_dir': 't5_emotion', 'model_name_or_path': 't5-base', 'tokenizer_name_or_path': 't5-base', 'max_seq_length': 512, 'learning_rate': 0.0003, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'warmup_steps': 0, 'train_batch_size': 8, 'eval_batch_size': 8, 'num_train_epochs': 2, 'gradient_accumulation_steps': 16, 'n_gpu': 1, 'early_stop_callback': False, 'fp_16': False, 'opt_level': 'O1', 'max_grad_norm': 1.0, 'seed': 42}

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return EmotionDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)
# Out:
# INFO:transformers.configuration_utils:loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/t5-base-config.json from cache at /root/.cache/torch/transformers/40578967d1f029acb6162b36db9d8b4307063e885990ccd297c2c5be1cf1b3d7.2995d650f5eba18c8baa4146e210d32d56165e90d374281741fc78b872cd6c9b
# INFO:transformers.configuration_utils:Model config T5Config {
#   "architectures": [
#     "T5WithLMHeadModel"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "vocab_size": 32128
# }
#
# INFO:transformers.modeling_utils:loading weights file https://cdn.huggingface.co/t5-base-pytorch_model.bin from cache at /root/.cache/torch/transformers/f6f2fde9fa7611f4eff74620de9cbe734e7a717b5b143bd283cae4c2d6022990.54f906ff53bd09195cfc183a29cadc81b7705f07fcdb796d24163cb632b6bdfa
# INFO:transformers.modeling_utils:Weights of T5ForConditionalGeneration not initialized from pretrained model: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight']
# INFO:transformers.tokenization_utils:loading file https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model from cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                  | Type                       | Params
# -----------------------------------------------------------------------------------------------------------------
# 0   | model                                                                 | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                          | Embedding                  | 24 M
# 2   | model.encoder                                                         | T5Stack                    | 109 M
# 3   | model.encoder.block                                                   | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                                 | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                           | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                         | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 21  | model.encoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 22  | model.encoder.block.1                                                 | T5Block                    | 7 M
# 23  | model.encoder.block.1.layer                                           | ModuleList                 | 7 M
# 24  | model.encoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 25  | model.encoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 27  | model.encoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 31  | model.encoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 32  | model.encoder.block.1.layer.1                                         | T5LayerFF                  | 4 M
# 33  | model.encoder.block.1.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 37  | model.encoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 38  | model.encoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 39  | model.encoder.block.2                                                 | T5Block                    | 7 M
# 40  | model.encoder.block.2.layer                                           | ModuleList                 | 7 M
# 41  | model.encoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 42  | model.encoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 43  | model.encoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 44  | model.encoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 45  | model.encoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 48  | model.encoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 49  | model.encoder.block.2.layer.1                                         | T5LayerFF                  | 4 M
# 50  | model.encoder.block.2.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 51  | model.encoder.block.2.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 54  | model.encoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 55  | model.encoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 56  | model.encoder.block.3                                                 | T5Block                    | 7 M
# 57  | model.encoder.block.3.layer                                           | ModuleList                 | 7 M
# 58  | model.encoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 59  | model.encoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 60  | model.encoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 61  | model.encoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 62  | model.encoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 63  | model.encoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 65  | model.encoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 66  | model.encoder.block.3.layer.1                                         | T5LayerFF                  | 4 M
# 67  | model.encoder.block.3.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 68  | model.encoder.block.3.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 69  | model.encoder.block.3.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 71  | model.encoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 72  | model.encoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 73  | model.encoder.block.4                                                 | T5Block                    | 7 M
# 74  | model.encoder.block.4.layer                                           | ModuleList                 | 7 M
# 75  | model.encoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 76  | model.encoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 77  | model.encoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 78  | model.encoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 79  | model.encoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 80  | model.encoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 81  | model.encoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 82  | model.encoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 83  | model.encoder.block.4.layer.1                                         | T5LayerFF                  | 4 M
# 84  | model.encoder.block.4.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 85  | model.encoder.block.4.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 86  | model.encoder.block.4.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 87  | model.encoder.block.4.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 88  | model.encoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 89  | model.encoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 90  | model.encoder.block.5                                                 | T5Block                    | 7 M
# 91  | model.encoder.block.5.layer                                           | ModuleList                 | 7 M
# 92  | model.encoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 93  | model.encoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 94  | model.encoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 95  | model.encoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 96  | model.encoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 97  | model.encoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 98  | model.encoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 99  | model.encoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 100 | model.encoder.block.5.layer.1                                         | T5LayerFF                  | 4 M
# 101 | model.encoder.block.5.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 102 | model.encoder.block.5.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 103 | model.encoder.block.5.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 104 | model.encoder.block.5.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 106 | model.encoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 107 | model.encoder.block.6                                                 | T5Block                    | 7 M
# 108 | model.encoder.block.6.layer                                           | ModuleList                 | 7 M
# 109 | model.encoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 110 | model.encoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 111 | model.encoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 112 | model.encoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 113 | model.encoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 114 | model.encoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 115 | model.encoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 116 | model.encoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 117 | model.encoder.block.6.layer.1                                         | T5LayerFF                  | 4 M
# 118 | model.encoder.block.6.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 119 | model.encoder.block.6.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 120 | model.encoder.block.6.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 121 | model.encoder.block.6.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 122 | model.encoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 123 | model.encoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 124 | model.encoder.block.7                                                 | T5Block                    | 7 M
# 125 | model.encoder.block.7.layer                                           | ModuleList                 | 7 M
# 126 | model.encoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 127 | model.encoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 128 | model.encoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 129 | model.encoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 130 | model.encoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 131 | model.encoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 132 | model.encoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 133 | model.encoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 134 | model.encoder.block.7.layer.1                                         | T5LayerFF                  | 4 M
# 135 | model.encoder.block.7.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 136 | model.encoder.block.7.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 137 | model.encoder.block.7.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 138 | model.encoder.block.7.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 139 | model.encoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 141 | model.encoder.block.8                                                 | T5Block                    | 7 M
# 142 | model.encoder.block.8.layer                                           | ModuleList                 | 7 M
# 143 | model.encoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 144 | model.encoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 145 | model.encoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 146 | model.encoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 147 | model.encoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 148 | model.encoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 149 | model.encoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 150 | model.encoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 151 | model.encoder.block.8.layer.1                                         | T5LayerFF                  | 4 M
# 152 | model.encoder.block.8.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 153 | model.encoder.block.8.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 154 | model.encoder.block.8.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 155 | model.encoder.block.8.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 156 | model.encoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 157 | model.encoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 158 | model.encoder.block.9                                                 | T5Block                    | 7 M
# 159 | model.encoder.block.9.layer                                           | ModuleList                 | 7 M
# 160 | model.encoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 161 | model.encoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 162 | model.encoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 163 | model.encoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 164 | model.encoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 165 | model.encoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 166 | model.encoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 167 | model.encoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 168 | model.encoder.block.9.layer.1                                         | T5LayerFF                  | 4 M
# 169 | model.encoder.block.9.layer.1.DenseReluDense                          | T5DenseReluDense           | 4 M
# 170 | model.encoder.block.9.layer.1.DenseReluDense.wi                       | Linear                     | 2 M
# 171 | model.encoder.block.9.layer.1.DenseReluDense.wo                       | Linear                     | 2 M
# 172 | model.encoder.block.9.layer.1.DenseReluDense.dropout                  | Dropout                    | 0
# 173 | model.encoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 174 | model.encoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 175 | model.encoder.block.10                                                | T5Block                    | 7 M
# 176 | model.encoder.block.10.layer                                          | ModuleList                 | 7 M
# 177 | model.encoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 178 | model.encoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 179 | model.encoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 180 | model.encoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 181 | model.encoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 182 | model.encoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 183 | model.encoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 184 | model.encoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 185 | model.encoder.block.10.layer.1                                        | T5LayerFF                  | 4 M
# 186 | model.encoder.block.10.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 187 | model.encoder.block.10.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 188 | model.encoder.block.10.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 189 | model.encoder.block.10.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 190 | model.encoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 191 | model.encoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 192 | model.encoder.block.11                                                | T5Block                    | 7 M
# 193 | model.encoder.block.11.layer                                          | ModuleList                 | 7 M
# 194 | model.encoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 195 | model.encoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 196 | model.encoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 197 | model.encoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 198 | model.encoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 199 | model.encoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 200 | model.encoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 201 | model.encoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 202 | model.encoder.block.11.layer.1                                        | T5LayerFF                  | 4 M
# 203 | model.encoder.block.11.layer.1.DenseReluDense                         | T5DenseReluDense           | 4 M
# 204 | model.encoder.block.11.layer.1.DenseReluDense.wi                      | Linear                     | 2 M
# 205 | model.encoder.block.11.layer.1.DenseReluDense.wo                      | Linear                     | 2 M
# 206 | model.encoder.block.11.layer.1.DenseReluDense.dropout                 | Dropout                    | 0
# 207 | model.encoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 208 | model.encoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 209 | model.encoder.final_layer_norm                                        | T5LayerNorm                | 768
# 210 | model.encoder.dropout                                                 | Dropout                    | 0
# 211 | model.decoder                                                         | T5Stack                    | 137 M
# 212 | model.decoder.block                                                   | ModuleList                 | 113 M
# 213 | model.decoder.block.0                                                 | T5Block                    | 9 M
# 214 | model.decoder.block.0.layer                                           | ModuleList                 | 9 M
# 215 | model.decoder.block.0.layer.0                                         | T5LayerSelfAttention       | 2 M
# 216 | model.decoder.block.0.layer.0.SelfAttention                           | T5Attention                | 2 M
# 217 | model.decoder.block.0.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 218 | model.decoder.block.0.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 219 | model.decoder.block.0.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 220 | model.decoder.block.0.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 221 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias   | Embedding                  | 384
# 222 | model.decoder.block.0.layer.0.layer_norm                              | T5LayerNorm                | 768
# 223 | model.decoder.block.0.layer.0.dropout                                 | Dropout                    | 0
# 224 | model.decoder.block.0.layer.1                                         | T5LayerCrossAttention      | 2 M
# 225 | model.decoder.block.0.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 226 | model.decoder.block.0.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 227 | model.decoder.block.0.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 228 | model.decoder.block.0.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 229 | model.decoder.block.0.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.1.EncDecAttention.relative_attention_bias | Embedding                  | 384
# 231 | model.decoder.block.0.layer.1.layer_norm                              | T5LayerNorm                | 768
# 232 | model.decoder.block.0.layer.1.dropout                                 | Dropout                    | 0
# 233 | model.decoder.block.0.layer.2                                         | T5LayerFF                  | 4 M
# 234 | model.decoder.block.0.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 235 | model.decoder.block.0.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 236 | model.decoder.block.0.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 237 | model.decoder.block.0.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 238 | model.decoder.block.0.layer.2.layer_norm                              | T5LayerNorm                | 768
# 239 | model.decoder.block.0.layer.2.dropout                                 | Dropout                    | 0
# 240 | model.decoder.block.1                                                 | T5Block                    | 9 M
# 241 | model.decoder.block.1.layer                                           | ModuleList                 | 9 M
# 242 | model.decoder.block.1.layer.0                                         | T5LayerSelfAttention       | 2 M
# 243 | model.decoder.block.1.layer.0.SelfAttention                           | T5Attention                | 2 M
# 244 | model.decoder.block.1.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 245 | model.decoder.block.1.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 246 | model.decoder.block.1.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 247 | model.decoder.block.1.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 248 | model.decoder.block.1.layer.0.layer_norm                              | T5LayerNorm                | 768
# 249 | model.decoder.block.1.layer.0.dropout                                 | Dropout                    | 0
# 250 | model.decoder.block.1.layer.1                                         | T5LayerCrossAttention      | 2 M
# 251 | model.decoder.block.1.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 252 | model.decoder.block.1.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 253 | model.decoder.block.1.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 254 | model.decoder.block.1.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 255 | model.decoder.block.1.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 256 | model.decoder.block.1.layer.1.layer_norm                              | T5LayerNorm                | 768
# 257 | model.decoder.block.1.layer.1.dropout                                 | Dropout                    | 0
# 258 | model.decoder.block.1.layer.2                                         | T5LayerFF                  | 4 M
# 259 | model.decoder.block.1.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 260 | model.decoder.block.1.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 261 | model.decoder.block.1.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 262 | model.decoder.block.1.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 263 | model.decoder.block.1.layer.2.layer_norm                              | T5LayerNorm                | 768
# 264 | model.decoder.block.1.layer.2.dropout                                 | Dropout                    | 0
# 265 | model.decoder.block.2                                                 | T5Block                    | 9 M
# 266 | model.decoder.block.2.layer                                           | ModuleList                 | 9 M
# 267 | model.decoder.block.2.layer.0                                         | T5LayerSelfAttention       | 2 M
# 268 | model.decoder.block.2.layer.0.SelfAttention                           | T5Attention                | 2 M
# 269 | model.decoder.block.2.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 270 | model.decoder.block.2.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 271 | model.decoder.block.2.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 272 | model.decoder.block.2.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 273 | model.decoder.block.2.layer.0.layer_norm                              | T5LayerNorm                | 768
# 274 | model.decoder.block.2.layer.0.dropout                                 | Dropout                    | 0
# 275 | model.decoder.block.2.layer.1                                         | T5LayerCrossAttention      | 2 M
# 276 | model.decoder.block.2.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 277 | model.decoder.block.2.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 278 | model.decoder.block.2.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 279 | model.decoder.block.2.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 280 | model.decoder.block.2.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 281 | model.decoder.block.2.layer.1.layer_norm                              | T5LayerNorm                | 768
# 282 | model.decoder.block.2.layer.1.dropout                                 | Dropout                    | 0
# 283 | model.decoder.block.2.layer.2                                         | T5LayerFF                  | 4 M
# 284 | model.decoder.block.2.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 285 | model.decoder.block.2.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 286 | model.decoder.block.2.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 287 | model.decoder.block.2.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 288 | model.decoder.block.2.layer.2.layer_norm                              | T5LayerNorm                | 768
# 289 | model.decoder.block.2.layer.2.dropout                                 | Dropout                    | 0
# 290 | model.decoder.block.3                                                 | T5Block                    | 9 M
# 291 | model.decoder.block.3.layer                                           | ModuleList                 | 9 M
# 292 | model.decoder.block.3.layer.0                                         | T5LayerSelfAttention       | 2 M
# 293 | model.decoder.block.3.layer.0.SelfAttention                           | T5Attention                | 2 M
# 294 | model.decoder.block.3.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 295 | model.decoder.block.3.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 296 | model.decoder.block.3.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 297 | model.decoder.block.3.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 298 | model.decoder.block.3.layer.0.layer_norm                              | T5LayerNorm                | 768
# 299 | model.decoder.block.3.layer.0.dropout                                 | Dropout                    | 0
# 300 | model.decoder.block.3.layer.1                                         | T5LayerCrossAttention      | 2 M
# 301 | model.decoder.block.3.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 302 | model.decoder.block.3.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 303 | model.decoder.block.3.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 304 | model.decoder.block.3.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 305 | model.decoder.block.3.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 306 | model.decoder.block.3.layer.1.layer_norm                              | T5LayerNorm                | 768
# 307 | model.decoder.block.3.layer.1.dropout                                 | Dropout                    | 0
# 308 | model.decoder.block.3.layer.2                                         | T5LayerFF                  | 4 M
# 309 | model.decoder.block.3.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 310 | model.decoder.block.3.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 311 | model.decoder.block.3.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 312 | model.decoder.block.3.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 313 | model.decoder.block.3.layer.2.layer_norm                              | T5LayerNorm                | 768
# 314 | model.decoder.block.3.layer.2.dropout                                 | Dropout                    | 0
# 315 | model.decoder.block.4                                                 | T5Block                    | 9 M
# 316 | model.decoder.block.4.layer                                           | ModuleList                 | 9 M
# 317 | model.decoder.block.4.layer.0                                         | T5LayerSelfAttention       | 2 M
# 318 | model.decoder.block.4.layer.0.SelfAttention                           | T5Attention                | 2 M
# 319 | model.decoder.block.4.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 320 | model.decoder.block.4.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 321 | model.decoder.block.4.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 322 | model.decoder.block.4.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 323 | model.decoder.block.4.layer.0.layer_norm                              | T5LayerNorm                | 768
# 324 | model.decoder.block.4.layer.0.dropout                                 | Dropout                    | 0
# 325 | model.decoder.block.4.layer.1                                         | T5LayerCrossAttention      | 2 M
# 326 | model.decoder.block.4.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 327 | model.decoder.block.4.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 328 | model.decoder.block.4.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 329 | model.decoder.block.4.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 330 | model.decoder.block.4.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 331 | model.decoder.block.4.layer.1.layer_norm                              | T5LayerNorm                | 768
# 332 | model.decoder.block.4.layer.1.dropout                                 | Dropout                    | 0
# 333 | model.decoder.block.4.layer.2                                         | T5LayerFF                  | 4 M
# 334 | model.decoder.block.4.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 335 | model.decoder.block.4.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 336 | model.decoder.block.4.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 337 | model.decoder.block.4.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 338 | model.decoder.block.4.layer.2.layer_norm                              | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.2.dropout                                 | Dropout                    | 0
# 340 | model.decoder.block.5                                                 | T5Block                    | 9 M
# 341 | model.decoder.block.5.layer                                           | ModuleList                 | 9 M
# 342 | model.decoder.block.5.layer.0                                         | T5LayerSelfAttention       | 2 M
# 343 | model.decoder.block.5.layer.0.SelfAttention                           | T5Attention                | 2 M
# 344 | model.decoder.block.5.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 345 | model.decoder.block.5.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 346 | model.decoder.block.5.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 347 | model.decoder.block.5.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 348 | model.decoder.block.5.layer.0.layer_norm                              | T5LayerNorm                | 768
# 349 | model.decoder.block.5.layer.0.dropout                                 | Dropout                    | 0
# 350 | model.decoder.block.5.layer.1                                         | T5LayerCrossAttention      | 2 M
# 351 | model.decoder.block.5.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 352 | model.decoder.block.5.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 353 | model.decoder.block.5.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 354 | model.decoder.block.5.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 355 | model.decoder.block.5.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 356 | model.decoder.block.5.layer.1.layer_norm                              | T5LayerNorm                | 768
# 357 | model.decoder.block.5.layer.1.dropout                                 | Dropout                    | 0
# 358 | model.decoder.block.5.layer.2                                         | T5LayerFF                  | 4 M
# 359 | model.decoder.block.5.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 360 | model.decoder.block.5.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 361 | model.decoder.block.5.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 362 | model.decoder.block.5.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 363 | model.decoder.block.5.layer.2.layer_norm                              | T5LayerNorm                | 768
# 364 | model.decoder.block.5.layer.2.dropout                                 | Dropout                    | 0
# 365 | model.decoder.block.6                                                 | T5Block                    | 9 M
# 366 | model.decoder.block.6.layer                                           | ModuleList                 | 9 M
# 367 | model.decoder.block.6.layer.0                                         | T5LayerSelfAttention       | 2 M
# 368 | model.decoder.block.6.layer.0.SelfAttention                           | T5Attention                | 2 M
# 369 | model.decoder.block.6.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 370 | model.decoder.block.6.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 371 | model.decoder.block.6.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 372 | model.decoder.block.6.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 373 | model.decoder.block.6.layer.0.layer_norm                              | T5LayerNorm                | 768
# 374 | model.decoder.block.6.layer.0.dropout                                 | Dropout                    | 0
# 375 | model.decoder.block.6.layer.1                                         | T5LayerCrossAttention      | 2 M
# 376 | model.decoder.block.6.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 377 | model.decoder.block.6.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 378 | model.decoder.block.6.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 379 | model.decoder.block.6.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 380 | model.decoder.block.6.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 381 | model.decoder.block.6.layer.1.layer_norm                              | T5LayerNorm                | 768
# 382 | model.decoder.block.6.layer.1.dropout                                 | Dropout                    | 0
# 383 | model.decoder.block.6.layer.2                                         | T5LayerFF                  | 4 M
# 384 | model.decoder.block.6.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 385 | model.decoder.block.6.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 386 | model.decoder.block.6.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 387 | model.decoder.block.6.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 388 | model.decoder.block.6.layer.2.layer_norm                              | T5LayerNorm                | 768
# 389 | model.decoder.block.6.layer.2.dropout                                 | Dropout                    | 0
# 390 | model.decoder.block.7                                                 | T5Block                    | 9 M
# 391 | model.decoder.block.7.layer                                           | ModuleList                 | 9 M
# 392 | model.decoder.block.7.layer.0                                         | T5LayerSelfAttention       | 2 M
# 393 | model.decoder.block.7.layer.0.SelfAttention                           | T5Attention                | 2 M
# 394 | model.decoder.block.7.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 395 | model.decoder.block.7.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 396 | model.decoder.block.7.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 397 | model.decoder.block.7.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 398 | model.decoder.block.7.layer.0.layer_norm                              | T5LayerNorm                | 768
# 399 | model.decoder.block.7.layer.0.dropout                                 | Dropout                    | 0
# 400 | model.decoder.block.7.layer.1                                         | T5LayerCrossAttention      | 2 M
# 401 | model.decoder.block.7.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 402 | model.decoder.block.7.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 403 | model.decoder.block.7.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 404 | model.decoder.block.7.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 405 | model.decoder.block.7.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 406 | model.decoder.block.7.layer.1.layer_norm                              | T5LayerNorm                | 768
# 407 | model.decoder.block.7.layer.1.dropout                                 | Dropout                    | 0
# 408 | model.decoder.block.7.layer.2                                         | T5LayerFF                  | 4 M
# 409 | model.decoder.block.7.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 410 | model.decoder.block.7.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 411 | model.decoder.block.7.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 412 | model.decoder.block.7.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 413 | model.decoder.block.7.layer.2.layer_norm                              | T5LayerNorm                | 768
# 414 | model.decoder.block.7.layer.2.dropout                                 | Dropout                    | 0
# 415 | model.decoder.block.8                                                 | T5Block                    | 9 M
# 416 | model.decoder.block.8.layer                                           | ModuleList                 | 9 M
# 417 | model.decoder.block.8.layer.0                                         | T5LayerSelfAttention       | 2 M
# 418 | model.decoder.block.8.layer.0.SelfAttention                           | T5Attention                | 2 M
# 419 | model.decoder.block.8.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 420 | model.decoder.block.8.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 421 | model.decoder.block.8.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 422 | model.decoder.block.8.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 423 | model.decoder.block.8.layer.0.layer_norm                              | T5LayerNorm                | 768
# 424 | model.decoder.block.8.layer.0.dropout                                 | Dropout                    | 0
# 425 | model.decoder.block.8.layer.1                                         | T5LayerCrossAttention      | 2 M
# 426 | model.decoder.block.8.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 427 | model.decoder.block.8.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 428 | model.decoder.block.8.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 429 | model.decoder.block.8.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 430 | model.decoder.block.8.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 431 | model.decoder.block.8.layer.1.layer_norm                              | T5LayerNorm                | 768
# 432 | model.decoder.block.8.layer.1.dropout                                 | Dropout                    | 0
# 433 | model.decoder.block.8.layer.2                                         | T5LayerFF                  | 4 M
# 434 | model.decoder.block.8.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 435 | model.decoder.block.8.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 436 | model.decoder.block.8.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 437 | model.decoder.block.8.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 438 | model.decoder.block.8.layer.2.layer_norm                              | T5LayerNorm                | 768
# 439 | model.decoder.block.8.layer.2.dropout                                 | Dropout                    | 0
# 440 | model.decoder.block.9                                                 | T5Block                    | 9 M
# 441 | model.decoder.block.9.layer                                           | ModuleList                 | 9 M
# 442 | model.decoder.block.9.layer.0                                         | T5LayerSelfAttention       | 2 M
# 443 | model.decoder.block.9.layer.0.SelfAttention                           | T5Attention                | 2 M
# 444 | model.decoder.block.9.layer.0.SelfAttention.q                         | Linear                     | 589 K
# 445 | model.decoder.block.9.layer.0.SelfAttention.k                         | Linear                     | 589 K
# 446 | model.decoder.block.9.layer.0.SelfAttention.v                         | Linear                     | 589 K
# 447 | model.decoder.block.9.layer.0.SelfAttention.o                         | Linear                     | 589 K
# 448 | model.decoder.block.9.layer.0.layer_norm                              | T5LayerNorm                | 768
# 449 | model.decoder.block.9.layer.0.dropout                                 | Dropout                    | 0
# 450 | model.decoder.block.9.layer.1                                         | T5LayerCrossAttention      | 2 M
# 451 | model.decoder.block.9.layer.1.EncDecAttention                         | T5Attention                | 2 M
# 452 | model.decoder.block.9.layer.1.EncDecAttention.q                       | Linear                     | 589 K
# 453 | model.decoder.block.9.layer.1.EncDecAttention.k                       | Linear                     | 589 K
# 454 | model.decoder.block.9.layer.1.EncDecAttention.v                       | Linear                     | 589 K
# 455 | model.decoder.block.9.layer.1.EncDecAttention.o                       | Linear                     | 589 K
# 456 | model.decoder.block.9.layer.1.layer_norm                              | T5LayerNorm                | 768
# 457 | model.decoder.block.9.layer.1.dropout                                 | Dropout                    | 0
# 458 | model.decoder.block.9.layer.2                                         | T5LayerFF                  | 4 M
# 459 | model.decoder.block.9.layer.2.DenseReluDense                          | T5DenseReluDense           | 4 M
# 460 | model.decoder.block.9.layer.2.DenseReluDense.wi                       | Linear                     | 2 M
# 461 | model.decoder.block.9.layer.2.DenseReluDense.wo                       | Linear                     | 2 M
# 462 | model.decoder.block.9.layer.2.DenseReluDense.dropout                  | Dropout                    | 0
# 463 | model.decoder.block.9.layer.2.layer_norm                              | T5LayerNorm                | 768
# 464 | model.decoder.block.9.layer.2.dropout                                 | Dropout                    | 0
# 465 | model.decoder.block.10                                                | T5Block                    | 9 M
# 466 | model.decoder.block.10.layer                                          | ModuleList                 | 9 M
# 467 | model.decoder.block.10.layer.0                                        | T5LayerSelfAttention       | 2 M
# 468 | model.decoder.block.10.layer.0.SelfAttention                          | T5Attention                | 2 M
# 469 | model.decoder.block.10.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 470 | model.decoder.block.10.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 471 | model.decoder.block.10.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 472 | model.decoder.block.10.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 473 | model.decoder.block.10.layer.0.layer_norm                             | T5LayerNorm                | 768
# 474 | model.decoder.block.10.layer.0.dropout                                | Dropout                    | 0
# 475 | model.decoder.block.10.layer.1                                        | T5LayerCrossAttention      | 2 M
# 476 | model.decoder.block.10.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 477 | model.decoder.block.10.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 478 | model.decoder.block.10.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 479 | model.decoder.block.10.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 480 | model.decoder.block.10.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 481 | model.decoder.block.10.layer.1.layer_norm                             | T5LayerNorm                | 768
# 482 | model.decoder.block.10.layer.1.dropout                                | Dropout                    | 0
# 483 | model.decoder.block.10.layer.2                                        | T5LayerFF                  | 4 M
# 484 | model.decoder.block.10.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 485 | model.decoder.block.10.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 486 | model.decoder.block.10.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 487 | model.decoder.block.10.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 488 | model.decoder.block.10.layer.2.layer_norm                             | T5LayerNorm                | 768
# 489 | model.decoder.block.10.layer.2.dropout                                | Dropout                    | 0
# 490 | model.decoder.block.11                                                | T5Block                    | 9 M
# 491 | model.decoder.block.11.layer                                          | ModuleList                 | 9 M
# 492 | model.decoder.block.11.layer.0                                        | T5LayerSelfAttention       | 2 M
# 493 | model.decoder.block.11.layer.0.SelfAttention                          | T5Attention                | 2 M
# 494 | model.decoder.block.11.layer.0.SelfAttention.q                        | Linear                     | 589 K
# 495 | model.decoder.block.11.layer.0.SelfAttention.k                        | Linear                     | 589 K
# 496 | model.decoder.block.11.layer.0.SelfAttention.v                        | Linear                     | 589 K
# 497 | model.decoder.block.11.layer.0.SelfAttention.o                        | Linear                     | 589 K
# 498 | model.decoder.block.11.layer.0.layer_norm                             | T5LayerNorm                | 768
# 499 | model.decoder.block.11.layer.0.dropout                                | Dropout                    | 0
# 500 | model.decoder.block.11.layer.1                                        | T5LayerCrossAttention      | 2 M
# 501 | model.decoder.block.11.layer.1.EncDecAttention                        | T5Attention                | 2 M
# 502 | model.decoder.block.11.layer.1.EncDecAttention.q                      | Linear                     | 589 K
# 503 | model.decoder.block.11.layer.1.EncDecAttention.k                      | Linear                     | 589 K
# 504 | model.decoder.block.11.layer.1.EncDecAttention.v                      | Linear                     | 589 K
# 505 | model.decoder.block.11.layer.1.EncDecAttention.o                      | Linear                     | 589 K
# 506 | model.decoder.block.11.layer.1.layer_norm                             | T5LayerNorm                | 768
# 507 | model.decoder.block.11.layer.1.dropout                                | Dropout                    | 0
# 508 | model.decoder.block.11.layer.2                                        | T5LayerFF                  | 4 M
# 509 | model.decoder.block.11.layer.2.DenseReluDense                         | T5DenseReluDense           | 4 M
# 510 | model.decoder.block.11.layer.2.DenseReluDense.wi                      | Linear                     | 2 M
# 511 | model.decoder.block.11.layer.2.DenseReluDense.wo                      | Linear                     | 2 M
# 512 | model.decoder.block.11.layer.2.DenseReluDense.dropout                 | Dropout                    | 0
# 513 | model.decoder.block.11.layer.2.layer_norm                             | T5LayerNorm                | 768
# 514 | model.decoder.block.11.layer.2.dropout                                | Dropout                    | 0
# 515 | model.decoder.final_layer_norm                                        | T5LayerNorm                | 768
# 516 | model.decoder.dropout                                                 | Dropout                    | 0
# 517 | model.lm_head                                                         | Linear                     | 24 M
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_val_loss = tensor(0.0846, device='cuda:0')
#
# INFO:__main__:loss = tensor(0.0290, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0290, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0846, device='cuda:0')
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:__main__:***** Validation results *****
# INFO:__main__:avg_train_loss = tensor(0.5601, device='cuda:0')
#
# INFO:__main__:avg_val_loss = tensor(0.0696, device='cuda:0')
#
# INFO:__main__:epoch = 0
#
# INFO:__main__:loss = tensor(0.0134, device='cuda:0')
#
# INFO:__main__:train_loss = tensor(0.0134, device='cuda:0')
#
# INFO:__main__:val_loss = tensor(0.0696, device='cuda:0')
# 1

# %% [markdown]
# ### Eval

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'test', 512)
loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
it = iter(loader)

# %%
batch = next(it)
batch["source_ids"].shape
# Out:
# torch.Size([32, 512])

# %%
outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

dec = [tokenizer.decode(ids) for ids in outs]

texts = [tokenizer.decode(ids) for ids in batch['source_ids']]
targets = [tokenizer.decode(ids) for ids in batch['target_ids']]

# %%
for i in range(32):
    c = texts[i]
    lines = textwrap.wrap("text:\n%s\n" % c, width=100)
    print("\n".join(lines))
    print("\nActual sentiment: %s" % targets[i])
    print("predicted sentiment: %s" % dec[i])
    print("=====================================================================\n")
# Out:
# text: i feel like ive come a long way and im proud of what ive achieved not only this week but this
# year as well
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel unfathomably rich in having had a healthy pregnancy so far
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: im just feeling emo and bitchy atm
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i always feel troubled when we re on the road touring living in a van or more recently in the
# circus buses no place to hang my hat as the song lyric has it
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i still feel confused and guilty about the whole thing
#
# Actual sentiment: fear
# predicted sentiment: fear
# =====================================================================
#
# text: i feel immensely distracted by the barrage of media i receive solicit
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: im feeling too tortured to write today
#
# Actual sentiment: fear
# predicted sentiment: anger
# =====================================================================
#
# text: i have the joy of allowing kids to feel like the valued treasures that they are and to just
# have a blast being a kid alongside with them but can i just say its an incredibly humbling
# experience to have influence into a childs life and to know that what you do and say is being
# internalized
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i dont want flowers or candy but the kind of guy that knows i like thinly sliced limes in my
# mineral water because it makes me feel glamorous and is humored by how pretentious that is
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i just was expressing myself and her unexpected and kind gesture made me feel bad for a short
# moment as that was not my intent but for a larger moment which remains with me it reminded me of my
# blessings like having good friends that have your back
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: im feeling brave ill snatch him to on my lap and after a few seconds of struggling he
# completely relaxes and submits to mommy scratches
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: im sick of feeling unimportant like nobody needs me
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel like these unfortunate events fit in with my thought quote i posted above
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel like they don t think it s sincere when it really is she told us exclusively
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel a little low about being in japan and i always feel pangs of guilt when i fail to
# appreciate my living situation and decisions
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i couldn t help but feel pissed off at both sides of the debate and the unnecessary dichotomy
# itself
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i felt so bad for the bad grade and feeling like having to hide it that i didnt know what to
# say except to declare in all my frustration that i hated school
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i do feel proud and happy and also very grateful to all who read me
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i am going to have to check on in just a few minutes but there is this clock up above the
# screen that keeps ticking down the minutes i have left so am feeling a bit frantic
#
# Actual sentiment: fear
# predicted sentiment: fear
# =====================================================================
#
# text: i am feeling bitchy this evening
#
# Actual sentiment: anger
# predicted sentiment: anger
# =====================================================================
#
# text: i feel like my room is messy if theyre open
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: im starting to feel really pathetic giving the bulk of my enthusiasm these days to the
# kardashians us weekly and roseanne marathons and completely ignoring this blog
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i am feeling content and happy with myself
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel slightly saddened to know that some of the kids have also resigned during my absence
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel that passionate about
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i too feel a sense of melancholy for them
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i can t quite figure out how i feel i m not devastated like i was with lucy and i m not sure
# if that s because it s easier to do after the first time or what
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel ashamed of you
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i like the fresh feeling of sweet he gave me
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================
#
# text: i feel so jaded and bored
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i feel fake because i think if you really want to have a good conversation and make good
# contact you have to appear especially self confident and even risk talking to some people which are
# no good to talk to at all until you meet one person which you have a good connection to
#
# Actual sentiment: sadness
# predicted sentiment: sadness
# =====================================================================
#
# text: i am feeling pretty fearless
#
# Actual sentiment: joy
# predicted sentiment: joy
# =====================================================================

# %% [markdown]
# #### Test Metrics

# %%
dataset = EmotionDataset(tokenizer, 'emotion_data', 'test', 512)
loader = DataLoader(dataset, batch_size=32, num_workers=4)
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=63.0), HTML(value='')))

# %%
for i, out in enumerate(outputs):
  if out not in emotions:
    print(i, 'detected invalid prediction')

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.929

# %%
print(metrics.classification_report(targets, outputs))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.94      0.93      0.93       275
#         fear       0.86      0.92      0.89       224
#          joy       0.97      0.93      0.95       695
#         love       0.79      0.89      0.84       159
#      sadness       0.97      0.96      0.97       581
#     surprise       0.75      0.74      0.75        66
#
#     accuracy                           0.93      2000
#    macro avg       0.88      0.90      0.89      2000
# weighted avg       0.93      0.93      0.93      2000

# %% [markdown]
# Now lets plot  the confusion matrix and see for which classes our model is getting confused

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
cm = metrics.confusion_matrix(targets, outputs)

# %%
df_cm = pd.DataFrame(cm, index = ["anger", "fear", "joy", "love", "sadness", "surprise"], columns = ["anger", "fear", "joy", "love", "sadness", "surprise"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap='Purples', fmt='g')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %% [markdown]
# From the above plot we can see that the most confused classes are 'joy' and 'love' which seems obivous as these two emotions are really close. We can say the same thing 'surprise' and 'anger' as well. So our model is doing pretty well.

# %% [markdown]
# ## SWAG
#
# Now lets try a more challenging task and see how it performs.
#
# SWAG is a natural language inference and commonsense reasoning task proposed in this [paper](https://arxiv.org/pdf/1808.05326.pdf).
#
# The basic task is that  a model is
# given a context **c = (s, n)**: a complete sentence
# **s** and a noun phrase **n** that begins a second sentence, as well as a list of possible verb phrase sentence endings **V**. The model must then
# select the most appropriate verb phrase **v** in **V**. For example
#
# On stage, a woman takes a seat at the piano. She
#
# a) sits on a bench as her sister plays with the doll.
#
# b) smiles with someone as the music plays.
#
# c) is in the crowd, watching the dancers.
#
# **d) nervously sets her fingers on the keys.**
#
# The correct answer is bolded. Given the above example the model should select **nervously sets her fingers on the keys** as the most appropriate verb phrase
#
# To frame this task in text-2-text setting the example is processed as below.
#
# context: context_text options: 1: option_1 2: option_2 3: option_3 4: option_4
#
# and if the actual label is 1 then the model is asked to predict the text '1'. Here's how the above example will be processed
#
# **Input**
#
# context: On stage, a woman takes a seat at the piano. She  options: 1: sits on a bench as her sister plays with the doll. 2: smiles with someone as the music plays. 3: is in the crowd, watching the dancers. 4: nervously sets her fingers on the keys.
#
# **Target**
#
# 4
#
# This is just one possible way to process these examples, there are various other ways we can formulate this problem in text-2-text setting but that's for later.

# %% [markdown]
# ### Dataset

# %%
import csv
from dataclasses import dataclass

from enum import Enum
from typing import List, Optional
from transformers import PreTrainedTokenizer

# %%
# !wget https://raw.githubusercontent.com/rowanz/swagaf/master/data/train.csv
# !wget https://raw.githubusercontent.com/rowanz/swagaf/master/data/val.csv

# !mkdir swag_data
# !mv *.csv swag_data
# Out:
# --2024-01-27 20:28:41--  https://raw.githubusercontent.com/rowanz/swagaf/master/data/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28243333 (27M) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  26.93M   104MB/s    in 0.3s
#
# 2024-01-27 20:28:41 (104 MB/s) - ‘train.csv’ saved [28243333/28243333]
#
# --2024-01-27 20:28:42--  https://raw.githubusercontent.com/rowanz/swagaf/master/data/val.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7893588 (7.5M) [text/plain]
# Saving to: ‘val.csv’
#
# val.csv             100%[===================>]   7.53M  --.-KB/s    in 0.06s
#
# 2024-01-27 20:28:42 (120 MB/s) - ‘val.csv’ saved [7893588/7893588]
#
# mkdir: cannot create directory ‘swag_data’: File exists

# %%
# below code is adapted from https://github.com/huggingface/transformers/blob/master/examples/multiple-choice/utils_multiple_choice.py

@dataclass(frozen=True)
class InputExample:
    """
    A single training/test example for multiple choice
    Args:
        example_id: Unique id for the example.
        question: string. The untokenized text of the second sequence (question).
        contexts: list of str. The untokenized text of the first sequence (context of corresponding question).
        endings: list of str. multiple choice's options. Its length must be equal to contexts' length.
        label: (Optional) string. The label of the example. This should be
        specified for train and dev examples, but not for test examples.
    """

    example_id: str
    context: str
    endings: List[str]
    label: Optional[str]

class Split(Enum):
    train = "train"
    dev = "dev"
    test = "test"

class DataProcessor:
    """Base class for data converters for multiple choice data sets."""

    def get_train_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the train set."""
        raise NotImplementedError()

    def get_dev_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the dev set."""
        raise NotImplementedError()

    def get_test_examples(self, data_dir):
        """Gets a collection of `InputExample`s for the test set."""
        raise NotImplementedError()

    def get_labels(self):
        """Gets the list of labels for this data set."""
        raise NotImplementedError()

class SwagProcessor(DataProcessor):
    """Processor for the SWAG data set."""

    def get_train_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} train".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "train.csv")), "train")

    def get_dev_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        return self._create_examples(self._read_csv(os.path.join(data_dir, "val.csv")), "dev")

    def get_test_examples(self, data_dir):
        """See base class."""
        logger.info("LOOKING AT {} dev".format(data_dir))
        raise ValueError(
            "For swag testing, the input file does not contain a label column. It can not be tested in current code"
            "setting!"
        )
        return self._create_examples(self._read_csv(os.path.join(data_dir, "test.csv")), "test")

    def get_labels(self):
        """See base class."""
        return ["0", "1", "2", "3"]

    def _read_csv(self, input_file):
        with open(input_file, "r", encoding="utf-8") as f:
            return list(csv.reader(f))

    def _create_examples(self, lines: List[List[str]], type: str):
        """Creates examples for the training and dev sets."""
        if type == "train" and lines[0][-1] != "label":
            raise ValueError("For training, the input file must contain a label column.")

        examples = [
            InputExample(
                example_id=line[2],
                # common beginning of each
                # choice is stored in "sent2".
                context=line[3],
                endings=[line[7], line[8], line[9], line[10]],
                label=line[11],
            )
            for line in lines[1:]  # we skip the line with the column names
        ]

        return examples

# %%
class SwagDataset(Dataset):
  def __init__(self, tokenizer, data_dir, type_path,  max_len=512):
    self.data_dir = data_dir
    self.type_path = type_path
    self.max_len = max_len
    self.tokenizer = tokenizer
    self.inputs = []
    self.targets = []

    self.proc = SwagProcessor()

    self._build()
  
  def __getitem__(self, index):
    source_ids = self.inputs[index]["input_ids"].squeeze()
    target_ids = self.targets[index]["input_ids"].squeeze()

    src_mask    = self.inputs[index]["attention_mask"].squeeze()  # might need to squeeze
    target_mask = self.targets[index]["attention_mask"].squeeze()  # might need to squeeze

    return {"source_ids": source_ids, "source_mask": src_mask, "target_ids": target_ids, "target_mask": target_mask}
  
  def __len__(self):
    return len(self.inputs)
  
  def _build(self):
    if self.type_path == 'train':
      examples = self.proc.get_train_examples(self.data_dir)
    else:
      examples = self.proc.get_dev_examples(self.data_dir)
    
    for example in examples:
      self._create_features(example)
  
  def _create_features(self, example):
    input_ = example.context
    options = ['%s: %s' % (i, option) for i, option in zip('1234', example.endings)]
    options = " ".join(options)
    input_ = "context: %s  options: %s </s>" % (input_, options)
    target = "%s </s>" % str(int(example.label) + 1)

    # tokenize inputs
    tokenized_inputs = self.tokenizer.batch_encode_plus(
        [input_], max_length=self.max_len, pad_to_max_length=True, return_tensors="pt"
    )
    # tokenize targets
    tokenized_targets = self.tokenizer.batch_encode_plus(
        [target], max_length=2, pad_to_max_length=True, return_tensors="pt"
    )

    self.inputs.append(tokenized_inputs)
    self.targets.append(tokenized_targets)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
dataset = SwagDataset(tokenizer, data_dir='swag_data', type_path='val')
len(dataset)
# Out:
# INFO:__main__:LOOKING AT swag_data dev
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2619: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /home/ubuntu/.local/lib/python3.10/site-packages/transformers/models/t5/tokenization_t5.py:303: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   warnings.warn(
# 20006

# %%
data = dataset[69]
print(tokenizer.decode(data['source_ids']))
print(tokenizer.decode(data['target_ids']))
# Out:
# context: A little girl plays softly the drums holding two sticks while she is singing on a microphone. The, the girl options: 1: take in the greeting and an asian girl followed by two people standing on stage. 2: holds the microphone up and begins to girl dance an entire time. 3: claps the girls hands anxiously. 4: plays more fast the drums.</s><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>
# 4</s>

# %% [markdown]
# ### Train

# %%
# !mkdir -p t5_swag

# %%
args_dict.update({'data_dir': 'swag_data', 'output_dir': 't5_swag', 'num_train_epochs': 3})
args = argparse.Namespace(**args_dict)
print(args_dict)
# Out:
# {'data_dir': 'swag_data', 'output_dir': 't5_swag', 'model_name_or_path': 't5-base', 'tokenizer_name_or_path': 't5-base', 'max_seq_length': 512, 'learning_rate': 0.0003, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'warmup_steps': 0, 'train_batch_size': 8, 'eval_batch_size': 8, 'num_train_epochs': 3, 'gradient_accumulation_steps': 16, 'n_gpu': 1, 'early_stop_callback': False, 'fp_16': False, 'opt_level': 'O1', 'max_grad_norm': 1.0, 'seed': 42}

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    filepath=args.output_dir, prefix="checkpoint", monitor="val_loss", mode="min", save_top_k=5
    #dirpath=args.output_dir, filename="checkpoint", monitor="val_loss", mode="min", save_top_k=5
)

train_params = dict(
    accumulate_grad_batches=args.gradient_accumulation_steps,
    gpus=args.n_gpu,
    max_epochs=args.num_train_epochs,
    early_stop_callback=False,
    precision= 16 if args.fp_16 else 32,
    amp_level=args.opt_level,
    gradient_clip_val=args.max_grad_norm,
    checkpoint_callback=checkpoint_callback,
    callbacks=[LoggingCallback()],
)

# %%
def get_dataset(tokenizer, type_path, args):
  return SwagDataset(tokenizer=tokenizer, data_dir=args.data_dir, type_path=type_path,  max_len=args.max_seq_length)

# %%
model = T5FineTuner(args)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
trainer = pl.Trainer(**train_params)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                                                | Type                       | Params
# ---------------------------------------------------------------------------------------------------------------
# 0   | model                                                               | T5ForConditionalGeneration | 222 M
# 1   | model.shared                                                        | Embedding                  | 24 M
# 2   | model.encoder                                                       | T5Stack                    | 109 M
# 3   | model.encoder.block                                                 | ModuleList                 | 84 M
# 4   | model.encoder.block.0                                               | T5Block                    | 7 M
# 5   | model.encoder.block.0.layer                                         | ModuleList                 | 7 M
# 6   | model.encoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 7   | model.encoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 8   | model.encoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 9   | model.encoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 10  | model.encoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 11  | model.encoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 12  | model.encoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 384
# 13  | model.encoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 768
# 14  | model.encoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 15  | model.encoder.block.0.layer.1                                       | T5LayerFF                  | 4 M
# 16  | model.encoder.block.0.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 17  | model.encoder.block.0.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 18  | model.encoder.block.0.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 19  | model.encoder.block.0.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 20  | model.encoder.block.0.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 21  | model.encoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 768
# 22  | model.encoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 23  | model.encoder.block.1                                               | T5Block                    | 7 M
# 24  | model.encoder.block.1.layer                                         | ModuleList                 | 7 M
# 25  | model.encoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 26  | model.encoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 27  | model.encoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 28  | model.encoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 29  | model.encoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 30  | model.encoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 31  | model.encoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 768
# 32  | model.encoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 33  | model.encoder.block.1.layer.1                                       | T5LayerFF                  | 4 M
# 34  | model.encoder.block.1.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 35  | model.encoder.block.1.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 36  | model.encoder.block.1.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 37  | model.encoder.block.1.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 38  | model.encoder.block.1.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 39  | model.encoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 768
# 40  | model.encoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 41  | model.encoder.block.2                                               | T5Block                    | 7 M
# 42  | model.encoder.block.2.layer                                         | ModuleList                 | 7 M
# 43  | model.encoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 44  | model.encoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 45  | model.encoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 46  | model.encoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 47  | model.encoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 48  | model.encoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 49  | model.encoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 768
# 50  | model.encoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 51  | model.encoder.block.2.layer.1                                       | T5LayerFF                  | 4 M
# 52  | model.encoder.block.2.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 53  | model.encoder.block.2.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 54  | model.encoder.block.2.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 55  | model.encoder.block.2.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 56  | model.encoder.block.2.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 57  | model.encoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 768
# 58  | model.encoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 59  | model.encoder.block.3                                               | T5Block                    | 7 M
# 60  | model.encoder.block.3.layer                                         | ModuleList                 | 7 M
# 61  | model.encoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 62  | model.encoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 63  | model.encoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 64  | model.encoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 65  | model.encoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 66  | model.encoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 67  | model.encoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 768
# 68  | model.encoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 69  | model.encoder.block.3.layer.1                                       | T5LayerFF                  | 4 M
# 70  | model.encoder.block.3.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 71  | model.encoder.block.3.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 72  | model.encoder.block.3.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 73  | model.encoder.block.3.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 74  | model.encoder.block.3.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 75  | model.encoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 768
# 76  | model.encoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 77  | model.encoder.block.4                                               | T5Block                    | 7 M
# 78  | model.encoder.block.4.layer                                         | ModuleList                 | 7 M
# 79  | model.encoder.block.4.layer.0                                       | T5LayerSelfAttention       | 2 M
# 80  | model.encoder.block.4.layer.0.SelfAttention                         | T5Attention                | 2 M
# 81  | model.encoder.block.4.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 82  | model.encoder.block.4.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 83  | model.encoder.block.4.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 84  | model.encoder.block.4.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 85  | model.encoder.block.4.layer.0.layer_norm                            | T5LayerNorm                | 768
# 86  | model.encoder.block.4.layer.0.dropout                               | Dropout                    | 0
# 87  | model.encoder.block.4.layer.1                                       | T5LayerFF                  | 4 M
# 88  | model.encoder.block.4.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 89  | model.encoder.block.4.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 90  | model.encoder.block.4.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 91  | model.encoder.block.4.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 92  | model.encoder.block.4.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 93  | model.encoder.block.4.layer.1.layer_norm                            | T5LayerNorm                | 768
# 94  | model.encoder.block.4.layer.1.dropout                               | Dropout                    | 0
# 95  | model.encoder.block.5                                               | T5Block                    | 7 M
# 96  | model.encoder.block.5.layer                                         | ModuleList                 | 7 M
# 97  | model.encoder.block.5.layer.0                                       | T5LayerSelfAttention       | 2 M
# 98  | model.encoder.block.5.layer.0.SelfAttention                         | T5Attention                | 2 M
# 99  | model.encoder.block.5.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 100 | model.encoder.block.5.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 101 | model.encoder.block.5.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 102 | model.encoder.block.5.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 103 | model.encoder.block.5.layer.0.layer_norm                            | T5LayerNorm                | 768
# 104 | model.encoder.block.5.layer.0.dropout                               | Dropout                    | 0
# 105 | model.encoder.block.5.layer.1                                       | T5LayerFF                  | 4 M
# 106 | model.encoder.block.5.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 107 | model.encoder.block.5.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 108 | model.encoder.block.5.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 109 | model.encoder.block.5.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 110 | model.encoder.block.5.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 111 | model.encoder.block.5.layer.1.layer_norm                            | T5LayerNorm                | 768
# 112 | model.encoder.block.5.layer.1.dropout                               | Dropout                    | 0
# 113 | model.encoder.block.6                                               | T5Block                    | 7 M
# 114 | model.encoder.block.6.layer                                         | ModuleList                 | 7 M
# 115 | model.encoder.block.6.layer.0                                       | T5LayerSelfAttention       | 2 M
# 116 | model.encoder.block.6.layer.0.SelfAttention                         | T5Attention                | 2 M
# 117 | model.encoder.block.6.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 118 | model.encoder.block.6.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 119 | model.encoder.block.6.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 120 | model.encoder.block.6.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 121 | model.encoder.block.6.layer.0.layer_norm                            | T5LayerNorm                | 768
# 122 | model.encoder.block.6.layer.0.dropout                               | Dropout                    | 0
# 123 | model.encoder.block.6.layer.1                                       | T5LayerFF                  | 4 M
# 124 | model.encoder.block.6.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 125 | model.encoder.block.6.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 126 | model.encoder.block.6.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 127 | model.encoder.block.6.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 128 | model.encoder.block.6.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 129 | model.encoder.block.6.layer.1.layer_norm                            | T5LayerNorm                | 768
# 130 | model.encoder.block.6.layer.1.dropout                               | Dropout                    | 0
# 131 | model.encoder.block.7                                               | T5Block                    | 7 M
# 132 | model.encoder.block.7.layer                                         | ModuleList                 | 7 M
# 133 | model.encoder.block.7.layer.0                                       | T5LayerSelfAttention       | 2 M
# 134 | model.encoder.block.7.layer.0.SelfAttention                         | T5Attention                | 2 M
# 135 | model.encoder.block.7.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 136 | model.encoder.block.7.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 137 | model.encoder.block.7.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 138 | model.encoder.block.7.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 139 | model.encoder.block.7.layer.0.layer_norm                            | T5LayerNorm                | 768
# 140 | model.encoder.block.7.layer.0.dropout                               | Dropout                    | 0
# 141 | model.encoder.block.7.layer.1                                       | T5LayerFF                  | 4 M
# 142 | model.encoder.block.7.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 143 | model.encoder.block.7.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 144 | model.encoder.block.7.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 145 | model.encoder.block.7.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 146 | model.encoder.block.7.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 147 | model.encoder.block.7.layer.1.layer_norm                            | T5LayerNorm                | 768
# 148 | model.encoder.block.7.layer.1.dropout                               | Dropout                    | 0
# 149 | model.encoder.block.8                                               | T5Block                    | 7 M
# 150 | model.encoder.block.8.layer                                         | ModuleList                 | 7 M
# 151 | model.encoder.block.8.layer.0                                       | T5LayerSelfAttention       | 2 M
# 152 | model.encoder.block.8.layer.0.SelfAttention                         | T5Attention                | 2 M
# 153 | model.encoder.block.8.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 154 | model.encoder.block.8.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 155 | model.encoder.block.8.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 156 | model.encoder.block.8.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 157 | model.encoder.block.8.layer.0.layer_norm                            | T5LayerNorm                | 768
# 158 | model.encoder.block.8.layer.0.dropout                               | Dropout                    | 0
# 159 | model.encoder.block.8.layer.1                                       | T5LayerFF                  | 4 M
# 160 | model.encoder.block.8.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 161 | model.encoder.block.8.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 162 | model.encoder.block.8.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 163 | model.encoder.block.8.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 164 | model.encoder.block.8.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 165 | model.encoder.block.8.layer.1.layer_norm                            | T5LayerNorm                | 768
# 166 | model.encoder.block.8.layer.1.dropout                               | Dropout                    | 0
# 167 | model.encoder.block.9                                               | T5Block                    | 7 M
# 168 | model.encoder.block.9.layer                                         | ModuleList                 | 7 M
# 169 | model.encoder.block.9.layer.0                                       | T5LayerSelfAttention       | 2 M
# 170 | model.encoder.block.9.layer.0.SelfAttention                         | T5Attention                | 2 M
# 171 | model.encoder.block.9.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 172 | model.encoder.block.9.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 173 | model.encoder.block.9.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 174 | model.encoder.block.9.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 175 | model.encoder.block.9.layer.0.layer_norm                            | T5LayerNorm                | 768
# 176 | model.encoder.block.9.layer.0.dropout                               | Dropout                    | 0
# 177 | model.encoder.block.9.layer.1                                       | T5LayerFF                  | 4 M
# 178 | model.encoder.block.9.layer.1.DenseReluDense                        | T5DenseActDense            | 4 M
# 179 | model.encoder.block.9.layer.1.DenseReluDense.wi                     | Linear                     | 2 M
# 180 | model.encoder.block.9.layer.1.DenseReluDense.wo                     | Linear                     | 2 M
# 181 | model.encoder.block.9.layer.1.DenseReluDense.dropout                | Dropout                    | 0
# 182 | model.encoder.block.9.layer.1.DenseReluDense.act                    | ReLU                       | 0
# 183 | model.encoder.block.9.layer.1.layer_norm                            | T5LayerNorm                | 768
# 184 | model.encoder.block.9.layer.1.dropout                               | Dropout                    | 0
# 185 | model.encoder.block.10                                              | T5Block                    | 7 M
# 186 | model.encoder.block.10.layer                                        | ModuleList                 | 7 M
# 187 | model.encoder.block.10.layer.0                                      | T5LayerSelfAttention       | 2 M
# 188 | model.encoder.block.10.layer.0.SelfAttention                        | T5Attention                | 2 M
# 189 | model.encoder.block.10.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 190 | model.encoder.block.10.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 191 | model.encoder.block.10.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 192 | model.encoder.block.10.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 193 | model.encoder.block.10.layer.0.layer_norm                           | T5LayerNorm                | 768
# 194 | model.encoder.block.10.layer.0.dropout                              | Dropout                    | 0
# 195 | model.encoder.block.10.layer.1                                      | T5LayerFF                  | 4 M
# 196 | model.encoder.block.10.layer.1.DenseReluDense                       | T5DenseActDense            | 4 M
# 197 | model.encoder.block.10.layer.1.DenseReluDense.wi                    | Linear                     | 2 M
# 198 | model.encoder.block.10.layer.1.DenseReluDense.wo                    | Linear                     | 2 M
# 199 | model.encoder.block.10.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 200 | model.encoder.block.10.layer.1.DenseReluDense.act                   | ReLU                       | 0
# 201 | model.encoder.block.10.layer.1.layer_norm                           | T5LayerNorm                | 768
# 202 | model.encoder.block.10.layer.1.dropout                              | Dropout                    | 0
# 203 | model.encoder.block.11                                              | T5Block                    | 7 M
# 204 | model.encoder.block.11.layer                                        | ModuleList                 | 7 M
# 205 | model.encoder.block.11.layer.0                                      | T5LayerSelfAttention       | 2 M
# 206 | model.encoder.block.11.layer.0.SelfAttention                        | T5Attention                | 2 M
# 207 | model.encoder.block.11.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 208 | model.encoder.block.11.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 209 | model.encoder.block.11.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 210 | model.encoder.block.11.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 211 | model.encoder.block.11.layer.0.layer_norm                           | T5LayerNorm                | 768
# 212 | model.encoder.block.11.layer.0.dropout                              | Dropout                    | 0
# 213 | model.encoder.block.11.layer.1                                      | T5LayerFF                  | 4 M
# 214 | model.encoder.block.11.layer.1.DenseReluDense                       | T5DenseActDense            | 4 M
# 215 | model.encoder.block.11.layer.1.DenseReluDense.wi                    | Linear                     | 2 M
# 216 | model.encoder.block.11.layer.1.DenseReluDense.wo                    | Linear                     | 2 M
# 217 | model.encoder.block.11.layer.1.DenseReluDense.dropout               | Dropout                    | 0
# 218 | model.encoder.block.11.layer.1.DenseReluDense.act                   | ReLU                       | 0
# 219 | model.encoder.block.11.layer.1.layer_norm                           | T5LayerNorm                | 768
# 220 | model.encoder.block.11.layer.1.dropout                              | Dropout                    | 0
# 221 | model.encoder.final_layer_norm                                      | T5LayerNorm                | 768
# 222 | model.encoder.dropout                                               | Dropout                    | 0
# 223 | model.decoder                                                       | T5Stack                    | 137 M
# 224 | model.decoder.block                                                 | ModuleList                 | 113 M
# 225 | model.decoder.block.0                                               | T5Block                    | 9 M
# 226 | model.decoder.block.0.layer                                         | ModuleList                 | 9 M
# 227 | model.decoder.block.0.layer.0                                       | T5LayerSelfAttention       | 2 M
# 228 | model.decoder.block.0.layer.0.SelfAttention                         | T5Attention                | 2 M
# 229 | model.decoder.block.0.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 230 | model.decoder.block.0.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 231 | model.decoder.block.0.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 232 | model.decoder.block.0.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 233 | model.decoder.block.0.layer.0.SelfAttention.relative_attention_bias | Embedding                  | 384
# 234 | model.decoder.block.0.layer.0.layer_norm                            | T5LayerNorm                | 768
# 235 | model.decoder.block.0.layer.0.dropout                               | Dropout                    | 0
# 236 | model.decoder.block.0.layer.1                                       | T5LayerCrossAttention      | 2 M
# 237 | model.decoder.block.0.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 238 | model.decoder.block.0.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 239 | model.decoder.block.0.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 240 | model.decoder.block.0.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 241 | model.decoder.block.0.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 242 | model.decoder.block.0.layer.1.layer_norm                            | T5LayerNorm                | 768
# 243 | model.decoder.block.0.layer.1.dropout                               | Dropout                    | 0
# 244 | model.decoder.block.0.layer.2                                       | T5LayerFF                  | 4 M
# 245 | model.decoder.block.0.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 246 | model.decoder.block.0.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 247 | model.decoder.block.0.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 248 | model.decoder.block.0.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 249 | model.decoder.block.0.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 250 | model.decoder.block.0.layer.2.layer_norm                            | T5LayerNorm                | 768
# 251 | model.decoder.block.0.layer.2.dropout                               | Dropout                    | 0
# 252 | model.decoder.block.1                                               | T5Block                    | 9 M
# 253 | model.decoder.block.1.layer                                         | ModuleList                 | 9 M
# 254 | model.decoder.block.1.layer.0                                       | T5LayerSelfAttention       | 2 M
# 255 | model.decoder.block.1.layer.0.SelfAttention                         | T5Attention                | 2 M
# 256 | model.decoder.block.1.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 257 | model.decoder.block.1.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 258 | model.decoder.block.1.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 259 | model.decoder.block.1.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 260 | model.decoder.block.1.layer.0.layer_norm                            | T5LayerNorm                | 768
# 261 | model.decoder.block.1.layer.0.dropout                               | Dropout                    | 0
# 262 | model.decoder.block.1.layer.1                                       | T5LayerCrossAttention      | 2 M
# 263 | model.decoder.block.1.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 264 | model.decoder.block.1.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 265 | model.decoder.block.1.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 266 | model.decoder.block.1.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 267 | model.decoder.block.1.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 268 | model.decoder.block.1.layer.1.layer_norm                            | T5LayerNorm                | 768
# 269 | model.decoder.block.1.layer.1.dropout                               | Dropout                    | 0
# 270 | model.decoder.block.1.layer.2                                       | T5LayerFF                  | 4 M
# 271 | model.decoder.block.1.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 272 | model.decoder.block.1.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 273 | model.decoder.block.1.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 274 | model.decoder.block.1.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 275 | model.decoder.block.1.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 276 | model.decoder.block.1.layer.2.layer_norm                            | T5LayerNorm                | 768
# 277 | model.decoder.block.1.layer.2.dropout                               | Dropout                    | 0
# 278 | model.decoder.block.2                                               | T5Block                    | 9 M
# 279 | model.decoder.block.2.layer                                         | ModuleList                 | 9 M
# 280 | model.decoder.block.2.layer.0                                       | T5LayerSelfAttention       | 2 M
# 281 | model.decoder.block.2.layer.0.SelfAttention                         | T5Attention                | 2 M
# 282 | model.decoder.block.2.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 283 | model.decoder.block.2.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 284 | model.decoder.block.2.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 285 | model.decoder.block.2.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 286 | model.decoder.block.2.layer.0.layer_norm                            | T5LayerNorm                | 768
# 287 | model.decoder.block.2.layer.0.dropout                               | Dropout                    | 0
# 288 | model.decoder.block.2.layer.1                                       | T5LayerCrossAttention      | 2 M
# 289 | model.decoder.block.2.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 290 | model.decoder.block.2.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 291 | model.decoder.block.2.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 292 | model.decoder.block.2.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 293 | model.decoder.block.2.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 294 | model.decoder.block.2.layer.1.layer_norm                            | T5LayerNorm                | 768
# 295 | model.decoder.block.2.layer.1.dropout                               | Dropout                    | 0
# 296 | model.decoder.block.2.layer.2                                       | T5LayerFF                  | 4 M
# 297 | model.decoder.block.2.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 298 | model.decoder.block.2.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 299 | model.decoder.block.2.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 300 | model.decoder.block.2.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 301 | model.decoder.block.2.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 302 | model.decoder.block.2.layer.2.layer_norm                            | T5LayerNorm                | 768
# 303 | model.decoder.block.2.layer.2.dropout                               | Dropout                    | 0
# 304 | model.decoder.block.3                                               | T5Block                    | 9 M
# 305 | model.decoder.block.3.layer                                         | ModuleList                 | 9 M
# 306 | model.decoder.block.3.layer.0                                       | T5LayerSelfAttention       | 2 M
# 307 | model.decoder.block.3.layer.0.SelfAttention                         | T5Attention                | 2 M
# 308 | model.decoder.block.3.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 309 | model.decoder.block.3.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 310 | model.decoder.block.3.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 311 | model.decoder.block.3.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 312 | model.decoder.block.3.layer.0.layer_norm                            | T5LayerNorm                | 768
# 313 | model.decoder.block.3.layer.0.dropout                               | Dropout                    | 0
# 314 | model.decoder.block.3.layer.1                                       | T5LayerCrossAttention      | 2 M
# 315 | model.decoder.block.3.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 316 | model.decoder.block.3.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 317 | model.decoder.block.3.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 318 | model.decoder.block.3.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 319 | model.decoder.block.3.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 320 | model.decoder.block.3.layer.1.layer_norm                            | T5LayerNorm                | 768
# 321 | model.decoder.block.3.layer.1.dropout                               | Dropout                    | 0
# 322 | model.decoder.block.3.layer.2                                       | T5LayerFF                  | 4 M
# 323 | model.decoder.block.3.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 324 | model.decoder.block.3.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 325 | model.decoder.block.3.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 326 | model.decoder.block.3.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 327 | model.decoder.block.3.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 328 | model.decoder.block.3.layer.2.layer_norm                            | T5LayerNorm                | 768
# 329 | model.decoder.block.3.layer.2.dropout                               | Dropout                    | 0
# 330 | model.decoder.block.4                                               | T5Block                    | 9 M
# 331 | model.decoder.block.4.layer                                         | ModuleList                 | 9 M
# 332 | model.decoder.block.4.layer.0                                       | T5LayerSelfAttention       | 2 M
# 333 | model.decoder.block.4.layer.0.SelfAttention                         | T5Attention                | 2 M
# 334 | model.decoder.block.4.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 335 | model.decoder.block.4.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 336 | model.decoder.block.4.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 337 | model.decoder.block.4.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 338 | model.decoder.block.4.layer.0.layer_norm                            | T5LayerNorm                | 768
# 339 | model.decoder.block.4.layer.0.dropout                               | Dropout                    | 0
# 340 | model.decoder.block.4.layer.1                                       | T5LayerCrossAttention      | 2 M
# 341 | model.decoder.block.4.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 342 | model.decoder.block.4.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 343 | model.decoder.block.4.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 344 | model.decoder.block.4.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 345 | model.decoder.block.4.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 346 | model.decoder.block.4.layer.1.layer_norm                            | T5LayerNorm                | 768
# 347 | model.decoder.block.4.layer.1.dropout                               | Dropout                    | 0
# 348 | model.decoder.block.4.layer.2                                       | T5LayerFF                  | 4 M
# 349 | model.decoder.block.4.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 350 | model.decoder.block.4.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 351 | model.decoder.block.4.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 352 | model.decoder.block.4.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 353 | model.decoder.block.4.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 354 | model.decoder.block.4.layer.2.layer_norm                            | T5LayerNorm                | 768
# 355 | model.decoder.block.4.layer.2.dropout                               | Dropout                    | 0
# 356 | model.decoder.block.5                                               | T5Block                    | 9 M
# 357 | model.decoder.block.5.layer                                         | ModuleList                 | 9 M
# 358 | model.decoder.block.5.layer.0                                       | T5LayerSelfAttention       | 2 M
# 359 | model.decoder.block.5.layer.0.SelfAttention                         | T5Attention                | 2 M
# 360 | model.decoder.block.5.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 361 | model.decoder.block.5.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 362 | model.decoder.block.5.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 363 | model.decoder.block.5.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 364 | model.decoder.block.5.layer.0.layer_norm                            | T5LayerNorm                | 768
# 365 | model.decoder.block.5.layer.0.dropout                               | Dropout                    | 0
# 366 | model.decoder.block.5.layer.1                                       | T5LayerCrossAttention      | 2 M
# 367 | model.decoder.block.5.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 368 | model.decoder.block.5.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 369 | model.decoder.block.5.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 370 | model.decoder.block.5.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 371 | model.decoder.block.5.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 372 | model.decoder.block.5.layer.1.layer_norm                            | T5LayerNorm                | 768
# 373 | model.decoder.block.5.layer.1.dropout                               | Dropout                    | 0
# 374 | model.decoder.block.5.layer.2                                       | T5LayerFF                  | 4 M
# 375 | model.decoder.block.5.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 376 | model.decoder.block.5.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 377 | model.decoder.block.5.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 378 | model.decoder.block.5.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 379 | model.decoder.block.5.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 380 | model.decoder.block.5.layer.2.layer_norm                            | T5LayerNorm                | 768
# 381 | model.decoder.block.5.layer.2.dropout                               | Dropout                    | 0
# 382 | model.decoder.block.6                                               | T5Block                    | 9 M
# 383 | model.decoder.block.6.layer                                         | ModuleList                 | 9 M
# 384 | model.decoder.block.6.layer.0                                       | T5LayerSelfAttention       | 2 M
# 385 | model.decoder.block.6.layer.0.SelfAttention                         | T5Attention                | 2 M
# 386 | model.decoder.block.6.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 387 | model.decoder.block.6.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 388 | model.decoder.block.6.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 389 | model.decoder.block.6.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 390 | model.decoder.block.6.layer.0.layer_norm                            | T5LayerNorm                | 768
# 391 | model.decoder.block.6.layer.0.dropout                               | Dropout                    | 0
# 392 | model.decoder.block.6.layer.1                                       | T5LayerCrossAttention      | 2 M
# 393 | model.decoder.block.6.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 394 | model.decoder.block.6.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 395 | model.decoder.block.6.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 396 | model.decoder.block.6.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 397 | model.decoder.block.6.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 398 | model.decoder.block.6.layer.1.layer_norm                            | T5LayerNorm                | 768
# 399 | model.decoder.block.6.layer.1.dropout                               | Dropout                    | 0
# 400 | model.decoder.block.6.layer.2                                       | T5LayerFF                  | 4 M
# 401 | model.decoder.block.6.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 402 | model.decoder.block.6.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 403 | model.decoder.block.6.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 404 | model.decoder.block.6.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 405 | model.decoder.block.6.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 406 | model.decoder.block.6.layer.2.layer_norm                            | T5LayerNorm                | 768
# 407 | model.decoder.block.6.layer.2.dropout                               | Dropout                    | 0
# 408 | model.decoder.block.7                                               | T5Block                    | 9 M
# 409 | model.decoder.block.7.layer                                         | ModuleList                 | 9 M
# 410 | model.decoder.block.7.layer.0                                       | T5LayerSelfAttention       | 2 M
# 411 | model.decoder.block.7.layer.0.SelfAttention                         | T5Attention                | 2 M
# 412 | model.decoder.block.7.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 413 | model.decoder.block.7.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 414 | model.decoder.block.7.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 415 | model.decoder.block.7.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 416 | model.decoder.block.7.layer.0.layer_norm                            | T5LayerNorm                | 768
# 417 | model.decoder.block.7.layer.0.dropout                               | Dropout                    | 0
# 418 | model.decoder.block.7.layer.1                                       | T5LayerCrossAttention      | 2 M
# 419 | model.decoder.block.7.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 420 | model.decoder.block.7.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 421 | model.decoder.block.7.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 422 | model.decoder.block.7.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 423 | model.decoder.block.7.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 424 | model.decoder.block.7.layer.1.layer_norm                            | T5LayerNorm                | 768
# 425 | model.decoder.block.7.layer.1.dropout                               | Dropout                    | 0
# 426 | model.decoder.block.7.layer.2                                       | T5LayerFF                  | 4 M
# 427 | model.decoder.block.7.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 428 | model.decoder.block.7.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 429 | model.decoder.block.7.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 430 | model.decoder.block.7.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 431 | model.decoder.block.7.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 432 | model.decoder.block.7.layer.2.layer_norm                            | T5LayerNorm                | 768
# 433 | model.decoder.block.7.layer.2.dropout                               | Dropout                    | 0
# 434 | model.decoder.block.8                                               | T5Block                    | 9 M
# 435 | model.decoder.block.8.layer                                         | ModuleList                 | 9 M
# 436 | model.decoder.block.8.layer.0                                       | T5LayerSelfAttention       | 2 M
# 437 | model.decoder.block.8.layer.0.SelfAttention                         | T5Attention                | 2 M
# 438 | model.decoder.block.8.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 439 | model.decoder.block.8.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 440 | model.decoder.block.8.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 441 | model.decoder.block.8.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 442 | model.decoder.block.8.layer.0.layer_norm                            | T5LayerNorm                | 768
# 443 | model.decoder.block.8.layer.0.dropout                               | Dropout                    | 0
# 444 | model.decoder.block.8.layer.1                                       | T5LayerCrossAttention      | 2 M
# 445 | model.decoder.block.8.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 446 | model.decoder.block.8.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 447 | model.decoder.block.8.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 448 | model.decoder.block.8.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 449 | model.decoder.block.8.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 450 | model.decoder.block.8.layer.1.layer_norm                            | T5LayerNorm                | 768
# 451 | model.decoder.block.8.layer.1.dropout                               | Dropout                    | 0
# 452 | model.decoder.block.8.layer.2                                       | T5LayerFF                  | 4 M
# 453 | model.decoder.block.8.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 454 | model.decoder.block.8.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 455 | model.decoder.block.8.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 456 | model.decoder.block.8.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 457 | model.decoder.block.8.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 458 | model.decoder.block.8.layer.2.layer_norm                            | T5LayerNorm                | 768
# 459 | model.decoder.block.8.layer.2.dropout                               | Dropout                    | 0
# 460 | model.decoder.block.9                                               | T5Block                    | 9 M
# 461 | model.decoder.block.9.layer                                         | ModuleList                 | 9 M
# 462 | model.decoder.block.9.layer.0                                       | T5LayerSelfAttention       | 2 M
# 463 | model.decoder.block.9.layer.0.SelfAttention                         | T5Attention                | 2 M
# 464 | model.decoder.block.9.layer.0.SelfAttention.q                       | Linear                     | 589 K
# 465 | model.decoder.block.9.layer.0.SelfAttention.k                       | Linear                     | 589 K
# 466 | model.decoder.block.9.layer.0.SelfAttention.v                       | Linear                     | 589 K
# 467 | model.decoder.block.9.layer.0.SelfAttention.o                       | Linear                     | 589 K
# 468 | model.decoder.block.9.layer.0.layer_norm                            | T5LayerNorm                | 768
# 469 | model.decoder.block.9.layer.0.dropout                               | Dropout                    | 0
# 470 | model.decoder.block.9.layer.1                                       | T5LayerCrossAttention      | 2 M
# 471 | model.decoder.block.9.layer.1.EncDecAttention                       | T5Attention                | 2 M
# 472 | model.decoder.block.9.layer.1.EncDecAttention.q                     | Linear                     | 589 K
# 473 | model.decoder.block.9.layer.1.EncDecAttention.k                     | Linear                     | 589 K
# 474 | model.decoder.block.9.layer.1.EncDecAttention.v                     | Linear                     | 589 K
# 475 | model.decoder.block.9.layer.1.EncDecAttention.o                     | Linear                     | 589 K
# 476 | model.decoder.block.9.layer.1.layer_norm                            | T5LayerNorm                | 768
# 477 | model.decoder.block.9.layer.1.dropout                               | Dropout                    | 0
# 478 | model.decoder.block.9.layer.2                                       | T5LayerFF                  | 4 M
# 479 | model.decoder.block.9.layer.2.DenseReluDense                        | T5DenseActDense            | 4 M
# 480 | model.decoder.block.9.layer.2.DenseReluDense.wi                     | Linear                     | 2 M
# 481 | model.decoder.block.9.layer.2.DenseReluDense.wo                     | Linear                     | 2 M
# 482 | model.decoder.block.9.layer.2.DenseReluDense.dropout                | Dropout                    | 0
# 483 | model.decoder.block.9.layer.2.DenseReluDense.act                    | ReLU                       | 0
# 484 | model.decoder.block.9.layer.2.layer_norm                            | T5LayerNorm                | 768
# 485 | model.decoder.block.9.layer.2.dropout                               | Dropout                    | 0
# 486 | model.decoder.block.10                                              | T5Block                    | 9 M
# 487 | model.decoder.block.10.layer                                        | ModuleList                 | 9 M
# 488 | model.decoder.block.10.layer.0                                      | T5LayerSelfAttention       | 2 M
# 489 | model.decoder.block.10.layer.0.SelfAttention                        | T5Attention                | 2 M
# 490 | model.decoder.block.10.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 491 | model.decoder.block.10.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 492 | model.decoder.block.10.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 493 | model.decoder.block.10.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 494 | model.decoder.block.10.layer.0.layer_norm                           | T5LayerNorm                | 768
# 495 | model.decoder.block.10.layer.0.dropout                              | Dropout                    | 0
# 496 | model.decoder.block.10.layer.1                                      | T5LayerCrossAttention      | 2 M
# 497 | model.decoder.block.10.layer.1.EncDecAttention                      | T5Attention                | 2 M
# 498 | model.decoder.block.10.layer.1.EncDecAttention.q                    | Linear                     | 589 K
# 499 | model.decoder.block.10.layer.1.EncDecAttention.k                    | Linear                     | 589 K
# 500 | model.decoder.block.10.layer.1.EncDecAttention.v                    | Linear                     | 589 K
# 501 | model.decoder.block.10.layer.1.EncDecAttention.o                    | Linear                     | 589 K
# 502 | model.decoder.block.10.layer.1.layer_norm                           | T5LayerNorm                | 768
# 503 | model.decoder.block.10.layer.1.dropout                              | Dropout                    | 0
# 504 | model.decoder.block.10.layer.2                                      | T5LayerFF                  | 4 M
# 505 | model.decoder.block.10.layer.2.DenseReluDense                       | T5DenseActDense            | 4 M
# 506 | model.decoder.block.10.layer.2.DenseReluDense.wi                    | Linear                     | 2 M
# 507 | model.decoder.block.10.layer.2.DenseReluDense.wo                    | Linear                     | 2 M
# 508 | model.decoder.block.10.layer.2.DenseReluDense.dropout               | Dropout                    | 0
# 509 | model.decoder.block.10.layer.2.DenseReluDense.act                   | ReLU                       | 0
# 510 | model.decoder.block.10.layer.2.layer_norm                           | T5LayerNorm                | 768
# 511 | model.decoder.block.10.layer.2.dropout                              | Dropout                    | 0
# 512 | model.decoder.block.11                                              | T5Block                    | 9 M
# 513 | model.decoder.block.11.layer                                        | ModuleList                 | 9 M
# 514 | model.decoder.block.11.layer.0                                      | T5LayerSelfAttention       | 2 M
# 515 | model.decoder.block.11.layer.0.SelfAttention                        | T5Attention                | 2 M
# 516 | model.decoder.block.11.layer.0.SelfAttention.q                      | Linear                     | 589 K
# 517 | model.decoder.block.11.layer.0.SelfAttention.k                      | Linear                     | 589 K
# 518 | model.decoder.block.11.layer.0.SelfAttention.v                      | Linear                     | 589 K
# 519 | model.decoder.block.11.layer.0.SelfAttention.o                      | Linear                     | 589 K
# 520 | model.decoder.block.11.layer.0.layer_norm                           | T5LayerNorm                | 768
# 521 | model.decoder.block.11.layer.0.dropout                              | Dropout                    | 0
# 522 | model.decoder.block.11.layer.1                                      | T5LayerCrossAttention      | 2 M
# 523 | model.decoder.block.11.layer.1.EncDecAttention                      | T5Attention                | 2 M
# 524 | model.decoder.block.11.layer.1.EncDecAttention.q                    | Linear                     | 589 K
# 525 | model.decoder.block.11.layer.1.EncDecAttention.k                    | Linear                     | 589 K
# 526 | model.decoder.block.11.layer.1.EncDecAttention.v                    | Linear                     | 589 K
# 527 | model.decoder.block.11.layer.1.EncDecAttention.o                    | Linear                     | 589 K
# 528 | model.decoder.block.11.layer.1.layer_norm                           | T5LayerNorm                | 768
# 529 | model.decoder.block.11.layer.1.dropout                              | Dropout                    | 0
# 530 | model.decoder.block.11.layer.2                                      | T5LayerFF                  | 4 M
# 531 | model.decoder.block.11.layer.2.DenseReluDense                       | T5DenseActDense            | 4 M
# 532 | model.decoder.block.11.layer.2.DenseReluDense.wi                    | Linear                     | 2 M
# 533 | model.decoder.block.11.layer.2.DenseReluDense.wo                    | Linear                     | 2 M
# 534 | model.decoder.block.11.layer.2.DenseReluDense.dropout               | Dropout                    | 0
# 535 | model.decoder.block.11.layer.2.DenseReluDense.act                   | ReLU                       | 0
# 536 | model.decoder.block.11.layer.2.layer_norm                           | T5LayerNorm                | 768
# 537 | model.decoder.block.11.layer.2.dropout                              | Dropout                    | 0
# 538 | model.decoder.final_layer_norm                                      | T5LayerNorm                | 768
# 539 | model.decoder.dropout                                               | Dropout                    | 0
# 540 | model.lm_head                                                       | Linear                     | 24 M
# INFO:__main__:LOOKING AT swag_data dev
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Validation sanity check: 0it [00:00, ?it/s]
# INFO:__main__:LOOKING AT swag_data train
# INFO:__main__:LOOKING AT swag_data dev
# Training: 0it [00:00, ?it/s]

# %% [markdown]
# ### Eval

# %%
import textwrap
from tqdm.auto import tqdm
from sklearn import metrics

# %%
dataset =  SwagDataset(tokenizer, data_dir='swag_data', type_path='val')
loader = DataLoader(dataset, batch_size=32, num_workers=4)
# Out:
# INFO:__main__:LOOKING AT swag_data dev

# %%
model.model.eval()
outputs = []
targets = []
for batch in tqdm(loader):
  outs = model.model.generate(input_ids=batch['source_ids'].cuda(), 
                              attention_mask=batch['source_mask'].cuda(), 
                              max_length=2)

  dec = [tokenizer.decode(ids) for ids in outs]
  target = [tokenizer.decode(ids) for ids in batch["target_ids"]]
  
  outputs.extend(dec)
  targets.extend(target)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=626.0), HTML(value='')))

# %%
for i, out in enumerate(outputs):
  if out not in "1234":
    print(i, 'detected invalid prediction')

# %%
metrics.accuracy_score(targets, outputs)
# Out:
# 0.7397280815755274

# %% [markdown]
# This is great! We have achieved almost 74% accuracy with this simple formulation. This is great becuase with BERT like models to make a prediction on single example the model needs to do 4 forward passes, one for each possible endings and then the logits are concatenated together for all 4 passes and then passed through final softmax layer to produce 4 probabilities. This approach needs only a single pass for one example.
